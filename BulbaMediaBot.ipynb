# %%
# Inport definitions
import pwiki
import mwparserfromhell
import re

from rdflib import Graph, URIRef, Literal, Namespace

# %%
# piwiki configuration
bulbabot = pwiki.wiki.Wiki(api_endpoint="https://bulbapedia.bulbagarden.net/w/api.php")

# %%
# piwiki basic tests
print(bulbabot.exists("Bulbasaur"))

bulbasaur_test = bulbabot.parse(title="Bulbasaur")
print( bulbasaur_test)

# %%
#Bulbasaur page content test
bulbasaur_test2 = bulbabot.page_text(title="Bulbasaur (Pokémon)")
bulbasaur_test2

# %%
# FUNCTION DEFINITION : pokémon infobox text extraction
def extract_infobox(content):
    match = re.search(r"{{Pokémon Infobox.*?}}", content, re.DOTALL)
    if match:
        return match.group(0)
    return None


def extract_region_infobox(content):
    match = re.search(r"{{RegionInfobox.*?}}", content, re.DOTALL)
    if match:
        return match.group(0)
    return None

def extract_character_infobox(content):
    match = re.search(r"{{Character Infobox.*?}}", content, re.DOTALL)
    if match:
        return match.group(0)
    return None

# %%
# infobox extration test
infobox = extract_infobox(bulbasaur_test2)
infobox
# Out:
# '{{Pokémon Infobox\n|name=Bulbasaur\n|jname=フシギダネ\n|tmname=Fushigidane\n|ndex=0001\n|type1=Grass\n|type2=Poison\n|category=Seed\n|height-ftin=2\'04"\n|height-m=0.7\n|weight-lbs=15.2\n|weight-kg=6.9\n|abilityn=d\n|ability1=Overgrow\n|abilityd=Chlorophyll\n|egggroupn=2\n|egggroup1=Monster\n|egggroup2=Grass\n|eggcycles=20\n|evtotal=1\n|evsa=1\n|expyield=64\n|oldexp=64\n|lv100exp=1,059,860\n|gendercode=31\n|color=Green\n|catchrate=45\n|body=08\n|generation=1\n|pokefordex=bulbasaur\n|friendship=70\n}}'

# %%
# FUNCTION DEFINITION : parsing of the infobox text 
def parse_infobox(infobox):
    properties = {}
    lines = infobox.split("\n")
    for line in lines:
        if line.startswith("|"):
            key_value = line[1:].split("=", 1)  # Remove leading `|` and split at `=`
            if len(key_value) == 2:
                key, value = key_value
                properties[key.strip()] = value.strip()
    return properties

# %%
# Infobox text parsing test 
properties = parse_infobox(infobox)
properties
# Out:
# {'name': 'Bulbasaur',
#  'jname': 'フシギダネ',
#  'tmname': 'Fushigidane',
#  'ndex': '0001',
#  'type1': 'Grass',
#  'type2': 'Poison',
#  'category': 'Seed',
#  'height-ftin': '2\'04"',
#  'height-m': '0.7',
#  'weight-lbs': '15.2',
#  'weight-kg': '6.9',
#  'abilityn': 'd',
#  'ability1': 'Overgrow',
#  'abilityd': 'Chlorophyll',
#  'egggroupn': '2',
#  'egggroup1': 'Monster',
#  'egggroup2': 'Grass',
#  'eggcycles': '20',
#  'evtotal': '1',
#  'evsa': '1',
#  'expyield': '64',
#  'oldexp': '64',
#  'lv100exp': '1,059,860',
#  'gendercode': '31',
#  'color': 'Green',
#  'catchrate': '45',
#  'body': '08',
#  'generation': '1',
#  'pokefordex': 'bulbasaur',
#  'friendship': '70'}

# %%
pokemon_infobox_graph = Graph()

# %%
# FUNCTION DEFINITION : mapping of pokemon infobox properties to existing graph
def map_infobox_to_rdf(graph, properties):
    
    POKEMON = Namespace("http://example.org/pokemon/")
    RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

    pokemon_uri = URIRef(POKEMON[properties.get("name", "Unknown").replace(" ", "_")])
    graph.add((pokemon_uri, RDF.type, POKEMON.Pokémon))

    mappings = {
        "name": POKEMON.name,
        "jname": POKEMON.japaneseName,
        "tmname": POKEMON.trademarkedJapaneseName,
        "jtranslit": POKEMON.japaneseTransliteration,
        "category": POKEMON.category,
        "ndex": POKEMON.nationalDexNumber,
        "forme": POKEMON.numberOfForms,
        "type1": POKEMON.primaryType,
        "type2": POKEMON.secondaryType,
        "ability1": POKEMON.ability1,
        "ability2": POKEMON.ability2,
        "abilityd": POKEMON.hiddenAbility,
        "height-m": POKEMON.heightInMeters,
        "height-ftin": POKEMON.heightInFeetInches,
        "weight-kg": POKEMON.weightInKilograms,
        "weight-lbs": POKEMON.weightInPounds,
        "catchrate": POKEMON.catchRate,
        "gendercode": POKEMON.genderRatioCode,
        "egggroup1": POKEMON.eggGroup1,
        "egggroup2": POKEMON.eggGroup2,
        "color": POKEMON.color,
        "friendship": POKEMON.baseFriendship,
        "generation": POKEMON.generationIntroduced,
        "expyield": POKEMON.baseExperienceYield,
        "evtotal": POKEMON.evTotal,
        "evhp": POKEMON.evYieldHP,
        "evat": POKEMON.evYieldAttack,
        "evde": POKEMON.evYieldDefense,
        "evsa": POKEMON.evYieldSpecialAttack,
        "evsd": POKEMON.evYieldSpecialDefense,
        "evsp": POKEMON.evYieldSpeed
    }

    for i in range(2, 7):  # Forms 2 through 6
        form_suffix = f"form{i}"
        mappings.update({
            f"{form_suffix}": POKEMON[f"form{i}Name"],
            f"{form_suffix}type1": POKEMON[f"form{i}PrimaryType"],
            f"{form_suffix}type2": POKEMON[f"form{i}SecondaryType"],
            f"height-m{i}": POKEMON[f"form{i}HeightInMeters"],
            f"height-ftin{i}": POKEMON[f"form{i}HeightInFeetInches"],
            f"weight-kg{i}": POKEMON[f"form{i}WeightInKilograms"],
            f"weight-lbs{i}": POKEMON[f"form{i}WeightInPounds"],
        })

    for key, predicate in mappings.items():
        if key in properties and properties[key]:
            graph.add((pokemon_uri, predicate, Literal(properties[key])))

    return graph

# %%
pokemon_infobox_graph = map_infobox_to_rdf(pokemon_infobox_graph, properties=properties)
print(pokemon_infobox_graph.serialize(format="turtle"))
# Out:
# @prefix ns1: <http://example.org/pokemon/> .
#
# ns1:Bulbasaur a ns1:Pokémon ;
#     ns1:ability1 "Overgrow" ;
#     ns1:baseExperienceYield "64" ;
#     ns1:baseFriendship "70" ;
#     ns1:catchRate "45" ;
#     ns1:category "Seed" ;
#     ns1:color "Green" ;
#     ns1:eggGroup1 "Monster" ;
#     ns1:eggGroup2 "Grass" ;
#     ns1:evTotal "1" ;
#     ns1:evYieldSpecialAttack "1" ;
#     ns1:genderRatioCode "31" ;
#     ns1:generationIntroduced "1" ;
#     ns1:heightInFeetInches "2'04\"" ;
#     ns1:heightInMeters "0.7" ;
#     ns1:hiddenAbility "Chlorophyll" ;
#     ns1:japaneseName "フシギダネ" ;
#     ns1:name "Bulbasaur" ;
#     ns1:nationalDexNumber "0001" ;
#     ns1:primaryType "Grass" ;
#     ns1:secondaryType "Poison" ;
#     ns1:trademarkedJapaneseName "Fushigidane" ;
#     ns1:weightInKilograms "6.9" ;
#     ns1:weightInPounds "15.2" .

# %%
# FUNCTION DEFINITION : mapping of region infobox properties to existing graph
def map_region_infobox_to_rdf(graph, properties):

    REGION = Namespace("http://example.org/region/")
    RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

    region_uri = URIRef(REGION[properties.get("name", "Unknown").replace(" ", "_")])
    graph.add((region_uri, RDF.type, REGION.Region))

    mappings = {
        "regioncolor": REGION.colorTemplate,
        "name": REGION.name,
        "jname": REGION.japaneseName,
        "tmname": REGION.romanizedJapaneseName,
        "region": REGION.isRegion,
        "image": REGION.image,
        "size": REGION.imageSize,
        "caption": REGION.imageCaption,
        "introduction": REGION.introductionMedia,
        "professor": REGION.professor,
        "firstpartner": REGION.firstPartnerPokemon,
        "villain": REGION.villainousOrganization,
        "league": REGION.league,
        "location": REGION.leagueLocation,
        "pokedext": REGION.pokedex,
        "series": REGION.animationSeries,
        "season": REGION.animationSeason,
        "generation": REGION.generation,
        "games": REGION.games,
        "manga": REGION.mangaChapter,
    }

    for key, predicate in mappings.items():
        if key in properties and properties[key]:
            graph.add((region_uri, predicate, Literal(properties[key])))

    return graph

# %%
# FUNCTION DEFINITION : mapping of character infobox properties to existing graph
def map_character_infobox_to_rdf(graph, properties):
    CHARACTER = Namespace("http://example.org/character/")
    RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

    character_uri = URIRef(CHARACTER[properties.get("name", "Unknown").replace(" ", "_")])
    graph.add((character_uri, RDF.type, CHARACTER.Character))

    mappings = {
        "color": CHARACTER.color,
        "bordercolor": CHARACTER.borderColor,
        "corecolor": CHARACTER.coreColor,
        "name": CHARACTER.name,
        "jname": CHARACTER.japaneseName,
        "tmname": CHARACTER.romanizedJapaneseName,
        "jtranslit": CHARACTER.japaneseTransliteration,
        "text": CHARACTER.textColor,
        "sloganline": CHARACTER.sloganLine,
        "image": CHARACTER.image,
        "size": CHARACTER.imageSize,
        "caption": CHARACTER.imageCaption,
        "age": CHARACTER.age,
        "birthday": CHARACTER.birthday,
        "gender": CHARACTER.gender,
        "height": CHARACTER.height,
        "eyes": CHARACTER.eyeColor,
        "hair": CHARACTER.hairColor,
        "hometown": CHARACTER.hometown,
        "region": CHARACTER.region,
        "relatives": CHARACTER.relatives,
    }

    for key, predicate in mappings.items():
        if key in properties and properties[key]:
            graph.add((character_uri, predicate, Literal(properties[key])))

    return graph

# %%
# Get the list of pokemons
poke_list = bulbabot.page_text("List_of_Pokémon_by_National_Pokédex_number")
poke_list
# Out:
# '{{shortcut|3|Ndex|Olddex|Natdex}}\nThis is a list of Pokémon in the order dictated by the [[National Pokédex]], meaning that Pokémon from the [[Kanto]] region will appear first, followed by those from [[Johto]], [[Hoenn]], [[Sinnoh]], [[Unova]], [[Kalos]], [[Alola]], [[Galar]], [[Hisui]], and [[Paldea]]. As of the release of the [[Mochi Mayhem]] epilogue of [[The Indigo Disk]] expansion for {{g|Scarlet and Violet}}, there are 1025 Pokémon in total. Each region\'s set of Pokémon starts with its own set of [[first partner Pokémon]] and their [[evolution]]s, going in order of {{t|Grass}}, {{t|Fire}}, {{t|Water}}; the only exception is Unova, which begins with {{p|Victini}}, who is then followed by the first partner Pokémon. \n\nThe first 151 entries in this Pokédex also serve as [[List of Pokémon by Kanto Pokédex number|Kanto\'s]] [[regional Pokédex]]. In [[Generation II]], this Pokédex order was known as the "Old Pokédex", with a [[List of Pokémon by New Pokédex number|new order]] that put related Pokémon near each other also included.\n\n==Legend==\nAll [[form]] names below match what is seen in the Pokédex in the latest game they were in. In places where this does not sufficiently differentiate forms, extra clarification is provided in \'\'(italicized parentheticals)\'\'.\n\n==List of Pokémon by National Pokédex number==\n===[[Generation I]]===\n{{ndexh|Red|Green}}\n{{ndex|0001|Bulbasaur|Grass|Poison}}\n{{ndex|0002|Ivysaur|Grass|Poison}}\n{{ndex|0003|Venusaur|Grass|Poison}}\n{{ndex|0004|Charmander|Fire}}\n{{ndex|0005|Charmeleon|Fire}}\n{{ndex|0006|Charizard|Fire|Flying}}\n{{ndex|0007|Squirtle|Water}}\n{{ndex|0008|Wartortle|Water}}\n{{ndex|0009|Blastoise|Water}}\n{{ndex|0010|Caterpie|Bug}}\n{{ndex|0011|Metapod|Bug}}\n{{ndex|0012|Butterfree|Bug|Flying}}\n{{ndex|0013|Weedle|Bug|Poison}}\n{{ndex|0014|Kakuna|Bug|Poison}}\n{{ndex|0015|Beedrill|Bug|Poison}}\n{{ndex|0016|Pidgey|Normal|Flying}}\n{{ndex|0017|Pidgeotto|Normal|Flying}}\n{{ndex|0018|Pidgeot|Normal|Flying}}\n{{ndex|0019|Rattata|Normal|forms=2}}\n{{ndex/form|0019|Rattata|-Alola|Alolan Form|Dark|Normal}}\n{{ndex|0020|Raticate|Normal|forms=2}}\n{{ndex/form|0020|Raticate|-Alola|Alolan Form|Dark|Normal}}\n{{ndex|0021|Spearow|Normal|Flying}}\n{{ndex|0022|Fearow|Normal|Flying}}\n{{ndex|0023|Ekans|Poison}}\n{{ndex|0024|Arbok|Poison}}\n{{ndex|0025|Pikachu|Electric}}\n{{ndex|0026|Raichu|Electric|forms=2}}\n{{ndex/form|0026|Raichu|-Alola|Alolan Form|Electric|Psychic}}\n{{ndex|0027|Sandshrew|Ground|forms=2}}\n{{ndex/form|0027|Sandshrew|-Alola|Alolan Form|Ice|Steel}}\n{{ndex|0028|Sandslash|Ground|forms=2}}\n{{ndex/form|0028|Sandslash|-Alola|Alolan Form|Ice|Steel}}\n{{ndex|0029|Nidoran♀|Poison}}\n{{ndex|0030|Nidorina|Poison}}\n{{ndex|0031|Nidoqueen|Poison|Ground}}\n{{ndex|0032|Nidoran♂|Poison}}\n{{ndex|0033|Nidorino|Poison}}\n{{ndex|0034|Nidoking|Poison|Ground}}\n{{ndex|0035|Clefairy|Fairy}}\n{{ndex|0036|Clefable|Fairy}}\n{{ndex|0037|Vulpix|Fire|forms=2}}\n{{ndex/form|0037|Vulpix|-Alola|Alolan Form|Ice}}\n{{ndex|0038|Ninetales|Fire|forms=2}}\n{{ndex/form|0038|Ninetales|-Alola|Alolan Form|Ice|Fairy}}\n{{ndex|0039|Jigglypuff|Normal|Fairy}}\n{{ndex|0040|Wigglytuff|Normal|Fairy}}\n{{ndex|0041|Zubat|Poison|Flying}}\n{{ndex|0042|Golbat|Poison|Flying}}\n{{ndex|0043|Oddish|Grass|Poison}}\n{{ndex|0044|Gloom|Grass|Poison}}\n{{ndex|0045|Vileplume|Grass|Poison}}\n{{ndex|0046|Paras|Bug|Grass}}\n{{ndex|0047|Parasect|Bug|Grass}}\n{{ndex|0048|Venonat|Bug|Poison}}\n{{ndex|0049|Venomoth|Bug|Poison}}\n{{ndex|0050|Diglett|Ground|forms=2}}\n{{ndex/form|0050|Diglett|-Alola|Alolan Form|Ground|Steel}}\n{{ndex|0051|Dugtrio|Ground|forms=2}}\n{{ndex/form|0051|Dugtrio|-Alola|Alolan Form|Ground|Steel}}\n{{ndex|0052|Meowth|Normal|forms=3}}\n{{ndex/form|0052|Meowth|-Alola|Alolan Form|Dark}}\n{{ndex/form|0052|Meowth|-Galar|Galarian Form|Steel}}\n{{ndex|0053|Persian|Normal|forms=2}}\n{{ndex/form|0053|Persian|-Alola|Alolan Form|Dark}}\n{{ndex|0054|Psyduck|Water}}\n{{ndex|0055|Golduck|Water}}\n{{ndex|0056|Mankey|Fighting ...

# %%
# FUNTION DEFINITION : get pokemon list
def extract_third_substrings(input_string):
    # Define the regular expression pattern
    # pattern = r"\{\{ndex\|\d+\|([^\|]+)\|[^\|]+\|[^\|]+\}\}"
    # pattern = r"\{\{ndex\|\d+\|([^\|]+)(?:\|[^\|]+)*\}\}"
    pattern = r"\{\{ndex\|\d+\|([^\|]+)\|?.*?\}\}"
    
    # Find all matches of the pattern
    matches = re.findall(pattern, input_string)
    
    # Return the list of third substrings
    return matches

# %%
poke_list = extract_third_substrings(poke_list)
poke_list = [name + " (Pokémon)" for name in poke_list]
poke_list
# Out:
# ['Bulbasaur (Pokémon)',
#  'Ivysaur (Pokémon)',
#  'Venusaur (Pokémon)',
#  'Charmander (Pokémon)',
#  'Charmeleon (Pokémon)',
#  'Charizard (Pokémon)',
#  'Squirtle (Pokémon)',
#  'Wartortle (Pokémon)',
#  'Blastoise (Pokémon)',
#  'Caterpie (Pokémon)',
#  'Metapod (Pokémon)',
#  'Butterfree (Pokémon)',
#  'Weedle (Pokémon)',
#  'Kakuna (Pokémon)',
#  'Beedrill (Pokémon)',
#  'Pidgey (Pokémon)',
#  'Pidgeotto (Pokémon)',
#  'Pidgeot (Pokémon)',
#  'Rattata (Pokémon)',
#  'Raticate (Pokémon)',
#  'Spearow (Pokémon)',
#  'Fearow (Pokémon)',
#  'Ekans (Pokémon)',
#  'Arbok (Pokémon)',
#  'Pikachu (Pokémon)',
#  'Raichu (Pokémon)',
#  'Sandshrew (Pokémon)',
#  'Sandslash (Pokémon)',
#  'Nidoran♀ (Pokémon)',
#  'Nidorina (Pokémon)',
#  'Nidoqueen (Pokémon)',
#  'Nidoran♂ (Pokémon)',
#  'Nidorino (Pokémon)',
#  'Nidoking (Pokémon)',
#  'Clefairy (Pokémon)',
#  'Clefable (Pokémon)',
#  'Vulpix (Pokémon)',
#  'Ninetales (Pokémon)',
#  'Jigglypuff (Pokémon)',
#  'Wigglytuff (Pokémon)',
#  'Zubat (Pokémon)',
#  'Golbat (Pokémon)',
#  'Oddish (Pokémon)',
#  'Gloom (Pokémon)',
#  'Vileplume (Pokémon)',
#  'Paras (Pokémon)',
#  'Parasect (Pokémon)',
#  'Venonat (Pokémon)',
#  'Venomoth (Pokémon)',
#  'Diglett (Pokémon)',
#  'Dugtrio (Pokémon)',
#  'Meowth (Pokémon)',
#  'Persian (Pokémon)',
#  'Psyduck (Pokémon)',
#  'Golduck (Pokémon)',
#  'Mankey (Pokémon)',
#  'Primeape (Pokémon)',
#  'Growlithe (Pokémon)',
#  'Arcanine (Pokémon)',
#  'Poliwag (Pokémon)',
#  'Poliwhirl (Pokémon)',
#  'Poliwrath (Pokémon)',
#  'Abra (Pokémon)',
#  'Kadabra (Pokémon)',
#  'Alakazam (Pokémon)',
#  'Machop (Pokémon)',
#  'Machoke (Pokémon)',
#  'Machamp (Pokémon)',
#  'Bellsprout (Pokémon)',
#  'Weepinbell (Pokémon)',
#  'Victreebel (Pokémon)',
#  'Tentacool (Pokémon)',
#  'Tentacruel (Pokémon)',
#  'Geodude (Pokémon)',
#  'Graveler (Pokémon)',
#  'Golem (Pokémon)',
#  'Ponyta (Pokémon)',
#  'Rapidash (Pokémon)',
#  'Slowpoke (Pokémon)',
#  'Slowbro (Pokémon)',
#  'Magnemite (Pokémon)',
#  'Magneton (Pokémon)',
#  "Farfetch'd (Pokémon)",
#  'Doduo (Pokémon)',
#  'Dodrio (Pokémon)',
#  'Seel (Pokémon)',
#  'Dewgong (Pokémon)',
#  'Grimer (Pokémon)',
#  'Muk (Pokémon)',
#  'Shellder (Pokémon)',
#  'Cloyster (Pokémon)',
#  'Gastly (Pokémon)',
#  'Haunter (Pokémon)',
#  'Gengar (Pokémon)',
#  'Onix (Pokémon)',
#  'Drowzee (Pokémon)',
#  'Hypno (Pokémon)',
#  'Krabby (Pokémon)',
#  'Kingler (Pokémon)',
#  'Voltorb (Pokémon)',
#  'Electrode (Pokémon)',
#  'Exeggcute (Pokémon)',
#  'Exeggutor (Pokémon)',
#  'Cubone (Pokémon)',
#  'Marowak (Pokémon)',
#  'Hitmonlee (Pokémon)',
#  'Hitmonchan (Pokémon)',
#  'Lickitung (Pokémon)',
#  'Koffing (Pokémon)',
#  'Weezing (Pokémon)',
#  'Rhyhorn (Pokémon)',
#  'Rhydon (Pokémon)',
#  'Chansey (Pokémon)',
#  'Tangela (Pokémon)',
#  'Kangaskhan (Pokémon)',
#  'Horsea (Pokémon)',
#  'Seadra (Pokémon)',
#  'Goldeen (Pokémon)',
#  'Seaking (Pokémon)',
#  'Staryu (Pokémon)',
#  'Starmie (Pokémon)',
#  'Mr. Mime (Pokémon)',
#  'Scyther (Pokémon)',
#  'Jynx (Pokémon)',
#  'Electabuzz (Pokémon)',
#  'Magmar (Pokémon)',
#  'Pinsir (Pokémon)',
#  'Tauros (Pokémon)',
#  'Magikarp (Pokémon)',
#  'Gyarados (Pokémon)',
#  'Lapras (Pokémon)',
#  'Ditto (Pokémon)',
#  'Eevee (Pokémon)',
#  'Vaporeon (Pokémon)',
#  'Jolteon (Pokémon)',
#  'Flareon (Pokémon)',
#  'Porygon (Pokémon)',
#  'Omanyte (Pokémon)',
#  'Omastar (Pokémon)',
#  'Kabuto (Pokémon)',
#  'Kabutops (Pokémon)',
#  'Aerodactyl (Pokémon)',
#  'Snorlax (Pokémon)',
#  'Articuno (Pokémon)',
#  'Zapdos (Pokémon)',
#  'Moltres (Pokémon)',
#  'Dratini (Pokémon)',
#  'Dragonair (Pokémon)',
#  'Dragonite (Pokémon)',
#  'Mewtwo (Pokémon)',
#  'Mew (Pokémon)',
#  'Chikorita (Pokémon)',
#  'Bayleef (Pokémon)',
#  'Meganium (Pokémon)',
#  'Cyndaquil (Pokémon)',
#  'Quilava (Pokémon)',
#  'Typhlosion (Pokémon)',
#  'Totodile (Pokémon)',
#  'Croconaw (Pokémon)',
#  'Feraligatr (Pokémon)',
#  'Sentret (Pokémon)',
#  'Furret (Pokémon)',
#  'Hoothoot (Pokémon)',
#  'Noctowl (Pokémon)',
#  'Ledyba (Pokémon)',
#  'Ledian (Pokémon)',
#  'Spinarak (Pokémon)',
#  'Ariados (Pokémon)',
#  'Crobat (Pokémon)',
#  'Chinchou (Pokémon)',
#  'Lanturn (Pokémon)',
#  'Pichu (Pokémon)',
#  'Cleffa (Pokémon)',
#  'Igglybuff (Pokémon)',
#  'Togepi (Pokémon)',
#  'Togetic (Pokémon)',
#  'Natu (Pokémon)',
#  'Xatu (Pokémon)',
#  'Mareep (Pokémon)',
#  'Flaaffy (Pokémon)',
#  'Ampharos (Pokémon)',
#  'Bellossom (Pokémon)',
#  'Marill (Pokémon)',
#  'Azumarill (Pokémon)',
#  'Sudowoodo (Pokémon)',
#  'Politoed (Pokémon)',
#  'Hoppip (Pokémon)',
#  'Skiploom (Pokémon)',
#  'Jumpluff (Pokémon)',
#  'Aipom (Pokémon)',
#  'Sunkern (Pokémon)',
#  'Sunflora (Pokémon)',
#  'Yanma (Pokémon)',
#  'Wooper (Pokémon)',
#  'Quagsire (Pokémon)',
#  'Espeon (Pokémon)',
#  'Umbreon (Pokémon)',
#  'Murkrow (Pokémon)',
#  'Slowking (Pokémon)',
#  'Misdreavus (Pokémon)',
#  'Unown (Pokémon)',
#  'Wobbuffet (Pokémon)',
#  'Girafarig (Pokémon)',
#  'Pineco (Pokémon)',
#  'Forretress (Pokémon)',
#  'Dunsparce (Pokémon)',
#  'Gligar (Pokémon)',
#  'Steelix (Pokémon)',
#  'Snubbull (Pokémon)',
#  'Granbull (Pokémon)',
#  'Qwilfish (Pokémon)',
#  'Scizor (Pokémon)',
#  'Shuckle (Pokémon)',
#  'Heracross (Pokémon)',
#  'Sneasel (Pokémon)',
#  'Teddiursa (Pokémon)',
#  'Ursaring (Pokémon)',
#  'Slugma (Pokémon)',
#  'Magcargo (Pokémon)',
#  'Swinub (Pokémon)',
#  'Piloswine (Pokémon)',
#  'Corsola (Pokémon)',
#  'Remoraid (Pokémon)',
#  'Octillery (Pokémon)',
#  'Delibird (Pokémon)',
#  'Mantine (Pokémon)',
#  'Skarmory (Pokémon)',
#  'Houndour (Pokémon)',
#  'Houndoom (Pokémon)',
#  'Kingdra (Pokémon)',
#  'Phanpy (Pokémon)',
#  'Donphan (Pokémon)',
#  'Porygon2 (Pokémon)',
#  'Stantler (Pokémon)',
#  'Smeargle (Pokémon)',
#  'Tyrogue (Pokémon)',
#  'Hitmontop (Pokémon)',
#  'Smoochum (Pokémon)',
#  'Elekid (Pokémon)',
#  'Magby (Pokémon)',
#  'Miltank (Pokémon)',
#  'Blissey (Pokémon)',
#  'Raikou (Pokémon)',
#  'Entei (Pokémon)',
#  'Suicune (Pokémon)',
#  'Larvitar (Pokémon)',
#  'Pupitar (Pokémon)',
#  'Tyranitar (Pokémon)',
#  'Lugia (Pokémon)',
#  'Ho-Oh (Pokémon)',
#  'Celebi (Pokémon)',
#  'Treecko (Pokémon)',
#  'Grovyle (Pokémon)',
#  'Sceptile (Pokémon)',
#  'Torchic (Pokémon)',
#  'Combusken (Pokémon)',
#  'Blaziken (Pokémon)',
#  'Mudkip (Pokémon)',
#  'Marshtomp (Pokémon)',
#  'Swampert (Pokémon)',
#  'Poochyena (Pokémon)',
#  'Mightyena (Pokémon)',
#  'Zigzagoon (Pokémon)',
#  'Linoone (Pokémon)',
#  'Wurmple (Pokémon)',
#  'Silcoon (Pokémon)',
#  'Beautifly (Pokémon)',
#  'Cascoon (Pokémon)',
#  'Dustox (Pokémon)',
#  'Lotad (Pokémon)',
#  'Lombre (Pokémon)',
#  'Ludicolo (Pokémon)',
#  'Seedot (Pokémon)',
#  'Nuzleaf (Pokémon)',
#  'Shiftry (Pokémon)',
#  'Taillow (Pokémon)',
#  'Swellow (Pokémon)',
#  'Wingull (Pokémon)',
#  'Pelipper (Pokémon)',
#  'Ralts (Pokémon)',
#  'Kirlia (Pokémon)',
#  'Gardevoir (Pokémon)',
#  'Surskit (Pokémon)',
#  'Masquerain (Pokémon)',
#  'Shroomish (Pokémon)',
#  'Breloom (Pokémon)',
#  'Slakoth (Pokémon)',
#  'Vigoroth (Pokémon)',
#  'Slaking (Pokémon)',
#  'Nincada (Pokémon)',
#  'Ninjask (Pokémon)',
#  'Shedinja (Pokémon)',
#  'Whismur (Pokémon)',
#  'Loudred (Pokémon)',
#  'Exploud (Pokémon)',
#  'Makuhita (Pokémon)',
#  'Hariyama (Pokémon)',
#  'Azurill (Pokémon)',
#  'Nosepass (Pokémon)',
#  'Skitty (Pokémon)',
#  'Delcatty (Pokémon)',
#  'Sableye (Pokémon)',
#  'Mawile (Pokémon)',
#  'Aron (Pokémon)',
#  'Lairon (Pokémon)',
#  'Aggron (Pokémon)',
#  'Meditite (Pokémon)',
#  'Medicham (Pokémon)',
#  'Electrike (Pokémon)',
#  'Manectric (Pokémon)',
#  'Plusle (Pokémon)',
#  'Minun (Pokémon)',
#  'Volbeat (Pokémon)',
#  'Illumise (Pokémon)',
#  'Roselia (Pokémon)',
#  'Gulpin (Pokémon)',
#  'Swalot (Pokémon)',
#  'Carvanha (Pokémon)',
#  'Sharpedo (Pokémon)',
#  'Wailmer (Pokémon)',
#  'Wailord (Pokémon)',
#  'Numel (Pokémon)',
#  'Camerupt (Pokémon)',
#  'Torkoal (Pokémon)',
#  'Spoink (Pokémon)',
#  'Grumpig (Pokémon)',
#  'Spinda (Pokémon)',
#  'Trapinch (Pokémon)',
#  'Vibrava (Pokémon)',
#  'Flygon (Pokémon)',
#  'Cacnea (Pokémon)',
#  'Cacturne (Pokémon)',
#  'Swablu (Pokémon)',
#  'Altaria (Pokémon)',
#  'Zangoose (Pokémon)',
#  'Seviper (Pokémon)',
#  'Lunatone (Pokémon)',
#  'Solrock (Pokémon)',
#  'Barboach (Pokémon)',
#  'Whiscash (Pokémon)',
#  'Corphish (Pokémon)',
#  'Crawdaunt (Pokémon)',
#  'Baltoy (Pokémon)',
#  'Claydol (Pokémon)',
#  'Lileep (Pokémon)',
#  'Cradily (Pokémon)',
#  'Anorith (Pokémon)',
#  'Armaldo (Pokémon)',
#  'Feebas (Pokémon)',
#  'Milotic (Pokémon)',
#  'Castform (Pokémon)',
#  'Kecleon (Pokémon)',
#  'Shuppet (Pokémon)',
#  'Banette (Pokémon)',
#  'Duskull (Pokémon)',
#  'Dusclops (Pokémon)',
#  'Tropius (Pokémon)',
#  'Chimecho (Pokémon)',
#  'Absol (Pokémon)',
#  'Wynaut (Pokémon)',
#  'Snorunt (Pokémon)',
#  'Glalie (Pokémon)',
#  'Spheal (Pokémon)',
#  'Sealeo (Pokémon)',
#  'Walrein (Pokémon)',
#  'Clamperl (Pokémon)',
#  'Huntail (Pokémon)',
#  'Gorebyss (Pokémon)',
#  'Relicanth (Pokémon)',
#  'Luvdisc (Pokémon)',
#  'Bagon (Pokémon)',
#  'Shelgon (Pokémon)',
#  'Salamence (Pokémon)',
#  'Beldum (Pokémon)',
#  'Metang (Pokémon)',
#  'Metagross (Pokémon)',
#  'Regirock (Pokémon)',
#  'Regice (Pokémon)',
#  'Registeel (Pokémon)',
#  'Latias (Pokémon)',
#  'Latios (Pokémon)',
#  'Kyogre (Pokémon)',
#  'Groudon (Pokémon)',
#  'Rayquaza (Pokémon)',
#  'Jirachi (Pokémon)',
#  'Deoxys (Pokémon)',
#  'Turtwig (Pokémon)',
#  'Grotle (Pokémon)',
#  'Torterra (Pokémon)',
#  'Chimchar (Pokémon)',
#  'Monferno (Pokémon)',
#  'Infernape (Pokémon)',
#  'Piplup (Pokémon)',
#  'Prinplup (Pokémon)',
#  'Empoleon (Pokémon)',
#  'Starly (Pokémon)',
#  'Staravia (Pokémon)',
#  'Staraptor (Pokémon)',
#  'Bidoof (Pokémon)',
#  'Bibarel (Pokémon)',
#  'Kricketot (Pokémon)',
#  'Kricketune (Pokémon)',
#  'Shinx (Pokémon)',
#  'Luxio (Pokémon)',
#  'Luxray (Pokémon)',
#  'Budew (Pokémon)',
#  'Roserade (Pokémon)',
#  'Cranidos (Pokémon)',
#  'Rampardos (Pokémon)',
#  'Shieldon (Pokémon)',
#  'Bastiodon (Pokémon)',
#  'Burmy (Pokémon)',
#  'Wormadam (Pokémon)',
#  'Mothim (Pokémon)',
#  'Combee (Pokémon)',
#  'Vespiquen (Pokémon)',
#  'Pachirisu (Pokémon)',
#  'Buizel (Pokémon)',
#  'Floatzel (Pokémon)',
#  'Cherubi (Pokémon)',
#  'Cherrim (Pokémon)',
#  'Shellos (Pokémon)',
#  'Gastrodon (Pokémon)',
#  'Ambipom (Pokémon)',
#  'Drifloon (Pokémon)',
#  'Drifblim (Pokémon)',
#  'Buneary (Pokémon)',
#  'Lopunny (Pokémon)',
#  'Mismagius (Pokémon)',
#  'Honchkrow (Pokémon)',
#  'Glameow (Pokémon)',
#  'Purugly (Pokémon)',
#  'Chingling (Pokémon)',
#  'Stunky (Pokémon)',
#  'Skuntank (Pokémon)',
#  'Bronzor (Pokémon)',
#  'Bronzong (Pokémon)',
#  'Bonsly (Pokémon)',
#  'Mime Jr. (Pokémon)',
#  'Happiny (Pokémon)',
#  'Chatot (Pokémon)',
#  'Spiritomb (Pokémon)',
#  'Gible (Pokémon)',
#  'Gabite (Pokémon)',
#  'Garchomp (Pokémon)',
#  'Munchlax (Pokémon)',
#  'Riolu (Pokémon)',
#  'Lucario (Pokémon)',
#  'Hippopotas (Pokémon)',
#  'Hippowdon (Pokémon)',
#  'Skorupi (Pokémon)',
#  'Drapion (Pokémon)',
#  'Croagunk (Pokémon)',
#  'Toxicroak (Pokémon)',
#  'Carnivine (Pokémon)',
#  'Finneon (Pokémon)',
#  'Lumineon (Pokémon)',
#  'Mantyke (Pokémon)',
#  'Snover (Pokémon)',
#  'Abomasnow (Pokémon)',
#  'Weavile (Pokémon)',
#  'Magnezone (Pokémon)',
#  'Lickilicky (Pokémon)',
#  'Rhyperior (Pokémon)',
#  'Tangrowth (Pokémon)',
#  'Electivire (Pokémon)',
#  'Magmortar (Pokémon)',
#  'Togekiss (Pokémon)',
#  'Yanmega (Pokémon)',
#  'Leafeon (Pokémon)',
#  'Glaceon (Pokémon)',
#  'Gliscor (Pokémon)',
#  'Mamoswine (Pokémon)',
#  'Porygon-Z (Pokémon)',
#  'Gallade (Pokémon)',
#  'Probopass (Pokémon)',
#  'Dusknoir (Pokémon)',
#  'Froslass (Pokémon)',
#  'Rotom (Pokémon)',
#  'Uxie (Pokémon)',
#  'Mesprit (Pokémon)',
#  'Azelf (Pokémon)',
#  'Dialga (Pokémon)',
#  'Palkia (Pokémon)',
#  'Heatran (Pokémon)',
#  'Regigigas (Pokémon)',
#  'Giratina (Pokémon)',
#  'Cresselia (Pokémon)',
#  'Phione (Pokémon)',
#  'Manaphy (Pokémon)',
#  'Darkrai (Pokémon)',
#  'Shaymin (Pokémon)',
#  'Arceus (Pokémon)',
#  'Victini (Pokémon)',
#  'Snivy (Pokémon)',
#  'Servine (Pokémon)',
#  'Serperior (Pokémon)',
#  'Tepig (Pokémon)',
#  'Pignite (Pokémon)',
#  'Emboar (Pokémon)',
#  'Oshawott (Pokémon)',
#  'Dewott (Pokémon)',
#  'Samurott (Pokémon)',
#  'Patrat (Pokémon)',
#  'Watchog (Pokémon)',
#  'Lillipup (Pokémon)',
#  'Herdier (Pokémon)',
#  'Stoutland (Pokémon)',
#  'Purrloin (Pokémon)',
#  'Liepard (Pokémon)',
#  'Pansage (Pokémon)',
#  'Simisage (Pokémon)',
#  'Pansear (Pokémon)',
#  'Simisear (Pokémon)',
#  'Panpour (Pokémon)',
#  'Simipour (Pokémon)',
#  'Munna (Pokémon)',
#  'Musharna (Pokémon)',
#  'Pidove (Pokémon)',
#  'Tranquill (Pokémon)',
#  'Unfezant (Pokémon)',
#  'Blitzle (Pokémon)',
#  'Zebstrika (Pokémon)',
#  'Roggenrola (Pokémon)',
#  'Boldore (Pokémon)',
#  'Gigalith (Pokémon)',
#  'Woobat (Pokémon)',
#  'Swoobat (Pokémon)',
#  'Drilbur (Pokémon)',
#  'Excadrill (Pokémon)',
#  'Audino (Pokémon)',
#  'Timburr (Pokémon)',
#  'Gurdurr (Pokémon)',
#  'Conkeldurr (Pokémon)',
#  'Tympole (Pokémon)',
#  'Palpitoad (Pokémon)',
#  'Seismitoad (Pokémon)',
#  'Throh (Pokémon)',
#  'Sawk (Pokémon)',
#  'Sewaddle (Pokémon)',
#  'Swadloon (Pokémon)',
#  'Leavanny (Pokémon)',
#  'Venipede (Pokémon)',
#  'Whirlipede (Pokémon)',
#  'Scolipede (Pokémon)',
#  'Cottonee (Pokémon)',
#  'Whimsicott (Pokémon)',
#  'Petilil (Pokémon)',
#  'Lilligant (Pokémon)',
#  'Basculin (Pokémon)',
#  'Sandile (Pokémon)',
#  'Krokorok (Pokémon)',
#  'Krookodile (Pokémon)',
#  'Darumaka (Pokémon)',
#  'Darmanitan (Pokémon)',
#  'Maractus (Pokémon)',
#  'Dwebble (Pokémon)',
#  'Crustle (Pokémon)',
#  'Scraggy (Pokémon)',
#  'Scrafty (Pokémon)',
#  'Sigilyph (Pokémon)',
#  'Yamask (Pokémon)',
#  'Cofagrigus (Pokémon)',
#  'Tirtouga (Pokémon)',
#  'Carracosta (Pokémon)',
#  'Archen (Pokémon)',
#  'Archeops (Pokémon)',
#  'Trubbish (Pokémon)',
#  'Garbodor (Pokémon)',
#  'Zorua (Pokémon)',
#  'Zoroark (Pokémon)',
#  'Minccino (Pokémon)',
#  'Cinccino (Pokémon)',
#  'Gothita (Pokémon)',
#  'Gothorita (Pokémon)',
#  'Gothitelle (Pokémon)',
#  'Solosis (Pokémon)',
#  'Duosion (Pokémon)',
#  'Reuniclus (Pokémon)',
#  'Ducklett (Pokémon)',
#  'Swanna (Pokémon)',
#  'Vanillite (Pokémon)',
#  'Vanillish (Pokémon)',
#  'Vanilluxe (Pokémon)',
#  'Deerling (Pokémon)',
#  'Sawsbuck (Pokémon)',
#  'Emolga (Pokémon)',
#  'Karrablast (Pokémon)',
#  'Escavalier (Pokémon)',
#  'Foongus (Pokémon)',
#  'Amoonguss (Pokémon)',
#  'Frillish (Pokémon)',
#  'Jellicent (Pokémon)',
#  'Alomomola (Pokémon)',
#  'Joltik (Pokémon)',
#  'Galvantula (Pokémon)',
#  'Ferroseed (Pokémon)',
#  'Ferrothorn (Pokémon)',
#  'Klink (Pokémon)',
#  'Klang (Pokémon)',
#  'Klinklang (Pokémon)',
#  'Tynamo (Pokémon)',
#  'Eelektrik (Pokémon)',
#  'Eelektross (Pokémon)',
#  'Elgyem (Pokémon)',
#  'Beheeyem (Pokémon)',
#  'Litwick (Pokémon)',
#  'Lampent (Pokémon)',
#  'Chandelure (Pokémon)',
#  'Axew (Pokémon)',
#  'Fraxure (Pokémon)',
#  'Haxorus (Pokémon)',
#  'Cubchoo (Pokémon)',
#  'Beartic (Pokémon)',
#  'Cryogonal (Pokémon)',
#  'Shelmet (Pokémon)',
#  'Accelgor (Pokémon)',
#  'Stunfisk (Pokémon)',
#  'Mienfoo (Pokémon)',
#  'Mienshao (Pokémon)',
#  'Druddigon (Pokémon)',
#  'Golett (Pokémon)',
#  'Golurk (Pokémon)',
#  'Pawniard (Pokémon)',
#  'Bisharp (Pokémon)',
#  'Bouffalant (Pokémon)',
#  'Rufflet (Pokémon)',
#  'Braviary (Pokémon)',
#  'Vullaby (Pokémon)',
#  'Mandibuzz (Pokémon)',
#  'Heatmor (Pokémon)',
#  'Durant (Pokémon)',
#  'Deino (Pokémon)',
#  'Zweilous (Pokémon)',
#  'Hydreigon (Pokémon)',
#  'Larvesta (Pokémon)',
#  'Volcarona (Pokémon)',
#  'Cobalion (Pokémon)',
#  'Terrakion (Pokémon)',
#  'Virizion (Pokémon)',
#  'Tornadus (Pokémon)',
#  'Thundurus (Pokémon)',
#  'Reshiram (Pokémon)',
#  'Zekrom (Pokémon)',
#  'Landorus (Pokémon)',
#  'Kyurem (Pokémon)',
#  'Keldeo (Pokémon)',
#  'Meloetta (Pokémon)',
#  'Genesect (Pokémon)',
#  'Chespin (Pokémon)',
#  'Quilladin (Pokémon)',
#  'Chesnaught (Pokémon)',
#  'Fennekin (Pokémon)',
#  'Braixen (Pokémon)',
#  'Delphox (Pokémon)',
#  'Froakie (Pokémon)',
#  'Frogadier (Pokémon)',
#  'Greninja (Pokémon)',
#  'Bunnelby (Pokémon)',
#  'Diggersby (Pokémon)',
#  'Fletchling (Pokémon)',
#  'Fletchinder (Pokémon)',
#  'Talonflame (Pokémon)',
#  'Scatterbug (Pokémon)',
#  'Spewpa (Pokémon)',
#  'Vivillon (Pokémon)',
#  'Litleo (Pokémon)',
#  'Pyroar (Pokémon)',
#  'Flabébé (Pokémon)',
#  'Floette (Pokémon)',
#  'Florges (Pokémon)',
#  'Skiddo (Pokémon)',
#  'Gogoat (Pokémon)',
#  'Pancham (Pokémon)',
#  'Pangoro (Pokémon)',
#  'Furfrou (Pokémon)',
#  'Espurr (Pokémon)',
#  'Meowstic (Pokémon)',
#  'Honedge (Pokémon)',
#  'Doublade (Pokémon)',
#  'Aegislash (Pokémon)',
#  'Spritzee (Pokémon)',
#  'Aromatisse (Pokémon)',
#  'Swirlix (Pokémon)',
#  'Slurpuff (Pokémon)',
#  'Inkay (Pokémon)',
#  'Malamar (Pokémon)',
#  'Binacle (Pokémon)',
#  'Barbaracle (Pokémon)',
#  'Skrelp (Pokémon)',
#  'Dragalge (Pokémon)',
#  'Clauncher (Pokémon)',
#  'Clawitzer (Pokémon)',
#  'Helioptile (Pokémon)',
#  'Heliolisk (Pokémon)',
#  'Tyrunt (Pokémon)',
#  'Tyrantrum (Pokémon)',
#  'Amaura (Pokémon)',
#  'Aurorus (Pokémon)',
#  'Sylveon (Pokémon)',
#  'Hawlucha (Pokémon)',
#  'Dedenne (Pokémon)',
#  'Carbink (Pokémon)',
#  'Goomy (Pokémon)',
#  'Sliggoo (Pokémon)',
#  'Goodra (Pokémon)',
#  'Klefki (Pokémon)',
#  'Phantump (Pokémon)',
#  'Trevenant (Pokémon)',
#  'Pumpkaboo (Pokémon)',
#  'Gourgeist (Pokémon)',
#  'Bergmite (Pokémon)',
#  'Avalugg (Pokémon)',
#  'Noibat (Pokémon)',
#  'Noivern (Pokémon)',
#  'Xerneas (Pokémon)',
#  'Yveltal (Pokémon)',
#  'Zygarde (Pokémon)',
#  'Diancie (Pokémon)',
#  'Hoopa (Pokémon)',
#  'Volcanion (Pokémon)',
#  'Rowlet (Pokémon)',
#  'Dartrix (Pokémon)',
#  'Decidueye (Pokémon)',
#  'Litten (Pokémon)',
#  'Torracat (Pokémon)',
#  'Incineroar (Pokémon)',
#  'Popplio (Pokémon)',
#  'Brionne (Pokémon)',
#  'Primarina (Pokémon)',
#  'Pikipek (Pokémon)',
#  'Trumbeak (Pokémon)',
#  'Toucannon (Pokémon)',
#  'Yungoos (Pokémon)',
#  'Gumshoos (Pokémon)',
#  'Grubbin (Pokémon)',
#  'Charjabug (Pokémon)',
#  'Vikavolt (Pokémon)',
#  'Crabrawler (Pokémon)',
#  'Crabominable (Pokémon)',
#  'Oricorio (Pokémon)',
#  'Cutiefly (Pokémon)',
#  'Ribombee (Pokémon)',
#  'Rockruff (Pokémon)',
#  'Lycanroc (Pokémon)',
#  'Wishiwashi (Pokémon)',
#  'Mareanie (Pokémon)',
#  'Toxapex (Pokémon)',
#  'Mudbray (Pokémon)',
#  'Mudsdale (Pokémon)',
#  'Dewpider (Pokémon)',
#  'Araquanid (Pokémon)',
#  'Fomantis (Pokémon)',
#  'Lurantis (Pokémon)',
#  'Morelull (Pokémon)',
#  'Shiinotic (Pokémon)',
#  'Salandit (Pokémon)',
#  'Salazzle (Pokémon)',
#  'Stufful (Pokémon)',
#  'Bewear (Pokémon)',
#  'Bounsweet (Pokémon)',
#  'Steenee (Pokémon)',
#  'Tsareena (Pokémon)',
#  'Comfey (Pokémon)',
#  'Oranguru (Pokémon)',
#  'Passimian (Pokémon)',
#  'Wimpod (Pokémon)',
#  'Golisopod (Pokémon)',
#  'Sandygast (Pokémon)',
#  'Palossand (Pokémon)',
#  'Pyukumuku (Pokémon)',
#  'Type: Null (Pokémon)',
#  'Silvally (Pokémon)',
#  'Minior (Pokémon)',
#  'Komala (Pokémon)',
#  'Turtonator (Pokémon)',
#  'Togedemaru (Pokémon)',
#  'Mimikyu (Pokémon)',
#  'Bruxish (Pokémon)',
#  'Drampa (Pokémon)',
#  'Dhelmise (Pokémon)',
#  'Jangmo-o (Pokémon)',
#  'Hakamo-o (Pokémon)',
#  'Kommo-o (Pokémon)',
#  'Tapu Koko (Pokémon)',
#  'Tapu Lele (Pokémon)',
#  'Tapu Bulu (Pokémon)',
#  'Tapu Fini (Pokémon)',
#  'Cosmog (Pokémon)',
#  'Cosmoem (Pokémon)',
#  'Solgaleo (Pokémon)',
#  'Lunala (Pokémon)',
#  'Nihilego (Pokémon)',
#  'Buzzwole (Pokémon)',
#  'Pheromosa (Pokémon)',
#  'Xurkitree (Pokémon)',
#  'Celesteela (Pokémon)',
#  'Kartana (Pokémon)',
#  'Guzzlord (Pokémon)',
#  'Necrozma (Pokémon)',
#  'Magearna (Pokémon)',
#  'Marshadow (Pokémon)',
#  'Poipole (Pokémon)',
#  'Naganadel (Pokémon)',
#  'Stakataka (Pokémon)',
#  'Blacephalon (Pokémon)',
#  'Zeraora (Pokémon)',
#  'Meltan (Pokémon)',
#  'Melmetal (Pokémon)',
#  'Grookey (Pokémon)',
#  'Thwackey (Pokémon)',
#  'Rillaboom (Pokémon)',
#  'Scorbunny (Pokémon)',
#  'Raboot (Pokémon)',
#  'Cinderace (Pokémon)',
#  'Sobble (Pokémon)',
#  'Drizzile (Pokémon)',
#  'Inteleon (Pokémon)',
#  'Skwovet (Pokémon)',
#  'Greedent (Pokémon)',
#  'Rookidee (Pokémon)',
#  'Corvisquire (Pokémon)',
#  'Corviknight (Pokémon)',
#  'Blipbug (Pokémon)',
#  'Dottler (Pokémon)',
#  'Orbeetle (Pokémon)',
#  'Nickit (Pokémon)',
#  'Thievul (Pokémon)',
#  'Gossifleur (Pokémon)',
#  'Eldegoss (Pokémon)',
#  'Wooloo (Pokémon)',
#  'Dubwool (Pokémon)',
#  'Chewtle (Pokémon)',
#  'Drednaw (Pokémon)',
#  'Yamper (Pokémon)',
#  'Boltund (Pokémon)',
#  'Rolycoly (Pokémon)',
#  'Carkol (Pokémon)',
#  'Coalossal (Pokémon)',
#  'Applin (Pokémon)',
#  'Flapple (Pokémon)',
#  'Appletun (Pokémon)',
#  'Silicobra (Pokémon)',
#  'Sandaconda (Pokémon)',
#  'Cramorant (Pokémon)',
#  'Arrokuda (Pokémon)',
#  'Barraskewda (Pokémon)',
#  'Toxel (Pokémon)',
#  'Toxtricity (Pokémon)',
#  'Sizzlipede (Pokémon)',
#  'Centiskorch (Pokémon)',
#  'Clobbopus (Pokémon)',
#  'Grapploct (Pokémon)',
#  'Sinistea (Pokémon)',
#  'Polteageist (Pokémon)',
#  'Hatenna (Pokémon)',
#  'Hattrem (Pokémon)',
#  'Hatterene (Pokémon)',
#  'Impidimp (Pokémon)',
#  'Morgrem (Pokémon)',
#  'Grimmsnarl (Pokémon)',
#  'Obstagoon (Pokémon)',
#  'Perrserker (Pokémon)',
#  'Cursola (Pokémon)',
#  "Sirfetch'd (Pokémon)",
#  'Mr. Rime (Pokémon)',
#  'Runerigus (Pokémon)',
#  'Milcery (Pokémon)',
#  'Alcremie (Pokémon)',
#  'Falinks (Pokémon)',
#  'Pincurchin (Pokémon)',
#  'Snom (Pokémon)',
#  'Frosmoth (Pokémon)',
#  'Stonjourner (Pokémon)',
#  'Eiscue (Pokémon)',
#  'Indeedee (Pokémon)',
#  'Morpeko (Pokémon)',
#  'Cufant (Pokémon)',
#  'Copperajah (Pokémon)',
#  'Dracozolt (Pokémon)',
#  'Arctozolt (Pokémon)',
#  'Dracovish (Pokémon)',
#  'Arctovish (Pokémon)',
#  'Duraludon (Pokémon)',
#  'Dreepy (Pokémon)',
#  'Drakloak (Pokémon)',
#  'Dragapult (Pokémon)',
#  'Zacian (Pokémon)',
#  'Zamazenta (Pokémon)',
#  'Eternatus (Pokémon)',
#  'Kubfu (Pokémon)',
#  'Urshifu (Pokémon)',
#  'Zarude (Pokémon)',
#  'Regieleki (Pokémon)',
#  'Regidrago (Pokémon)',
#  'Glastrier (Pokémon)',
#  'Spectrier (Pokémon)',
#  'Calyrex (Pokémon)',
#  'Wyrdeer (Pokémon)',
#  'Kleavor (Pokémon)',
#  'Ursaluna (Pokémon)',
#  'Basculegion (Pokémon)',
#  'Sneasler (Pokémon)',
#  'Overqwil (Pokémon)',
#  'Enamorus (Pokémon)',
#  'Sprigatito (Pokémon)',
#  'Floragato (Pokémon)',
#  'Meowscarada (Pokémon)',
#  'Fuecoco (Pokémon)',
#  'Crocalor (Pokémon)',
#  'Skeledirge (Pokémon)',
#  'Quaxly (Pokémon)',
#  'Quaxwell (Pokémon)',
#  'Quaquaval (Pokémon)',
#  'Lechonk (Pokémon)',
#  'Oinkologne (Pokémon)',
#  'Tarountula (Pokémon)',
#  'Spidops (Pokémon)',
#  'Nymble (Pokémon)',
#  'Lokix (Pokémon)',
#  'Pawmi (Pokémon)',
#  'Pawmo (Pokémon)',
#  'Pawmot (Pokémon)',
#  'Tandemaus (Pokémon)',
#  'Maushold (Pokémon)',
#  'Fidough (Pokémon)',
#  'Dachsbun (Pokémon)',
#  'Smoliv (Pokémon)',
#  'Dolliv (Pokémon)',
#  'Arboliva (Pokémon)',
#  'Squawkabilly (Pokémon)',
#  'Nacli (Pokémon)',
#  'Naclstack (Pokémon)',
#  'Garganacl (Pokémon)',
#  'Charcadet (Pokémon)',
#  'Armarouge (Pokémon)',
#  'Ceruledge (Pokémon)',
#  'Tadbulb (Pokémon)',
#  'Bellibolt (Pokémon)',
#  'Wattrel (Pokémon)',
#  'Kilowattrel (Pokémon)',
#  'Maschiff (Pokémon)',
#  'Mabosstiff (Pokémon)',
#  'Shroodle (Pokémon)',
#  'Grafaiai (Pokémon)',
#  'Bramblin (Pokémon)',
#  'Brambleghast (Pokémon)',
#  'Toedscool (Pokémon)',
#  'Toedscruel (Pokémon)',
#  'Klawf (Pokémon)',
#  'Capsakid (Pokémon)',
#  'Scovillain (Pokémon)',
#  'Rellor (Pokémon)',
#  'Rabsca (Pokémon)',
#  'Flittle (Pokémon)',
#  'Espathra (Pokémon)',
#  'Tinkatink (Pokémon)',
#  'Tinkatuff (Pokémon)',
#  'Tinkaton (Pokémon)',
#  'Wiglett (Pokémon)',
#  'Wugtrio (Pokémon)',
#  'Bombirdier (Pokémon)',
#  'Finizen (Pokémon)',
#  'Palafin (Pokémon)',
#  'Varoom (Pokémon)',
#  'Revavroom (Pokémon)',
#  'Cyclizar (Pokémon)',
#  'Orthworm (Pokémon)',
#  'Glimmet (Pokémon)',
#  'Glimmora (Pokémon)',
#  'Greavard (Pokémon)',
#  'Houndstone (Pokémon)',
#  'Flamigo (Pokémon)',
#  'Cetoddle (Pokémon)',
#  'Cetitan (Pokémon)',
#  'Veluza (Pokémon)',
#  'Dondozo (Pokémon)',
#  'Tatsugiri (Pokémon)',
#  'Annihilape (Pokémon)',
#  'Clodsire (Pokémon)',
#  'Farigiraf (Pokémon)',
#  'Dudunsparce (Pokémon)',
#  'Kingambit (Pokémon)',
#  'Great Tusk (Pokémon)',
#  'Scream Tail (Pokémon)',
#  'Brute Bonnet (Pokémon)',
#  'Flutter Mane (Pokémon)',
#  'Slither Wing (Pokémon)',
#  'Sandy Shocks (Pokémon)',
#  'Iron Treads (Pokémon)',
#  'Iron Bundle (Pokémon)',
#  'Iron Hands (Pokémon)',
#  'Iron Jugulis (Pokémon)',
#  'Iron Moth (Pokémon)',
#  'Iron Thorns (Pokémon)',
#  'Frigibax (Pokémon)',
#  'Arctibax (Pokémon)',
#  'Baxcalibur (Pokémon)',
#  'Gimmighoul (Pokémon)',
#  'Gholdengo (Pokémon)',
#  ...]

# %%
intial_graph = Graph()
for pokemon in poke_list:
    try:
        # Step 1: Fetch the page text
        result1 = bulbabot.page_text(title=pokemon)
        
        # Step 2: Extract the infobox
        result2 = extract_infobox(result1)
        
        # Step 3: Parse the infobox
        result3 = parse_infobox(result2)
        
        # Step 4: Map the parsed infobox to RDF
        final_graph = map_infobox_to_rdf(intial_graph, result3)
        
        # Log or handle the final result (optional)
        print(f"Successfully processed {pokemon}")
    except Exception as e:
        # Handle any errors that occur in the pipeline
        print(f"Error processing {pokemon}: {e}")
# Out:
# Successfully processed Bulbasaur (Pokémon)
# Successfully processed Ivysaur (Pokémon)
# Successfully processed Venusaur (Pokémon)
# Successfully processed Charmander (Pokémon)
# Successfully processed Charmeleon (Pokémon)
# Successfully processed Charizard (Pokémon)
# Successfully processed Squirtle (Pokémon)
# Successfully processed Wartortle (Pokémon)
# Successfully processed Blastoise (Pokémon)
# Successfully processed Caterpie (Pokémon)
# Successfully processed Metapod (Pokémon)
# Successfully processed Butterfree (Pokémon)
# Successfully processed Weedle (Pokémon)
# Successfully processed Kakuna (Pokémon)
# Successfully processed Beedrill (Pokémon)
# Successfully processed Pidgey (Pokémon)
# Successfully processed Pidgeotto (Pokémon)
# Successfully processed Pidgeot (Pokémon)
# Successfully processed Rattata (Pokémon)
# Successfully processed Raticate (Pokémon)
# Successfully processed Spearow (Pokémon)
# Successfully processed Fearow (Pokémon)
# Successfully processed Ekans (Pokémon)
# Successfully processed Arbok (Pokémon)
# Successfully processed Pikachu (Pokémon)
# Successfully processed Raichu (Pokémon)
# Successfully processed Sandshrew (Pokémon)
# Successfully processed Sandslash (Pokémon)
# Successfully processed Nidoran♀ (Pokémon)
# Successfully processed Nidorina (Pokémon)
# Successfully processed Nidoqueen (Pokémon)
# Successfully processed Nidoran♂ (Pokémon)
# Successfully processed Nidorino (Pokémon)
# Successfully processed Nidoking (Pokémon)
# Successfully processed Clefairy (Pokémon)
# Successfully processed Clefable (Pokémon)
# Successfully processed Vulpix (Pokémon)
# Successfully processed Ninetales (Pokémon)
# Successfully processed Jigglypuff (Pokémon)
# Successfully processed Wigglytuff (Pokémon)
# Successfully processed Zubat (Pokémon)
# Successfully processed Golbat (Pokémon)
# Successfully processed Oddish (Pokémon)
# Successfully processed Gloom (Pokémon)
# Successfully processed Vileplume (Pokémon)
# Successfully processed Paras (Pokémon)
# Successfully processed Parasect (Pokémon)
# Successfully processed Venonat (Pokémon)
# Successfully processed Venomoth (Pokémon)
# Successfully processed Diglett (Pokémon)
# Successfully processed Dugtrio (Pokémon)
# Successfully processed Meowth (Pokémon)
# Successfully processed Persian (Pokémon)
# Successfully processed Psyduck (Pokémon)
# Successfully processed Golduck (Pokémon)
# Successfully processed Mankey (Pokémon)
# Successfully processed Primeape (Pokémon)
# Successfully processed Growlithe (Pokémon)
# Successfully processed Arcanine (Pokémon)
# Successfully processed Poliwag (Pokémon)
# Successfully processed Poliwhirl (Pokémon)
# Successfully processed Poliwrath (Pokémon)
# Successfully processed Abra (Pokémon)
# Successfully processed Kadabra (Pokémon)
# Successfully processed Alakazam (Pokémon)
# Successfully processed Machop (Pokémon)
# Successfully processed Machoke (Pokémon)
# Successfully processed Machamp (Pokémon)
# Successfully processed Bellsprout (Pokémon)
# Successfully processed Weepinbell (Pokémon)
# Successfully processed Victreebel (Pokémon)
# Successfully processed Tentacool (Pokémon)
# Successfully processed Tentacruel (Pokémon)
# Successfully processed Geodude (Pokémon)
# Successfully processed Graveler (Pokémon)
# Successfully processed Golem (Pokémon)
# Successfully processed Ponyta (Pokémon)
# Successfully processed Rapidash (Pokémon)
# Successfully processed Slowpoke (Pokémon)
# Successfully processed Slowbro (Pokémon)
# Successfully processed Magnemite (Pokémon)
# Successfully processed Magneton (Pokémon)
# Successfully processed Farfetch'd (Pokémon)
# Successfully processed Doduo (Pokémon)
# Successfully processed Dodrio (Pokémon)
# Successfully processed Seel (Pokémon)
# Successfully processed Dewgong (Pokémon)
# Successfully processed Grimer (Pokémon)
# Successfully processed Muk (Pokémon)
# Successfully processed Shellder (Pokémon)
# Successfully processed Cloyster (Pokémon)
# Successfully processed Gastly (Pokémon)
# Successfully processed Haunter (Pokémon)
# Successfully processed Gengar (Pokémon)
# Successfully processed Onix (Pokémon)
# Successfully processed Drowzee (Pokémon)
# Successfully processed Hypno (Pokémon)
# Successfully processed Krabby (Pokémon)
# Successfully processed Kingler (Pokémon)
# Successfully processed Voltorb (Pokémon)
# Successfully processed Electrode (Pokémon)
# Successfully processed Exeggcute (Pokémon)
# Successfully processed Exeggutor (Pokémon)
# Successfully processed Cubone (Pokémon)
# Successfully processed Marowak (Pokémon)
# Successfully processed Hitmonlee (Pokémon)
# Successfully processed Hitmonchan (Pokémon)
# Successfully processed Lickitung (Pokémon)
# Successfully processed Koffing (Pokémon)
# Successfully processed Weezing (Pokémon)
# Successfully processed Rhyhorn (Pokémon)
# Successfully processed Rhydon (Pokémon)
# Successfully processed Chansey (Pokémon)
# Successfully processed Tangela (Pokémon)
# Successfully processed Kangaskhan (Pokémon)
# Successfully processed Horsea (Pokémon)
# Successfully processed Seadra (Pokémon)
# Successfully processed Goldeen (Pokémon)
# Successfully processed Seaking (Pokémon)
# Successfully processed Staryu (Pokémon)
# Successfully processed Starmie (Pokémon)
# Successfully processed Mr. Mime (Pokémon)
# Successfully processed Scyther (Pokémon)
# Successfully processed Jynx (Pokémon)
# Successfully processed Electabuzz (Pokémon)
# Successfully processed Magmar (Pokémon)
# Successfully processed Pinsir (Pokémon)
# Successfully processed Tauros (Pokémon)
# Successfully processed Magikarp (Pokémon)
# Successfully processed Gyarados (Pokémon)
# Successfully processed Lapras (Pokémon)
# Successfully processed Ditto (Pokémon)
# Successfully processed Eevee (Pokémon)
# Successfully processed Vaporeon (Pokémon)
# Successfully processed Jolteon (Pokémon)
# Successfully processed Flareon (Pokémon)
# Successfully processed Porygon (Pokémon)
# Successfully processed Omanyte (Pokémon)
# Successfully processed Omastar (Pokémon)
# Successfully processed Kabuto (Pokémon)
# Successfully processed Kabutops (Pokémon)
# Successfully processed Aerodactyl (Pokémon)
# Successfully processed Snorlax (Pokémon)
# Successfully processed Articuno (Pokémon)
# Successfully processed Zapdos (Pokémon)
# Successfully processed Moltres (Pokémon)
# Successfully processed Dratini (Pokémon)
# Successfully processed Dragonair (Pokémon)
# Successfully processed Dragonite (Pokémon)
# Successfully processed Mewtwo (Pokémon)
# Successfully processed Mew (Pokémon)
# Successfully processed Chikorita (Pokémon)
# Successfully processed Bayleef (Pokémon)
# Successfully processed Meganium (Pokémon)
# Successfully processed Cyndaquil (Pokémon)
# Successfully processed Quilava (Pokémon)
# Successfully processed Typhlosion (Pokémon)
# Successfully processed Totodile (Pokémon)
# Successfully processed Croconaw (Pokémon)
# Successfully processed Feraligatr (Pokémon)
# Successfully processed Sentret (Pokémon)
# Successfully processed Furret (Pokémon)
# Successfully processed Hoothoot (Pokémon)
# Successfully processed Noctowl (Pokémon)
# Successfully processed Ledyba (Pokémon)
# Successfully processed Ledian (Pokémon)
# Successfully processed Spinarak (Pokémon)
# Successfully processed Ariados (Pokémon)
# Successfully processed Crobat (Pokémon)
# Successfully processed Chinchou (Pokémon)
# Successfully processed Lanturn (Pokémon)
# Successfully processed Pichu (Pokémon)
# Successfully processed Cleffa (Pokémon)
# Successfully processed Igglybuff (Pokémon)
# Successfully processed Togepi (Pokémon)
# Successfully processed Togetic (Pokémon)
# Successfully processed Natu (Pokémon)
# Successfully processed Xatu (Pokémon)
# Successfully processed Mareep (Pokémon)
# Successfully processed Flaaffy (Pokémon)
# Successfully processed Ampharos (Pokémon)
# Successfully processed Bellossom (Pokémon)
# Successfully processed Marill (Pokémon)
# Successfully processed Azumarill (Pokémon)
# Successfully processed Sudowoodo (Pokémon)
# Successfully processed Politoed (Pokémon)
# Successfully processed Hoppip (Pokémon)
# Successfully processed Skiploom (Pokémon)
# Successfully processed Jumpluff (Pokémon)
# Successfully processed Aipom (Pokémon)
# Successfully processed Sunkern (Pokémon)
# Successfully processed Sunflora (Pokémon)
# Successfully processed Yanma (Pokémon)
# Successfully processed Wooper (Pokémon)
# Successfully processed Quagsire (Pokémon)
# Successfully processed Espeon (Pokémon)
# Successfully processed Umbreon (Pokémon)
# Successfully processed Murkrow (Pokémon)
# Successfully processed Slowking (Pokémon)
# Successfully processed Misdreavus (Pokémon)
# Successfully processed Unown (Pokémon)
# Successfully processed Wobbuffet (Pokémon)
# Successfully processed Girafarig (Pokémon)
# Successfully processed Pineco (Pokémon)
# Successfully processed Forretress (Pokémon)
# Successfully processed Dunsparce (Pokémon)
# Successfully processed Gligar (Pokémon)
# Successfully processed Steelix (Pokémon)
# Successfully processed Snubbull (Pokémon)
# Successfully processed Granbull (Pokémon)
# Successfully processed Qwilfish (Pokémon)
# Successfully processed Scizor (Pokémon)
# Successfully processed Shuckle (Pokémon)
# Successfully processed Heracross (Pokémon)
# Successfully processed Sneasel (Pokémon)
# Successfully processed Teddiursa (Pokémon)
# Successfully processed Ursaring (Pokémon)
# Successfully processed Slugma (Pokémon)
# Successfully processed Magcargo (Pokémon)
# Successfully processed Swinub (Pokémon)
# Successfully processed Piloswine (Pokémon)
# Successfully processed Corsola (Pokémon)
# Successfully processed Remoraid (Pokémon)
# Successfully processed Octillery (Pokémon)
# Successfully processed Delibird (Pokémon)
# Successfully processed Mantine (Pokémon)
# Successfully processed Skarmory (Pokémon)
# Successfully processed Houndour (Pokémon)
# Successfully processed Houndoom (Pokémon)
# Successfully processed Kingdra (Pokémon)
# Successfully processed Phanpy (Pokémon)
# Successfully processed Donphan (Pokémon)
# Successfully processed Porygon2 (Pokémon)
# Successfully processed Stantler (Pokémon)
# Successfully processed Smeargle (Pokémon)
# Successfully processed Tyrogue (Pokémon)
# Successfully processed Hitmontop (Pokémon)
# Successfully processed Smoochum (Pokémon)
# Successfully processed Elekid (Pokémon)
# Successfully processed Magby (Pokémon)
# Successfully processed Miltank (Pokémon)
# Successfully processed Blissey (Pokémon)
# Successfully processed Raikou (Pokémon)
# Successfully processed Entei (Pokémon)
# Successfully processed Suicune (Pokémon)
# Successfully processed Larvitar (Pokémon)
# Successfully processed Pupitar (Pokémon)
# Successfully processed Tyranitar (Pokémon)
# Successfully processed Lugia (Pokémon)
# Successfully processed Ho-Oh (Pokémon)
# Successfully processed Celebi (Pokémon)
# Successfully processed Treecko (Pokémon)
# Successfully processed Grovyle (Pokémon)
# Successfully processed Sceptile (Pokémon)
# Successfully processed Torchic (Pokémon)
# Successfully processed Combusken (Pokémon)
# Successfully processed Blaziken (Pokémon)
# Successfully processed Mudkip (Pokémon)
# Successfully processed Marshtomp (Pokémon)
# Successfully processed Swampert (Pokémon)
# Successfully processed Poochyena (Pokémon)
# Successfully processed Mightyena (Pokémon)
# Successfully processed Zigzagoon (Pokémon)
# Successfully processed Linoone (Pokémon)
# Successfully processed Wurmple (Pokémon)
# Successfully processed Silcoon (Pokémon)
# Successfully processed Beautifly (Pokémon)
# Successfully processed Cascoon (Pokémon)
# Successfully processed Dustox (Pokémon)
# Successfully processed Lotad (Pokémon)
# Successfully processed Lombre (Pokémon)
# Successfully processed Ludicolo (Pokémon)
# Successfully processed Seedot (Pokémon)
# Successfully processed Nuzleaf (Pokémon)
# Successfully processed Shiftry (Pokémon)
# Successfully processed Taillow (Pokémon)
# Successfully processed Swellow (Pokémon)
# Successfully processed Wingull (Pokémon)
# Successfully processed Pelipper (Pokémon)
# Successfully processed Ralts (Pokémon)
# Successfully processed Kirlia (Pokémon)
# Successfully processed Gardevoir (Pokémon)
# Successfully processed Surskit (Pokémon)
# Successfully processed Masquerain (Pokémon)
# Successfully processed Shroomish (Pokémon)
# Successfully processed Breloom (Pokémon)
# Successfully processed Slakoth (Pokémon)
# Successfully processed Vigoroth (Pokémon)
# Successfully processed Slaking (Pokémon)
# Successfully processed Nincada (Pokémon)
# Successfully processed Ninjask (Pokémon)
# Successfully processed Shedinja (Pokémon)
# Successfully processed Whismur (Pokémon)
# Successfully processed Loudred (Pokémon)
# Successfully processed Exploud (Pokémon)
# Successfully processed Makuhita (Pokémon)
# Successfully processed Hariyama (Pokémon)
# Successfully processed Azurill (Pokémon)
# Successfully processed Nosepass (Pokémon)
# Successfully processed Skitty (Pokémon)
# Successfully processed Delcatty (Pokémon)
# Successfully processed Sableye (Pokémon)
# Successfully processed Mawile (Pokémon)
# Successfully processed Aron (Pokémon)
# Successfully processed Lairon (Pokémon)
# Successfully processed Aggron (Pokémon)
# Successfully processed Meditite (Pokémon)
# Successfully processed Medicham (Pokémon)
# Successfully processed Electrike (Pokémon)
# Successfully processed Manectric (Pokémon)
# Successfully processed Plusle (Pokémon)
# Successfully processed Minun (Pokémon)
# Successfully processed Volbeat (Pokémon)
# Successfully processed Illumise (Pokémon)
# Successfully processed Roselia (Pokémon)
# Successfully processed Gulpin (Pokémon)
# Successfully processed Swalot (Pokémon)
# Successfully processed Carvanha (Pokémon)
# Successfully processed Sharpedo (Pokémon)
# Successfully processed Wailmer (Pokémon)
# Successfully processed Wailord (Pokémon)
# Successfully processed Numel (Pokémon)
# Successfully processed Camerupt (Pokémon)
# Successfully processed Torkoal (Pokémon)
# Successfully processed Spoink (Pokémon)
# Successfully processed Grumpig (Pokémon)
# Successfully processed Spinda (Pokémon)
# Successfully processed Trapinch (Pokémon)
# Successfully processed Vibrava (Pokémon)
# Successfully processed Flygon (Pokémon)
# Successfully processed Cacnea (Pokémon)
# Successfully processed Cacturne (Pokémon)
# Successfully processed Swablu (Pokémon)
# Successfully processed Altaria (Pokémon)
# Successfully processed Zangoose (Pokémon)
# Successfully processed Seviper (Pokémon)
# Successfully processed Lunatone (Pokémon)
# Successfully processed Solrock (Pokémon)
# Successfully processed Barboach (Pokémon)
# Successfully processed Whiscash (Pokémon)
# Successfully processed Corphish (Pokémon)
# Successfully processed Crawdaunt (Pokémon)
# Successfully processed Baltoy (Pokémon)
# Successfully processed Claydol (Pokémon)
# Successfully processed Lileep (Pokémon)
# Successfully processed Cradily (Pokémon)
# Successfully processed Anorith (Pokémon)
# Successfully processed Armaldo (Pokémon)
# Successfully processed Feebas (Pokémon)
# Successfully processed Milotic (Pokémon)
# Successfully processed Castform (Pokémon)
# Successfully processed Kecleon (Pokémon)
# Successfully processed Shuppet (Pokémon)
# Successfully processed Banette (Pokémon)
# Successfully processed Duskull (Pokémon)
# Successfully processed Dusclops (Pokémon)
# Successfully processed Tropius (Pokémon)
# Successfully processed Chimecho (Pokémon)
# Successfully processed Absol (Pokémon)
# Successfully processed Wynaut (Pokémon)
# Successfully processed Snorunt (Pokémon)
# Successfully processed Glalie (Pokémon)
# Successfully processed Spheal (Pokémon)
# Successfully processed Sealeo (Pokémon)
# Successfully processed Walrein (Pokémon)
# Successfully processed Clamperl (Pokémon)
# Successfully processed Huntail (Pokémon)
# Successfully processed Gorebyss (Pokémon)
# Successfully processed Relicanth (Pokémon)
# Successfully processed Luvdisc (Pokémon)
# Successfully processed Bagon (Pokémon)
# Successfully processed Shelgon (Pokémon)
# Successfully processed Salamence (Pokémon)
# Successfully processed Beldum (Pokémon)
# Successfully processed Metang (Pokémon)
# Successfully processed Metagross (Pokémon)
# Successfully processed Regirock (Pokémon)
# Successfully processed Regice (Pokémon)
# Successfully processed Registeel (Pokémon)
# Successfully processed Latias (Pokémon)
# Successfully processed Latios (Pokémon)
# Successfully processed Kyogre (Pokémon)
# Successfully processed Groudon (Pokémon)
# Successfully processed Rayquaza (Pokémon)
# Successfully processed Jirachi (Pokémon)
# Successfully processed Deoxys (Pokémon)
# Successfully processed Turtwig (Pokémon)
# Successfully processed Grotle (Pokémon)
# Successfully processed Torterra (Pokémon)
# Successfully processed Chimchar (Pokémon)
# Successfully processed Monferno (Pokémon)
# Successfully processed Infernape (Pokémon)
# Successfully processed Piplup (Pokémon)
# Successfully processed Prinplup (Pokémon)
# Successfully processed Empoleon (Pokémon)
# Successfully processed Starly (Pokémon)
# Successfully processed Staravia (Pokémon)
# Successfully processed Staraptor (Pokémon)
# Successfully processed Bidoof (Pokémon)
# Successfully processed Bibarel (Pokémon)
# Successfully processed Kricketot (Pokémon)
# Successfully processed Kricketune (Pokémon)
# Successfully processed Shinx (Pokémon)
# Successfully processed Luxio (Pokémon)
# Successfully processed Luxray (Pokémon)
# Successfully processed Budew (Pokémon)
# Successfully processed Roserade (Pokémon)
# Successfully processed Cranidos (Pokémon)
# Successfully processed Rampardos (Pokémon)
# Successfully processed Shieldon (Pokémon)
# Successfully processed Bastiodon (Pokémon)
# Successfully processed Burmy (Pokémon)
# Successfully processed Wormadam (Pokémon)
# Successfully processed Mothim (Pokémon)
# Successfully processed Combee (Pokémon)
# Successfully processed Vespiquen (Pokémon)
# Successfully processed Pachirisu (Pokémon)
# Successfully processed Buizel (Pokémon)
# Successfully processed Floatzel (Pokémon)
# Successfully processed Cherubi (Pokémon)
# Successfully processed Cherrim (Pokémon)
# Successfully processed Shellos (Pokémon)
# Successfully processed Gastrodon (Pokémon)
# Successfully processed Ambipom (Pokémon)
# Successfully processed Drifloon (Pokémon)
# Successfully processed Drifblim (Pokémon)
# Successfully processed Buneary (Pokémon)
# Successfully processed Lopunny (Pokémon)
# Successfully processed Mismagius (Pokémon)
# Successfully processed Honchkrow (Pokémon)
# Successfully processed Glameow (Pokémon)
# Successfully processed Purugly (Pokémon)
# Successfully processed Chingling (Pokémon)
# Successfully processed Stunky (Pokémon)
# Successfully processed Skuntank (Pokémon)
# Successfully processed Bronzor (Pokémon)
# Successfully processed Bronzong (Pokémon)
# Successfully processed Bonsly (Pokémon)
# Successfully processed Mime Jr. (Pokémon)
# Successfully processed Happiny (Pokémon)
# Successfully processed Chatot (Pokémon)
# Successfully processed Spiritomb (Pokémon)
# Successfully processed Gible (Pokémon)
# Successfully processed Gabite (Pokémon)
# Successfully processed Garchomp (Pokémon)
# Successfully processed Munchlax (Pokémon)
# Successfully processed Riolu (Pokémon)
# Successfully processed Lucario (Pokémon)
# Successfully processed Hippopotas (Pokémon)
# Successfully processed Hippowdon (Pokémon)
# Successfully processed Skorupi (Pokémon)
# Successfully processed Drapion (Pokémon)
# Successfully processed Croagunk (Pokémon)
# Successfully processed Toxicroak (Pokémon)
# Successfully processed Carnivine (Pokémon)
# Successfully processed Finneon (Pokémon)
# Successfully processed Lumineon (Pokémon)
# Successfully processed Mantyke (Pokémon)
# Successfully processed Snover (Pokémon)
# Successfully processed Abomasnow (Pokémon)
# Successfully processed Weavile (Pokémon)
# Successfully processed Magnezone (Pokémon)
# Successfully processed Lickilicky (Pokémon)
# Successfully processed Rhyperior (Pokémon)
# Successfully processed Tangrowth (Pokémon)
# Successfully processed Electivire (Pokémon)
# Successfully processed Magmortar (Pokémon)
# Successfully processed Togekiss (Pokémon)
# Successfully processed Yanmega (Pokémon)
# Successfully processed Leafeon (Pokémon)
# Successfully processed Glaceon (Pokémon)
# Successfully processed Gliscor (Pokémon)
# Successfully processed Mamoswine (Pokémon)
# Successfully processed Porygon-Z (Pokémon)
# Successfully processed Gallade (Pokémon)
# Successfully processed Probopass (Pokémon)
# Successfully processed Dusknoir (Pokémon)
# Successfully processed Froslass (Pokémon)
# Successfully processed Rotom (Pokémon)
# Successfully processed Uxie (Pokémon)
# Successfully processed Mesprit (Pokémon)
# Successfully processed Azelf (Pokémon)
# Successfully processed Dialga (Pokémon)
# Successfully processed Palkia (Pokémon)
# Successfully processed Heatran (Pokémon)
# Successfully processed Regigigas (Pokémon)
# Successfully processed Giratina (Pokémon)
# Successfully processed Cresselia (Pokémon)
# Successfully processed Phione (Pokémon)
# Successfully processed Manaphy (Pokémon)
# Successfully processed Darkrai (Pokémon)
# Successfully processed Shaymin (Pokémon)
# Successfully processed Arceus (Pokémon)
# Successfully processed Victini (Pokémon)
# Successfully processed Snivy (Pokémon)
# Successfully processed Servine (Pokémon)
# Successfully processed Serperior (Pokémon)
# Successfully processed Tepig (Pokémon)
# Successfully processed Pignite (Pokémon)
# Successfully processed Emboar (Pokémon)
# Successfully processed Oshawott (Pokémon)
# Successfully processed Dewott (Pokémon)
# Successfully processed Samurott (Pokémon)
# Successfully processed Patrat (Pokémon)
# Successfully processed Watchog (Pokémon)
# Successfully processed Lillipup (Pokémon)
# Successfully processed Herdier (Pokémon)
# Successfully processed Stoutland (Pokémon)
# Successfully processed Purrloin (Pokémon)
# Successfully processed Liepard (Pokémon)
# Successfully processed Pansage (Pokémon)
# Successfully processed Simisage (Pokémon)
# Successfully processed Pansear (Pokémon)
# Successfully processed Simisear (Pokémon)
# Successfully processed Panpour (Pokémon)
# Successfully processed Simipour (Pokémon)
# Successfully processed Munna (Pokémon)
# Successfully processed Musharna (Pokémon)
# Successfully processed Pidove (Pokémon)
# Successfully processed Tranquill (Pokémon)
# Successfully processed Unfezant (Pokémon)
# Successfully processed Blitzle (Pokémon)
# Successfully processed Zebstrika (Pokémon)
# Successfully processed Roggenrola (Pokémon)
# Successfully processed Boldore (Pokémon)
# Successfully processed Gigalith (Pokémon)
# Successfully processed Woobat (Pokémon)
# Successfully processed Swoobat (Pokémon)
# Successfully processed Drilbur (Pokémon)
# Successfully processed Excadrill (Pokémon)
# Successfully processed Audino (Pokémon)
# Successfully processed Timburr (Pokémon)
# Successfully processed Gurdurr (Pokémon)
# Successfully processed Conkeldurr (Pokémon)
# Successfully processed Tympole (Pokémon)
# Successfully processed Palpitoad (Pokémon)
# Successfully processed Seismitoad (Pokémon)
# Successfully processed Throh (Pokémon)
# Successfully processed Sawk (Pokémon)
# Successfully processed Sewaddle (Pokémon)
# Successfully processed Swadloon (Pokémon)
# Successfully processed Leavanny (Pokémon)
# Successfully processed Venipede (Pokémon)
# Successfully processed Whirlipede (Pokémon)
# Successfully processed Scolipede (Pokémon)
# Successfully processed Cottonee (Pokémon)
# Successfully processed Whimsicott (Pokémon)
# Successfully processed Petilil (Pokémon)
# Successfully processed Lilligant (Pokémon)
# Successfully processed Basculin (Pokémon)
# Successfully processed Sandile (Pokémon)
# Successfully processed Krokorok (Pokémon)
# Successfully processed Krookodile (Pokémon)
# Successfully processed Darumaka (Pokémon)
# Successfully processed Darmanitan (Pokémon)
# Successfully processed Maractus (Pokémon)
# Successfully processed Dwebble (Pokémon)
# Successfully processed Crustle (Pokémon)
# Successfully processed Scraggy (Pokémon)
# Successfully processed Scrafty (Pokémon)
# Successfully processed Sigilyph (Pokémon)
# Successfully processed Yamask (Pokémon)
# Successfully processed Cofagrigus (Pokémon)
# Successfully processed Tirtouga (Pokémon)
# Successfully processed Carracosta (Pokémon)
# Successfully processed Archen (Pokémon)
# Successfully processed Archeops (Pokémon)
# Successfully processed Trubbish (Pokémon)
# Successfully processed Garbodor (Pokémon)
# Successfully processed Zorua (Pokémon)
# Successfully processed Zoroark (Pokémon)
# Successfully processed Minccino (Pokémon)
# Successfully processed Cinccino (Pokémon)
# Successfully processed Gothita (Pokémon)
# Successfully processed Gothorita (Pokémon)
# Successfully processed Gothitelle (Pokémon)
# Successfully processed Solosis (Pokémon)
# Successfully processed Duosion (Pokémon)
# Successfully processed Reuniclus (Pokémon)
# Successfully processed Ducklett (Pokémon)
# Successfully processed Swanna (Pokémon)
# Successfully processed Vanillite (Pokémon)
# Successfully processed Vanillish (Pokémon)
# Successfully processed Vanilluxe (Pokémon)
# Successfully processed Deerling (Pokémon)
# Successfully processed Sawsbuck (Pokémon)
# Successfully processed Emolga (Pokémon)
# Successfully processed Karrablast (Pokémon)
# Successfully processed Escavalier (Pokémon)
# Successfully processed Foongus (Pokémon)
# Successfully processed Amoonguss (Pokémon)
# Successfully processed Frillish (Pokémon)
# Successfully processed Jellicent (Pokémon)
# Successfully processed Alomomola (Pokémon)
# Successfully processed Joltik (Pokémon)
# Successfully processed Galvantula (Pokémon)
# Successfully processed Ferroseed (Pokémon)
# Successfully processed Ferrothorn (Pokémon)
# Successfully processed Klink (Pokémon)
# Successfully processed Klang (Pokémon)
# Successfully processed Klinklang (Pokémon)
# Successfully processed Tynamo (Pokémon)
# Successfully processed Eelektrik (Pokémon)
# Successfully processed Eelektross (Pokémon)
# Successfully processed Elgyem (Pokémon)
# Successfully processed Beheeyem (Pokémon)
# Successfully processed Litwick (Pokémon)
# Successfully processed Lampent (Pokémon)
# Successfully processed Chandelure (Pokémon)
# Successfully processed Axew (Pokémon)
# Successfully processed Fraxure (Pokémon)
# Successfully processed Haxorus (Pokémon)
# Successfully processed Cubchoo (Pokémon)
# Successfully processed Beartic (Pokémon)
# Successfully processed Cryogonal (Pokémon)
# Successfully processed Shelmet (Pokémon)
# Successfully processed Accelgor (Pokémon)
# Successfully processed Stunfisk (Pokémon)
# Successfully processed Mienfoo (Pokémon)
# Successfully processed Mienshao (Pokémon)
# Successfully processed Druddigon (Pokémon)
# Successfully processed Golett (Pokémon)
# Successfully processed Golurk (Pokémon)
# Successfully processed Pawniard (Pokémon)
# Successfully processed Bisharp (Pokémon)
# Successfully processed Bouffalant (Pokémon)
# Successfully processed Rufflet (Pokémon)
# Successfully processed Braviary (Pokémon)
# Successfully processed Vullaby (Pokémon)
# Successfully processed Mandibuzz (Pokémon)
# Successfully processed Heatmor (Pokémon)
# Successfully processed Durant (Pokémon)
# Successfully processed Deino (Pokémon)
# Successfully processed Zweilous (Pokémon)
# Successfully processed Hydreigon (Pokémon)
# Successfully processed Larvesta (Pokémon)
# Successfully processed Volcarona (Pokémon)
# Successfully processed Cobalion (Pokémon)
# Successfully processed Terrakion (Pokémon)
# Successfully processed Virizion (Pokémon)
# Successfully processed Tornadus (Pokémon)
# Successfully processed Thundurus (Pokémon)
# Successfully processed Reshiram (Pokémon)
# Successfully processed Zekrom (Pokémon)
# Successfully processed Landorus (Pokémon)
# Successfully processed Kyurem (Pokémon)
# Successfully processed Keldeo (Pokémon)
# Successfully processed Meloetta (Pokémon)
# Successfully processed Genesect (Pokémon)
# Successfully processed Chespin (Pokémon)
# Successfully processed Quilladin (Pokémon)
# Successfully processed Chesnaught (Pokémon)
# Successfully processed Fennekin (Pokémon)
# Successfully processed Braixen (Pokémon)
# Successfully processed Delphox (Pokémon)
# Successfully processed Froakie (Pokémon)
# Successfully processed Frogadier (Pokémon)
# Successfully processed Greninja (Pokémon)
# Successfully processed Bunnelby (Pokémon)
# Successfully processed Diggersby (Pokémon)
# Successfully processed Fletchling (Pokémon)
# Successfully processed Fletchinder (Pokémon)
# Successfully processed Talonflame (Pokémon)
# Successfully processed Scatterbug (Pokémon)
# Successfully processed Spewpa (Pokémon)
# Successfully processed Vivillon (Pokémon)
# Successfully processed Litleo (Pokémon)
# Successfully processed Pyroar (Pokémon)
# Successfully processed Flabébé (Pokémon)
# Successfully processed Floette (Pokémon)
# Successfully processed Florges (Pokémon)
# Successfully processed Skiddo (Pokémon)
# Successfully processed Gogoat (Pokémon)
# Successfully processed Pancham (Pokémon)
# Successfully processed Pangoro (Pokémon)
# Successfully processed Furfrou (Pokémon)
# Successfully processed Espurr (Pokémon)
# Successfully processed Meowstic (Pokémon)
# Successfully processed Honedge (Pokémon)
# Successfully processed Doublade (Pokémon)
# Successfully processed Aegislash (Pokémon)
# Successfully processed Spritzee (Pokémon)
# Successfully processed Aromatisse (Pokémon)
# Successfully processed Swirlix (Pokémon)
# Successfully processed Slurpuff (Pokémon)
# Successfully processed Inkay (Pokémon)
# Successfully processed Malamar (Pokémon)
# Successfully processed Binacle (Pokémon)
# Successfully processed Barbaracle (Pokémon)
# Successfully processed Skrelp (Pokémon)
# Successfully processed Dragalge (Pokémon)
# Successfully processed Clauncher (Pokémon)
# Successfully processed Clawitzer (Pokémon)
# Successfully processed Helioptile (Pokémon)
# Successfully processed Heliolisk (Pokémon)
# Successfully processed Tyrunt (Pokémon)
# Successfully processed Tyrantrum (Pokémon)
# Successfully processed Amaura (Pokémon)
# Successfully processed Aurorus (Pokémon)
# Successfully processed Sylveon (Pokémon)
# Successfully processed Hawlucha (Pokémon)
# Successfully processed Dedenne (Pokémon)
# Successfully processed Carbink (Pokémon)
# Successfully processed Goomy (Pokémon)
# Successfully processed Sliggoo (Pokémon)
# Successfully processed Goodra (Pokémon)
# Successfully processed Klefki (Pokémon)
# Successfully processed Phantump (Pokémon)
# Successfully processed Trevenant (Pokémon)
# Successfully processed Pumpkaboo (Pokémon)
# Successfully processed Gourgeist (Pokémon)
# Successfully processed Bergmite (Pokémon)
# Successfully processed Avalugg (Pokémon)
# Successfully processed Noibat (Pokémon)
# Successfully processed Noivern (Pokémon)
# Successfully processed Xerneas (Pokémon)
# Successfully processed Yveltal (Pokémon)
# Successfully processed Zygarde (Pokémon)
# Successfully processed Diancie (Pokémon)
# Successfully processed Hoopa (Pokémon)
# Successfully processed Volcanion (Pokémon)
# Successfully processed Rowlet (Pokémon)
# Successfully processed Dartrix (Pokémon)
# Successfully processed Decidueye (Pokémon)
# Successfully processed Litten (Pokémon)
# Successfully processed Torracat (Pokémon)
# Successfully processed Incineroar (Pokémon)
# Successfully processed Popplio (Pokémon)
# Successfully processed Brionne (Pokémon)
# Successfully processed Primarina (Pokémon)
# Successfully processed Pikipek (Pokémon)
# Successfully processed Trumbeak (Pokémon)
# Successfully processed Toucannon (Pokémon)
# Successfully processed Yungoos (Pokémon)
# Successfully processed Gumshoos (Pokémon)
# Successfully processed Grubbin (Pokémon)
# Successfully processed Charjabug (Pokémon)
# Successfully processed Vikavolt (Pokémon)
# Successfully processed Crabrawler (Pokémon)
# Successfully processed Crabominable (Pokémon)
# Successfully processed Oricorio (Pokémon)
# Successfully processed Cutiefly (Pokémon)
# Successfully processed Ribombee (Pokémon)
# Successfully processed Rockruff (Pokémon)
# Successfully processed Lycanroc (Pokémon)
# Successfully processed Wishiwashi (Pokémon)
# Successfully processed Mareanie (Pokémon)
# Successfully processed Toxapex (Pokémon)
# Successfully processed Mudbray (Pokémon)
# Successfully processed Mudsdale (Pokémon)
# Successfully processed Dewpider (Pokémon)
# Successfully processed Araquanid (Pokémon)
# Successfully processed Fomantis (Pokémon)
# Successfully processed Lurantis (Pokémon)
# Successfully processed Morelull (Pokémon)
# Successfully processed Shiinotic (Pokémon)
# Successfully processed Salandit (Pokémon)
# Successfully processed Salazzle (Pokémon)
# Successfully processed Stufful (Pokémon)
# Successfully processed Bewear (Pokémon)
# Successfully processed Bounsweet (Pokémon)
# Successfully processed Steenee (Pokémon)
# Successfully processed Tsareena (Pokémon)
# Successfully processed Comfey (Pokémon)
# Successfully processed Oranguru (Pokémon)
# Successfully processed Passimian (Pokémon)
# Successfully processed Wimpod (Pokémon)
# Successfully processed Golisopod (Pokémon)
# Successfully processed Sandygast (Pokémon)
# Successfully processed Palossand (Pokémon)
# Successfully processed Pyukumuku (Pokémon)
# Successfully processed Type: Null (Pokémon)
# Successfully processed Silvally (Pokémon)
# Successfully processed Minior (Pokémon)
# Successfully processed Komala (Pokémon)
# Successfully processed Turtonator (Pokémon)
# Successfully processed Togedemaru (Pokémon)
# Successfully processed Mimikyu (Pokémon)
# Successfully processed Bruxish (Pokémon)
# Successfully processed Drampa (Pokémon)
# Successfully processed Dhelmise (Pokémon)
# Successfully processed Jangmo-o (Pokémon)
# Successfully processed Hakamo-o (Pokémon)
# Successfully processed Kommo-o (Pokémon)
# Successfully processed Tapu Koko (Pokémon)
# Successfully processed Tapu Lele (Pokémon)
# Successfully processed Tapu Bulu (Pokémon)
# Successfully processed Tapu Fini (Pokémon)
# Successfully processed Cosmog (Pokémon)
# Successfully processed Cosmoem (Pokémon)
# Successfully processed Solgaleo (Pokémon)
# Successfully processed Lunala (Pokémon)
# Successfully processed Nihilego (Pokémon)
# Successfully processed Buzzwole (Pokémon)
# Successfully processed Pheromosa (Pokémon)
# Successfully processed Xurkitree (Pokémon)
# Successfully processed Celesteela (Pokémon)
# Successfully processed Kartana (Pokémon)
# Successfully processed Guzzlord (Pokémon)
# Successfully processed Necrozma (Pokémon)
# Successfully processed Magearna (Pokémon)
# Successfully processed Marshadow (Pokémon)
# Successfully processed Poipole (Pokémon)
# Successfully processed Naganadel (Pokémon)
# Successfully processed Stakataka (Pokémon)
# Successfully processed Blacephalon (Pokémon)
# Successfully processed Zeraora (Pokémon)
# Successfully processed Meltan (Pokémon)
# Successfully processed Melmetal (Pokémon)
# Successfully processed Grookey (Pokémon)
# Successfully processed Thwackey (Pokémon)
# Successfully processed Rillaboom (Pokémon)
# Successfully processed Scorbunny (Pokémon)
# Successfully processed Raboot (Pokémon)
# Successfully processed Cinderace (Pokémon)
# Successfully processed Sobble (Pokémon)
# Successfully processed Drizzile (Pokémon)
# Successfully processed Inteleon (Pokémon)
# Successfully processed Skwovet (Pokémon)
# Successfully processed Greedent (Pokémon)
# Successfully processed Rookidee (Pokémon)
# Successfully processed Corvisquire (Pokémon)
# Successfully processed Corviknight (Pokémon)
# Successfully processed Blipbug (Pokémon)
# Successfully processed Dottler (Pokémon)
# Successfully processed Orbeetle (Pokémon)
# Successfully processed Nickit (Pokémon)
# Successfully processed Thievul (Pokémon)
# Successfully processed Gossifleur (Pokémon)
# Successfully processed Eldegoss (Pokémon)
# Successfully processed Wooloo (Pokémon)
# Successfully processed Dubwool (Pokémon)
# Successfully processed Chewtle (Pokémon)
# Successfully processed Drednaw (Pokémon)
# Successfully processed Yamper (Pokémon)
# Successfully processed Boltund (Pokémon)
# Successfully processed Rolycoly (Pokémon)
# Successfully processed Carkol (Pokémon)
# Successfully processed Coalossal (Pokémon)
# Successfully processed Applin (Pokémon)
# Successfully processed Flapple (Pokémon)
# Successfully processed Appletun (Pokémon)
# Successfully processed Silicobra (Pokémon)
# Successfully processed Sandaconda (Pokémon)
# Successfully processed Cramorant (Pokémon)
# Successfully processed Arrokuda (Pokémon)
# Successfully processed Barraskewda (Pokémon)
# Successfully processed Toxel (Pokémon)
# Successfully processed Toxtricity (Pokémon)
# Successfully processed Sizzlipede (Pokémon)
# Successfully processed Centiskorch (Pokémon)
# Successfully processed Clobbopus (Pokémon)
# Successfully processed Grapploct (Pokémon)
# Successfully processed Sinistea (Pokémon)
# Successfully processed Polteageist (Pokémon)
# Successfully processed Hatenna (Pokémon)
# Successfully processed Hattrem (Pokémon)
# Successfully processed Hatterene (Pokémon)
# Successfully processed Impidimp (Pokémon)
# Successfully processed Morgrem (Pokémon)
# Successfully processed Grimmsnarl (Pokémon)
# Successfully processed Obstagoon (Pokémon)
# Successfully processed Perrserker (Pokémon)
# Successfully processed Cursola (Pokémon)
# Successfully processed Sirfetch'd (Pokémon)
# Successfully processed Mr. Rime (Pokémon)
# Successfully processed Runerigus (Pokémon)
# Successfully processed Milcery (Pokémon)
# Successfully processed Alcremie (Pokémon)
# Successfully processed Falinks (Pokémon)
# Successfully processed Pincurchin (Pokémon)
# Successfully processed Snom (Pokémon)
# Successfully processed Frosmoth (Pokémon)
# Successfully processed Stonjourner (Pokémon)
# Successfully processed Eiscue (Pokémon)
# Successfully processed Indeedee (Pokémon)
# Successfully processed Morpeko (Pokémon)
# Successfully processed Cufant (Pokémon)
# Successfully processed Copperajah (Pokémon)
# Successfully processed Dracozolt (Pokémon)
# Successfully processed Arctozolt (Pokémon)
# Successfully processed Dracovish (Pokémon)
# Successfully processed Arctovish (Pokémon)
# Successfully processed Duraludon (Pokémon)
# Successfully processed Dreepy (Pokémon)
# Successfully processed Drakloak (Pokémon)
# Successfully processed Dragapult (Pokémon)
# Successfully processed Zacian (Pokémon)
# Successfully processed Zamazenta (Pokémon)
# Successfully processed Eternatus (Pokémon)
# Successfully processed Kubfu (Pokémon)
# Successfully processed Urshifu (Pokémon)
# Successfully processed Zarude (Pokémon)
# Successfully processed Regieleki (Pokémon)
# Successfully processed Regidrago (Pokémon)
# Successfully processed Glastrier (Pokémon)
# Successfully processed Spectrier (Pokémon)
# Successfully processed Calyrex (Pokémon)
# Successfully processed Wyrdeer (Pokémon)
# Successfully processed Kleavor (Pokémon)
# Successfully processed Ursaluna (Pokémon)
# Successfully processed Basculegion (Pokémon)
# Successfully processed Sneasler (Pokémon)
# Successfully processed Overqwil (Pokémon)
# Successfully processed Enamorus (Pokémon)
# Successfully processed Sprigatito (Pokémon)
# Successfully processed Floragato (Pokémon)
# Successfully processed Meowscarada (Pokémon)
# Successfully processed Fuecoco (Pokémon)
# Successfully processed Crocalor (Pokémon)
# Successfully processed Skeledirge (Pokémon)
# Successfully processed Quaxly (Pokémon)
# Successfully processed Quaxwell (Pokémon)
# Successfully processed Quaquaval (Pokémon)
# Successfully processed Lechonk (Pokémon)
# Successfully processed Oinkologne (Pokémon)
# Successfully processed Tarountula (Pokémon)
# Successfully processed Spidops (Pokémon)
# Successfully processed Nymble (Pokémon)
# Successfully processed Lokix (Pokémon)
# Successfully processed Pawmi (Pokémon)
# Successfully processed Pawmo (Pokémon)
# Successfully processed Pawmot (Pokémon)
# Successfully processed Tandemaus (Pokémon)
# Successfully processed Maushold (Pokémon)
# Successfully processed Fidough (Pokémon)
# Successfully processed Dachsbun (Pokémon)
# Successfully processed Smoliv (Pokémon)
# Successfully processed Dolliv (Pokémon)
# Successfully processed Arboliva (Pokémon)
# Successfully processed Squawkabilly (Pokémon)
# Successfully processed Nacli (Pokémon)
# Successfully processed Naclstack (Pokémon)
# Successfully processed Garganacl (Pokémon)
# Successfully processed Charcadet (Pokémon)
# Successfully processed Armarouge (Pokémon)
# Successfully processed Ceruledge (Pokémon)
# Successfully processed Tadbulb (Pokémon)
# Successfully processed Bellibolt (Pokémon)
# Successfully processed Wattrel (Pokémon)
# Successfully processed Kilowattrel (Pokémon)
# Successfully processed Maschiff (Pokémon)
# Successfully processed Mabosstiff (Pokémon)
# Successfully processed Shroodle (Pokémon)
# Successfully processed Grafaiai (Pokémon)
# Successfully processed Bramblin (Pokémon)
# Successfully processed Brambleghast (Pokémon)
# Successfully processed Toedscool (Pokémon)
# Successfully processed Toedscruel (Pokémon)
# Successfully processed Klawf (Pokémon)
# Successfully processed Capsakid (Pokémon)
# Successfully processed Scovillain (Pokémon)
# Successfully processed Rellor (Pokémon)
# Successfully processed Rabsca (Pokémon)
# Successfully processed Flittle (Pokémon)
# Successfully processed Espathra (Pokémon)
# Successfully processed Tinkatink (Pokémon)
# Successfully processed Tinkatuff (Pokémon)
# Successfully processed Tinkaton (Pokémon)
# Successfully processed Wiglett (Pokémon)
# Successfully processed Wugtrio (Pokémon)
# Successfully processed Bombirdier (Pokémon)
# Successfully processed Finizen (Pokémon)
# Successfully processed Palafin (Pokémon)
# Successfully processed Varoom (Pokémon)
# Successfully processed Revavroom (Pokémon)
# Successfully processed Cyclizar (Pokémon)
# Successfully processed Orthworm (Pokémon)
# Successfully processed Glimmet (Pokémon)
# Successfully processed Glimmora (Pokémon)
# Successfully processed Greavard (Pokémon)
# Successfully processed Houndstone (Pokémon)
# Successfully processed Flamigo (Pokémon)
# Successfully processed Cetoddle (Pokémon)
# Successfully processed Cetitan (Pokémon)
# Successfully processed Veluza (Pokémon)
# Successfully processed Dondozo (Pokémon)
# Successfully processed Tatsugiri (Pokémon)
# Successfully processed Annihilape (Pokémon)
# Successfully processed Clodsire (Pokémon)
# Successfully processed Farigiraf (Pokémon)
# Successfully processed Dudunsparce (Pokémon)
# Successfully processed Kingambit (Pokémon)
# Successfully processed Great Tusk (Pokémon)
# Successfully processed Scream Tail (Pokémon)
# Successfully processed Brute Bonnet (Pokémon)
# Successfully processed Flutter Mane (Pokémon)
# Successfully processed Slither Wing (Pokémon)
# Successfully processed Sandy Shocks (Pokémon)
# Successfully processed Iron Treads (Pokémon)
# Successfully processed Iron Bundle (Pokémon)
# Successfully processed Iron Hands (Pokémon)
# Successfully processed Iron Jugulis (Pokémon)
# Successfully processed Iron Moth (Pokémon)
# Successfully processed Iron Thorns (Pokémon)
# Successfully processed Frigibax (Pokémon)
# Successfully processed Arctibax (Pokémon)
# Successfully processed Baxcalibur (Pokémon)
# Successfully processed Gimmighoul (Pokémon)
# Successfully processed Gholdengo (Pokémon)
# Successfully processed Wo-Chien (Pokémon)
# Successfully processed Chien-Pao (Pokémon)
# Successfully processed Ting-Lu (Pokémon)
# Successfully processed Chi-Yu (Pokémon)
# Successfully processed Roaring Moon (Pokémon)
# Successfully processed Iron Valiant (Pokémon)
# Successfully processed Koraidon (Pokémon)
# Successfully processed Koraidon (Pokémon)
# Successfully processed Miraidon (Pokémon)
# Successfully processed Miraidon (Pokémon)
# Successfully processed Walking Wake (Pokémon)
# Successfully processed Iron Leaves (Pokémon)
# Successfully processed Dipplin (Pokémon)
# Successfully processed Poltchageist (Pokémon)
# Successfully processed Sinistcha (Pokémon)
# Successfully processed Okidogi (Pokémon)
# Successfully processed Munkidori (Pokémon)
# Successfully processed Fezandipiti (Pokémon)
# Successfully processed Ogerpon (Pokémon)
# Successfully processed Archaludon (Pokémon)
# Successfully processed Hydrapple (Pokémon)
# Successfully processed Gouging Fire (Pokémon)
# Successfully processed Raging Bolt (Pokémon)
# Successfully processed Iron Boulder (Pokémon)
# Successfully processed Iron Crown (Pokémon)
# Successfully processed Terapagos (Pokémon)
# Successfully processed Pecharunt (Pokémon)

# %%
# Save or print the created graph
#print(final_graph.serialize(format="turtle"))
with open("poke_graph.ttl", "w", encoding="utf-8") as file:
    file.write(final_graph.serialize(format="turtle"))

# %%
Regions_wiht_infobox = [
    "Kanto",
    "Johto",
    "Hoenn",
    "Orre",
    "Sevii Islands",
    "Orange Islands",
    "Pokémon Island",
    "White City",
    "Fiore",
    "Sinnoh",
    "Pokétopia",
    "Pokémon world (Mystery Dungeon)",
    "Mintale Town",
    "Almia",
    "Trading Card Game Islands",
    "Oblivia",
    "Unova",
    "PokéPark (game)",
    "Ransei",
    "Decolore Islands",
    "Kalos",
    "Ferrum",
    "Alola",
    "Carmonte Island",
    "Ryme City",
    "Tumblecube Island",
    "Galar",
    "Pasio",
    "Isle of Armor",
    "Crown Tundra",
    "Lental",
    "Hisui",
    "Aeos Island",
    "Paldea",
    "Kitakami",
    "Blueberry Academy"
]

# %%
intial_region_graph = Graph()
for region in Regions_wiht_infobox:
    try:
        # Step 1: Fetch the page text
        result1 = bulbabot.page_text(title=region)
        
        # Step 2: Extract the infobox
        result2 = extract_region_infobox(result1)
        
        # Step 3: Parse the infobox
        result3 = parse_infobox(result2)
        
        # Step 4: Map the parsed infobox to RDF
        final_region_graph = map_region_infobox_to_rdf(intial_region_graph, result3)
        
        # Log or handle the final result (optional)
        print(f"Successfully processed {region}")
    except Exception as e:
        # Handle any errors that occur in the pipeline
        print(f"Error processing {region}: {e}")
# Out:
# Successfully processed Kanto
# Successfully processed Johto
# Successfully processed Hoenn
# Successfully processed Orre
# Successfully processed Sevii Islands
# Successfully processed Orange Islands
# Successfully processed Pokémon Island
# Successfully processed White City
# Successfully processed Fiore
# Successfully processed Sinnoh
# Successfully processed Pokétopia
# Successfully processed Pokémon world (Mystery Dungeon)
# Successfully processed Mintale Town
# Successfully processed Almia
# Successfully processed Trading Card Game Islands
# Successfully processed Oblivia
# Successfully processed Unova
# Successfully processed PokéPark (game)
# Successfully processed Ransei
# Successfully processed Decolore Islands
# Successfully processed Kalos
# Successfully processed Ferrum
# Successfully processed Alola
# Successfully processed Carmonte Island
# Successfully processed Ryme City
# Successfully processed Tumblecube Island
# Successfully processed Galar
# Successfully processed Pasio
# Successfully processed Isle of Armor
# Successfully processed Crown Tundra
# Successfully processed Lental
# Successfully processed Hisui
# Successfully processed Aeos Island
# Successfully processed Paldea
# Successfully processed Kitakami
# Successfully processed Blueberry Academy

# %%
# Save or print the created graph
print(final_region_graph.serialize(format="turtle"))
# with open("region_graph.ttl", "w", encoding="utf-8") as file:
#     file.write(final_region_graph.serialize(format="turtle"))
# Out:
# @prefix ns1: <http://example.org/region/> .
#
# ns1:Aeos_Island a ns1:Region ;
#     ns1:colorTemplate "Orange" ;
#     ns1:generation "{{gen|VIII}}" ;
#     ns1:image "UNITE Aeos Island.png" ;
#     ns1:imageCaption "Aeos Island" ;
#     ns1:imageSize "250" ;
#     ns1:introductionMedia "[[Pokémon UNITE]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "エオス島" ;
#     ns1:name "Aeos Island" ;
#     ns1:professor "[[Professor Phorus]]" ;
#     ns1:romanizedJapaneseName "Aeos Island" .
#
# ns1:Almia a ns1:Region ;
#     ns1:colorTemplate "SoA" ;
#     ns1:image "Almia.png" ;
#     ns1:imageSize "200" ;
#     ns1:introductionMedia "[[Pokémon Ranger: Shadows of Almia]]" ;
#     ns1:japaneseName "アルミア" ;
#     ns1:name "Almia" ;
#     ns1:professor "[[Professor Hastings]]" ;
#     ns1:romanizedJapaneseName "Almia" ;
#     ns1:villainousOrganization "[[Team Dim Sun]]" .
#
# ns1:Alola a ns1:Region ;
#     ns1:colorTemplate "alola" ;
#     ns1:image "Alola USUM artwork.png" ;
#     ns1:imageCaption "Artwork of the Alola region from {{g|Ultra Sun and Ultra Moon}}" ;
#     ns1:imageSize "300" ;
#     ns1:japaneseName "アローラ" ;
#     ns1:name "Alola" ;
#     ns1:romanizedJapaneseName "Alola" .
#
# ns1:Blueberry_Academy a ns1:Region ;
#     ns1:colorTemplate "Blueberry" ;
#     ns1:image "Blueberry Academy entrance.png" ;
#     ns1:imageCaption "Entrance to Blueberry Academy in {{g|Scarlet and Violet}}" ;
#     ns1:imageSize "300" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ブルーベリー学園" ;
#     ns1:name "Blueberry Academy" ;
#     ns1:romanizedJapaneseName "Blueberry Academy" .
#
# ns1:Carmonte_Island a ns1:Region ;
#     ns1:colorTemplate "Moon" ;
#     ns1:generation "{{gen|VI}}" ;
#     ns1:image "Carmonte Island.png" ;
#     ns1:imageCaption "Carmonte Island" ;
#     ns1:imageSize "300" ;
#     ns1:introductionMedia "[[Pokémon Duel]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "カルモンテ島" ;
#     ns1:name "Carmonte Island" ;
#     ns1:romanizedJapaneseName "Carmonte Island" ;
#     ns1:villainousOrganization "[[The Roger family|Roger family]]" .
#
# ns1:Crown_Tundra a ns1:Region ;
#     ns1:colorTemplate "Crown Tundra" ;
#     ns1:image "Crown Tundra artwork.png" ;
#     ns1:imageCaption "Artwork of the Crown Tundra from {{g|Sword and Shield}}" ;
#     ns1:imageSize "300" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "カンムリせつげん" ;
#     ns1:name "Crown Tundra" ;
#     ns1:romanizedJapaneseName "Crown Snowfield" .
#
# ns1:Decolore_Islands a ns1:Region ;
#     ns1:animationSeason "[[S16|Adventures in Unova and Beyond]] (16) |" ;
#     ns1:animationSeries "''[[Pokémon the Series: Black & White]]''" ;
#     ns1:colorTemplate "water" ;
#     ns1:image "Decolore.png" ;
#     ns1:introductionMedia "[[Pokémon animated series]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "デコロラ諸島" ;
#     ns1:name "Decolore Islands" ;
#     ns1:romanizedJapaneseName "Decolora Archipelago" .
#
# ns1:Ferrum a ns1:Region ;
#     ns1:colorTemplate "steel" ;
#     ns1:generation "{{gen|VI}}" ;
#     ns1:image "Ferrum.png" ;
#     ns1:imageCaption "The Ferrum region" ;
#     ns1:introductionMedia "[[Pokkén Tournament]]" ;
#     ns1:japaneseName "フェルム" ;
#     ns1:name "Ferrum" ;
#     ns1:romanizedJapaneseName "Ferrum" .
#
# ns1:Fiore a ns1:Region ;
#     ns1:colorTemplate "Ranger" ;
#     ns1:image "Fiore alt.png" ;
#     ns1:introductionMedia "{{vg|Pokémon Ranger}}" ;
#     ns1:japaneseName "フィオレ" ;
#     ns1:name "Fiore" ;
#     ns1:romanizedJapaneseName "Fiore" .
#
# ns1:Galar a ns1:Region ;
#     ns1:colorTemplate "galar" ;
#     ns1:image "Galar artwork.png" ;
#     ns1:imageCaption "Artwork of the Galar region from {{g|Sword and Shield}}" ;
#     ns1:imageSize "300" ;
#     ns1:japaneseName "ガラル" ;
#     ns1:name "Galar" ;
#     ns1:romanizedJapaneseName "Galar" .
#
# ns1:Hisui a ns1:Region ;
#     ns1:colorTemplate "Hisui" ;
#     ns1:image "Legends Arceus Hisui.png" ;
#     ns1:imageCaption "Artwork of the Hisui region from {{g|Legends: Arceus}}" ;
#     ns1:imageSize "300px" ;
#     ns1:japaneseName "ヒスイ" ;
#     ns1:name "Hisui" ;
#     ns1:romanizedJapaneseName "Hisui" .
#
# ns1:Hoenn a ns1:Region ;
#     ns1:colorTemplate "Hoenn" ;
#     ns1:image "Hoenn ORAS.png" ;
#     ns1:imageCaption "Artwork of the Hoenn region from<br>[[Pokémon Omega Ruby and Alpha Sapphire]] illustrated by [[kawayoo]]" ;
#     ns1:imageSize "300px" ;
#     ns1:introductionMedia "{{game|Ruby and Sapphire|s}}" ;
#     ns1:japaneseName "ホウエン" ;
#     ns1:name "Hoenn" ;
#     ns1:romanizedJapaneseName "Hoenn" .
#
# ns1:Isle_of_Armor a ns1:Region ;
#     ns1:colorTemplate "Isle of Armor" ;
#     ns1:image "Isle of Armor artwork.png" ;
#     ns1:imageCaption "Artwork of the Isle of Armor from {{g|Sword and Shield}}" ;
#     ns1:imageSize "300" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ヨロイ" ;
#     ns1:name "Isle of Armor" ;
#     ns1:romanizedJapaneseName "Armor Island" .
#
# ns1:Johto a ns1:Region ;
#     ns1:colorTemplate "Johto" ;
#     ns1:image "JohtoMap.png" ;
#     ns1:imageCaption "Artwork of the Johto region from [[Generation IV]]" ;
#     ns1:imageSize "300px" ;
#     ns1:introductionMedia "{{game|Gold and Silver|s}}" ;
#     ns1:japaneseName "ジョウト" ;
#     ns1:name "Johto" ;
#     ns1:romanizedJapaneseName "Johto" .
#
# ns1:Kalos a ns1:Region ;
#     ns1:colorTemplate "kalos" ;
#     ns1:image "Kalos alt.png" ;
#     ns1:imageCaption "Artwork of the Kalos region from {{g|X and Y}}" ;
#     ns1:imageSize "300" ;
#     ns1:japaneseName "カロス" ;
#     ns1:name "Kalos" ;
#     ns1:romanizedJapaneseName "Kalos" .
#
# ns1:Kanto a ns1:Region ;
#     ns1:colorTemplate "kanto" ;
#     ns1:image "PE Kanto Map.png" ;
#     ns1:imageCaption "Artwork of Kanto from [[Generation VII]] by [[kawayoo]]<ref name=\"gen7-art\">[https://twitter.com/PK__SAYONARA/status/1643013730966581248 Tweet by @PK__SAYONARA (reposted by @kawayoo)]</ref>" ;
#     ns1:imageSize "300px" ;
#     ns1:introductionMedia "{{2v2|Red|Green}}" ;
#     ns1:japaneseName "カントー" ;
#     ns1:name "Kanto" ;
#     ns1:romanizedJapaneseName "Kanto" .
#
# ns1:Kitakami a ns1:Region ;
#     ns1:colorTemplate "Kitakami" ;
#     ns1:image "Mossui Town SV Concept Art.png" ;
#     ns1:imageCaption "Concept art" ;
#     ns1:imageSize "300" ;
#     ns1:introductionMedia "[[Pokémon Scarlet and Violet]] ([[The Teal Mask]])" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "キタカミ" ;
#     ns1:name "Kitakami" ;
#     ns1:professor "None" ;
#     ns1:romanizedJapaneseName "Kitakami" ;
#     ns1:villainousOrganization "[[Loyal Three|The Loyal Three]]<br>{{ga|Pecharunt}}" .
#
# ns1:Lental a ns1:Region ;
#     ns1:colorTemplate "electric" ;
#     ns1:generation "{{gen|VIII}}" ;
#     ns1:image "Lental.png" ;
#     ns1:introductionMedia "[[New Pokémon Snap]]" ;
#     ns1:japaneseName "レンティル" ;
#     ns1:name "Lental" ;
#     ns1:professor "[[Professor Mirror]]" ;
#     ns1:romanizedJapaneseName "Lentil" ;
#     ns1:villainousOrganization "N/A" .
#
# ns1:Mintale_Town a ns1:Region ;
#     ns1:colorTemplate "Grass" ;
#     ns1:generation "{{Gen|III}}" ;
#     ns1:image "Mintale Town.png" ;
#     ns1:imageCaption "Mintale Town" ;
#     ns1:introductionMedia "[[Pokémon Channel]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ハツカタウン" ;
#     ns1:name "Mintale Town" ;
#     ns1:professor "[[Professor Oak]]" ;
#     ns1:romanizedJapaneseName "Hatsuka Town" .
#
# ns1:Oblivia a ns1:Region ;
#     ns1:colorTemplate "GS" ;
#     ns1:image "Oblivia artwork.png" ;
#     ns1:introductionMedia "[[Pokémon Ranger: Guardian Signs]]" ;
#     ns1:japaneseName "オブリビア" ;
#     ns1:name "Oblivia" ;
#     ns1:professor "[[Professor Hastings]]" ;
#     ns1:romanizedJapaneseName "Oblivia" ;
#     ns1:villainousOrganization "[[Pokémon Pinchers]]" .
#
# ns1:Orange_Islands a ns1:Region ;
#     ns1:colorTemplate "orange" ;
#     ns1:image "Orange.jpg" ;
#     ns1:imageCaption "A complete map of the Orange Islands in relation to [[Kanto]] and [[Johto]]" ;
#     ns1:introductionMedia "{{aniseries|PTS}}" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "オレンジ諸島" ;
#     ns1:name "Orange Islands" ;
#     ns1:romanizedJapaneseName "Orange Islands" .
#
# ns1:Orre a ns1:Region ;
#     ns1:colorTemplate "Orre" ;
#     ns1:image "Orre.png" ;
#     ns1:imageCaption "In-game map of Orre in {{g|XD: Gale of Darkness}}" ;
#     ns1:japaneseName "オーレ" ;
#     ns1:name "Orre" ;
#     ns1:romanizedJapaneseName "Ōre" .
#
# ns1:Paldea a ns1:Region ;
#     ns1:colorTemplate "paldea" ;
#     ns1:image "Paldea artwork.png" ;
#     ns1:imageCaption "Artwork of the Paldea region from {{g|Scarlet and Violet}}" ;
#     ns1:imageSize "300" ;
#     ns1:japaneseName "パルデア" ;
#     ns1:name "Paldea" ;
#     ns1:romanizedJapaneseName "Paldea" .
#
# ns1:Pasio a ns1:Region ;
#     ns1:colorTemplate "masters" ;
#     ns1:generation "{{gen|VII}}" ;
#     ns1:image "Pasio.png" ;
#     ns1:imageSize "150" ;
#     ns1:introductionMedia "[[Pokémon Masters EX]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "パシオ" ;
#     ns1:league "[[Pokémon Masters League]]" ;
#     ns1:leagueLocation "[[Centra City]]" ;
#     ns1:name "Pasio" ;
#     ns1:professor "[[Professor Bellis]]" ;
#     ns1:romanizedJapaneseName "Pasio" ;
#     ns1:villainousOrganization "[[Team Break]]" .
#
# ns1:PokéPark a ns1:Region ;
#     ns1:colorTemplate "PokéPark" ;
#     ns1:image "PokePark Wii Map.png" ;
#     ns1:imageCaption "Map of the PokéPark in PokéPark Wii" ;
#     ns1:introductionMedia "[[PokéPark Wii: Pikachu's Adventure]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ポケパーク" ;
#     ns1:name "PokéPark" ;
#     ns1:romanizedJapaneseName "Poké Park" ;
#     ns1:villainousOrganization "{{p|Darkrai}}" .
#
# ns1:Pokémon_Island a ns1:Region ;
#     ns1:colorTemplate "Psychic" ;
#     ns1:generation "{{Gen|I}}" ;
#     ns1:image "Snap Pokémon Island.png" ;
#     ns1:imageCaption "Pokémon Island artwork" ;
#     ns1:introductionMedia "[[Pokémon Snap]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ポケモンアイランド" ;
#     ns1:name "Pokémon Island" ;
#     ns1:professor "[[Professor Oak]]" ;
#     ns1:romanizedJapaneseName "Pokémon Island" .
#
# ns1:Pokémon_world a ns1:Region ;
#     ns1:colorTemplate "MD" ;
#     ns1:image "Mystery Dungeon World PSMD.png" ;
#     ns1:imageCaption "Map of the Pokémon world from [[Pokémon Super Mystery Dungeon]]" ;
#     ns1:introductionMedia "[[Pokémon Mystery Dungeon: Red Rescue Team and Blue Rescue Team]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ポケモン世界" ;
#     ns1:name "Pokémon world" ;
#     ns1:romanizedJapaneseName "Pokémon world" ;
#     ns1:villainousOrganization "[[Team Meanies]]<br>{{mdc|Team Skull}}" .
#
# ns1:Pokétopia a ns1:Region ;
#     ns1:colorTemplate "Gold" ;
#     ns1:generation "{{gen|IV}}" ;
#     ns1:image "Poketopia.png" ;
#     ns1:imageCaption "Pokétopia" ;
#     ns1:imageSize "300" ;
#     ns1:introductionMedia "[[Pokémon Battle Revolution]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ポケトピア" ;
#     ns1:name "Pokétopia" ;
#     ns1:romanizedJapaneseName "Pokétopia" .
#
# ns1:Ransei a ns1:Region ;
#     ns1:colorTemplate "Unova" ;
#     ns1:games "[[Pokémon Conquest]]" ;
#     ns1:generation "[[Generation V]]" ;
#     ns1:image "Ransei.png" ;
#     ns1:imageCaption "The Ransei region" ;
#     ns1:introductionMedia "[[Pokémon Conquest]]" ;
#     ns1:japaneseName "ランセ" ;
#     ns1:name "Ransei" ;
#     ns1:romanizedJapaneseName "Ranse" ;
#     ns1:villainousOrganization "[[Nobunaga]]'s Army" .
#
# ns1:Ryme_City a ns1:Region ;
#     ns1:colorTemplate "Electric" ;
#     ns1:image "Ryme City artwork.png" ;
#     ns1:imageCaption "Artwork of Ryme City from {{OBP|Detective Pikachu|video game}}" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ライムシティ" ;
#     ns1:name "Ryme City" ;
#     ns1:romanizedJapaneseName "Ryme City" .
#
# ns1:Sevii_Islands a ns1:Region ;
#     ns1:colorTemplate "Sevii" ;
#     ns1:image "Sevii Islands.png" ;
#     ns1:imageCaption "Artwork of the Sevii Islands from FireRed and LeafGreen" ;
#     ns1:introductionMedia "{{game|FireRed and LeafGreen|s}}" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ナナシマ" ;
#     ns1:name "Sevii Islands" ;
#     ns1:romanizedJapaneseName "Nanashima" .
#
# ns1:Sinnoh a ns1:Region ;
#     ns1:colorTemplate "Sinnoh" ;
#     ns1:image "Sinnoh BDSP artwork.png" ;
#     ns1:imageCaption "Artwork of the Sinnoh region from {{g|Brilliant Diamond and Shining Pearl}}" ;
#     ns1:imageSize "300px" ;
#     ns1:japaneseName "シンオウ" ;
#     ns1:name "Sinnoh" ;
#     ns1:romanizedJapaneseName "Sinnoh" .
#
# ns1:Trading_Card_Game_Islands a ns1:Region ;
#     ns1:colorTemplate "tcg trainer" ;
#     ns1:image "TCG Island artwork.jpg" ;
#     ns1:imageSize "200" ;
#     ns1:introductionMedia "{{vg|Pokémon Trading Card Game}}" ;
#     ns1:isRegion "no" ;
#     ns1:name "Trading Card Game Islands" .
#
# ns1:Tumblecube_Island a ns1:Region ;
#     ns1:colorTemplate "Orange" ;
#     ns1:generation "{{gen|VII}}" ;
#     ns1:image "Tumblecube Island.png" ;
#     ns1:imageSize "300" ;
#     ns1:introductionMedia "[[Pokémon Quest]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "カクコロ島" ;
#     ns1:name "Tumblecube Island" ;
#     ns1:romanizedJapaneseName "Kakukoro Island" .
#
# ns1:Unova a ns1:Region ;
#     ns1:colorTemplate "Unova" ;
#     ns1:image "Unova B2W2 alt.png" ;
#     ns1:imageCaption "Artwork of the Unova region from {{2v2|Black|White|2}}" ;
#     ns1:imageSize "300" ;
#     ns1:japaneseName "イッシュ" ;
#     ns1:name "Unova" ;
#     ns1:romanizedJapaneseName "Issyu" .
#
# ns1:White_City a ns1:Region ;
#     ns1:colorTemplate "White" ;
#     ns1:generation "{{Gen|II}}" ;
#     ns1:image "White City.png" ;
#     ns1:imageCaption "White City in Pokémon Stadium 2" ;
#     ns1:introductionMedia "[[Pokémon Stadium 2]]" ;
#     ns1:isRegion "no" ;
#     ns1:japaneseName "ホワイトシティ" ;
#     ns1:name "White City" ;
#     ns1:professor "[[Professor Oak]]" ;
#     ns1:romanizedJapaneseName "White City" ;
#     ns1:villainousOrganization "[[Team Rocket]]" .

# %%
with open('character_list.txt', 'r') as file:
    character_list = [line.strip() for line in file]

print(character_list)
# Out:
# ['Tracey Sketchit', 'Max', 'Misty', 'Steven Stone', 'Norman', 'Ritchie', 'Giovanni', 'Erika', 'Wes', 'Red (game)', 'Jessie', 'James', 'Lt. Surge', 'Sabrina', 'Blaine', 'Lorelei', 'Lance', 'Nurse Joy', 'Name Rater', 'Todd Snap', 'Leaf (game)', 'Ethan (game)', 'Kris (game)', 'May (game)', 'Anabel', 'Peanut', 'Michael', 'Solana', 'Fantina', 'Lunick', 'Dawn (game)', 'Mark (TCG GB)', 'Mint (TCG GB)', 'Lucy Fleetfoot', 'Mai', 'Marnie', 'PokÃ©mon Center lady', 'Kellyn', 'Kate (Ranger)', 'Koga', 'Ash Ketchum', 'Brock', 'Kanata (CCP)', 'Primo', 'Cynthia', 'Lyra (game)', 'May (anime)', 'Carob', 'Day-Care Couple', 'Dawn (anime)', 'Ben (Ranger)', 'Summer (Ranger)', 'Misty (anime)', 'Brock (anime)', 'Professor Juniper', 'Hilda (game)', 'Hilbert (game)', 'Cheren', 'Bianca', 'N', 'Fennel', 'Iris (anime)', 'Cilan', 'Lenora', 'Cress', 'Chili', 'Ghetsis', 'Iris', 'Clay', 'Drayden', 'Shadow Triad', 'Amanita', 'Giallo', 'Cedric Juniper', 'Hawes', 'Ingo', 'Emmet', 'Charles', 'Anthea and Concordia', 'Gorm', 'Bronius', 'Zinzolin', 'Rood', 'Ryoku', 'Caretaker', "Bianca's father", 'Hop', 'Colress', 'Rosa (game)', 'Hugh', 'Nate (game)', 'Professor Burnet', 'Benga', 'Curtis', 'Yancy', 'Pop Roxie', 'Viola', 'Alexa', 'Shauna', 'Tierno', 'Trevor', 'Calem (game)', 'Serena (game)', 'Clemont', 'Professor Sycamore', 'Grant', 'Korrina', 'Diantha', 'Bonnie', 'Celosia', 'Mable', 'Bryony', 'Aliana', 'Xerosic', 'Ramos', 'Valerie', 'Olympia', 'Wulfric', 'Malva', 'Wikstrom', 'Siebold', 'Drasna', 'Emma', 'Lysandre', 'AZ', 'Grace (Kalos)', 'Nita', 'Evelyn', 'Dana', 'Morgan', 'Gurkinn', 'Cassius', 'Sina', 'Dexio', 'Mr. Bonding', 'Phil the Photo Guy', 'Phil', 'Inver', 'Alain', 'Aarune', 'Lisia', 'Zinnia', 'Chaz (game)', 'Amelia', 'Lillie', 'Hau', 'Professor Kukui', 'Hala', 'Elio (game)', 'Selene (game)', 'Professor Willow', 'Candela', 'Lana', 'Mallow', 'Sophocles', 'Kiawe', 'Plumeria', 'Guzma', 'Lusamine', 'Faba', 'Wicke', 'Gladion', 'Samson Oak', 'Olivia', 'Ilima', 'Mohn', 'Molayne', 'Kahili', 'Ryuki', 'Acerola', 'Nanu', 'Hapu', 'Mina', 'Harper and Sarah', "Hugh's sister", 'Dulse', 'Zossie', 'Soliera', 'Phyco', 'Shin Kyougi', 'Makoto Kyougi', 'Trace (game)', 'Elaine (game)', 'Chase (game)', 'Tim Goodman', 'Spark (GO)', 'Blanche', 'Professor Magnolia', 'Leon', 'Sonia', 'Milo', 'Nessa', 'Victor (game)', 'Gloria (game)', 'Bea', 'Allister', 'Rose', 'Oleana', 'Bede', 'Goh', 'Cliff (GO)', 'Arlo', 'Sierra', 'Green (game)', 'Kabu', 'Opal', 'Melony', 'Gordie', 'Piers', 'Raihan', 'Ball Guy', 'Shielbert', 'Sordward', 'Digging Duo', 'Watt Trader', 'Cara Liss', 'Avery', 'Klara', 'Mustard', 'Jack (Galar)', 'Grand Oak', 'PokÃ© Boy', 'Leon (anime)', 'Cynthia (anime)', 'Peony', 'Honey (Galar)', 'Hyde', 'Leah', 'Scottie', 'Bettie', 'Peonia', 'Cyndy', 'Nate (Battle Revolution)', 'Professor Mirror', 'Rita', 'Rei (game)', 'Akari (game)', 'Giovanni (GO)', 'Professor Laventon', 'Kamado', 'Cyllene', 'Lian', 'Iscan', 'Arezu', 'Adaman', 'Irida', 'Ginter', 'Volo', 'Calaba', 'Palina', 'Melli', 'Sabi', 'Gaeric', 'Zisu', 'Pesselle', 'Tao Hua', 'Sanqua', 'Colza', 'Beni', 'Charm (Hisui)', 'Clover', 'Coin (Hisui)', 'Cogita', 'Choy', 'Anthe', 'Rye', 'Tuli', 'Lance (anime)', 'Professor Phorus', 'Erbie', 'Zirco', 'Nemona', 'Professor Sada', 'Professor Turo', 'Rhi', 'Steven Stone (anime)', 'Grusha', 'Arven', 'Clavell', 'Jacq', 'Penny', 'Florian (game)', 'Juliana (game)', 'Brassius', 'Mela', 'Geeta', 'Iono', 'Dendra', 'Miriam', 'Raifort', 'Saguaro', 'Salvatore', 'Tyme', 'Atticus', 'Eri', 'Giacomo', 'Ortega', 'Larry', 'Katy', 'Kofu', 'Ryme', 'Tulip', 'Rika', 'Poppy', 'Hassel', 'Liko', 'Roy', 'Friede', 'Haru', 'Kieran', 'Carmine', 'Professor Neroli', 'Orla', 'Murdock', 'Mollie', 'Ludlow', 'Amethio', 'Onia', 'Zirc', 'Dot', 'Ann', 'Diana', "Roy's grandfather", 'Lucca', 'Alex', 'Hamber', 'Gibeon', 'Nemona (anime)', 'Spinel', 'Lacey', 'Cyrano', 'Lucius', 'Chalce', 'Coral', 'Sidian', 'Briar', 'Perrin', 'Drayton', 'Amarys', 'Ohara', 'Aliquis', 'Crispin', 'Ava', 'Hohma', 'Joshua (Path to the Peak)', 'Celestine', 'He ...

# %%
intial_character_graph = Graph()
for character in character_list:
    try:
        # Step 1: Fetch the page text
        result1 = bulbabot.page_text(title=character)
        
        # Step 2: Extract the infobox
        result2 = extract_character_infobox(result1)
        
        # Step 3: Parse the infobox
        result3 = parse_infobox(result2)
        
        # Step 4: Map the parsed infobox to RDF
        final_character_graph = map_character_infobox_to_rdf(intial_character_graph, result3)
        
        # Log or handle the final result (optional)
        print(f"Successfully processed {character}")
    except Exception as e:
        # Handle any errors that occur in the pipeline
        print(f"Error processing {character}: {e}")
# Out:
# Successfully processed Tracey Sketchit
# Successfully processed Max
# Successfully processed Misty
# Successfully processed Steven Stone
# Successfully processed Norman
# Successfully processed Ritchie
# Successfully processed Giovanni
# Successfully processed Erika
# Successfully processed Wes
# Successfully processed Red (game)
# Successfully processed Jessie
# Successfully processed James
# Successfully processed Lt. Surge
# Successfully processed Sabrina
# Successfully processed Blaine
# Successfully processed Lorelei
# Successfully processed Lance
# Successfully processed Nurse Joy
# Successfully processed Name Rater
# Successfully processed Todd Snap
# Successfully processed Leaf (game)
# Successfully processed Ethan (game)
# Successfully processed Kris (game)
# Successfully processed May (game)
# Successfully processed Anabel
# Successfully processed Peanut
# Successfully processed Michael
# Successfully processed Solana
# Successfully processed Fantina
# Successfully processed Lunick
# Successfully processed Dawn (game)
# Successfully processed Mark (TCG GB)
# Successfully processed Mint (TCG GB)
# Successfully processed Lucy Fleetfoot
# Successfully processed Mai
# Successfully processed Marnie
# Error processing PokÃ©mon Center lady: 'NoneType' object has no attribute 'split'
# Successfully processed Kellyn
# Successfully processed Kate (Ranger)
# Successfully processed Koga
# Successfully processed Ash Ketchum
# Successfully processed Brock
# Successfully processed Kanata (CCP)
# Successfully processed Primo
# Successfully processed Cynthia
# Successfully processed Lyra (game)
# Successfully processed May (anime)
# Successfully processed Carob
# Successfully processed Day-Care Couple
# Successfully processed Dawn (anime)
# Successfully processed Ben (Ranger)
# Successfully processed Summer (Ranger)
# Successfully processed Misty (anime)
# Successfully processed Brock (anime)
# Successfully processed Professor Juniper
# Successfully processed Hilda (game)
# Successfully processed Hilbert (game)
# Successfully processed Cheren
# Successfully processed Bianca
# Successfully processed N
# Successfully processed Fennel
# Successfully processed Iris (anime)
# Successfully processed Cilan
# Successfully processed Lenora
# Successfully processed Cress
# Successfully processed Chili
# Successfully processed Ghetsis
# Successfully processed Iris
# Successfully processed Clay
# Successfully processed Drayden
# Successfully processed Shadow Triad
# Successfully processed Amanita
# Successfully processed Giallo
# Successfully processed Cedric Juniper
# Successfully processed Hawes
# Successfully processed Ingo
# Successfully processed Emmet
# Successfully processed Charles
# Successfully processed Anthea and Concordia
# Successfully processed Gorm
# Successfully processed Bronius
# Successfully processed Zinzolin
# Successfully processed Rood
# Successfully processed Ryoku
# Successfully processed Caretaker
# Successfully processed Bianca's father
# Successfully processed Hop
# Successfully processed Colress
# Successfully processed Rosa (game)
# Successfully processed Hugh
# Successfully processed Nate (game)
# Successfully processed Professor Burnet
# Successfully processed Benga
# Successfully processed Curtis
# Successfully processed Yancy
# Successfully processed Pop Roxie
# Successfully processed Viola
# Successfully processed Alexa
# Successfully processed Shauna
# Successfully processed Tierno
# Successfully processed Trevor
# Successfully processed Calem (game)
# Successfully processed Serena (game)
# Successfully processed Clemont
# Successfully processed Professor Sycamore
# Successfully processed Grant
# Successfully processed Korrina
# Successfully processed Diantha
# Successfully processed Bonnie
# Successfully processed Celosia
# Successfully processed Mable
# Successfully processed Bryony
# Successfully processed Aliana
# Successfully processed Xerosic
# Successfully processed Ramos
# Successfully processed Valerie
# Successfully processed Olympia
# Successfully processed Wulfric
# Successfully processed Malva
# Successfully processed Wikstrom
# Successfully processed Siebold
# Successfully processed Drasna
# Successfully processed Emma
# Successfully processed Lysandre
# Successfully processed AZ
# Successfully processed Grace (Kalos)
# Successfully processed Nita
# Successfully processed Evelyn
# Successfully processed Dana
# Successfully processed Morgan
# Successfully processed Gurkinn
# Successfully processed Cassius
# Successfully processed Sina
# Successfully processed Dexio
# Successfully processed Mr. Bonding
# Successfully processed Phil the Photo Guy
# Successfully processed Phil
# Successfully processed Inver
# Successfully processed Alain
# Successfully processed Aarune
# Successfully processed Lisia
# Successfully processed Zinnia
# Successfully processed Chaz (game)
# Successfully processed Amelia
# Successfully processed Lillie
# Successfully processed Hau
# Successfully processed Professor Kukui
# Successfully processed Hala
# Successfully processed Elio (game)
# Successfully processed Selene (game)
# Successfully processed Professor Willow
# Successfully processed Candela
# Successfully processed Lana
# Successfully processed Mallow
# Successfully processed Sophocles
# Successfully processed Kiawe
# Successfully processed Plumeria
# Successfully processed Guzma
# Successfully processed Lusamine
# Successfully processed Faba
# Successfully processed Wicke
# Successfully processed Gladion
# Successfully processed Samson Oak
# Successfully processed Olivia
# Successfully processed Ilima
# Successfully processed Mohn
# Successfully processed Molayne
# Successfully processed Kahili
# Successfully processed Ryuki
# Successfully processed Acerola
# Successfully processed Nanu
# Successfully processed Hapu
# Successfully processed Mina
# Successfully processed Harper and Sarah
# Successfully processed Hugh's sister
# Successfully processed Dulse
# Successfully processed Zossie
# Successfully processed Soliera
# Successfully processed Phyco
# Successfully processed Shin Kyougi
# Successfully processed Makoto Kyougi
# Successfully processed Trace (game)
# Successfully processed Elaine (game)
# Successfully processed Chase (game)
# Successfully processed Tim Goodman
# Successfully processed Spark (GO)
# Successfully processed Blanche
# Successfully processed Professor Magnolia
# Successfully processed Leon
# Successfully processed Sonia
# Successfully processed Milo
# Successfully processed Nessa
# Successfully processed Victor (game)
# Successfully processed Gloria (game)
# Successfully processed Bea
# Successfully processed Allister
# Successfully processed Rose
# Successfully processed Oleana
# Successfully processed Bede
# Successfully processed Goh
# Successfully processed Cliff (GO)
# Successfully processed Arlo
# Successfully processed Sierra
# Successfully processed Green (game)
# Successfully processed Kabu
# Successfully processed Opal
# Successfully processed Melony
# Successfully processed Gordie
# Successfully processed Piers
# Successfully processed Raihan
# Successfully processed Ball Guy
# Successfully processed Shielbert
# Successfully processed Sordward
# Successfully processed Digging Duo
# Successfully processed Watt Trader
# Successfully processed Cara Liss
# Successfully processed Avery
# Successfully processed Klara
# Successfully processed Mustard
# Successfully processed Jack (Galar)
# Successfully processed Grand Oak
# Error processing PokÃ© Boy: 'NoneType' object has no attribute 'split'
# Successfully processed Leon (anime)
# Successfully processed Cynthia (anime)
# Successfully processed Peony
# Successfully processed Honey (Galar)
# Successfully processed Hyde
# Successfully processed Leah
# Successfully processed Scottie
# Successfully processed Bettie
# Successfully processed Peonia
# Successfully processed Cyndy
# Successfully processed Nate (Battle Revolution)
# Successfully processed Professor Mirror
# Successfully processed Rita
# Successfully processed Rei (game)
# Successfully processed Akari (game)
# Successfully processed Giovanni (GO)
# Successfully processed Professor Laventon
# Successfully processed Kamado
# Successfully processed Cyllene
# Successfully processed Lian
# Successfully processed Iscan
# Successfully processed Arezu
# Successfully processed Adaman
# Successfully processed Irida
# Successfully processed Ginter
# Successfully processed Volo
# Successfully processed Calaba
# Successfully processed Palina
# Successfully processed Melli
# Successfully processed Sabi
# Successfully processed Gaeric
# Successfully processed Zisu
# Successfully processed Pesselle
# Successfully processed Tao Hua
# Successfully processed Sanqua
# Successfully processed Colza
# Successfully processed Beni
# Successfully processed Charm (Hisui)
# Successfully processed Clover
# Successfully processed Coin (Hisui)
# Successfully processed Cogita
# Successfully processed Choy
# Successfully processed Anthe
# Successfully processed Rye
# Successfully processed Tuli
# Successfully processed Lance (anime)
# Successfully processed Professor Phorus
# Successfully processed Erbie
# Successfully processed Zirco
# Successfully processed Nemona
# Successfully processed Professor Sada
# Successfully processed Professor Turo
# Successfully processed Rhi
# Successfully processed Steven Stone (anime)
# Successfully processed Grusha
# Successfully processed Arven
# Successfully processed Clavell
# Successfully processed Jacq
# Successfully processed Penny
# Successfully processed Florian (game)
# Successfully processed Juliana (game)
# Successfully processed Brassius
# Successfully processed Mela
# Successfully processed Geeta
# Successfully processed Iono
# Successfully processed Dendra
# Successfully processed Miriam
# Successfully processed Raifort
# Successfully processed Saguaro
# Successfully processed Salvatore
# Successfully processed Tyme
# Successfully processed Atticus
# Successfully processed Eri
# Successfully processed Giacomo
# Successfully processed Ortega
# Successfully processed Larry
# Successfully processed Katy
# Successfully processed Kofu
# Successfully processed Ryme
# Successfully processed Tulip
# Successfully processed Rika
# Successfully processed Poppy
# Successfully processed Hassel
# Successfully processed Liko
# Successfully processed Roy
# Successfully processed Friede
# Successfully processed Haru
# Successfully processed Kieran
# Successfully processed Carmine
# Successfully processed Professor Neroli
# Successfully processed Orla
# Successfully processed Murdock
# Successfully processed Mollie
# Successfully processed Ludlow
# Successfully processed Amethio
# Successfully processed Onia
# Successfully processed Zirc
# Successfully processed Dot
# Successfully processed Ann
# Successfully processed Diana
# Successfully processed Roy's grandfather
# Successfully processed Lucca
# Successfully processed Alex
# Successfully processed Hamber
# Successfully processed Gibeon
# Successfully processed Nemona (anime)
# Successfully processed Spinel
# Successfully processed Lacey
# Successfully processed Cyrano
# Successfully processed Lucius
# Successfully processed Chalce
# Successfully processed Coral
# Successfully processed Sidian
# Successfully processed Briar
# Successfully processed Perrin
# Successfully processed Drayton
# Successfully processed Amarys
# Successfully processed Ohara
# Successfully processed Aliquis
# Successfully processed Crispin
# Successfully processed Ava
# Successfully processed Hohma
# Successfully processed Joshua (Path to the Peak)
# Successfully processed Celestine
# Successfully processed Heath
# Successfully processed Violet (Adventures)
# Successfully processed Edgar Troy
# Successfully processed Captain Vince
# Successfully processed Vessa
# Successfully processed Glitterati
# Successfully processed Yukito and Hideko
# Successfully processed Ingredients Seller
# Successfully processed Watanabe
# Successfully processed Tyler
# Successfully processed Alisa
# Successfully processed Carmen
# Successfully processed Harrington
# Successfully processed Mateo
# Successfully processed Snacksworth
# Successfully processed Synclaire
# Successfully processed Scarlet (Adventures)
# Successfully processed Nao
# Successfully processed Liko's homeroom teacher
# Successfully processed Franka
# Successfully processed Ress
# Successfully processed MoBee
# Successfully processed Iono (anime)
# Successfully processed Rai
# Successfully processed Luka (HZ053)
# Successfully processed Aeos Emporium shopkeeper
# Successfully processed Crave
# Error processing Master RosÃ©: 'NoneType' object has no attribute 'split'
# Successfully processed Yuji (Duel)
# Successfully processed Brenda
# Successfully processed Tamarind
# Successfully processed Nadya
# Successfully processed Don Roger
# Successfully processed Joe (Duel)
# Successfully processed Karolin
# Successfully processed Number 7
# Successfully processed Luca
# Successfully processed Sharon (Duel)
# Successfully processed Carlo
# Successfully processed Another
# Successfully processed Tia
# Successfully processed Marabelle
# Successfully processed Chalmers
# Successfully processed Charles Merloch
# Successfully processed Will Butler
# Successfully processed Jessica Miller
# Successfully processed Youssef
# Successfully processed Shizune
# Successfully processed MC Sledge
# Successfully processed Rystal

# %%
# Save or print the created graph
print(final_character_graph.serialize(format="turtle"))
with open("character_graph.ttl", "w", encoding="utf-8") as file:
    file.write(final_character_graph.serialize(format="turtle"))
# Out:
# @prefix ns1: <http://example.org/character/> .
#
# ns1:Aliquis a ns1:Character ;
#     ns1:borderColor "D87257" ;
#     ns1:color "4B5293" ;
#     ns1:coreColor "F1CB90" ;
#     ns1:eyeColor "Blue" ;
#     ns1:gender "Male" ;
#     ns1:hairColor "Dark blue (Yellow highlights)" ;
#     ns1:hometown "Unknown" ;
#     ns1:image "Aliquis PW.png" ;
#     ns1:imageCaption "Aliquis" ;
#     ns1:imageSize "220px" ;
#     ns1:japaneseName "アリキス" ;
#     ns1:name "Aliquis" ;
#     ns1:region "[[Paldea]]" ;
#     ns1:relatives "[[Aliquis's brother|Unnamed older brother]]<ref>https://www.pokemon.co.jp/ex/sv/ja/sp_anime/</ref>" ;
#     ns1:romanizedJapaneseName "Aliquis" ;
#     ns1:textColor "FFF" .
#
# ns1:Anabel a ns1:Character ;
#     ns1:borderColor "4a474a" ;
#     ns1:color "c0b2dd" ;
#     ns1:coreColor "e5cff9" ;
#     ns1:gender "Female" ;
#     ns1:height "5'5\" (1.65 m){{sup/7|SM}}" ;
#     ns1:image "Anabel SM concept art.png" ;
#     ns1:imageCaption "Concept art from [[Pokémon Sun and Moon]]" ;
#     ns1:imageSize "200px" ;
#     ns1:japaneseName "リラ" ;
#     ns1:name "Anabel" ;
#     ns1:romanizedJapaneseName "Lila" .
#
# ns1:Anthea_and_Concordia a ns1:Character ;
#     ns1:borderColor "f1c8b4" ;
#     ns1:color "fffeba" ;
#     ns1:coreColor "f1c8b4" ;
#     ns1:image "Black 2 White 2 Anthea and Concordia.png" ;
#     ns1:imageCaption "Concept art from {{2v2|Black|White|2}}" ;
#     ns1:imageSize "200px" ;
#     ns1:japaneseName "愛の女神と平和の女神" ;
#     ns1:name "Anthea and Concordia" ;
#     ns1:romanizedJapaneseName "<br />Goddess of Love and Goddess of Peace" .
#
# ns1:Diantha a ns1:Character ;
#     ns1:borderColor "BAC5D7" ;
#     ns1:color "F3F7FA" ;
#     ns1:coreColor "E8E48E" ;
#     ns1:image "XY Diantha.png" ;
#     ns1:imageCaption "Artwork from {{pkmn|X and Y}}" ;
#     ns1:imageSize "200px" ;
#     ns1:japaneseName "カルネ" ;
#     ns1:name "Diantha" ;
#     ns1:romanizedJapaneseName "Carne" .
#
# ns1:Giovanni a ns1:Character ;
#     ns1:borderColor "CC0000" ;
#     ns1:color "666" ;
#     ns1:coreColor "CCC" ;
#     ns1:image "GO Team GO Rocket Giovanni and legendary birds.png" ;
#     ns1:imageCaption "Promotional artwork from {{g|GO}}" ;
#     ns1:imageSize "360px" ;
#     ns1:japaneseName "サカキ" ;
#     ns1:name "Giovanni" ;
#     ns1:romanizedJapaneseName "Sakaki" ;
#     ns1:sloganLine "The Self-Proclaimed Strongest Trainer-->" ;
#     ns1:textColor "fff<!--" .
#
# ns1:Hohma a ns1:Character ;
#     ns1:borderColor "D46C50" ;
#     ns1:color "B88354" ;
#     ns1:coreColor "E49E7F" ;
#     ns1:eyeColor "Green" ;
#     ns1:gender "Male" ;
#     ns1:hairColor "Honey" ;
#     ns1:hometown "Unknown" ;
#     ns1:image "Hohma PW.png" ;
#     ns1:imageCaption "Hohma" ;
#     ns1:imageSize "220px" ;
#     ns1:japaneseName "ホーマ" ;
#     ns1:name "Hohma" ;
#     ns1:region "[[Paldea]]" ;
#     ns1:romanizedJapaneseName "Hohma" .
#
# ns1:James a ns1:Character ;
#     ns1:age "Unconfirmed<ref name=\"age\"/><!--Not confirmed in M02, see https://dogasu.bulbagarden.net/learn/rumor_guide/movie_02_reveals_rockets_age.html-->" ;
#     ns1:borderColor "C00" ;
#     ns1:color "666" ;
#     ns1:coreColor "CCC" ;
#     ns1:eyeColor "Green" ;
#     ns1:gender "Male" ;
#     ns1:hairColor "Periwinkle{{tt|*|Also said to be Lavender in the English Dub}}" ;
#     ns1:image "James JN.png" ;
#     ns1:imageCaption "James in ''[[Pokémon Journeys: The Series]]''" ;
#     ns1:imageSize "159px" ;
#     ns1:japaneseName "コジロウ" ;
#     ns1:name "James" ;
#     ns1:romanizedJapaneseName "Kojirō" ;
#     ns1:textColor "fff" .
#
# ns1:Jessie a ns1:Character ;
#     ns1:age "Unconfirmed<ref name=\"age\"/> <!--Not confirmed in M02, see https://dogasu.bulbagarden.net/learn/rumor_guide/movie_02_reveals_rockets_age.html-->" ;
#     ns1:borderColor "C00" ;
#     ns1:color "666" ;
#     ns1:coreColor "CCC" ;
#     ns1:eyeColor "Blue" ;
#     ns1:gender "Female" ;
#     ns1:hairColor "Dark Pink <small>([[EP002]]&ndash;[[EP080]])</small><br>Crimson <small>([[EP081]]&ndash;[[EP260]])</small><br>Magenta <small>([[EP261]]&ndash;present)</small>" ;
#     ns1:hometown "Unknown" ;
#     ns1:image "Jessie JN.png" ;
#     ns1:imageCaption "Jessie in ''[[Pokémon Journeys: The Series]]''" ;
#     ns1:imageSize "187px" ;
#     ns1:japaneseName "ムサシ" ;
#     ns1:name "Jessie" ;
#     ns1:region "[[Kanto]]" ;
#     ns1:relatives "[[Miyamoto]] (mother), [[James]] (husband, [[The Electric Tale of Pikachu|EToP]] only)" ;
#     ns1:romanizedJapaneseName "Musashi" ;
#     ns1:textColor "fff" .
#
# ns1:Kris a ns1:Character ;
#     ns1:borderColor "439ba7" ;
#     ns1:color "76c7d2" ;
#     ns1:coreColor "b6f0f8" ;
#     ns1:image "Crystal Kris.png" ;
#     ns1:imageCaption "Art from {{v2|Crystal}}" ;
#     ns1:imageSize "155px" ;
#     ns1:japaneseName "クリス" ;
#     ns1:name "Kris" ;
#     ns1:romanizedJapaneseName "Kris" .
#
# ns1:Leon a ns1:Character ;
#     ns1:borderColor "761724" ;
#     ns1:color "6C62A1" ;
#     ns1:coreColor "F7DD98" ;
#     ns1:eyeColor "Yellow" ;
#     ns1:gender "Male" ;
#     ns1:hairColor "Purple" ;
#     ns1:hometown "[[Postwick]]" ;
#     ns1:image "Leon anime JN.png",
#         "Sword Shield Leon.png" ;
#     ns1:imageCaption "Artwork from {{pkmn|Sword and Shield}}",
#         "Leon" ;
#     ns1:imageSize "250px" ;
#     ns1:japaneseName "ダンデ" ;
#     ns1:name "Leon" ;
#     ns1:region "[[Galar]]" ;
#     ns1:relatives "Mentioned parents<br>[[Hop]] (younger brother)" ;
#     ns1:romanizedJapaneseName "Dande" ;
#     ns1:textColor "fff" .
#
# ns1:Lysandre a ns1:Character ;
#     ns1:borderColor "ab3f26" ;
#     ns1:color "eb8b51" ;
#     ns1:coreColor "e36226" ;
#     ns1:japaneseName "{{tt|フラダリ|Furadari}}" ;
#     ns1:name "Lysandre" .
#
# ns1:Name_Rater a ns1:Character ;
#     ns1:borderColor "ADA1C9" ;
#     ns1:color "D5CFE3" ;
#     ns1:coreColor "E7E4ED" ;
#     ns1:japaneseName "{{tt|姓名判断師|せいめいはんだんし}}" ;
#     ns1:name "Name Rater" .
#
# ns1:Unknown a ns1:Character ;
#     ns1:borderColor "ab3f26",
#         "{{black color dark}}",
#         "{{blue color}}",
#         "{{red color}}",
#         "{{yellow color}}" ;
#     ns1:color "526D82",
#         "666",
#         "eb8b51",
#         "{{#switch: {{#expr: {{#time: U}}",
#         "{{Alola color}}",
#         "{{Bug color}}",
#         "{{Dark color}}",
#         "{{Fighting color}}",
#         "{{Fire color}}",
#         "{{GO color}}",
#         "{{GS color}}",
#         "{{Ghost color}}",
#         "{{Grass color}}",
#         "{{Green color}}",
#         "{{HOME color}}",
#         "{{Indigo Disk color light}}",
#         "{{Indigo Disk color}}",
#         "{{Isle of Armor color}}",
#         "{{Kalos color}}",
#         "{{Kitakami color}}",
#         "{{Let's Go Eevee color}}",
#         "{{Let's Go Pikachu color}}",
#         "{{Mineral egg color}}",
#         "{{Normal color}}",
#         "{{Omega Ruby color}}",
#         "{{Orange color}}",
#         "{{Paldea color}}",
#         "{{Pokémon color}}",
#         "{{Rock color}}",
#         "{{Scarlet color}}",
#         "{{SoA color}}",
#         "{{Steel color}}",
#         "{{Stellar color}}",
#         "{{TCG Ability color}}",
#         "{{TCG Poké-Body color light}}",
#         "{{TCG Poké-Power color}}",
#         "{{TCG Pokémon Tool color}}",
#         "{{Treasures color}}",
#         "{{Unknown color}}",
#         "{{Unova color}}",
#         "{{Water color}}",
#         "{{X color light}}",
#         "{{X color}}",
#         "{{XD color}}",
#         "{{Y color}}",
#         "{{alder color}}",
#         "{{alola color}}",
#         "{{beauty color}}",
#         "{{black 2 color}}",
#         "{{black color light}}",
#         "{{black color}}",
#         "{{blue color light}}",
#         "{{blue color}}",
#         "{{blueberry color}}",
#         "{{bronze color}}",
#         "{{bug color}}",
#         "{{bulba color}}",
#         "{{castle color}}",
#         "{{cleverness color light}}",
#         "{{colo color}}",
#         "{{contest color}}",
#         "{{cute color light}}",
#         "{{cute color}}",
#         "{{cuteness color}}",
#         "{{cynthia color}}",
#         "{{dark color light}}",
#         "{{dark color}}",
#         "{{diamond color dark}}",
#         "{{diamond color}}",
#         "{{dragon color}}",
#         "{{dream color}}",
#         "{{electric color}}",
#         "{{emerald color}}",
#         "{{fairy color}}",
#         "{{fairy egg color}}",
#         "{{fighting color}}",
#         "{{fire color light}}",
#         "{{fire color}}",
#         "{{flying color}}",
#         "{{galar color}}",
#         "{{ghost color light}}",
#         "{{ghost color}}",
#         "{{gold color}}",
#         "{{grass color}}",
#         "{{green color light}}",
#         "{{green color}}",
#         "{{grey color light}}",
#         "{{ground color}}",
#         "{{heartgold color light}}",
#         "{{hisui color}}",
#         "{{hoenn color}}",
#         "{{ice color}}",
#         "{{indigo color}}",
#         "{{kalos color}}",
#         "{{kitakami color}}",
#         "{{leafgreen color}}",
#         "{{legends arceus color}}",
#         "{{locationcolor/light|mountain}}",
#         "{{locationcolor/med|ruins}}",
#         "{{mail color}}",
#         "{{masters color}}",
#         "{{moon color}}",
#         "{{night color light}}",
#         "{{night color}}",
#         "{{normal color light}}",
#         "{{normal color}}",
#         "{{orange color}}",
#         "{{paldea color}}",
#         "{{pbr color}}",
#         "{{pearl color}}",
#         "{{poison color}}",
#         "{{power color}}",
#         "{{psychic color light}}",
#         "{{psychic color}}",
#         "{{ranger color}}",
#         "{{red color light}}",
#         "{{red color}}",
#         "{{rock color}}",
#         "{{ruby color}}",
#         "{{sapphire color}}",
#         "{{scarlet color}}",
#         "{{shield color}}",
#         "{{silver color}}",
#         "{{sinnoh color}}",
#         "{{slumbering color light}}",
#         "{{soulsilver color}}",
#         "{{spicy color}}",
#         "{{status color}}",
#         "{{steel color light}}",
#         "{{steel color}}",
#         "{{stellar color light}}",
#         "{{summer color}}",
#         "{{sun color}}",
#         "{{sweet color}}",
#         "{{sword color}}",
#         "{{tcg Supporter color}}",
#         "{{tcg fighting color}}",
#         "{{tcg grass color}}",
#         "{{tcg lightning color}}",
#         "{{tcg psychic color}}",
#         "{{tcg water color}}",
#         "{{unite color}}",
#         "{{unova color}}",
#         "{{violet color}}",
#         "{{water color light}}",
#         "{{water color}}",
#         "{{white 2 color}}",
#         "{{white color light}}",
#         "{{white color}}",
#         "{{x color}}",
#         "{{y color}}",
#         "{{yellow color}}" ;
#     ns1:coreColor "CCC",
#         "F1ECD7",
#         "{{grass color light}}",
#         "{{orange color light}}",
#         "{{poison color light}}",
#         "{{water color light}}",
#         "{{white color light}}" ;
#     ns1:textColor "fff" .

# %%
# Define namespaces
POKEMON = Namespace("http://example.org/pokemon/")
RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

# Initialize RDF graph
g = Graph()

# Add Pokémon URI
pokemon_uri = URIRef(POKEMON[properties.get("name", "Unknown").replace(" ", "_")])
g.add((pokemon_uri, RDF.type, POKEMON.Pokémon))

# Map properties to RDF triples
if "species" in properties:
    g.add((pokemon_uri, POKEMON.species, Literal(properties["species"])))

if "type1" in properties:
    g.add((pokemon_uri, POKEMON.type, Literal(properties["type1"])))

if "type2" in properties:
    g.add((pokemon_uri, POKEMON.type, Literal(properties["type2"])))

if "height-m" in properties:
    g.add((pokemon_uri, POKEMON.height, Literal(properties["height-m"])))

if "weight-kg" in properties:
    g.add((pokemon_uri, POKEMON.weight, Literal(properties["weight-kg"])))

# Serialize RDF to Turtle format
print(g.serialize(format="turtle"))

# %%
def map_infobox_to_rdf(properties):
    # Define RDF namespaces
    POKEMON = Namespace("http://example.org/pokemon/")
    RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

    # Initialize RDF graph
    g = Graph()

    # Add Pokémon URI
    pokemon_uri = URIRef(POKEMON[properties.get("name", "Unknown").replace(" ", "_")])
    g.add((pokemon_uri, RDF.type, POKEMON.Pokémon))

    # Map general properties
    mappings = {
        "name": POKEMON.name,
        "jname": POKEMON.japaneseName,
        "tmname": POKEMON.trademarkedJapaneseName,
        "jtranslit": POKEMON.japaneseTransliteration,
        "category": POKEMON.category,
        "ndex": POKEMON.nationalDexNumber,
        "forme": POKEMON.numberOfForms,
        "type1": POKEMON.primaryType,
        "type2": POKEMON.secondaryType,
        "ability1": POKEMON.ability1,
        "ability2": POKEMON.ability2,
        "abilityd": POKEMON.hiddenAbility,
        "height-m": POKEMON.heightInMeters,
        "height-ftin": POKEMON.heightInFeetInches,
        "weight-kg": POKEMON.weightInKilograms,
        "weight-lbs": POKEMON.weightInPounds,
        "catchrate": POKEMON.catchRate,
        "gendercode": POKEMON.genderRatioCode,
        "egggroup1": POKEMON.eggGroup1,
        "egggroup2": POKEMON.eggGroup2,
        "color": POKEMON.color,
        "friendship": POKEMON.baseFriendship,
        "generation": POKEMON.generationIntroduced,
        "expyield": POKEMON.baseExperienceYield,
        "evtotal": POKEMON.evTotal,
        "evhp": POKEMON.evYieldHP,
        "evat": POKEMON.evYieldAttack,
        "evde": POKEMON.evYieldDefense,
        "evsa": POKEMON.evYieldSpecialAttack,
        "evsd": POKEMON.evYieldSpecialDefense,
        "evsp": POKEMON.evYieldSpeed
    }

    # Map form-specific properties dynamically
    for i in range(2, 7):  # Forms 2 through 6
        form_suffix = f"form{i}"
        mappings.update({
            f"{form_suffix}": POKEMON[f"form{i}Name"],
            f"{form_suffix}type1": POKEMON[f"form{i}PrimaryType"],
            f"{form_suffix}type2": POKEMON[f"form{i}SecondaryType"],
            f"height-m{i}": POKEMON[f"form{i}HeightInMeters"],
            f"height-ftin{i}": POKEMON[f"form{i}HeightInFeetInches"],
            f"weight-kg{i}": POKEMON[f"form{i}WeightInKilograms"],
            f"weight-lbs{i}": POKEMON[f"form{i}WeightInPounds"],
        })

    # Generate RDF triples for properties that exist in the input
    for key, predicate in mappings.items():
        if key in properties and properties[key]:
            g.add((pokemon_uri, predicate, Literal(properties[key])))

    return g

# %%
grap = map_infobox_to_rdf(properties)
print(grap.serialize(format="turtle"))
