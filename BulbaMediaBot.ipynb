# %%
# Import definitions
import pwiki
import pwiki.wiki
import mwparserfromhell
import re
import os

from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS, XSD, OWL

# %%
# piwiki configuration

bulbabot = pwiki.wiki.Wiki(api_endpoint="https://bulbapedia.bulbagarden.net/w/api.php")

# %%
# piwiki basic tests
print(bulbabot.exists("Bulbasaur"))

bulbasaur_test = bulbabot.parse(title="Bulbasaur")
print( bulbasaur_test)

# %%
#Bulbasaur page content test
bulbasaur_test2 = bulbabot.page_text(title="Bulbasaur (Pokémon)")
bulbasaur_test2

# %%
# FUNCTION DEFINITION : pokémon infobox text extraction
def extract_infobox(content):
    match = re.search(r"{{Pokémon Infobox.*?}}", content, re.DOTALL)
    if match:
        return match.group(0)
    return None


def extract_region_infobox(content):
    match = re.search(r"{{RegionInfobox.*?}}", content, re.DOTALL)
    if match:
        return match.group(0)
    return None

def extract_character_infobox(content):
    match = re.search(r"{{Character Infobox.*?}}", content, re.DOTALL)
    if match:
        return match.group(0)
    return None

def extract_move_infobox(content):
    match = re.search(r"{{MoveInfobox.*?}}", content, re.DOTALL)
    if match:
        return match.group(0)
    return None

def extract_location_infobox(content):
    match = re.search(r"{{Infobox location.*?}}", content, re.DOTALL)
    if match:
        return match.group(0)
    return None

# %%
# infobox extration test
infobox = extract_infobox(bulbasaur_test2)
infobox

# %%
# FUNCTION DEFINITION : parsing of the infobox text 
def parse_infobox(infobox):
    properties = {}
    lines = infobox.split("\n")
    for line in lines:
        if line.startswith("|"):
            key_value = line[1:].split("=", 1)  # Remove leading `|` and split at `=`
            if len(key_value) == 2:
                key, value = key_value
                new_key = key.strip()
                new_value = value.strip().replace("[[","").replace("]]","").replace("{{","").replace("}}","")
                new_value = re.sub(r'<!--.*?-->', '', new_value, flags=re.DOTALL)
                if new_key == "size":
                    new_value = new_value.replace("px", "")
                if not("|" in new_value):
                    properties[new_key] = new_value
    return properties

# %%
# Infobox text parsing test 
properties = parse_infobox(infobox)
properties

# %%
# Vocabulary Graph 

#path 
vocabulary_path = f'C:/Users/HP/Documents/07. EMSE/Master DSC/WS/Project-BulbapediaKG/BulbapediaKG1/Vocabulary/'

vocabulary_graph = Graph()

for file_name in os.listdir(vocabulary_path):
    if file_name.endswith('.ttl'):
        vocabulary_graph.parse(os.path.join(vocabulary_path,file_name), format="ttl")
        print(file_name)


property_mappings = {}

# Iterate over the graph to get class properties and their types
for subject, predicate, obj in vocabulary_graph:
    if predicate == RDF.type and obj == RDFS.Class:
        # Class found, check for properties of this class
        class_uri = subject
        for s, p, o in vocabulary_graph.triples((None, RDFS.domain, class_uri)):
            if p == RDFS.domain and o == class_uri:
                # Now we know this property is for our class
                property_uri = s
                # Check for range (type) of the property
                range_type = None
                values_list = []

                for _, p, o in vocabulary_graph.triples((property_uri, RDFS.range, None)):
                    range_type = o

                values_list.append(range_type)
                match range_type:
                    case XSD.string:
                        values_list.append('Literal')
                    case XSD.integer:
                        values_list.append('Integer')
                    case XSD.date:
                        values_list.append('Date')
                    case XSD.decimal:
                        values_list.append('Decimal')
                    case _:
                        values_list.append('URIRef')

                property_mappings[str(property_uri)] = values_list
                    

property_mappings
# Out:
# infoboxCharacter.ttl
# infoboxLocation.ttl
# infoboxMove.ttl
# infoboxPokemon.ttl
# infoboxRegion.ttl
# {'http://example.org/move/n': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://schema.org/name': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/jname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/jtrans': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/jtranslit': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/gameimage': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://example.org/move/gameimage2': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://example.org/move/gameimagewidth': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/type': [rdflib.term.URIRef('http://example.org/move/type'),
#   'URIRef'],
#  'http://example.org/move/damagecategory': [rdflib.term.URIRef('http://example.org/move/damagecategory'),
#   'URIRef'],
#  'http://example.org/move/basepp': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/maxpp': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/power': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/accuracy': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/priority': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/touches': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/move/protect': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/move/magiccoat': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/move/snatch': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/move/mirrormove': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/move/kingsrock': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/move/sound': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/move/field': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/move/target': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/gen': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/category': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/appeal': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/jam': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/cdesc': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/appealsc': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/scdesc': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/category6': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/appeal6': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/jam6': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/move/cdesc6': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/footnotes': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/move/spm': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/character/color': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/character/bordercolor': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/character/corecolor': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/character/jname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/character/tmname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/character/jtranslit': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/character/textcolor': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/character/slogan': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/character/image': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/character/caption': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/character/age': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/character/birthday': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date'),
#   'Date'],
#  'http://example.org/character/gender': [rdflib.term.URIRef('http://schema.org/gender'),
#   'URIRef'],
#  'http://example.org/character/height': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/character/eyes': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/character/hair': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/character/hometown': [rdflib.term.URIRef('http://example.org/location/location'),
#   'URIRef'],
#  'http://example.org/character/region': [rdflib.term.URIRef('http://example.org/region/Region'),
#   'URIRef'],
#  'http://example.org/character/relatives': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/location/slogan': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/location/imageSize': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/location/mapDescription': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://schema.org/addressRegion': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/location/appearsInGeneration': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/location/locationType': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/location/mapFile': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://schema.org/image': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://example.org/pokemon/name': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/pokemon/jname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/pokemon/tmname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/pokemon/jtranslit': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/pokemon/category': [rdflib.term.URIRef('http://example.org/pokemon/category'),
#   'URIRef'],
#  'http://example.org/pokemon/ndex': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/pokemon/type1': [rdflib.term.URIRef('http://example.org/pokemon/type'),
#   'URIRef'],
#  'http://example.org/pokemon/type2': [rdflib.term.URIRef('http://example.org/pokemon/type'),
#   'URIRef'],
#  'http://example.org/pokemon/ability1': [rdflib.term.URIRef('http://example.org/pokemon/ability'),
#   'URIRef'],
#  'http://example.org/pokemon/ability2': [rdflib.term.URIRef('http://example.org/pokemon/ability'),
#   'URIRef'],
#  'http://example.org/pokemon/abilityd': [rdflib.term.URIRef('http://example.org/pokemon/ability'),
#   'URIRef'],
#  'http://example.org/pokemon/height-m': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal'),
#   'Decimal'],
#  'http://example.org/pokemon/weight-kg': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal'),
#   'Decimal'],
#  'http://example.org/pokemon/color': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/pokemon/friendship': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/region/regioncolor': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/region/jname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/tmname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/image': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://example.org/region/size': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/region/caption': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/introduction': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/professor': [rdflib.term.URIRef('http://example.org/character/Character'),
#   'URIRef'],
#  'http://example.org/region/firstpartner': [rdflib.term.URIRef('http://example.org/pokemon/Pokemon'),
#   'URIRef'],
#  'http://example.org/region/villain': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/league': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/location': [rdflib.term.URIRef('http://example.org/location/Location'),
#   'URIRef'],
#  'http://example.org/region/pokelist': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/series': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/season': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/generation': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/games': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/region/manga': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal']}

# %%
# FUNCTION DEFINITION : mapping of pokemon infobox properties to existing graph
def map_infobox_to_rdf(name_space, graph, property_mappings, properties):
    
    #POKEMON = Namespace("http://example.org/pokemon/")
    name_space = name_space
    nstype = str(name_space)
    nstype = nstype.rstrip('/').split('/')[-1]
    RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
    
    resoucre_uri = URIRef(name_space[properties.get("name", "Unknown").replace(" ", "_")])
    if properties.get("name", "Unknown").replace(" ", "_") == "Unkown":
        resoucre_uri = URIRef(name_space[properties.get("translated_name", "Unknown").replace(" ", "_")])
    graph.add((resoucre_uri, RDF.type, URIRef(name_space + nstype)))

    for propertyUri, propertyRestriction in property_mappings.items():
        if name_space in propertyUri:
            property_name = propertyUri[propertyUri.rfind('/') + 1:]
            if property_name in properties:
                match propertyRestriction[1]:
                    case "Literal":
                        graph.add((resoucre_uri, URIRef(propertyUri), Literal(properties[property_name])))
                    case "Integer":
                        if isinstance(int(properties[property_name]), int):
                            graph.add((resoucre_uri, URIRef(propertyUri), Literal(int(properties[property_name]))))
                    case "Date": 
                        graph.add((resoucre_uri, URIRef(propertyUri), Literal(properties[property_name], datatype=XSD.date)))
                    case "Decimal": 
                        graph.add((resoucre_uri, URIRef(propertyUri), Literal(properties[property_name], datatype=XSD.decimal)))
                    case _:
                        uriString = properties[property_name].replace(" ","_")
                        if str(name_space) in str(propertyRestriction[0]):
                            graph.add((resoucre_uri, URIRef(propertyUri), URIRef(propertyRestriction[0] +"/" +uriString)))
                        else:
                            graph.add((resoucre_uri, URIRef(propertyUri), URIRef(uriString)))
                            graph.add((URIRef(uriString), RDF.type ,propertyRestriction[0]))


    return graph

# %%
pokemon_infobox_graph = Graph()
POKEMON = Namespace("http://example.org/pokemon/")
pokemon_infobox_graph = map_infobox_to_rdf(POKEMON, pokemon_infobox_graph, property_mappings, properties=properties) 
print(pokemon_infobox_graph.serialize(format="turtle"))

# %%
# Get the list of pokemons
poke_list = bulbabot.page_text("List_of_Pokémon_by_National_Pokédex_number")
poke_list
# Out:
# '{{shortcut|3|Ndex|Olddex|Natdex}}\nThis is a list of Pokémon in the order dictated by the [[National Pokédex]], meaning that Pokémon from the [[Kanto]] region will appear first, followed by those from [[Johto]], [[Hoenn]], [[Sinnoh]], [[Unova]], [[Kalos]], [[Alola]], [[Galar]], [[Hisui]], and [[Paldea]]. As of the release of the [[Mochi Mayhem]] epilogue of [[The Indigo Disk]] expansion for {{g|Scarlet and Violet}}, there are 1025 Pokémon in total. Each region\'s set of Pokémon starts with its own set of [[first partner Pokémon]] and their [[evolution]]s, going in order of {{t|Grass}}, {{t|Fire}}, {{t|Water}}; the only exception is Unova, which begins with {{p|Victini}}, who is then followed by the first partner Pokémon. \n\nThe first 151 entries in this Pokédex also serve as [[List of Pokémon by Kanto Pokédex number|Kanto\'s]] [[regional Pokédex]]. In [[Generation II]], this Pokédex order was known as the "Old Pokédex", with a [[List of Pokémon by New Pokédex number|new order]] that put related Pokémon near each other also included.\n\n==Legend==\nAll [[form]] names below match what is seen in the Pokédex in the latest game they were in. In places where this does not sufficiently differentiate forms, extra clarification is provided in \'\'(italicized parentheticals)\'\'.\n\n==List of Pokémon by National Pokédex number==\n===[[Generation I]]===\n{{ndexh|Red|Green}}\n{{ndex|0001|Bulbasaur|Grass|Poison}}\n{{ndex|0002|Ivysaur|Grass|Poison}}\n{{ndex|0003|Venusaur|Grass|Poison}}\n{{ndex|0004|Charmander|Fire}}\n{{ndex|0005|Charmeleon|Fire}}\n{{ndex|0006|Charizard|Fire|Flying}}\n{{ndex|0007|Squirtle|Water}}\n{{ndex|0008|Wartortle|Water}}\n{{ndex|0009|Blastoise|Water}}\n{{ndex|0010|Caterpie|Bug}}\n{{ndex|0011|Metapod|Bug}}\n{{ndex|0012|Butterfree|Bug|Flying}}\n{{ndex|0013|Weedle|Bug|Poison}}\n{{ndex|0014|Kakuna|Bug|Poison}}\n{{ndex|0015|Beedrill|Bug|Poison}}\n{{ndex|0016|Pidgey|Normal|Flying}}\n{{ndex|0017|Pidgeotto|Normal|Flying}}\n{{ndex|0018|Pidgeot|Normal|Flying}}\n{{ndex|0019|Rattata|Normal|forms=2}}\n{{ndex/form|0019|Rattata|-Alola|Alolan Form|Dark|Normal}}\n{{ndex|0020|Raticate|Normal|forms=2}}\n{{ndex/form|0020|Raticate|-Alola|Alolan Form|Dark|Normal}}\n{{ndex|0021|Spearow|Normal|Flying}}\n{{ndex|0022|Fearow|Normal|Flying}}\n{{ndex|0023|Ekans|Poison}}\n{{ndex|0024|Arbok|Poison}}\n{{ndex|0025|Pikachu|Electric}}\n{{ndex|0026|Raichu|Electric|forms=2}}\n{{ndex/form|0026|Raichu|-Alola|Alolan Form|Electric|Psychic}}\n{{ndex|0027|Sandshrew|Ground|forms=2}}\n{{ndex/form|0027|Sandshrew|-Alola|Alolan Form|Ice|Steel}}\n{{ndex|0028|Sandslash|Ground|forms=2}}\n{{ndex/form|0028|Sandslash|-Alola|Alolan Form|Ice|Steel}}\n{{ndex|0029|Nidoran♀|Poison}}\n{{ndex|0030|Nidorina|Poison}}\n{{ndex|0031|Nidoqueen|Poison|Ground}}\n{{ndex|0032|Nidoran♂|Poison}}\n{{ndex|0033|Nidorino|Poison}}\n{{ndex|0034|Nidoking|Poison|Ground}}\n{{ndex|0035|Clefairy|Fairy}}\n{{ndex|0036|Clefable|Fairy}}\n{{ndex|0037|Vulpix|Fire|forms=2}}\n{{ndex/form|0037|Vulpix|-Alola|Alolan Form|Ice}}\n{{ndex|0038|Ninetales|Fire|forms=2}}\n{{ndex/form|0038|Ninetales|-Alola|Alolan Form|Ice|Fairy}}\n{{ndex|0039|Jigglypuff|Normal|Fairy}}\n{{ndex|0040|Wigglytuff|Normal|Fairy}}\n{{ndex|0041|Zubat|Poison|Flying}}\n{{ndex|0042|Golbat|Poison|Flying}}\n{{ndex|0043|Oddish|Grass|Poison}}\n{{ndex|0044|Gloom|Grass|Poison}}\n{{ndex|0045|Vileplume|Grass|Poison}}\n{{ndex|0046|Paras|Bug|Grass}}\n{{ndex|0047|Parasect|Bug|Grass}}\n{{ndex|0048|Venonat|Bug|Poison}}\n{{ndex|0049|Venomoth|Bug|Poison}}\n{{ndex|0050|Diglett|Ground|forms=2}}\n{{ndex/form|0050|Diglett|-Alola|Alolan Form|Ground|Steel}}\n{{ndex|0051|Dugtrio|Ground|forms=2}}\n{{ndex/form|0051|Dugtrio|-Alola|Alolan Form|Ground|Steel}}\n{{ndex|0052|Meowth|Normal|forms=3}}\n{{ndex/form|0052|Meowth|-Alola|Alolan Form|Dark}}\n{{ndex/form|0052|Meowth|-Galar|Galarian Form|Steel}}\n{{ndex|0053|Persian|Normal|forms=2}}\n{{ndex/form|0053|Persian|-Alola|Alolan Form|Dark}}\n{{ndex|0054|Psyduck|Water}}\n{{ndex|0055|Golduck|Water}}\n{{ndex|0056|Mankey|Fighting ...

# %%
# FUNTION DEFINITION : get pokemon list
def extract_third_substrings(input_string):
    # Define the regular expression pattern
    # pattern = r"\{\{ndex\|\d+\|([^\|]+)\|[^\|]+\|[^\|]+\}\}"
    # pattern = r"\{\{ndex\|\d+\|([^\|]+)(?:\|[^\|]+)*\}\}"
    pattern = r"\{\{ndex\|\d+\|([^\|]+)\|?.*?\}\}"
    
    # Find all matches of the pattern
    matches = re.findall(pattern, input_string)
    
    # Return the list of third substrings
    return matches

# %%
poke_list = extract_third_substrings(poke_list)
poke_list = [name + " (Pokémon)" for name in poke_list]
poke_list
# Out:
# ['Bulbasaur (Pokémon)',
#  'Ivysaur (Pokémon)',
#  'Venusaur (Pokémon)',
#  'Charmander (Pokémon)',
#  'Charmeleon (Pokémon)',
#  'Charizard (Pokémon)',
#  'Squirtle (Pokémon)',
#  'Wartortle (Pokémon)',
#  'Blastoise (Pokémon)',
#  'Caterpie (Pokémon)',
#  'Metapod (Pokémon)',
#  'Butterfree (Pokémon)',
#  'Weedle (Pokémon)',
#  'Kakuna (Pokémon)',
#  'Beedrill (Pokémon)',
#  'Pidgey (Pokémon)',
#  'Pidgeotto (Pokémon)',
#  'Pidgeot (Pokémon)',
#  'Rattata (Pokémon)',
#  'Raticate (Pokémon)',
#  'Spearow (Pokémon)',
#  'Fearow (Pokémon)',
#  'Ekans (Pokémon)',
#  'Arbok (Pokémon)',
#  'Pikachu (Pokémon)',
#  'Raichu (Pokémon)',
#  'Sandshrew (Pokémon)',
#  'Sandslash (Pokémon)',
#  'Nidoran♀ (Pokémon)',
#  'Nidorina (Pokémon)',
#  'Nidoqueen (Pokémon)',
#  'Nidoran♂ (Pokémon)',
#  'Nidorino (Pokémon)',
#  'Nidoking (Pokémon)',
#  'Clefairy (Pokémon)',
#  'Clefable (Pokémon)',
#  'Vulpix (Pokémon)',
#  'Ninetales (Pokémon)',
#  'Jigglypuff (Pokémon)',
#  'Wigglytuff (Pokémon)',
#  'Zubat (Pokémon)',
#  'Golbat (Pokémon)',
#  'Oddish (Pokémon)',
#  'Gloom (Pokémon)',
#  'Vileplume (Pokémon)',
#  'Paras (Pokémon)',
#  'Parasect (Pokémon)',
#  'Venonat (Pokémon)',
#  'Venomoth (Pokémon)',
#  'Diglett (Pokémon)',
#  'Dugtrio (Pokémon)',
#  'Meowth (Pokémon)',
#  'Persian (Pokémon)',
#  'Psyduck (Pokémon)',
#  'Golduck (Pokémon)',
#  'Mankey (Pokémon)',
#  'Primeape (Pokémon)',
#  'Growlithe (Pokémon)',
#  'Arcanine (Pokémon)',
#  'Poliwag (Pokémon)',
#  'Poliwhirl (Pokémon)',
#  'Poliwrath (Pokémon)',
#  'Abra (Pokémon)',
#  'Kadabra (Pokémon)',
#  'Alakazam (Pokémon)',
#  'Machop (Pokémon)',
#  'Machoke (Pokémon)',
#  'Machamp (Pokémon)',
#  'Bellsprout (Pokémon)',
#  'Weepinbell (Pokémon)',
#  'Victreebel (Pokémon)',
#  'Tentacool (Pokémon)',
#  'Tentacruel (Pokémon)',
#  'Geodude (Pokémon)',
#  'Graveler (Pokémon)',
#  'Golem (Pokémon)',
#  'Ponyta (Pokémon)',
#  'Rapidash (Pokémon)',
#  'Slowpoke (Pokémon)',
#  'Slowbro (Pokémon)',
#  'Magnemite (Pokémon)',
#  'Magneton (Pokémon)',
#  "Farfetch'd (Pokémon)",
#  'Doduo (Pokémon)',
#  'Dodrio (Pokémon)',
#  'Seel (Pokémon)',
#  'Dewgong (Pokémon)',
#  'Grimer (Pokémon)',
#  'Muk (Pokémon)',
#  'Shellder (Pokémon)',
#  'Cloyster (Pokémon)',
#  'Gastly (Pokémon)',
#  'Haunter (Pokémon)',
#  'Gengar (Pokémon)',
#  'Onix (Pokémon)',
#  'Drowzee (Pokémon)',
#  'Hypno (Pokémon)',
#  'Krabby (Pokémon)',
#  'Kingler (Pokémon)',
#  'Voltorb (Pokémon)',
#  'Electrode (Pokémon)',
#  'Exeggcute (Pokémon)',
#  'Exeggutor (Pokémon)',
#  'Cubone (Pokémon)',
#  'Marowak (Pokémon)',
#  'Hitmonlee (Pokémon)',
#  'Hitmonchan (Pokémon)',
#  'Lickitung (Pokémon)',
#  'Koffing (Pokémon)',
#  'Weezing (Pokémon)',
#  'Rhyhorn (Pokémon)',
#  'Rhydon (Pokémon)',
#  'Chansey (Pokémon)',
#  'Tangela (Pokémon)',
#  'Kangaskhan (Pokémon)',
#  'Horsea (Pokémon)',
#  'Seadra (Pokémon)',
#  'Goldeen (Pokémon)',
#  'Seaking (Pokémon)',
#  'Staryu (Pokémon)',
#  'Starmie (Pokémon)',
#  'Mr. Mime (Pokémon)',
#  'Scyther (Pokémon)',
#  'Jynx (Pokémon)',
#  'Electabuzz (Pokémon)',
#  'Magmar (Pokémon)',
#  'Pinsir (Pokémon)',
#  'Tauros (Pokémon)',
#  'Magikarp (Pokémon)',
#  'Gyarados (Pokémon)',
#  'Lapras (Pokémon)',
#  'Ditto (Pokémon)',
#  'Eevee (Pokémon)',
#  'Vaporeon (Pokémon)',
#  'Jolteon (Pokémon)',
#  'Flareon (Pokémon)',
#  'Porygon (Pokémon)',
#  'Omanyte (Pokémon)',
#  'Omastar (Pokémon)',
#  'Kabuto (Pokémon)',
#  'Kabutops (Pokémon)',
#  'Aerodactyl (Pokémon)',
#  'Snorlax (Pokémon)',
#  'Articuno (Pokémon)',
#  'Zapdos (Pokémon)',
#  'Moltres (Pokémon)',
#  'Dratini (Pokémon)',
#  'Dragonair (Pokémon)',
#  'Dragonite (Pokémon)',
#  'Mewtwo (Pokémon)',
#  'Mew (Pokémon)',
#  'Chikorita (Pokémon)',
#  'Bayleef (Pokémon)',
#  'Meganium (Pokémon)',
#  'Cyndaquil (Pokémon)',
#  'Quilava (Pokémon)',
#  'Typhlosion (Pokémon)',
#  'Totodile (Pokémon)',
#  'Croconaw (Pokémon)',
#  'Feraligatr (Pokémon)',
#  'Sentret (Pokémon)',
#  'Furret (Pokémon)',
#  'Hoothoot (Pokémon)',
#  'Noctowl (Pokémon)',
#  'Ledyba (Pokémon)',
#  'Ledian (Pokémon)',
#  'Spinarak (Pokémon)',
#  'Ariados (Pokémon)',
#  'Crobat (Pokémon)',
#  'Chinchou (Pokémon)',
#  'Lanturn (Pokémon)',
#  'Pichu (Pokémon)',
#  'Cleffa (Pokémon)',
#  'Igglybuff (Pokémon)',
#  'Togepi (Pokémon)',
#  'Togetic (Pokémon)',
#  'Natu (Pokémon)',
#  'Xatu (Pokémon)',
#  'Mareep (Pokémon)',
#  'Flaaffy (Pokémon)',
#  'Ampharos (Pokémon)',
#  'Bellossom (Pokémon)',
#  'Marill (Pokémon)',
#  'Azumarill (Pokémon)',
#  'Sudowoodo (Pokémon)',
#  'Politoed (Pokémon)',
#  'Hoppip (Pokémon)',
#  'Skiploom (Pokémon)',
#  'Jumpluff (Pokémon)',
#  'Aipom (Pokémon)',
#  'Sunkern (Pokémon)',
#  'Sunflora (Pokémon)',
#  'Yanma (Pokémon)',
#  'Wooper (Pokémon)',
#  'Quagsire (Pokémon)',
#  'Espeon (Pokémon)',
#  'Umbreon (Pokémon)',
#  'Murkrow (Pokémon)',
#  'Slowking (Pokémon)',
#  'Misdreavus (Pokémon)',
#  'Unown (Pokémon)',
#  'Wobbuffet (Pokémon)',
#  'Girafarig (Pokémon)',
#  'Pineco (Pokémon)',
#  'Forretress (Pokémon)',
#  'Dunsparce (Pokémon)',
#  'Gligar (Pokémon)',
#  'Steelix (Pokémon)',
#  'Snubbull (Pokémon)',
#  'Granbull (Pokémon)',
#  'Qwilfish (Pokémon)',
#  'Scizor (Pokémon)',
#  'Shuckle (Pokémon)',
#  'Heracross (Pokémon)',
#  'Sneasel (Pokémon)',
#  'Teddiursa (Pokémon)',
#  'Ursaring (Pokémon)',
#  'Slugma (Pokémon)',
#  'Magcargo (Pokémon)',
#  'Swinub (Pokémon)',
#  'Piloswine (Pokémon)',
#  'Corsola (Pokémon)',
#  'Remoraid (Pokémon)',
#  'Octillery (Pokémon)',
#  'Delibird (Pokémon)',
#  'Mantine (Pokémon)',
#  'Skarmory (Pokémon)',
#  'Houndour (Pokémon)',
#  'Houndoom (Pokémon)',
#  'Kingdra (Pokémon)',
#  'Phanpy (Pokémon)',
#  'Donphan (Pokémon)',
#  'Porygon2 (Pokémon)',
#  'Stantler (Pokémon)',
#  'Smeargle (Pokémon)',
#  'Tyrogue (Pokémon)',
#  'Hitmontop (Pokémon)',
#  'Smoochum (Pokémon)',
#  'Elekid (Pokémon)',
#  'Magby (Pokémon)',
#  'Miltank (Pokémon)',
#  'Blissey (Pokémon)',
#  'Raikou (Pokémon)',
#  'Entei (Pokémon)',
#  'Suicune (Pokémon)',
#  'Larvitar (Pokémon)',
#  'Pupitar (Pokémon)',
#  'Tyranitar (Pokémon)',
#  'Lugia (Pokémon)',
#  'Ho-Oh (Pokémon)',
#  'Celebi (Pokémon)',
#  'Treecko (Pokémon)',
#  'Grovyle (Pokémon)',
#  'Sceptile (Pokémon)',
#  'Torchic (Pokémon)',
#  'Combusken (Pokémon)',
#  'Blaziken (Pokémon)',
#  'Mudkip (Pokémon)',
#  'Marshtomp (Pokémon)',
#  'Swampert (Pokémon)',
#  'Poochyena (Pokémon)',
#  'Mightyena (Pokémon)',
#  'Zigzagoon (Pokémon)',
#  'Linoone (Pokémon)',
#  'Wurmple (Pokémon)',
#  'Silcoon (Pokémon)',
#  'Beautifly (Pokémon)',
#  'Cascoon (Pokémon)',
#  'Dustox (Pokémon)',
#  'Lotad (Pokémon)',
#  'Lombre (Pokémon)',
#  'Ludicolo (Pokémon)',
#  'Seedot (Pokémon)',
#  'Nuzleaf (Pokémon)',
#  'Shiftry (Pokémon)',
#  'Taillow (Pokémon)',
#  'Swellow (Pokémon)',
#  'Wingull (Pokémon)',
#  'Pelipper (Pokémon)',
#  'Ralts (Pokémon)',
#  'Kirlia (Pokémon)',
#  'Gardevoir (Pokémon)',
#  'Surskit (Pokémon)',
#  'Masquerain (Pokémon)',
#  'Shroomish (Pokémon)',
#  'Breloom (Pokémon)',
#  'Slakoth (Pokémon)',
#  'Vigoroth (Pokémon)',
#  'Slaking (Pokémon)',
#  'Nincada (Pokémon)',
#  'Ninjask (Pokémon)',
#  'Shedinja (Pokémon)',
#  'Whismur (Pokémon)',
#  'Loudred (Pokémon)',
#  'Exploud (Pokémon)',
#  'Makuhita (Pokémon)',
#  'Hariyama (Pokémon)',
#  'Azurill (Pokémon)',
#  'Nosepass (Pokémon)',
#  'Skitty (Pokémon)',
#  'Delcatty (Pokémon)',
#  'Sableye (Pokémon)',
#  'Mawile (Pokémon)',
#  'Aron (Pokémon)',
#  'Lairon (Pokémon)',
#  'Aggron (Pokémon)',
#  'Meditite (Pokémon)',
#  'Medicham (Pokémon)',
#  'Electrike (Pokémon)',
#  'Manectric (Pokémon)',
#  'Plusle (Pokémon)',
#  'Minun (Pokémon)',
#  'Volbeat (Pokémon)',
#  'Illumise (Pokémon)',
#  'Roselia (Pokémon)',
#  'Gulpin (Pokémon)',
#  'Swalot (Pokémon)',
#  'Carvanha (Pokémon)',
#  'Sharpedo (Pokémon)',
#  'Wailmer (Pokémon)',
#  'Wailord (Pokémon)',
#  'Numel (Pokémon)',
#  'Camerupt (Pokémon)',
#  'Torkoal (Pokémon)',
#  'Spoink (Pokémon)',
#  'Grumpig (Pokémon)',
#  'Spinda (Pokémon)',
#  'Trapinch (Pokémon)',
#  'Vibrava (Pokémon)',
#  'Flygon (Pokémon)',
#  'Cacnea (Pokémon)',
#  'Cacturne (Pokémon)',
#  'Swablu (Pokémon)',
#  'Altaria (Pokémon)',
#  'Zangoose (Pokémon)',
#  'Seviper (Pokémon)',
#  'Lunatone (Pokémon)',
#  'Solrock (Pokémon)',
#  'Barboach (Pokémon)',
#  'Whiscash (Pokémon)',
#  'Corphish (Pokémon)',
#  'Crawdaunt (Pokémon)',
#  'Baltoy (Pokémon)',
#  'Claydol (Pokémon)',
#  'Lileep (Pokémon)',
#  'Cradily (Pokémon)',
#  'Anorith (Pokémon)',
#  'Armaldo (Pokémon)',
#  'Feebas (Pokémon)',
#  'Milotic (Pokémon)',
#  'Castform (Pokémon)',
#  'Kecleon (Pokémon)',
#  'Shuppet (Pokémon)',
#  'Banette (Pokémon)',
#  'Duskull (Pokémon)',
#  'Dusclops (Pokémon)',
#  'Tropius (Pokémon)',
#  'Chimecho (Pokémon)',
#  'Absol (Pokémon)',
#  'Wynaut (Pokémon)',
#  'Snorunt (Pokémon)',
#  'Glalie (Pokémon)',
#  'Spheal (Pokémon)',
#  'Sealeo (Pokémon)',
#  'Walrein (Pokémon)',
#  'Clamperl (Pokémon)',
#  'Huntail (Pokémon)',
#  'Gorebyss (Pokémon)',
#  'Relicanth (Pokémon)',
#  'Luvdisc (Pokémon)',
#  'Bagon (Pokémon)',
#  'Shelgon (Pokémon)',
#  'Salamence (Pokémon)',
#  'Beldum (Pokémon)',
#  'Metang (Pokémon)',
#  'Metagross (Pokémon)',
#  'Regirock (Pokémon)',
#  'Regice (Pokémon)',
#  'Registeel (Pokémon)',
#  'Latias (Pokémon)',
#  'Latios (Pokémon)',
#  'Kyogre (Pokémon)',
#  'Groudon (Pokémon)',
#  'Rayquaza (Pokémon)',
#  'Jirachi (Pokémon)',
#  'Deoxys (Pokémon)',
#  'Turtwig (Pokémon)',
#  'Grotle (Pokémon)',
#  'Torterra (Pokémon)',
#  'Chimchar (Pokémon)',
#  'Monferno (Pokémon)',
#  'Infernape (Pokémon)',
#  'Piplup (Pokémon)',
#  'Prinplup (Pokémon)',
#  'Empoleon (Pokémon)',
#  'Starly (Pokémon)',
#  'Staravia (Pokémon)',
#  'Staraptor (Pokémon)',
#  'Bidoof (Pokémon)',
#  'Bibarel (Pokémon)',
#  'Kricketot (Pokémon)',
#  'Kricketune (Pokémon)',
#  'Shinx (Pokémon)',
#  'Luxio (Pokémon)',
#  'Luxray (Pokémon)',
#  'Budew (Pokémon)',
#  'Roserade (Pokémon)',
#  'Cranidos (Pokémon)',
#  'Rampardos (Pokémon)',
#  'Shieldon (Pokémon)',
#  'Bastiodon (Pokémon)',
#  'Burmy (Pokémon)',
#  'Wormadam (Pokémon)',
#  'Mothim (Pokémon)',
#  'Combee (Pokémon)',
#  'Vespiquen (Pokémon)',
#  'Pachirisu (Pokémon)',
#  'Buizel (Pokémon)',
#  'Floatzel (Pokémon)',
#  'Cherubi (Pokémon)',
#  'Cherrim (Pokémon)',
#  'Shellos (Pokémon)',
#  'Gastrodon (Pokémon)',
#  'Ambipom (Pokémon)',
#  'Drifloon (Pokémon)',
#  'Drifblim (Pokémon)',
#  'Buneary (Pokémon)',
#  'Lopunny (Pokémon)',
#  'Mismagius (Pokémon)',
#  'Honchkrow (Pokémon)',
#  'Glameow (Pokémon)',
#  'Purugly (Pokémon)',
#  'Chingling (Pokémon)',
#  'Stunky (Pokémon)',
#  'Skuntank (Pokémon)',
#  'Bronzor (Pokémon)',
#  'Bronzong (Pokémon)',
#  'Bonsly (Pokémon)',
#  'Mime Jr. (Pokémon)',
#  'Happiny (Pokémon)',
#  'Chatot (Pokémon)',
#  'Spiritomb (Pokémon)',
#  'Gible (Pokémon)',
#  'Gabite (Pokémon)',
#  'Garchomp (Pokémon)',
#  'Munchlax (Pokémon)',
#  'Riolu (Pokémon)',
#  'Lucario (Pokémon)',
#  'Hippopotas (Pokémon)',
#  'Hippowdon (Pokémon)',
#  'Skorupi (Pokémon)',
#  'Drapion (Pokémon)',
#  'Croagunk (Pokémon)',
#  'Toxicroak (Pokémon)',
#  'Carnivine (Pokémon)',
#  'Finneon (Pokémon)',
#  'Lumineon (Pokémon)',
#  'Mantyke (Pokémon)',
#  'Snover (Pokémon)',
#  'Abomasnow (Pokémon)',
#  'Weavile (Pokémon)',
#  'Magnezone (Pokémon)',
#  'Lickilicky (Pokémon)',
#  'Rhyperior (Pokémon)',
#  'Tangrowth (Pokémon)',
#  'Electivire (Pokémon)',
#  'Magmortar (Pokémon)',
#  'Togekiss (Pokémon)',
#  'Yanmega (Pokémon)',
#  'Leafeon (Pokémon)',
#  'Glaceon (Pokémon)',
#  'Gliscor (Pokémon)',
#  'Mamoswine (Pokémon)',
#  'Porygon-Z (Pokémon)',
#  'Gallade (Pokémon)',
#  'Probopass (Pokémon)',
#  'Dusknoir (Pokémon)',
#  'Froslass (Pokémon)',
#  'Rotom (Pokémon)',
#  'Uxie (Pokémon)',
#  'Mesprit (Pokémon)',
#  'Azelf (Pokémon)',
#  'Dialga (Pokémon)',
#  'Palkia (Pokémon)',
#  'Heatran (Pokémon)',
#  'Regigigas (Pokémon)',
#  'Giratina (Pokémon)',
#  'Cresselia (Pokémon)',
#  'Phione (Pokémon)',
#  'Manaphy (Pokémon)',
#  'Darkrai (Pokémon)',
#  'Shaymin (Pokémon)',
#  'Arceus (Pokémon)',
#  'Victini (Pokémon)',
#  'Snivy (Pokémon)',
#  'Servine (Pokémon)',
#  'Serperior (Pokémon)',
#  'Tepig (Pokémon)',
#  'Pignite (Pokémon)',
#  'Emboar (Pokémon)',
#  'Oshawott (Pokémon)',
#  'Dewott (Pokémon)',
#  'Samurott (Pokémon)',
#  'Patrat (Pokémon)',
#  'Watchog (Pokémon)',
#  'Lillipup (Pokémon)',
#  'Herdier (Pokémon)',
#  'Stoutland (Pokémon)',
#  'Purrloin (Pokémon)',
#  'Liepard (Pokémon)',
#  'Pansage (Pokémon)',
#  'Simisage (Pokémon)',
#  'Pansear (Pokémon)',
#  'Simisear (Pokémon)',
#  'Panpour (Pokémon)',
#  'Simipour (Pokémon)',
#  'Munna (Pokémon)',
#  'Musharna (Pokémon)',
#  'Pidove (Pokémon)',
#  'Tranquill (Pokémon)',
#  'Unfezant (Pokémon)',
#  'Blitzle (Pokémon)',
#  'Zebstrika (Pokémon)',
#  'Roggenrola (Pokémon)',
#  'Boldore (Pokémon)',
#  'Gigalith (Pokémon)',
#  'Woobat (Pokémon)',
#  'Swoobat (Pokémon)',
#  'Drilbur (Pokémon)',
#  'Excadrill (Pokémon)',
#  'Audino (Pokémon)',
#  'Timburr (Pokémon)',
#  'Gurdurr (Pokémon)',
#  'Conkeldurr (Pokémon)',
#  'Tympole (Pokémon)',
#  'Palpitoad (Pokémon)',
#  'Seismitoad (Pokémon)',
#  'Throh (Pokémon)',
#  'Sawk (Pokémon)',
#  'Sewaddle (Pokémon)',
#  'Swadloon (Pokémon)',
#  'Leavanny (Pokémon)',
#  'Venipede (Pokémon)',
#  'Whirlipede (Pokémon)',
#  'Scolipede (Pokémon)',
#  'Cottonee (Pokémon)',
#  'Whimsicott (Pokémon)',
#  'Petilil (Pokémon)',
#  'Lilligant (Pokémon)',
#  'Basculin (Pokémon)',
#  'Sandile (Pokémon)',
#  'Krokorok (Pokémon)',
#  'Krookodile (Pokémon)',
#  'Darumaka (Pokémon)',
#  'Darmanitan (Pokémon)',
#  'Maractus (Pokémon)',
#  'Dwebble (Pokémon)',
#  'Crustle (Pokémon)',
#  'Scraggy (Pokémon)',
#  'Scrafty (Pokémon)',
#  'Sigilyph (Pokémon)',
#  'Yamask (Pokémon)',
#  'Cofagrigus (Pokémon)',
#  'Tirtouga (Pokémon)',
#  'Carracosta (Pokémon)',
#  'Archen (Pokémon)',
#  'Archeops (Pokémon)',
#  'Trubbish (Pokémon)',
#  'Garbodor (Pokémon)',
#  'Zorua (Pokémon)',
#  'Zoroark (Pokémon)',
#  'Minccino (Pokémon)',
#  'Cinccino (Pokémon)',
#  'Gothita (Pokémon)',
#  'Gothorita (Pokémon)',
#  'Gothitelle (Pokémon)',
#  'Solosis (Pokémon)',
#  'Duosion (Pokémon)',
#  'Reuniclus (Pokémon)',
#  'Ducklett (Pokémon)',
#  'Swanna (Pokémon)',
#  'Vanillite (Pokémon)',
#  'Vanillish (Pokémon)',
#  'Vanilluxe (Pokémon)',
#  'Deerling (Pokémon)',
#  'Sawsbuck (Pokémon)',
#  'Emolga (Pokémon)',
#  'Karrablast (Pokémon)',
#  'Escavalier (Pokémon)',
#  'Foongus (Pokémon)',
#  'Amoonguss (Pokémon)',
#  'Frillish (Pokémon)',
#  'Jellicent (Pokémon)',
#  'Alomomola (Pokémon)',
#  'Joltik (Pokémon)',
#  'Galvantula (Pokémon)',
#  'Ferroseed (Pokémon)',
#  'Ferrothorn (Pokémon)',
#  'Klink (Pokémon)',
#  'Klang (Pokémon)',
#  'Klinklang (Pokémon)',
#  'Tynamo (Pokémon)',
#  'Eelektrik (Pokémon)',
#  'Eelektross (Pokémon)',
#  'Elgyem (Pokémon)',
#  'Beheeyem (Pokémon)',
#  'Litwick (Pokémon)',
#  'Lampent (Pokémon)',
#  'Chandelure (Pokémon)',
#  'Axew (Pokémon)',
#  'Fraxure (Pokémon)',
#  'Haxorus (Pokémon)',
#  'Cubchoo (Pokémon)',
#  'Beartic (Pokémon)',
#  'Cryogonal (Pokémon)',
#  'Shelmet (Pokémon)',
#  'Accelgor (Pokémon)',
#  'Stunfisk (Pokémon)',
#  'Mienfoo (Pokémon)',
#  'Mienshao (Pokémon)',
#  'Druddigon (Pokémon)',
#  'Golett (Pokémon)',
#  'Golurk (Pokémon)',
#  'Pawniard (Pokémon)',
#  'Bisharp (Pokémon)',
#  'Bouffalant (Pokémon)',
#  'Rufflet (Pokémon)',
#  'Braviary (Pokémon)',
#  'Vullaby (Pokémon)',
#  'Mandibuzz (Pokémon)',
#  'Heatmor (Pokémon)',
#  'Durant (Pokémon)',
#  'Deino (Pokémon)',
#  'Zweilous (Pokémon)',
#  'Hydreigon (Pokémon)',
#  'Larvesta (Pokémon)',
#  'Volcarona (Pokémon)',
#  'Cobalion (Pokémon)',
#  'Terrakion (Pokémon)',
#  'Virizion (Pokémon)',
#  'Tornadus (Pokémon)',
#  'Thundurus (Pokémon)',
#  'Reshiram (Pokémon)',
#  'Zekrom (Pokémon)',
#  'Landorus (Pokémon)',
#  'Kyurem (Pokémon)',
#  'Keldeo (Pokémon)',
#  'Meloetta (Pokémon)',
#  'Genesect (Pokémon)',
#  'Chespin (Pokémon)',
#  'Quilladin (Pokémon)',
#  'Chesnaught (Pokémon)',
#  'Fennekin (Pokémon)',
#  'Braixen (Pokémon)',
#  'Delphox (Pokémon)',
#  'Froakie (Pokémon)',
#  'Frogadier (Pokémon)',
#  'Greninja (Pokémon)',
#  'Bunnelby (Pokémon)',
#  'Diggersby (Pokémon)',
#  'Fletchling (Pokémon)',
#  'Fletchinder (Pokémon)',
#  'Talonflame (Pokémon)',
#  'Scatterbug (Pokémon)',
#  'Spewpa (Pokémon)',
#  'Vivillon (Pokémon)',
#  'Litleo (Pokémon)',
#  'Pyroar (Pokémon)',
#  'Flabébé (Pokémon)',
#  'Floette (Pokémon)',
#  'Florges (Pokémon)',
#  'Skiddo (Pokémon)',
#  'Gogoat (Pokémon)',
#  'Pancham (Pokémon)',
#  'Pangoro (Pokémon)',
#  'Furfrou (Pokémon)',
#  'Espurr (Pokémon)',
#  'Meowstic (Pokémon)',
#  'Honedge (Pokémon)',
#  'Doublade (Pokémon)',
#  'Aegislash (Pokémon)',
#  'Spritzee (Pokémon)',
#  'Aromatisse (Pokémon)',
#  'Swirlix (Pokémon)',
#  'Slurpuff (Pokémon)',
#  'Inkay (Pokémon)',
#  'Malamar (Pokémon)',
#  'Binacle (Pokémon)',
#  'Barbaracle (Pokémon)',
#  'Skrelp (Pokémon)',
#  'Dragalge (Pokémon)',
#  'Clauncher (Pokémon)',
#  'Clawitzer (Pokémon)',
#  'Helioptile (Pokémon)',
#  'Heliolisk (Pokémon)',
#  'Tyrunt (Pokémon)',
#  'Tyrantrum (Pokémon)',
#  'Amaura (Pokémon)',
#  'Aurorus (Pokémon)',
#  'Sylveon (Pokémon)',
#  'Hawlucha (Pokémon)',
#  'Dedenne (Pokémon)',
#  'Carbink (Pokémon)',
#  'Goomy (Pokémon)',
#  'Sliggoo (Pokémon)',
#  'Goodra (Pokémon)',
#  'Klefki (Pokémon)',
#  'Phantump (Pokémon)',
#  'Trevenant (Pokémon)',
#  'Pumpkaboo (Pokémon)',
#  'Gourgeist (Pokémon)',
#  'Bergmite (Pokémon)',
#  'Avalugg (Pokémon)',
#  'Noibat (Pokémon)',
#  'Noivern (Pokémon)',
#  'Xerneas (Pokémon)',
#  'Yveltal (Pokémon)',
#  'Zygarde (Pokémon)',
#  'Diancie (Pokémon)',
#  'Hoopa (Pokémon)',
#  'Volcanion (Pokémon)',
#  'Rowlet (Pokémon)',
#  'Dartrix (Pokémon)',
#  'Decidueye (Pokémon)',
#  'Litten (Pokémon)',
#  'Torracat (Pokémon)',
#  'Incineroar (Pokémon)',
#  'Popplio (Pokémon)',
#  'Brionne (Pokémon)',
#  'Primarina (Pokémon)',
#  'Pikipek (Pokémon)',
#  'Trumbeak (Pokémon)',
#  'Toucannon (Pokémon)',
#  'Yungoos (Pokémon)',
#  'Gumshoos (Pokémon)',
#  'Grubbin (Pokémon)',
#  'Charjabug (Pokémon)',
#  'Vikavolt (Pokémon)',
#  'Crabrawler (Pokémon)',
#  'Crabominable (Pokémon)',
#  'Oricorio (Pokémon)',
#  'Cutiefly (Pokémon)',
#  'Ribombee (Pokémon)',
#  'Rockruff (Pokémon)',
#  'Lycanroc (Pokémon)',
#  'Wishiwashi (Pokémon)',
#  'Mareanie (Pokémon)',
#  'Toxapex (Pokémon)',
#  'Mudbray (Pokémon)',
#  'Mudsdale (Pokémon)',
#  'Dewpider (Pokémon)',
#  'Araquanid (Pokémon)',
#  'Fomantis (Pokémon)',
#  'Lurantis (Pokémon)',
#  'Morelull (Pokémon)',
#  'Shiinotic (Pokémon)',
#  'Salandit (Pokémon)',
#  'Salazzle (Pokémon)',
#  'Stufful (Pokémon)',
#  'Bewear (Pokémon)',
#  'Bounsweet (Pokémon)',
#  'Steenee (Pokémon)',
#  'Tsareena (Pokémon)',
#  'Comfey (Pokémon)',
#  'Oranguru (Pokémon)',
#  'Passimian (Pokémon)',
#  'Wimpod (Pokémon)',
#  'Golisopod (Pokémon)',
#  'Sandygast (Pokémon)',
#  'Palossand (Pokémon)',
#  'Pyukumuku (Pokémon)',
#  'Type: Null (Pokémon)',
#  'Silvally (Pokémon)',
#  'Minior (Pokémon)',
#  'Komala (Pokémon)',
#  'Turtonator (Pokémon)',
#  'Togedemaru (Pokémon)',
#  'Mimikyu (Pokémon)',
#  'Bruxish (Pokémon)',
#  'Drampa (Pokémon)',
#  'Dhelmise (Pokémon)',
#  'Jangmo-o (Pokémon)',
#  'Hakamo-o (Pokémon)',
#  'Kommo-o (Pokémon)',
#  'Tapu Koko (Pokémon)',
#  'Tapu Lele (Pokémon)',
#  'Tapu Bulu (Pokémon)',
#  'Tapu Fini (Pokémon)',
#  'Cosmog (Pokémon)',
#  'Cosmoem (Pokémon)',
#  'Solgaleo (Pokémon)',
#  'Lunala (Pokémon)',
#  'Nihilego (Pokémon)',
#  'Buzzwole (Pokémon)',
#  'Pheromosa (Pokémon)',
#  'Xurkitree (Pokémon)',
#  'Celesteela (Pokémon)',
#  'Kartana (Pokémon)',
#  'Guzzlord (Pokémon)',
#  'Necrozma (Pokémon)',
#  'Magearna (Pokémon)',
#  'Marshadow (Pokémon)',
#  'Poipole (Pokémon)',
#  'Naganadel (Pokémon)',
#  'Stakataka (Pokémon)',
#  'Blacephalon (Pokémon)',
#  'Zeraora (Pokémon)',
#  'Meltan (Pokémon)',
#  'Melmetal (Pokémon)',
#  'Grookey (Pokémon)',
#  'Thwackey (Pokémon)',
#  'Rillaboom (Pokémon)',
#  'Scorbunny (Pokémon)',
#  'Raboot (Pokémon)',
#  'Cinderace (Pokémon)',
#  'Sobble (Pokémon)',
#  'Drizzile (Pokémon)',
#  'Inteleon (Pokémon)',
#  'Skwovet (Pokémon)',
#  'Greedent (Pokémon)',
#  'Rookidee (Pokémon)',
#  'Corvisquire (Pokémon)',
#  'Corviknight (Pokémon)',
#  'Blipbug (Pokémon)',
#  'Dottler (Pokémon)',
#  'Orbeetle (Pokémon)',
#  'Nickit (Pokémon)',
#  'Thievul (Pokémon)',
#  'Gossifleur (Pokémon)',
#  'Eldegoss (Pokémon)',
#  'Wooloo (Pokémon)',
#  'Dubwool (Pokémon)',
#  'Chewtle (Pokémon)',
#  'Drednaw (Pokémon)',
#  'Yamper (Pokémon)',
#  'Boltund (Pokémon)',
#  'Rolycoly (Pokémon)',
#  'Carkol (Pokémon)',
#  'Coalossal (Pokémon)',
#  'Applin (Pokémon)',
#  'Flapple (Pokémon)',
#  'Appletun (Pokémon)',
#  'Silicobra (Pokémon)',
#  'Sandaconda (Pokémon)',
#  'Cramorant (Pokémon)',
#  'Arrokuda (Pokémon)',
#  'Barraskewda (Pokémon)',
#  'Toxel (Pokémon)',
#  'Toxtricity (Pokémon)',
#  'Sizzlipede (Pokémon)',
#  'Centiskorch (Pokémon)',
#  'Clobbopus (Pokémon)',
#  'Grapploct (Pokémon)',
#  'Sinistea (Pokémon)',
#  'Polteageist (Pokémon)',
#  'Hatenna (Pokémon)',
#  'Hattrem (Pokémon)',
#  'Hatterene (Pokémon)',
#  'Impidimp (Pokémon)',
#  'Morgrem (Pokémon)',
#  'Grimmsnarl (Pokémon)',
#  'Obstagoon (Pokémon)',
#  'Perrserker (Pokémon)',
#  'Cursola (Pokémon)',
#  "Sirfetch'd (Pokémon)",
#  'Mr. Rime (Pokémon)',
#  'Runerigus (Pokémon)',
#  'Milcery (Pokémon)',
#  'Alcremie (Pokémon)',
#  'Falinks (Pokémon)',
#  'Pincurchin (Pokémon)',
#  'Snom (Pokémon)',
#  'Frosmoth (Pokémon)',
#  'Stonjourner (Pokémon)',
#  'Eiscue (Pokémon)',
#  'Indeedee (Pokémon)',
#  'Morpeko (Pokémon)',
#  'Cufant (Pokémon)',
#  'Copperajah (Pokémon)',
#  'Dracozolt (Pokémon)',
#  'Arctozolt (Pokémon)',
#  'Dracovish (Pokémon)',
#  'Arctovish (Pokémon)',
#  'Duraludon (Pokémon)',
#  'Dreepy (Pokémon)',
#  'Drakloak (Pokémon)',
#  'Dragapult (Pokémon)',
#  'Zacian (Pokémon)',
#  'Zamazenta (Pokémon)',
#  'Eternatus (Pokémon)',
#  'Kubfu (Pokémon)',
#  'Urshifu (Pokémon)',
#  'Zarude (Pokémon)',
#  'Regieleki (Pokémon)',
#  'Regidrago (Pokémon)',
#  'Glastrier (Pokémon)',
#  'Spectrier (Pokémon)',
#  'Calyrex (Pokémon)',
#  'Wyrdeer (Pokémon)',
#  'Kleavor (Pokémon)',
#  'Ursaluna (Pokémon)',
#  'Basculegion (Pokémon)',
#  'Sneasler (Pokémon)',
#  'Overqwil (Pokémon)',
#  'Enamorus (Pokémon)',
#  'Sprigatito (Pokémon)',
#  'Floragato (Pokémon)',
#  'Meowscarada (Pokémon)',
#  'Fuecoco (Pokémon)',
#  'Crocalor (Pokémon)',
#  'Skeledirge (Pokémon)',
#  'Quaxly (Pokémon)',
#  'Quaxwell (Pokémon)',
#  'Quaquaval (Pokémon)',
#  'Lechonk (Pokémon)',
#  'Oinkologne (Pokémon)',
#  'Tarountula (Pokémon)',
#  'Spidops (Pokémon)',
#  'Nymble (Pokémon)',
#  'Lokix (Pokémon)',
#  'Pawmi (Pokémon)',
#  'Pawmo (Pokémon)',
#  'Pawmot (Pokémon)',
#  'Tandemaus (Pokémon)',
#  'Maushold (Pokémon)',
#  'Fidough (Pokémon)',
#  'Dachsbun (Pokémon)',
#  'Smoliv (Pokémon)',
#  'Dolliv (Pokémon)',
#  'Arboliva (Pokémon)',
#  'Squawkabilly (Pokémon)',
#  'Nacli (Pokémon)',
#  'Naclstack (Pokémon)',
#  'Garganacl (Pokémon)',
#  'Charcadet (Pokémon)',
#  'Armarouge (Pokémon)',
#  'Ceruledge (Pokémon)',
#  'Tadbulb (Pokémon)',
#  'Bellibolt (Pokémon)',
#  'Wattrel (Pokémon)',
#  'Kilowattrel (Pokémon)',
#  'Maschiff (Pokémon)',
#  'Mabosstiff (Pokémon)',
#  'Shroodle (Pokémon)',
#  'Grafaiai (Pokémon)',
#  'Bramblin (Pokémon)',
#  'Brambleghast (Pokémon)',
#  'Toedscool (Pokémon)',
#  'Toedscruel (Pokémon)',
#  'Klawf (Pokémon)',
#  'Capsakid (Pokémon)',
#  'Scovillain (Pokémon)',
#  'Rellor (Pokémon)',
#  'Rabsca (Pokémon)',
#  'Flittle (Pokémon)',
#  'Espathra (Pokémon)',
#  'Tinkatink (Pokémon)',
#  'Tinkatuff (Pokémon)',
#  'Tinkaton (Pokémon)',
#  'Wiglett (Pokémon)',
#  'Wugtrio (Pokémon)',
#  'Bombirdier (Pokémon)',
#  'Finizen (Pokémon)',
#  'Palafin (Pokémon)',
#  'Varoom (Pokémon)',
#  'Revavroom (Pokémon)',
#  'Cyclizar (Pokémon)',
#  'Orthworm (Pokémon)',
#  'Glimmet (Pokémon)',
#  'Glimmora (Pokémon)',
#  'Greavard (Pokémon)',
#  'Houndstone (Pokémon)',
#  'Flamigo (Pokémon)',
#  'Cetoddle (Pokémon)',
#  'Cetitan (Pokémon)',
#  'Veluza (Pokémon)',
#  'Dondozo (Pokémon)',
#  'Tatsugiri (Pokémon)',
#  'Annihilape (Pokémon)',
#  'Clodsire (Pokémon)',
#  'Farigiraf (Pokémon)',
#  'Dudunsparce (Pokémon)',
#  'Kingambit (Pokémon)',
#  'Great Tusk (Pokémon)',
#  'Scream Tail (Pokémon)',
#  'Brute Bonnet (Pokémon)',
#  'Flutter Mane (Pokémon)',
#  'Slither Wing (Pokémon)',
#  'Sandy Shocks (Pokémon)',
#  'Iron Treads (Pokémon)',
#  'Iron Bundle (Pokémon)',
#  'Iron Hands (Pokémon)',
#  'Iron Jugulis (Pokémon)',
#  'Iron Moth (Pokémon)',
#  'Iron Thorns (Pokémon)',
#  'Frigibax (Pokémon)',
#  'Arctibax (Pokémon)',
#  'Baxcalibur (Pokémon)',
#  'Gimmighoul (Pokémon)',
#  'Gholdengo (Pokémon)',
#  ...]

# %%
POKEMON = Namespace("http://example.org/pokemon/")
intial_graph = Graph()
final_graph = Graph()

for pokemon in poke_list:
    try:
        # Step 1: Fetch the page text
        result1 = bulbabot.page_text(title=pokemon)
        
        # Step 2: Extract the infobox
        result2 = extract_infobox(result1)
        
        # Step 3: Parse the infobox
        result3 = parse_infobox(result2)
        
        # Step 4: Map the parsed infobox to RDF
        final_graph = map_infobox_to_rdf(POKEMON, intial_graph, property_mappings, result3)
        
        # Log or handle the final result (optional)
        # print(f"Successfully processed {pokemon}")
    except Exception as e:
        # Handle any errors that occur in the pipeline
        print(f"Error processing {pokemon}: {e}")

# %%
# Save or print the created graph
graph_path = "GeneratedGraphs/"
print(final_graph.serialize(format="turtle"))
with open(os.path.join(graph_path, "poke_graph.ttl"), "w", encoding="utf-8") as file:
    file.write(final_graph.serialize(format="turtle"))
# Out:
# @prefix ns1: <http://example.org/pokemon/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ns1:Abomasnow a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Snow_Warning> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Soundproof> ;
#     ns1:category <http://example.org/pokemon/category/Frost_Tree> ;
#     ns1:color <White> ;
#     ns1:friendship 70 ;
#     ns1:height-m 2.2 ;
#     ns1:jname "ユキノオー" ;
#     ns1:jtranslit "Yukino'ō" ;
#     ns1:name "Abomasnow" ;
#     ns1:ndex 460 ;
#     ns1:tmname "Yukinooh" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 135.5 .
#
# ns1:Abra a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Synchronize> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Inner_Focus> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Magic_Guard> ;
#     ns1:category <http://example.org/pokemon/category/Psi> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.9 ;
#     ns1:jname "ケーシィ" ;
#     ns1:jtranslit "Kēsyi" ;
#     ns1:name "Abra" ;
#     ns1:ndex 63 ;
#     ns1:tmname "Casey" ;
#     ns1:type1 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 19.5 .
#
# ns1:Absol a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Pressure> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Super_Luck> ;
#     ns1:category <http://example.org/pokemon/category/Disaster> ;
#     ns1:height-m 1.2 ;
#     ns1:jname "アブソル" ;
#     ns1:jtranslit "Abusoru" ;
#     ns1:name "Absol" ;
#     ns1:ndex 359 ;
#     ns1:tmname "Absol" ;
#     ns1:type1 <http://example.org/pokemon/type/Dark> ;
#     ns1:weight-kg 47.0 .
#
# ns1:Accelgor a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Hydration> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Sticky_Hold> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Unburden> ;
#     ns1:category <http://example.org/pokemon/category/Shell_Out> ;
#     ns1:color <Red> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.8 ;
#     ns1:jname "アギルダー" ;
#     ns1:jtranslit "Agirudā" ;
#     ns1:name "Accelgor" ;
#     ns1:ndex 617 ;
#     ns1:tmname "Agilder" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:weight-kg 25.3 .
#
# ns1:Aegislash a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Stance_Change> ;
#     ns1:category <http://example.org/pokemon/category/Royal_Sword> ;
#     ns1:height-m 1.7 ;
#     ns1:jname "ギルガルド" ;
#     ns1:jtranslit "Girugarudo" ;
#     ns1:name "Aegislash" ;
#     ns1:ndex 681 ;
#     ns1:tmname "Gillgard" ;
#     ns1:type1 <http://example.org/pokemon/type/Steel> ;
#     ns1:type2 <http://example.org/pokemon/type/Ghost> ;
#     ns1:weight-kg 53.0 .
#
# ns1:Aerodactyl a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Rock_Head> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Pressure> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Unnerve> ;
#     ns1:category <http://example.org/pokemon/category/Fossil> ;
#     ns1:color <Purple> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.8 ;
#     ns1:jname "プテラ" ;
#     ns1:jtranslit "Putera" ;
#     ns1:name "Aerodactyl" ;
#     ns1:ndex 142 ;
#     ns1:tmname "Ptera" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 59.0 .
#
# ns1:Aggron a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Sturdy> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Rock_Head> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Heavy_Metal> ;
#     ns1:category <http://example.org/pokemon/category/Iron_Armor> ;
#     ns1:color <Gray> ;
#     ns1:friendship 35 ;
#     ns1:height-m 2.1 ;
#     ns1:jname "ボスゴドラ" ;
#     ns1:jtranslit "Bosugodora" ;
#     ns1:name "Aggron" ;
#     ns1:ndex 306 ;
#     ns1:tmname "Bossgodora" ;
#     ns1:type1 <http://example.org/pokemon/type/Steel> ;
#     ns1:type2 <http://example.org/pokemon/type/Rock> ;
#     ns1:weight-kg 360.0 .
#
# ns1:Aipom a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Run_Away> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Pickup> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Skill_Link> ;
#     ns1:category <http://example.org/pokemon/category/Long_Tail> ;
#     ns1:color <Purple> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.8 ;
#     ns1:jname "エイパム" ;
#     ns1:jtranslit "Eipamu" ;
#     ns1:name "Aipom" ;
#     ns1:ndex 190 ;
#     ns1:tmname "Eipam" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 11.5 .
#
# ns1:Alakazam a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Synchronize> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Inner_Focus> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Magic_Guard> ;
#     ns1:category <http://example.org/pokemon/category/Psi> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.5 ;
#     ns1:jname "フーディン" ;
#     ns1:jtranslit "Fūdin" ;
#     ns1:name "Alakazam" ;
#     ns1:ndex 65 ;
#     ns1:tmname "Foodin" ;
#     ns1:type1 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 48.0 .
#
# ns1:Alcremie a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Sweet_Veil> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Aroma_Veil> ;
#     ns1:category <http://example.org/pokemon/category/Cream> ;
#     ns1:color <White> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.3 ;
#     ns1:jname "マホイップ" ;
#     ns1:jtranslit "Mahoippu" ;
#     ns1:name "Alcremie" ;
#     ns1:ndex 869 ;
#     ns1:tmname "Mawhip" ;
#     ns1:type1 <http://example.org/pokemon/type/Fairy> ;
#     ns1:weight-kg 0.5 .
#
# ns1:Alomomola a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Healer> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Hydration> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Regenerator> ;
#     ns1:category <http://example.org/pokemon/category/Caring> ;
#     ns1:color <Pink> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.2 ;
#     ns1:jname "ママンボウ" ;
#     ns1:name "Alomomola" ;
#     ns1:ndex 594 ;
#     ns1:tmname "Mamanbou" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 31.6 .
#
# ns1:Altaria a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Natural_Cure> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Cloud_Nine> ;
#     ns1:category <http://example.org/pokemon/category/Humming> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.1 ;
#     ns1:jname "チルタリス" ;
#     ns1:jtranslit "Chirutarisu" ;
#     ns1:name "Altaria" ;
#     ns1:ndex 334 ;
#     ns1:tmname "Tyltalis" ;
#     ns1:type1 <http://example.org/pokemon/type/Dragon> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 20.6 .
#
# ns1:Amaura a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Refrigerate> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Snow_Warning> ;
#     ns1:category <http://example.org/pokemon/category/Tundra> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.3 ;
#     ns1:jname "アマルス" ;
#     ns1:jtranslit "Amarusu" ;
#     ns1:name "Amaura" ;
#     ns1:ndex 698 ;
#     ns1:tmname "Amarus" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 25.2 .
#
# ns1:Ambipom a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Technician> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Pickup> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Skill_Link> ;
#     ns1:category <http://example.org/pokemon/category/Long_Tail> ;
#     ns1:color <Purple> ;
#     ns1:friendship 100 ;
#     ns1:height-m 1.2 ;
#     ns1:jname "エテボース" ;
#     ns1:jtranslit "Etebōsu" ;
#     ns1:name "Ambipom" ;
#     ns1:ndex 424 ;
#     ns1:tmname "Eteboth" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 20.3 .
#
# ns1:Amoonguss a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Effect_Spore> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Regenerator> ;
#     ns1:category <http://example.org/pokemon/category/Mushroom> ;
#     ns1:color <White> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.6 ;
#     ns1:jname "モロバレル" ;
#     ns1:name "Amoonguss" ;
#     ns1:ndex 591 ;
#     ns1:tmname "Morobareru" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Poison> ;
#     ns1:weight-kg 10.5 .
#
# ns1:Ampharos a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Static> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Plus> ;
#     ns1:category <http://example.org/pokemon/category/Light> ;
#     ns1:color <Yellow> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.4 ;
#     ns1:jname "デンリュウ" ;
#     ns1:jtranslit "Denryū" ;
#     ns1:name "Ampharos" ;
#     ns1:ndex 181 ;
#     ns1:tmname "Denryu" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 61.5 .
#
# ns1:Annihilape a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Vital_Spirit> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Inner_Focus> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Defiant> ;
#     ns1:category <http://example.org/pokemon/category/Rage_Monkey> ;
#     ns1:color <Gray> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.2 ;
#     ns1:jname "コノヨザル" ;
#     ns1:name "Annihilape" ;
#     ns1:ndex 979 ;
#     ns1:tmname "Konoyozaru" ;
#     ns1:type1 <http://example.org/pokemon/type/Fighting> ;
#     ns1:type2 <http://example.org/pokemon/type/Ghost> ;
#     ns1:weight-kg 56.0 .
#
# ns1:Anorith a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Battle_Armor> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Swift_Swim> ;
#     ns1:category <http://example.org/pokemon/category/Old_Shrimp> ;
#     ns1:color <Gray> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.7 ;
#     ns1:jname "アノプス" ;
#     ns1:jtranslit "Anopusu" ;
#     ns1:name "Anorith" ;
#     ns1:ndex 347 ;
#     ns1:tmname "Anopth" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Bug> ;
#     ns1:weight-kg 12.5 .
#
# ns1:Appletun a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Ripen> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Gluttony> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Thick_Fat> ;
#     ns1:category <http://example.org/pokemon/category/Apple_Nectar> ;
#     ns1:color <Green> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.4 ;
#     ns1:jname "タルップル" ;
#     ns1:jtranslit "Taruppuru" ;
#     ns1:name "Appletun" ;
#     ns1:ndex 842 ;
#     ns1:tmname "Tarupple" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Dragon> ;
#     ns1:weight-kg 13.0 .
#
# ns1:Applin a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Ripen> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Gluttony> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Bulletproof> ;
#     ns1:category <http://example.org/pokemon/category/Apple_Core> ;
#     ns1:color <Green> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.2 ;
#     ns1:jname "カジッチュ" ;
#     ns1:jtranslit "Kajitchu" ;
#     ns1:name "Applin" ;
#     ns1:ndex 840 ;
#     ns1:tmname "Kajicchu" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Dragon> ;
#     ns1:weight-kg 0.5 .
#
# ns1:Araquanid a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Water_Bubble> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Water_Absorb> ;
#     ns1:category <http://example.org/pokemon/category/Water_Bubble> ;
#     ns1:color <Green> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.8 ;
#     ns1:jname "オニシズクモ" ;
#     ns1:name "Araquanid" ;
#     ns1:ndex 752 ;
#     ns1:tmname "Onishizukumo" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:type2 <http://example.org/pokemon/type/Bug> ;
#     ns1:weight-kg 82.0 .
#
# ns1:Arbok a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Intimidate> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Shed_Skin> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Unnerve> ;
#     ns1:category <http://example.org/pokemon/category/Cobra> ;
#     ns1:color <Purple> ;
#     ns1:friendship 70 ;
#     ns1:height-m 3.5 ;
#     ns1:jname "アーボック" ;
#     ns1:jtranslit "Ābokku" ;
#     ns1:name "Arbok" ;
#     ns1:ndex 24 ;
#     ns1:tmname "Arbok" ;
#     ns1:type1 <http://example.org/pokemon/type/Poison> ;
#     ns1:weight-kg 65.0 .
#
# ns1:Arboliva a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Seed_Sower> ;
#     ns1:ability2 <http://example.org/pokemon/ability/> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Harvest> ;
#     ns1:category <http://example.org/pokemon/category/Olive> ;
#     ns1:color <Green> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.4 ;
#     ns1:jname "オリーヴァ" ;
#     ns1:jtranslit "Orīva" ;
#     ns1:name "Arboliva" ;
#     ns1:ndex 930 ;
#     ns1:tmname "Oliva" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 48.2 .
#
# ns1:Arcanine a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Intimidate> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Flash_Fire> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Justified> ;
#     ns1:category <http://example.org/pokemon/category/Legendary> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.9 ;
#     ns1:jname "ウインディ" ;
#     ns1:jtranslit "Uindi" ;
#     ns1:name "Arcanine" ;
#     ns1:ndex 59 ;
#     ns1:tmname "Windie" ;
#     ns1:type1 <http://example.org/pokemon/type/Fire> ;
#     ns1:weight-kg 155.0 .
#
# ns1:Arceus a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Multitype> ;
#     ns1:category <http://example.org/pokemon/category/Alpha> ;
#     ns1:color <White> ;
#     ns1:friendship 0 ;
#     ns1:height-m 3.2 ;
#     ns1:jname "アルセウス" ;
#     ns1:jtranslit "Aruseusu" ;
#     ns1:name "Arceus" ;
#     ns1:ndex 493 ;
#     ns1:tmname "Arceus" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 320.0 .
#
# ns1:Archaludon a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Stamina> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Sturdy> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Stalwart> ;
#     ns1:category <http://example.org/pokemon/category/Alloy> ;
#     ns1:color <White> ;
#     ns1:friendship 50 ;
#     ns1:height-m 2.0 ;
#     ns1:jname "ブリジュラス" ;
#     ns1:jtranslit "Burijurasu" ;
#     ns1:name "Archaludon" ;
#     ns1:ndex 1018 ;
#     ns1:tmname "Briduras" ;
#     ns1:type1 <http://example.org/pokemon/type/Steel> ;
#     ns1:type2 <http://example.org/pokemon/type/Dragon> ;
#     ns1:weight-kg 60.0 .
#
# ns1:Archen a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Defeatist> ;
#     ns1:category <http://example.org/pokemon/category/First_Bird> ;
#     ns1:color <Yellow> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.5 ;
#     ns1:jname "アーケン" ;
#     ns1:jtranslit "Āken" ;
#     ns1:name "Archen" ;
#     ns1:ndex 566 ;
#     ns1:tmname "Archen" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 9.5 .
#
# ns1:Archeops a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Defeatist> ;
#     ns1:category <http://example.org/pokemon/category/First_Bird> ;
#     ns1:color <Yellow> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.4 ;
#     ns1:jname "アーケオス" ;
#     ns1:jtranslit "Ākeosu" ;
#     ns1:name "Archeops" ;
#     ns1:ndex 567 ;
#     ns1:tmname "Archeos" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 32.0 .
#
# ns1:Arctibax a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Thermal_Exchange> ;
#     ns1:ability2 <http://example.org/pokemon/ability/> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Ice_Body> ;
#     ns1:category <http://example.org/pokemon/category/Ice_Fin> ;
#     ns1:color <Blue> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.8 ;
#     ns1:jname "セゴール" ;
#     ns1:jtranslit "Segōru" ;
#     ns1:name "Arctibax" ;
#     ns1:ndex 997 ;
#     ns1:tmname "Segohru" ;
#     ns1:type1 <http://example.org/pokemon/type/Dragon> ;
#     ns1:type2 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 30.0 .
#
# ns1:Arctovish a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Water_Absorb> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Ice_Body> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Slush_Rush> ;
#     ns1:category <http://example.org/pokemon/category/Fossil> ;
#     ns1:color <Blue> ;
#     ns1:friendship 50 ;
#     ns1:height-m 2.0 ;
#     ns1:jname "ウオチルドン" ;
#     ns1:jtranslit "Uochirudon" ;
#     ns1:name "Arctovish" ;
#     ns1:ndex 883 ;
#     ns1:tmname "Uochilldon" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:type2 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 175.0 .
#
# ns1:Arctozolt a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Volt_Absorb> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Static> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Slush_Rush> ;
#     ns1:category <http://example.org/pokemon/category/Fossil> ;
#     ns1:color <Blue> ;
#     ns1:friendship 50 ;
#     ns1:height-m 2.3 ;
#     ns1:jname "パッチルドン" ;
#     ns1:jtranslit "Patchirudon" ;
#     ns1:name "Arctozolt" ;
#     ns1:ndex 881 ;
#     ns1:tmname "Patchilldon" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:type2 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 150.0 .
#
# ns1:Ariados a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Swarm> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Insomnia> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sniper> ;
#     ns1:category <http://example.org/pokemon/category/Long_Leg> ;
#     ns1:color <Red> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.1 ;
#     ns1:jname "アリアドス" ;
#     ns1:jtranslit "Ariadosu" ;
#     ns1:name "Ariados" ;
#     ns1:ndex 168 ;
#     ns1:tmname "Ariados" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:type2 <http://example.org/pokemon/type/Poison> ;
#     ns1:weight-kg 33.5 .
#
# ns1:Armaldo a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Battle_Armor> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Swift_Swim> ;
#     ns1:category <http://example.org/pokemon/category/Plate> ;
#     ns1:color <Gray> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.5 ;
#     ns1:jname "アーマルド" ;
#     ns1:jtranslit "Āmarudo" ;
#     ns1:name "Armaldo" ;
#     ns1:ndex 348 ;
#     ns1:tmname "Armaldo" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Bug> ;
#     ns1:weight-kg 68.2 .
#
# ns1:Armarouge a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Flash_Fire> ;
#     ns1:ability2 <http://example.org/pokemon/ability/> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Weak_Armor> ;
#     ns1:category <http://example.org/pokemon/category/Fire_Warrior> ;
#     ns1:color <Red> ;
#     ns1:friendship 20 ;
#     ns1:height-m 1.5 ;
#     ns1:jname "グレンアルマ" ;
#     ns1:jtranslit "Guren'aruma" ;
#     ns1:name "Armarouge" ;
#     ns1:ndex 936 ;
#     ns1:tmname "Gurenarma" ;
#     ns1:type1 <http://example.org/pokemon/type/Fire> ;
#     ns1:type2 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 85.0 .
#
# ns1:Aromatisse a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Healer> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Aroma_Veil> ;
#     ns1:category <http://example.org/pokemon/category/Fragrance> ;
#     ns1:color <Pink> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.8 ;
#     ns1:jname "フレフワン" ;
#     ns1:jtranslit "Furefuwan" ;
#     ns1:name "Aromatisse" ;
#     ns1:ndex 683 ;
#     ns1:tmname "Frefuwan" ;
#     ns1:type1 <http://example.org/pokemon/type/Fairy> ;
#     ns1:weight-kg 15.5 .
#
# ns1:Aron a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Sturdy> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Rock_Head> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Heavy_Metal> ;
#     ns1:category <http://example.org/pokemon/category/Iron_Armor> ;
#     ns1:color <Gray> ;
#     ns1:friendship 35 ;
#     ns1:height-m 0.4 ;
#     ns1:jname "ココドラ" ;
#     ns1:jtranslit "Kokodora" ;
#     ns1:name "Aron" ;
#     ns1:ndex 304 ;
#     ns1:tmname "Cokodora" ;
#     ns1:type1 <http://example.org/pokemon/type/Steel> ;
#     ns1:type2 <http://example.org/pokemon/type/Rock> ;
#     ns1:weight-kg 60.0 .
#
# ns1:Arrokuda a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Swift_Swim> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Propeller_Tail> ;
#     ns1:category <http://example.org/pokemon/category/Rush> ;
#     ns1:color <Brown> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.5 ;
#     ns1:jname "サシカマス" ;
#     ns1:jtranslit "Sashikamasu" ;
#     ns1:name "Arrokuda" ;
#     ns1:ndex 846 ;
#     ns1:tmname "Sasikamasu" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 1.0 .
#
# ns1:Articuno a ns1:pokemon ;
#     ns1:jname "フリーザー" ;
#     ns1:jtranslit "Furīzā" ;
#     ns1:name "Articuno" ;
#     ns1:ndex 144 ;
#     ns1:tmname "Freezer" ;
#     ns1:type1 <http://example.org/pokemon/type/Ice> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> .
#
# ns1:Audino a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Healer> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Regenerator> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Klutz> ;
#     ns1:category <http://example.org/pokemon/category/Hearing> ;
#     ns1:color <Pink> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.1 ;
#     ns1:jname "タブンネ" ;
#     ns1:name "Audino" ;
#     ns1:ndex 531 ;
#     ns1:tmname "Tabunne" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 31.0 .
#
# ns1:Aurorus a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Refrigerate> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Snow_Warning> ;
#     ns1:category <http://example.org/pokemon/category/Tundra> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 2.7 ;
#     ns1:jname "アマルルガ" ;
#     ns1:name "Aurorus" ;
#     ns1:ndex 699 ;
#     ns1:tmname "Amaruruga" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 225.0 .
#
# ns1:Avalugg a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Own_Tempo> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Ice_Body> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sturdy> ;
#     ns1:category <http://example.org/pokemon/category/Iceberg> ;
#     ns1:height-m 2.0 ;
#     ns1:jname "クレベース" ;
#     ns1:jtranslit "Kurebēsu" ;
#     ns1:name "Avalugg" ;
#     ns1:ndex 713 ;
#     ns1:tmname "Crebase" ;
#     ns1:type1 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 505.0 .
#
# ns1:Axew a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Rivalry> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Mold_Breaker> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Unnerve> ;
#     ns1:category <http://example.org/pokemon/category/Tusk> ;
#     ns1:color <Green> ;
#     ns1:friendship 35 ;
#     ns1:height-m 0.6 ;
#     ns1:jname "キバゴ" ;
#     ns1:name "Axew" ;
#     ns1:ndex 610 ;
#     ns1:tmname "Kibago" ;
#     ns1:type1 <http://example.org/pokemon/type/Dragon> ;
#     ns1:weight-kg 18.0 .
#
# ns1:Azelf a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Levitate> ;
#     ns1:category <http://example.org/pokemon/category/Willpower> ;
#     ns1:color <Blue> ;
#     ns1:friendship 140 ;
#     ns1:height-m 0.3 ;
#     ns1:jname "アグノム" ;
#     ns1:jtranslit "Agunomu" ;
#     ns1:name "Azelf" ;
#     ns1:ndex 482 ;
#     ns1:tmname "Agnome" ;
#     ns1:type1 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 0.3 .
#
# ns1:Azumarill a ns1:pokemon ;
#     ns1:jname "マリルリ" ;
#     ns1:jtranslit "Mariruri" ;
#     ns1:name "Azumarill" ;
#     ns1:ndex 184 ;
#     ns1:tmname "Marilli" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:type2 <http://example.org/pokemon/type/Fairy> .
#
# ns1:Azurill a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Thick_Fat> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Huge_Power> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sap_Sipper> ;
#     ns1:category <http://example.org/pokemon/category/Polka_Dot> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.2 ;
#     ns1:jname "ルリリ" ;
#     ns1:name "Azurill" ;
#     ns1:ndex 298 ;
#     ns1:tmname "Ruriri" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:type2 <http://example.org/pokemon/type/Fairy> ;
#     ns1:weight-kg 2.0 .
#
# ns1:Bagon a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Rock_Head> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sheer_Force> ;
#     ns1:category <http://example.org/pokemon/category/Rock_Head> ;
#     ns1:color <Blue> ;
#     ns1:friendship 35 ;
#     ns1:height-m 0.6 ;
#     ns1:jname "タツベイ" ;
#     ns1:jtranslit "Tatsubei" ;
#     ns1:name "Bagon" ;
#     ns1:ndex 371 ;
#     ns1:tmname "Tatsubay" ;
#     ns1:type1 <http://example.org/pokemon/type/Dragon> ;
#     ns1:weight-kg 42.1 .
#
# ns1:Baltoy a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Levitate> ;
#     ns1:category <http://example.org/pokemon/category/Clay_Doll> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.5 ;
#     ns1:jname "ヤジロン" ;
#     ns1:jtranslit "Yajiron" ;
#     ns1:name "Baltoy" ;
#     ns1:ndex 343 ;
#     ns1:tmname "Yajilon" ;
#     ns1:type1 <http://example.org/pokemon/type/Ground> ;
#     ns1:type2 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 21.5 .
#
# ns1:Banette a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Insomnia> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Frisk> ;
#     ns1:category <http://example.org/pokemon/category/Marionette> ;
#     ns1:height-m 1.1 ;
#     ns1:jname "ジュペッタ" ;
#     ns1:jtranslit "Jupetta" ;
#     ns1:name "Banette" ;
#     ns1:ndex 354 ;
#     ns1:tmname "Juppeta" ;
#     ns1:type1 <http://example.org/pokemon/type/Ghost> ;
#     ns1:weight-kg 12.5 .
#
# ns1:Barbaracle a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Tough_Claws> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Sniper> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Pickpocket> ;
#     ns1:category <http://example.org/pokemon/category/Collective> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.3 ;
#     ns1:jname "ガメノデス" ;
#     ns1:jtranslit "Gamenodesu" ;
#     ns1:name "Barbaracle" ;
#     ns1:ndex 689 ;
#     ns1:tmname "Gamenodes" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 96.0 .
#
# ns1:Barboach a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Oblivious> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Anticipation> ;
#     ns1:category <http://example.org/pokemon/category/Whiskers> ;
#     ns1:height-m 0.4 ;
#     ns1:jname "ドジョッチ" ;
#     ns1:jtranslit "Dojotchi" ;
#     ns1:name "Barboach" ;
#     ns1:ndex 339 ;
#     ns1:tmname "Dojoach" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:type2 <http://example.org/pokemon/type/Ground> ;
#     ns1:weight-kg 1.9 .
#
# ns1:Barraskewda a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Swift_Swim> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Propeller_Tail> ;
#     ns1:category <http://example.org/pokemon/category/Skewer> ;
#     ns1:color <Brown> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.3 ;
#     ns1:jname "カマスジョー" ;
#     ns1:jtranslit "Kamasujō" ;
#     ns1:name "Barraskewda" ;
#     ns1:ndex 847 ;
#     ns1:tmname "Kamasujaw" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 30.0 .
#
# ns1:Basculegion a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Swift_Swim> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Adaptability> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Mold_Breaker> ;
#     ns1:category <http://example.org/pokemon/category/Big_Fish> ;
#     ns1:color <Green> ;
#     ns1:friendship 50 ;
#     ns1:height-m 3.0 ;
#     ns1:jname "イダイトウ" ;
#     ns1:name "Basculegion" ;
#     ns1:ndex 902 ;
#     ns1:tmname "Idaitou" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:type2 <http://example.org/pokemon/type/Ghost> ;
#     ns1:weight-kg 110.0 .
#
# ns1:Basculin a ns1:pokemon ;
#     ns1:jname "バスラオ" ;
#     ns1:jtranslit "Basurao" ;
#     ns1:name "Basculin" ;
#     ns1:ndex 550 ;
#     ns1:tmname "Bassrao" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> .
#
# ns1:Bastiodon a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Sturdy> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Soundproof> ;
#     ns1:category <http://example.org/pokemon/category/Shield> ;
#     ns1:color <Gray> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.3 ;
#     ns1:jname "トリデプス" ;
#     ns1:jtranslit "Toridepusu" ;
#     ns1:name "Bastiodon" ;
#     ns1:ndex 411 ;
#     ns1:tmname "Torideps" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Steel> ;
#     ns1:weight-kg 149.5 .
#
# ns1:Baxcalibur a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Thermal_Exchange> ;
#     ns1:ability2 <http://example.org/pokemon/ability/> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Ice_Body> ;
#     ns1:category <http://example.org/pokemon/category/Ice_Dragon> ;
#     ns1:color <Blue> ;
#     ns1:friendship 50 ;
#     ns1:height-m 2.1 ;
#     ns1:jname "セグレイブ" ;
#     ns1:jtranslit "Segureibu" ;
#     ns1:name "Baxcalibur" ;
#     ns1:ndex 998 ;
#     ns1:tmname "Seglaive" ;
#     ns1:type1 <http://example.org/pokemon/type/Dragon> ;
#     ns1:type2 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 210.0 .
#
# ns1:Bayleef a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Overgrow> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Leaf_Guard> ;
#     ns1:category <http://example.org/pokemon/category/Leaf> ;
#     ns1:color <Green> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.2 ;
#     ns1:jname "ベイリーフ" ;
#     ns1:jtranslit "Beirīfu" ;
#     ns1:name "Bayleef" ;
#     ns1:ndex 153 ;
#     ns1:tmname "Bayleaf" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:weight-kg 15.8 .
#
# ns1:Beartic a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Snow_Cloak> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Slush_Rush> ;
#     ns1:category <http://example.org/pokemon/category/Freezing> ;
#     ns1:jname "ツンベアー" ;
#     ns1:jtranslit "Tsunbeā" ;
#     ns1:name "Beartic" ;
#     ns1:tmname "Tunbear" ;
#     ns1:type1 <http://example.org/pokemon/type/Ice> .
#
# ns1:Beautifly a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Swarm> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Rivalry> ;
#     ns1:category <http://example.org/pokemon/category/Butterfly> ;
#     ns1:color <Yellow> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.0 ;
#     ns1:jname "アゲハント" ;
#     ns1:jtranslit "Agehanto" ;
#     ns1:name "Beautifly" ;
#     ns1:ndex 267 ;
#     ns1:tmname "Agehunt" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 28.4 .
#
# ns1:Beedrill a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Swarm> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sniper> ;
#     ns1:category <http://example.org/pokemon/category/Poison_Bee> ;
#     ns1:color <Yellow> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.0 ;
#     ns1:jname "スピアー" ;
#     ns1:jtranslit "Supiā" ;
#     ns1:name "Beedrill" ;
#     ns1:ndex 15 ;
#     ns1:tmname "Spear" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:type2 <http://example.org/pokemon/type/Poison> ;
#     ns1:weight-kg 29.5 .
#
# ns1:Beheeyem a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Telepathy> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Synchronize> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Analytic> ;
#     ns1:category <http://example.org/pokemon/category/Cerebral> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.0 ;
#     ns1:jname "オーベム" ;
#     ns1:jtranslit "Ōbemu" ;
#     ns1:name "Beheeyem" ;
#     ns1:ndex 606 ;
#     ns1:tmname "Ohbem" ;
#     ns1:type1 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 34.5 .
#
# ns1:Beldum a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Clear_Body> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Light_Metal> ;
#     ns1:category <http://example.org/pokemon/category/Iron_Ball> ;
#     ns1:color <Blue> ;
#     ns1:friendship 35 ;
#     ns1:height-m 0.6 ;
#     ns1:jname "ダンバル" ;
#     ns1:jtranslit "Danbaru" ;
#     ns1:name "Beldum" ;
#     ns1:ndex 374 ;
#     ns1:tmname "Dumbber" ;
#     ns1:type1 <http://example.org/pokemon/type/Steel> ;
#     ns1:type2 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 95.2 .
#
# ns1:Bellibolt a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Electromorphosis> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Static> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Damp> ;
#     ns1:category <http://example.org/pokemon/category/EleFrog> ;
#     ns1:color <Green> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.2 ;
#     ns1:jname "ハラバリー" ;
#     ns1:jtranslit "Harabarī" ;
#     ns1:name "Bellibolt" ;
#     ns1:ndex 939 ;
#     ns1:tmname "Harabarie" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 113.0 .
#
# ns1:Bellossom a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Chlorophyll> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Healer> ;
#     ns1:category <http://example.org/pokemon/category/Flower> ;
#     ns1:color <Green> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.4 ;
#     ns1:jname "キレイハナ" ;
#     ns1:name "Bellossom" ;
#     ns1:ndex 182 ;
#     ns1:tmname "Kireihana" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:weight-kg 5.8 .
#
# ns1:Bellsprout a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Chlorophyll> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Gluttony> ;
#     ns1:category <http://example.org/pokemon/category/Flower> ;
#     ns1:color <Green> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.7 ;
#     ns1:jname "マダツボミ" ;
#     ns1:name "Bellsprout" ;
#     ns1:ndex 69 ;
#     ns1:tmname "Madatsubomi" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Poison> ;
#     ns1:weight-kg 4.0 .
#
# ns1:Bergmite a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Own_Tempo> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Ice_Body> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sturdy> ;
#     ns1:category <http://example.org/pokemon/category/Ice_Chunk> ;
#     ns1:height-m 1.0 ;
#     ns1:jname "カチコール" ;
#     ns1:jtranslit "Kachikōru" ;
#     ns1:name "Bergmite" ;
#     ns1:ndex 712 ;
#     ns1:tmname "Kachikohru" ;
#     ns1:type1 <http://example.org/pokemon/type/Ice> ;
#     ns1:weight-kg 99.5 .
#
# ns1:Bewear a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Fluffy> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Klutz> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Unnerve> ;
#     ns1:category <http://example.org/pokemon/category/Strong_Arm> ;
#     ns1:color <Pink> ;
#     ns1:friendship 70 ;
#     ns1:height-m 2.1 ;
#     ns1:jname "キテルグマ" ;
#     ns1:name "Bewear" ;
#     ns1:ndex 760 ;
#     ns1:tmname "Kiteruguma" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:type2 <http://example.org/pokemon/type/Fighting> ;
#     ns1:weight-kg 135.0 .
#
# ns1:Bibarel a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Simple> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Unaware> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Moody> ;
#     ns1:category <http://example.org/pokemon/category/Beaver> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.0 ;
#     ns1:jname "ビーダル" ;
#     ns1:jtranslit "Bīdaru" ;
#     ns1:name "Bibarel" ;
#     ns1:ndex 400 ;
#     ns1:tmname "Beadaru" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:type2 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 31.5 .
#
# ns1:Bidoof a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Simple> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Unaware> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Moody> ;
#     ns1:category <http://example.org/pokemon/category/Plump_Mouse> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.5 ;
#     ns1:jname "ビッパ" ;
#     ns1:name "Bidoof" ;
#     ns1:ndex 399 ;
#     ns1:tmname "Bippa" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 20.0 .
#
# ns1:Binacle a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Tough_Claws> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Sniper> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Pickpocket> ;
#     ns1:category <http://example.org/pokemon/category/Two-Handed> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.5 ;
#     ns1:jname "カメテテ" ;
#     ns1:name "Binacle" ;
#     ns1:ndex 688 ;
#     ns1:tmname "Kametete" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:type2 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 31.0 .
#
# ns1:Bisharp a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Defiant> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Inner_Focus> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Pressure> ;
#     ns1:category <http://example.org/pokemon/category/Sword_Blade> ;
#     ns1:color <Red> ;
#     ns1:friendship 35 ;
#     ns1:height-m 1.6 ;
#     ns1:jname "キリキザン" ;
#     ns1:name "Bisharp" ;
#     ns1:ndex 625 ;
#     ns1:tmname "Kirikizan" ;
#     ns1:type1 <http://example.org/pokemon/type/Dark> ;
#     ns1:type2 <http://example.org/pokemon/type/Steel> ;
#     ns1:weight-kg 70.0 .
#
# ns1:Blacephalon a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Beast_Boost> ;
#     ns1:category <http://example.org/pokemon/category/Fireworks> ;
#     ns1:color <White> ;
#     ns1:friendship 0 ;
#     ns1:height-m 1.8 ;
#     ns1:jname "ズガドーン" ;
#     ns1:jtranslit "Zugadōn" ;
#     ns1:name "Blacephalon" ;
#     ns1:ndex 806 ;
#     ns1:tmname "Zugadoon" ;
#     ns1:type1 <http://example.org/pokemon/type/Fire> ;
#     ns1:type2 <http://example.org/pokemon/type/Ghost> ;
#     ns1:weight-kg 13.0 .
#
# ns1:Blastoise a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Torrent> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Rain_Dish> ;
#     ns1:category <http://example.org/pokemon/category/Shellfish> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.6 ;
#     ns1:jname "カメックス" ;
#     ns1:jtranslit "Kamekkusu" ;
#     ns1:name "Blastoise" ;
#     ns1:ndex 9 ;
#     ns1:tmname "Kamex" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 85.5 .
#
# ns1:Blaziken a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Blaze> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Speed_Boost> ;
#     ns1:category <http://example.org/pokemon/category/Blaze> ;
#     ns1:color <Red> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.9 ;
#     ns1:jname "バシャーモ" ;
#     ns1:jtranslit "Bashāmo" ;
#     ns1:name "Blaziken" ;
#     ns1:ndex 257 ;
#     ns1:tmname "Bursyamo" ;
#     ns1:type1 <http://example.org/pokemon/type/Fire> ;
#     ns1:type2 <http://example.org/pokemon/type/Fighting> ;
#     ns1:weight-kg 52.0 .
#
# ns1:Blipbug a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Swarm> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Compound_Eyes> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Telepathy> ;
#     ns1:category <http://example.org/pokemon/category/Larva> ;
#     ns1:color <Blue> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.4 ;
#     ns1:jname "サッチムシ" ;
#     ns1:jtranslit "Satchimushi" ;
#     ns1:name "Blipbug" ;
#     ns1:ndex 824 ;
#     ns1:tmname "Sacchimushi" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:weight-kg 8.0 .
#
# ns1:Blissey a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Natural_Cure> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Serene_Grace> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Healer> ;
#     ns1:category <http://example.org/pokemon/category/Happiness> ;
#     ns1:height-m 1.5 ;
#     ns1:jname "ハピナス" ;
#     ns1:jtranslit "Hapinasu" ;
#     ns1:name "Blissey" ;
#     ns1:ndex 242 ;
#     ns1:tmname "Happinas" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 46.8 .
#
# ns1:Blitzle a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Lightning_Rod> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Motor_Drive> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sap_Sipper> ;
#     ns1:category <http://example.org/pokemon/category/Electrified> ;
#     ns1:color <Black> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.8 ;
#     ns1:jname "シママ" ;
#     ns1:name "Blitzle" ;
#     ns1:ndex 522 ;
#     ns1:tmname "Shimama" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 29.8 .
#
# ns1:Boldore a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Sturdy> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Weak_Armor> ;
#     ns1:category <http://example.org/pokemon/category/Ore> ;
#     ns1:jname "ガントル" ;
#     ns1:jtranslit "Gantoru" ;
#     ns1:name "Boldore" ;
#     ns1:tmname "Gantle" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> .
#
# ns1:Boltund a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Strong_Jaw> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Competitive> ;
#     ns1:category <http://example.org/pokemon/category/Dog> ;
#     ns1:color <Yellow> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.0 ;
#     ns1:jname "パルスワン" ;
#     ns1:jtranslit "Parusuwan" ;
#     ns1:name "Boltund" ;
#     ns1:ndex 836 ;
#     ns1:tmname "Pulsewan" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 34.0 .
#
# ns1:Bombirdier a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Big_Pecks> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Keen_Eye> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Rocky_Payload> ;
#     ns1:category <http://example.org/pokemon/category/Item_Drop> ;
#     ns1:color <White> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.5 ;
#     ns1:jname "オトシドリ" ;
#     ns1:name "Bombirdier" ;
#     ns1:ndex 962 ;
#     ns1:tmname "Otoshidori" ;
#     ns1:type1 <http://example.org/pokemon/type/Flying> ;
#     ns1:type2 <http://example.org/pokemon/type/Dark> ;
#     ns1:weight-kg 42.9 .
#
# ns1:Bonsly a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Sturdy> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Rock_Head> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Rattled> ;
#     ns1:category <http://example.org/pokemon/category/Bonsai> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.5 ;
#     ns1:jname "ウソハチ" ;
#     ns1:name "Bonsly" ;
#     ns1:ndex 438 ;
#     ns1:tmname "Usohachi" ;
#     ns1:type1 <http://example.org/pokemon/type/Rock> ;
#     ns1:weight-kg 15.0 .
#
# ns1:Bouffalant a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Reckless> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Sap_Sipper> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Soundproof> ;
#     ns1:category <http://example.org/pokemon/category/Bash_Buffalo> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.6 ;
#     ns1:jname "バッフロン" ;
#     ns1:jtranslit "Baffuron" ;
#     ns1:name "Bouffalant" ;
#     ns1:ndex 626 ;
#     ns1:tmname "Buffron" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 94.6 .
#
# ns1:Bounsweet a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Leaf_Guard> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Oblivious> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sweet_Veil> ;
#     ns1:category <http://example.org/pokemon/category/Fruit> ;
#     ns1:color <Purple> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.3 ;
#     ns1:jname "アマカジ" ;
#     ns1:name "Bounsweet" ;
#     ns1:ndex 761 ;
#     ns1:tmname "Amakaji" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:weight-kg 3.2 .
#
# ns1:Braixen a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Blaze> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Magician> ;
#     ns1:category <http://example.org/pokemon/category/Fox> ;
#     ns1:color <Red> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.0 ;
#     ns1:jname "テールナー" ;
#     ns1:jtranslit "Tērunā" ;
#     ns1:name "Braixen" ;
#     ns1:ndex 654 ;
#     ns1:tmname "Tairenar" ;
#     ns1:type1 <http://example.org/pokemon/type/Fire> ;
#     ns1:weight-kg 14.5 .
#
# ns1:Brambleghast a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Wind_Rider> ;
#     ns1:ability2 <http://example.org/pokemon/ability/> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Infiltrator> ;
#     ns1:category <http://example.org/pokemon/category/Tumbleweed> ;
#     ns1:color <Brown> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.2 ;
#     ns1:jname "アノホラグサ" ;
#     ns1:name "Brambleghast" ;
#     ns1:ndex 947 ;
#     ns1:tmname "Anohoragusa" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Ghost> ;
#     ns1:weight-kg 6.0 .
#
# ns1:Bramblin a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Wind_Rider> ;
#     ns1:ability2 <http://example.org/pokemon/ability/> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Infiltrator> ;
#     ns1:category <http://example.org/pokemon/category/Tumbleweed> ;
#     ns1:color <Brown> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.6 ;
#     ns1:jname "アノクサ" ;
#     ns1:name "Bramblin" ;
#     ns1:ndex 946 ;
#     ns1:tmname "Anokusa" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Ghost> ;
#     ns1:weight-kg 0.6 .
#
# ns1:Braviary a ns1:pokemon ;
#     ns1:jname "ウォーグル" ;
#     ns1:jtranslit "Wōguru" ;
#     ns1:name "Braviary" ;
#     ns1:ndex 628 ;
#     ns1:tmname "Warrgle" .
#
# ns1:Breloom a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Effect_Spore> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Poison_Heal> ;
#     ns1:category <http://example.org/pokemon/category/Mushroom> ;
#     ns1:height-m 1.2 ;
#     ns1:jname "キノガッサ" ;
#     ns1:name "Breloom" ;
#     ns1:ndex 286 ;
#     ns1:tmname "Kinogassa" ;
#     ns1:type1 <http://example.org/pokemon/type/Grass> ;
#     ns1:type2 <http://example.org/pokemon/type/Fighting> ;
#     ns1:weight-kg 39.2 .
#
# ns1:Brionne a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Torrent> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Liquid_Voice> ;
#     ns1:category <http://example.org/pokemon/category/Pop_Star> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.6 ;
#     ns1:jname "オシャマリ" ;
#     ns1:jtranslit "Oshamari" ;
#     ns1:name "Brionne" ;
#     ns1:ndex 729 ;
#     ns1:tmname "Osyamari" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 17.5 .
#
# ns1:Bronzong a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Levitate> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Heatproof> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Heavy_Metal> ;
#     ns1:category <http://example.org/pokemon/category/Bronze_Bell> ;
#     ns1:color <Green> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.3 ;
#     ns1:jname "ドータクン" ;
#     ns1:jtranslit "Dōtakun" ;
#     ns1:name "Bronzong" ;
#     ns1:ndex 437 ;
#     ns1:tmname "Dohtakun" ;
#     ns1:type1 <http://example.org/pokemon/type/Steel> ;
#     ns1:type2 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 187.0 .
#
# ns1:Bronzor a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Levitate> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Heatproof> ;
# ...
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.2 ;
#     ns1:jname "ヨワシ" ;
#     ns1:name "Wishiwashi" ;
#     ns1:ndex 746 ;
#     ns1:tmname "Yowashi" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 0.3 .
#
# ns1:Wo-Chien a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Tablets_of_Ruin> ;
#     ns1:category <http://example.org/pokemon/category/Ruinous> ;
#     ns1:color <Brown> ;
#     ns1:friendship 0 ;
#     ns1:height-m 1.5 ;
#     ns1:jname "チオンジェン" ;
#     ns1:name "Wo-Chien" ;
#     ns1:ndex 1001 ;
#     ns1:tmname "Chionjen" ;
#     ns1:type1 <http://example.org/pokemon/type/Dark> ;
#     ns1:type2 <http://example.org/pokemon/type/Grass> ;
#     ns1:weight-kg 74.2 .
#
# ns1:Wobbuffet a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Shadow_Tag> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Telepathy> ;
#     ns1:category <http://example.org/pokemon/category/Patient> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.3 ;
#     ns1:jname "ソーナンス" ;
#     ns1:jtranslit "Sōnansu" ;
#     ns1:name "Wobbuffet" ;
#     ns1:ndex 202 ;
#     ns1:tmname "Sonans" ;
#     ns1:type1 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 28.5 .
#
# ns1:Woobat a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Unaware> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Klutz> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Simple> ;
#     ns1:category <http://example.org/pokemon/category/Bat> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.4 ;
#     ns1:jname "コロモリ" ;
#     ns1:name "Woobat" ;
#     ns1:ndex 527 ;
#     ns1:tmname "Koromori" ;
#     ns1:type1 <http://example.org/pokemon/type/Psychic> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 2.1 .
#
# ns1:Wooloo a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Fluffy> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Run_Away> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Bulletproof> ;
#     ns1:category <http://example.org/pokemon/category/Sheep> ;
#     ns1:color <White> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.6 ;
#     ns1:jname "ウールー" ;
#     ns1:jtranslit "Ūrū" ;
#     ns1:name "Wooloo" ;
#     ns1:ndex 831 ;
#     ns1:tmname "Wooluu" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 6.0 .
#
# ns1:Wooper a ns1:pokemon ;
#     ns1:jname "ウパー" ;
#     ns1:jtranslit "Upā" ;
#     ns1:name "Wooper" ;
#     ns1:ndex 194 ;
#     ns1:tmname "Upah" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:type2 <http://example.org/pokemon/type/Ground> .
#
# ns1:Wormadam a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Anticipation> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Overcoat> ;
#     ns1:category <http://example.org/pokemon/category/Bagworm> ;
#     ns1:color <Green> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.5 ;
#     ns1:jname "ミノマダム" ;
#     ns1:jtranslit "Minomadamu" ;
#     ns1:name "Wormadam" ;
#     ns1:ndex 413 ;
#     ns1:tmname "Minomadam" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:type2 <http://example.org/pokemon/type/Grass> ;
#     ns1:weight-kg 6.5 .
#
# ns1:Wugtrio a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Gooey> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Rattled> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sand_Veil> ;
#     ns1:category <http://example.org/pokemon/category/Garden_Eel> ;
#     ns1:color <Red> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.2 ;
#     ns1:jname "ウミトリオ" ;
#     ns1:jtranslit "Umitorio" ;
#     ns1:name "Wugtrio" ;
#     ns1:ndex 961 ;
#     ns1:tmname "Umitrio" ;
#     ns1:type1 <http://example.org/pokemon/type/Water> ;
#     ns1:weight-kg 5.4 .
#
# ns1:Wurmple a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Shield_Dust> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Run_Away> ;
#     ns1:category <http://example.org/pokemon/category/Worm> ;
#     ns1:color <Red> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.3 ;
#     ns1:jname "ケムッソ" ;
#     ns1:name "Wurmple" ;
#     ns1:ndex 265 ;
#     ns1:tmname "Kemusso" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:weight-kg 3.6 .
#
# ns1:Wynaut a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Shadow_Tag> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Telepathy> ;
#     ns1:category <http://example.org/pokemon/category/Bright> ;
#     ns1:color <Blue> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.6 ;
#     ns1:jname "ソーナノ" ;
#     ns1:jtranslit "Sōnano" ;
#     ns1:name "Wynaut" ;
#     ns1:ndex 360 ;
#     ns1:tmname "Sohnano" ;
#     ns1:type1 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 14.0 .
#
# ns1:Wyrdeer a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Intimidate> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Frisk> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sap_Sipper> ;
#     ns1:category <http://example.org/pokemon/category/Big_Horn> ;
#     ns1:color <Gray> ;
#     ns1:friendship 50 ;
#     ns1:height-m 1.8 ;
#     ns1:jname "アヤシシ" ;
#     ns1:name "Wyrdeer" ;
#     ns1:ndex 899 ;
#     ns1:tmname "Ayashishi" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:type2 <http://example.org/pokemon/type/Psychic> ;
#     ns1:weight-kg 95.1 .
#
# ns1:Xatu a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Synchronize> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Early_Bird> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Magic_Bounce> ;
#     ns1:category <http://example.org/pokemon/category/Mystic> ;
#     ns1:color <Green> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.5 ;
#     ns1:jname "ネイティオ" ;
#     ns1:jtranslit "Neitio" ;
#     ns1:name "Xatu" ;
#     ns1:ndex 178 ;
#     ns1:tmname "Natio" ;
#     ns1:type1 <http://example.org/pokemon/type/Psychic> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 15.0 .
#
# ns1:Xerneas a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Fairy_Aura> ;
#     ns1:category <http://example.org/pokemon/category/Life> ;
#     ns1:color <Blue> ;
#     ns1:friendship 0 ;
#     ns1:height-m 3.0 ;
#     ns1:jname "ゼルネアス" ;
#     ns1:jtranslit "Zeruneasu" ;
#     ns1:name "Xerneas" ;
#     ns1:ndex 716 ;
#     ns1:tmname "Xerneas" ;
#     ns1:type1 <http://example.org/pokemon/type/Fairy> ;
#     ns1:weight-kg 215.0 .
#
# ns1:Xurkitree a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Beast_Boost> ;
#     ns1:category <http://example.org/pokemon/category/Glowing> ;
#     ns1:color <Black> ;
#     ns1:friendship 0 ;
#     ns1:height-m 3.8 ;
#     ns1:jname "デンジュモク" ;
#     ns1:jtranslit "Denjumoku" ;
#     ns1:name "Xurkitree" ;
#     ns1:ndex 796 ;
#     ns1:tmname "Denjyumoku" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 100.0 .
#
# ns1:Yamask a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Mummy> ;
#     ns1:category <http://example.org/pokemon/category/Spirit> ;
#     ns1:color <Black> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.5 ;
#     ns1:jname "デスマス" ;
#     ns1:name "Yamask" ;
#     ns1:ndex 562 ;
#     ns1:tmname "Desumasu" ;
#     ns1:type1 <http://example.org/pokemon/type/Ghost> ;
#     ns1:weight-kg 1.5 .
#
# ns1:Yamper a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Ball_Fetch> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Rattled> ;
#     ns1:category <http://example.org/pokemon/category/Puppy> ;
#     ns1:color <Yellow> ;
#     ns1:friendship 50 ;
#     ns1:height-m 0.3 ;
#     ns1:jname "ワンパチ" ;
#     ns1:name "Yamper" ;
#     ns1:ndex 835 ;
#     ns1:tmname "Wanpachi" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 13.5 .
#
# ns1:Yanma a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Speed_Boost> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Compound_Eyes> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Frisk> ;
#     ns1:category <http://example.org/pokemon/category/Clear_Wing> ;
#     ns1:height-m 1.2 ;
#     ns1:jname "ヤンヤンマ" ;
#     ns1:name "Yanma" ;
#     ns1:ndex 193 ;
#     ns1:tmname "Yanyanma" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 38.0 .
#
# ns1:Yanmega a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Speed_Boost> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Tinted_Lens> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Frisk> ;
#     ns1:category <http://example.org/pokemon/category/Ogre_Darner> ;
#     ns1:color <Green> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.9 ;
#     ns1:jname "メガヤンマ" ;
#     ns1:name "Yanmega" ;
#     ns1:ndex 469 ;
#     ns1:tmname "Megayanma" ;
#     ns1:type1 <http://example.org/pokemon/type/Bug> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 51.5 .
#
# ns1:Yungoos a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Stakeout> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Strong_Jaw> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Adaptability> ;
#     ns1:category <http://example.org/pokemon/category/Loitering> ;
#     ns1:color <Brown> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.4 ;
#     ns1:jname "ヤングース" ;
#     ns1:jtranslit "Yangūsu" ;
#     ns1:name "Yungoos" ;
#     ns1:ndex 734 ;
#     ns1:tmname "Youngoose" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 6.0 .
#
# ns1:Yveltal a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Dark_Aura> ;
#     ns1:category <http://example.org/pokemon/category/Destruction> ;
#     ns1:color <Red> ;
#     ns1:friendship 0 ;
#     ns1:height-m 5.8 ;
#     ns1:jname "イベルタル" ;
#     ns1:jtranslit "Iberutaru" ;
#     ns1:name "Yveltal" ;
#     ns1:ndex 717 ;
#     ns1:tmname "Yveltal" ;
#     ns1:type1 <http://example.org/pokemon/type/Dark> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 203.0 .
#
# ns1:Zacian a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Intrepid_Sword> ;
#     ns1:category <http://example.org/pokemon/category/Warrior> ;
#     ns1:color <Blue> ;
#     ns1:friendship 0 ;
#     ns1:height-m 2.8 ;
#     ns1:jname "ザシアン" ;
#     ns1:jtranslit "Zashian" ;
#     ns1:name "Zacian" ;
#     ns1:ndex 888 ;
#     ns1:tmname "Zacian" ;
#     ns1:type1 <http://example.org/pokemon/type/Fairy> ;
#     ns1:weight-kg 110.0 .
#
# ns1:Zamazenta a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Dauntless_Shield> ;
#     ns1:category <http://example.org/pokemon/category/Warrior> ;
#     ns1:color <Red> ;
#     ns1:friendship 0 ;
#     ns1:height-m 2.9 ;
#     ns1:jname "ザマゼンタ" ;
#     ns1:name "Zamazenta" ;
#     ns1:ndex 889 ;
#     ns1:tmname "Zamazenta" ;
#     ns1:type1 <http://example.org/pokemon/type/Fighting> ;
#     ns1:weight-kg 210.0 .
#
# ns1:Zangoose a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Immunity> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Toxic_Boost> ;
#     ns1:category <http://example.org/pokemon/category/Cat_Ferret> ;
#     ns1:color <White> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.3 ;
#     ns1:jname "ザングース" ;
#     ns1:jtranslit "Zangūsu" ;
#     ns1:name "Zangoose" ;
#     ns1:ndex 335 ;
#     ns1:tmname "Zangoose" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> ;
#     ns1:weight-kg 40.3 .
#
# ns1:Zapdos a ns1:pokemon ;
#     ns1:jname "サンダー" ;
#     ns1:jtranslit "Sandā" ;
#     ns1:name "Zapdos" ;
#     ns1:ndex 145 ;
#     ns1:tmname "Thunder" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> .
#
# ns1:Zarude a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Leaf_Guard> ;
#     ns1:category <http://example.org/pokemon/category/Rogue_Monkey> ;
#     ns1:color <Black> ;
#     ns1:friendship 0 ;
#     ns1:height-m 1.8 ;
#     ns1:jname "ザルード" ;
#     ns1:jtranslit "Zarūdo" ;
#     ns1:name "Zarude" ;
#     ns1:ndex 893 ;
#     ns1:tmname "Zarude" ;
#     ns1:type1 <http://example.org/pokemon/type/Dark> ;
#     ns1:type2 <http://example.org/pokemon/type/Grass> ;
#     ns1:weight-kg 70.0 .
#
# ns1:Zebstrika a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Lightning_Rod> ;
#     ns1:ability2 <http://example.org/pokemon/ability/Motor_Drive> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Sap_Sipper> ;
#     ns1:category <http://example.org/pokemon/category/Thunderbolt> ;
#     ns1:color <Black> ;
#     ns1:friendship 70 ;
#     ns1:height-m 1.6 ;
#     ns1:jname "ゼブライカ" ;
#     ns1:jtranslit "Zeburaika" ;
#     ns1:name "Zebstrika" ;
#     ns1:ndex 523 ;
#     ns1:tmname "Zebraika" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 79.5 .
#
# ns1:Zekrom a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Teravolt> ;
#     ns1:category <http://example.org/pokemon/category/Deep_Black> ;
#     ns1:color <Black> ;
#     ns1:friendship 0 ;
#     ns1:height-m 2.9 ;
#     ns1:jname "ゼクロム" ;
#     ns1:jtranslit "Zekuromu" ;
#     ns1:name "Zekrom" ;
#     ns1:ndex 644 ;
#     ns1:tmname "Zekrom" ;
#     ns1:type1 <http://example.org/pokemon/type/Dragon> ;
#     ns1:type2 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 345.0 .
#
# ns1:Zeraora a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Volt_Absorb> ;
#     ns1:category <http://example.org/pokemon/category/Thunderclap> ;
#     ns1:color <Yellow> ;
#     ns1:friendship 0 ;
#     ns1:height-m 1.5 ;
#     ns1:jname "ゼラオラ" ;
#     ns1:name "Zeraora" ;
#     ns1:ndex 807 ;
#     ns1:tmname "Zeraora" ;
#     ns1:type1 <http://example.org/pokemon/type/Electric> ;
#     ns1:weight-kg 44.5 .
#
# ns1:Zigzagoon a ns1:pokemon ;
#     ns1:jname "ジグザグマ" ;
#     ns1:name "Zigzagoon" ;
#     ns1:ndex 263 ;
#     ns1:tmname "Jiguzaguma" ;
#     ns1:type1 <http://example.org/pokemon/type/Normal> .
#
# ns1:Zoroark a ns1:pokemon ;
#     ns1:jname "ゾロアーク" ;
#     ns1:jtranslit "Zoroāku" ;
#     ns1:name "Zoroark" ;
#     ns1:ndex 571 ;
#     ns1:tmname "Zoroark" ;
#     ns1:type1 <http://example.org/pokemon/type/Dark> .
#
# ns1:Zorua a ns1:pokemon ;
#     ns1:jname "ゾロア" ;
#     ns1:jtranslit "Zoroa" ;
#     ns1:name "Zorua" ;
#     ns1:ndex 570 ;
#     ns1:tmname "Zorua" ;
#     ns1:type1 <http://example.org/pokemon/type/Dark> .
#
# ns1:Zubat a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Inner_Focus> ;
#     ns1:abilityd <http://example.org/pokemon/ability/Infiltrator> ;
#     ns1:category <http://example.org/pokemon/category/Bat> ;
#     ns1:color <Purple> ;
#     ns1:friendship 70 ;
#     ns1:height-m 0.8 ;
#     ns1:jname "ズバット" ;
#     ns1:jtranslit "Zubatto" ;
#     ns1:name "Zubat" ;
#     ns1:ndex 41 ;
#     ns1:tmname "Zubat" ;
#     ns1:type1 <http://example.org/pokemon/type/Poison> ;
#     ns1:type2 <http://example.org/pokemon/type/Flying> ;
#     ns1:weight-kg 7.5 .
#
# ns1:Zweilous a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Hustle> ;
#     ns1:category <http://example.org/pokemon/category/Hostile> ;
#     ns1:color <Blue> ;
#     ns1:friendship 35 ;
#     ns1:height-m 1.4 ;
#     ns1:jname "ジヘッド" ;
#     ns1:jtranslit "Jiheddo" ;
#     ns1:name "Zweilous" ;
#     ns1:ndex 634 ;
#     ns1:tmname "Dihead" ;
#     ns1:type1 <http://example.org/pokemon/type/Dark> ;
#     ns1:type2 <http://example.org/pokemon/type/Dragon> ;
#     ns1:weight-kg 50.0 .
#
# ns1:Zygarde a ns1:pokemon ;
#     ns1:ability1 <http://example.org/pokemon/ability/Aura_Break> ;
#     ns1:category <http://example.org/pokemon/category/Order> ;
#     ns1:jname "ジガルデ" ;
#     ns1:jtranslit "Jigarude" ;
#     ns1:name "Zygarde" ;
#     ns1:tmname "Zygarde" ;
#     ns1:type1 <http://example.org/pokemon/type/Dragon> ;
#     ns1:type2 <http://example.org/pokemon/type/Ground> .
#
# <Pink> a <http://schema.org/color> .
#
# <Black> a <http://schema.org/color> .
#
# <Purple> a <http://schema.org/color> .
#
# <Yellow> a <http://schema.org/color> .
#
# <White> a <http://schema.org/color> .
#
# <Red> a <http://schema.org/color> .
#
# <Gray> a <http://schema.org/color> .
#
# <Green> a <http://schema.org/color> .
#
# <Brown> a <http://schema.org/color> .
#
# <Blue> a <http://schema.org/color> .

# %%
Regions_wiht_infobox = [
    "Kanto",
    "Johto",
    "Hoenn",
    "Orre",
    "Sevii Islands",
    "Orange Islands",
    "Pokémon Island",
    "White City",
    "Fiore",
    "Sinnoh",
    "Pokétopia",
    "Pokémon world (Mystery Dungeon)",
    "Mintale Town",
    "Almia",
    "Trading Card Game Islands",
    "Oblivia",
    "Unova",
    "PokéPark (game)",
    "Ransei",
    "Decolore Islands",
    "Kalos",
    "Ferrum",
    "Alola",
    "Carmonte Island",
    "Ryme City",
    "Tumblecube Island",
    "Galar",
    "Pasio",
    "Isle of Armor",
    "Crown Tundra",
    "Lental",
    "Hisui",
    "Aeos Island",
    "Paldea",
    "Kitakami",
    "Blueberry Academy"
]

# %%
final_region_graph = Graph()
intial_region_graph = Graph()
REGION = Namespace("http://example.org/region/")
for region in Regions_wiht_infobox:
    try:
        # Step 1: Fetch the page text
        result1 = bulbabot.page_text(title=region)
        
        # Step 2: Extract the infobox
        result2 = extract_region_infobox(result1)
        
        # Step 3: Parse the infobox
        result3 = parse_infobox(result2)
        
        # Step 4: Map the parsed infobox to RDF
        # final_region_graph = map_region_infobox_to_rdf(intial_region_graph, property_mappings, result3)}
        final_region_graph = map_infobox_to_rdf(REGION, intial_region_graph, property_mappings, result3)
        
        # Log or handle the final result (optional)
        # print(f"Successfully processed {region}")
    except Exception as e:
        # Handle any errors that occur in the pipeline
        print(f"Error processing {region}: {e}")
        print(e)

# %%
# Save or print the created graph
print(final_region_graph.serialize(format="turtle"))
with open(os.path.join(graph_path,"region_graph.ttl"), "w", encoding="utf-8") as file:
    file.write(final_region_graph.serialize(format="turtle"))
# Out:
# @prefix ns1: <http://example.org/region/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ns1:Aeos_Island a ns1:region ;
#     ns1:caption "Aeos Island" ;
#     ns1:image <UNITE_Aeos_Island.png> ;
#     ns1:introduction "Pokémon UNITE" ;
#     ns1:jname "エオス島" ;
#     ns1:professor <Professor_Phorus> ;
#     ns1:regioncolor <Orange> ;
#     ns1:size 250 ;
#     ns1:tmname "Aeos Island" .
#
# ns1:Almia a ns1:region ;
#     ns1:image <Almia.png> ;
#     ns1:introduction "Pokémon Ranger: Shadows of Almia" ;
#     ns1:jname "アルミア" ;
#     ns1:professor <Professor_Hastings> ;
#     ns1:regioncolor <SoA> ;
#     ns1:size 200 ;
#     ns1:tmname "Almia" ;
#     ns1:villain "Team Dim Sun" .
#
# ns1:Alola a ns1:region ;
#     ns1:image <Alola_USUM_artwork.png> ;
#     ns1:jname "アローラ" ;
#     ns1:regioncolor <alola> ;
#     ns1:size 300 ;
#     ns1:tmname "Alola" .
#
# ns1:Blueberry_Academy a ns1:region ;
#     ns1:image <Blueberry_Academy_entrance.png> ;
#     ns1:jname "ブルーベリー学園" ;
#     ns1:regioncolor <Blueberry> ;
#     ns1:size 300 ;
#     ns1:tmname "Blueberry Academy" .
#
# ns1:Carmonte_Island a ns1:region ;
#     ns1:caption "Carmonte Island" ;
#     ns1:image <Carmonte_Island.png> ;
#     ns1:introduction "Pokémon Duel" ;
#     ns1:jname "カルモンテ島" ;
#     ns1:regioncolor <Moon> ;
#     ns1:size 300 ;
#     ns1:tmname "Carmonte Island" .
#
# ns1:Crown_Tundra a ns1:region ;
#     ns1:image <Crown_Tundra_artwork.png> ;
#     ns1:jname "カンムリせつげん" ;
#     ns1:regioncolor <Crown_Tundra> ;
#     ns1:size 300 ;
#     ns1:tmname "Crown Snowfield" .
#
# ns1:Decolore_Islands a ns1:region ;
#     ns1:caption "" ;
#     ns1:image <Decolore.png> ;
#     ns1:introduction "Pokémon animated series" ;
#     ns1:jname "デコロラ諸島" ;
#     ns1:regioncolor <water> ;
#     ns1:series "''Pokémon the Series: Black & White''" ;
#     ns1:tmname "Decolora Archipelago" .
#
# ns1:Ferrum a ns1:region ;
#     ns1:caption "The Ferrum region" ;
#     ns1:image <Ferrum.png> ;
#     ns1:introduction "Pokkén Tournament" ;
#     ns1:jname "フェルム" ;
#     ns1:regioncolor <steel> ;
#     ns1:tmname "Ferrum" .
#
# ns1:Fiore a ns1:region ;
#     ns1:image <Fiore_alt.png> ;
#     ns1:jname "フィオレ" ;
#     ns1:regioncolor <Ranger> ;
#     ns1:tmname "Fiore" .
#
# ns1:Galar a ns1:region ;
#     ns1:image <Galar_artwork.png> ;
#     ns1:jname "ガラル" ;
#     ns1:regioncolor <galar> ;
#     ns1:size 300 ;
#     ns1:tmname "Galar" .
#
# ns1:Hisui a ns1:region ;
#     ns1:image <Legends_Arceus_Hisui.png> ;
#     ns1:jname "ヒスイ" ;
#     ns1:regioncolor <Hisui> ;
#     ns1:size 300 ;
#     ns1:tmname "Hisui" .
#
# ns1:Hoenn a ns1:region ;
#     ns1:caption "Artwork of the Hoenn region from<br>Pokémon Omega Ruby and Alpha Sapphire illustrated by kawayoo" ;
#     ns1:image <Hoenn_ORAS.png> ;
#     ns1:jname "ホウエン" ;
#     ns1:regioncolor <Hoenn> ;
#     ns1:size 300 ;
#     ns1:tmname "Hoenn" .
#
# ns1:Isle_of_Armor a ns1:region ;
#     ns1:image <Isle_of_Armor_artwork.png> ;
#     ns1:jname "ヨロイ" ;
#     ns1:regioncolor <Isle_of_Armor> ;
#     ns1:size 300 ;
#     ns1:tmname "Armor Island" .
#
# ns1:Johto a ns1:region ;
#     ns1:caption "Artwork of the Johto region from Generation IV" ;
#     ns1:image <JohtoMap.png> ;
#     ns1:jname "ジョウト" ;
#     ns1:regioncolor <Johto> ;
#     ns1:size 300 ;
#     ns1:tmname "Johto" .
#
# ns1:Kalos a ns1:region ;
#     ns1:image <Kalos_alt.png> ;
#     ns1:jname "カロス" ;
#     ns1:regioncolor <kalos> ;
#     ns1:size 300 ;
#     ns1:tmname "Kalos" .
#
# ns1:Kanto a ns1:region ;
#     ns1:caption "Artwork of Kanto from Generation VII by kawayoo<ref name=\"gen7-art\">[https://twitter.com/PK__SAYONARA/status/1643013730966581248 Tweet by @PK__SAYONARA (reposted by @kawayoo)]</ref>" ;
#     ns1:image <PE_Kanto_Map.png> ;
#     ns1:jname "カントー" ;
#     ns1:regioncolor <kanto> ;
#     ns1:size 300 ;
#     ns1:tmname "Kanto" .
#
# ns1:Kitakami a ns1:region ;
#     ns1:caption "Concept art" ;
#     ns1:image <Mossui_Town_SV_Concept_Art.png> ;
#     ns1:introduction "Pokémon Scarlet and Violet (The Teal Mask)" ;
#     ns1:jname "キタカミ" ;
#     ns1:professor <None> ;
#     ns1:regioncolor <Kitakami> ;
#     ns1:size 300 ;
#     ns1:tmname "Kitakami" .
#
# ns1:Lental a ns1:region ;
#     ns1:image <Lental.png> ;
#     ns1:introduction "New Pokémon Snap" ;
#     ns1:jname "レンティル" ;
#     ns1:professor <Professor_Mirror> ;
#     ns1:regioncolor <electric> ;
#     ns1:tmname "Lentil" ;
#     ns1:villain "N/A" .
#
# ns1:Mintale_Town a ns1:region ;
#     ns1:caption "Mintale Town" ;
#     ns1:image <Mintale_Town.png> ;
#     ns1:introduction "Pokémon Channel" ;
#     ns1:jname "ハツカタウン" ;
#     ns1:professor <Professor_Oak> ;
#     ns1:regioncolor <Grass> ;
#     ns1:tmname "Hatsuka Town" .
#
# ns1:Oblivia a ns1:region ;
#     ns1:image <Oblivia_artwork.png> ;
#     ns1:introduction "Pokémon Ranger: Guardian Signs" ;
#     ns1:jname "オブリビア" ;
#     ns1:professor <Professor_Hastings> ;
#     ns1:regioncolor <GS> ;
#     ns1:tmname "Oblivia" ;
#     ns1:villain "Pokémon Pinchers" .
#
# ns1:Orange_Islands a ns1:region ;
#     ns1:caption "A complete map of the Orange Islands in relation to Kanto and Johto" ;
#     ns1:image <Orange.jpg> ;
#     ns1:jname "オレンジ諸島" ;
#     ns1:regioncolor <orange> ;
#     ns1:tmname "Orange Islands" .
#
# ns1:Orre a ns1:region ;
#     ns1:image <Orre.png> ;
#     ns1:jname "オーレ" ;
#     ns1:pokelist "Strategy Memo" ;
#     ns1:regioncolor <Orre> ;
#     ns1:tmname "Ōre" .
#
# ns1:Paldea a ns1:region ;
#     ns1:image <Paldea_artwork.png> ;
#     ns1:jname "パルデア" ;
#     ns1:regioncolor <paldea> ;
#     ns1:size 300 ;
#     ns1:tmname "Paldea" .
#
# ns1:Pasio a ns1:region ;
#     ns1:caption "" ;
#     ns1:image <Pasio.png> ;
#     ns1:introduction "Pokémon Masters EX" ;
#     ns1:jname "パシオ" ;
#     ns1:league "Pokémon Masters League" ;
#     ns1:location <Centra_City> ;
#     ns1:professor <Professor_Bellis> ;
#     ns1:regioncolor <masters> ;
#     ns1:size 150 ;
#     ns1:tmname "Pasio" ;
#     ns1:villain "Team Break" .
#
# ns1:PokéPark a ns1:region ;
#     ns1:caption "Map of the PokéPark in PokéPark Wii" ;
#     ns1:image <PokePark_Wii_Map.png> ;
#     ns1:introduction "PokéPark Wii: Pikachu's Adventure" ;
#     ns1:jname "ポケパーク" ;
#     ns1:regioncolor <PokéPark> ;
#     ns1:tmname "Poké Park" .
#
# ns1:Pokémon_Island a ns1:region ;
#     ns1:caption "Pokémon Island artwork" ;
#     ns1:image <Snap_Pokémon_Island.png> ;
#     ns1:introduction "Pokémon Snap" ;
#     ns1:jname "ポケモンアイランド" ;
#     ns1:professor <Professor_Oak> ;
#     ns1:regioncolor <Psychic> ;
#     ns1:tmname "Pokémon Island" .
#
# ns1:Pokémon_world a ns1:region ;
#     ns1:caption "Map of the Pokémon world from Pokémon Super Mystery Dungeon" ;
#     ns1:image <Mystery_Dungeon_World_PSMD.png> ;
#     ns1:introduction "Pokémon Mystery Dungeon: Red Rescue Team and Blue Rescue Team" ;
#     ns1:jname "ポケモン世界" ;
#     ns1:regioncolor <MD> ;
#     ns1:tmname "Pokémon world" .
#
# ns1:Pokétopia a ns1:region ;
#     ns1:caption "Pokétopia" ;
#     ns1:image <Poketopia.png> ;
#     ns1:introduction "Pokémon Battle Revolution" ;
#     ns1:jname "ポケトピア" ;
#     ns1:regioncolor <Gold> ;
#     ns1:size 300 ;
#     ns1:tmname "Pokétopia" .
#
# ns1:Ransei a ns1:region ;
#     ns1:caption "The Ransei region" ;
#     ns1:games "Pokémon Conquest" ;
#     ns1:generation "Generation V" ;
#     ns1:image <Ransei.png> ;
#     ns1:introduction "Pokémon Conquest" ;
#     ns1:jname "ランセ" ;
#     ns1:regioncolor <Unova> ;
#     ns1:tmname "Ranse" ;
#     ns1:villain "Nobunaga's Army" .
#
# ns1:Ryme_City a ns1:region ;
#     ns1:image <Ryme_City_artwork.png> ;
#     ns1:jname "ライムシティ" ;
#     ns1:regioncolor <Electric> ;
#     ns1:tmname "Ryme City" .
#
# ns1:Sevii_Islands a ns1:region ;
#     ns1:caption "Artwork of the Sevii Islands from FireRed and LeafGreen" ;
#     ns1:image <Sevii_Islands.png> ;
#     ns1:jname "ナナシマ" ;
#     ns1:regioncolor <Sevii> ;
#     ns1:tmname "Nanashima" .
#
# ns1:Sinnoh a ns1:region ;
#     ns1:image <Sinnoh_BDSP_artwork.png> ;
#     ns1:jname "シンオウ" ;
#     ns1:regioncolor <Sinnoh> ;
#     ns1:size 300 ;
#     ns1:tmname "Sinnoh" .
#
# ns1:Trading_Card_Game_Islands a ns1:region ;
#     ns1:image <TCG_Island_artwork.jpg> ;
#     ns1:jname "" ;
#     ns1:regioncolor <tcg_trainer> ;
#     ns1:size 200 ;
#     ns1:tmname "" .
#
# ns1:Tumblecube_Island a ns1:region ;
#     ns1:caption "" ;
#     ns1:image <Tumblecube_Island.png> ;
#     ns1:introduction "Pokémon Quest" ;
#     ns1:jname "カクコロ島" ;
#     ns1:regioncolor <Orange> ;
#     ns1:size 300 ;
#     ns1:tmname "Kakukoro Island" .
#
# ns1:Unova a ns1:region ;
#     ns1:image <Unova_B2W2_alt.png> ;
#     ns1:jname "イッシュ" ;
#     ns1:regioncolor <Unova> ;
#     ns1:size 300 ;
#     ns1:tmname "Issyu" .
#
# ns1:White_City a ns1:region ;
#     ns1:caption "White City in Pokémon Stadium 2" ;
#     ns1:image <White_City.png> ;
#     ns1:introduction "Pokémon Stadium 2" ;
#     ns1:jname "ホワイトシティ" ;
#     ns1:professor <Professor_Oak> ;
#     ns1:regioncolor <White> ;
#     ns1:tmname "White City" ;
#     ns1:villain "Team Rocket" .
#
# <Almia.png> a xsd:anyURI .
#
# <Alola_USUM_artwork.png> a xsd:anyURI .
#
# <Blueberry> a <http://schema.org/color> .
#
# <Blueberry_Academy_entrance.png> a xsd:anyURI .
#
# <Carmonte_Island.png> a xsd:anyURI .
#
# <Centra_City> a <http://example.org/location/Location> .
#
# <Crown_Tundra> a <http://schema.org/color> .
#
# <Crown_Tundra_artwork.png> a xsd:anyURI .
#
# <Decolore.png> a xsd:anyURI .
#
# <Electric> a <http://schema.org/color> .
#
# <Ferrum.png> a xsd:anyURI .
#
# <Fiore_alt.png> a xsd:anyURI .
#
# <GS> a <http://schema.org/color> .
#
# <Galar_artwork.png> a xsd:anyURI .
#
# <Gold> a <http://schema.org/color> .
#
# <Grass> a <http://schema.org/color> .
#
# <Hisui> a <http://schema.org/color> .
#
# <Hoenn> a <http://schema.org/color> .
#
# <Hoenn_ORAS.png> a xsd:anyURI .
#
# <Isle_of_Armor> a <http://schema.org/color> .
#
# <Isle_of_Armor_artwork.png> a xsd:anyURI .
#
# <Johto> a <http://schema.org/color> .
#
# <JohtoMap.png> a xsd:anyURI .
#
# <Kalos_alt.png> a xsd:anyURI .
#
# <Kitakami> a <http://schema.org/color> .
#
# <Legends_Arceus_Hisui.png> a xsd:anyURI .
#
# <Lental.png> a xsd:anyURI .
#
# <MD> a <http://schema.org/color> .
#
# <Mintale_Town.png> a xsd:anyURI .
#
# <Moon> a <http://schema.org/color> .
#
# <Mossui_Town_SV_Concept_Art.png> a xsd:anyURI .
#
# <Mystery_Dungeon_World_PSMD.png> a xsd:anyURI .
#
# <None> a <http://example.org/character/Character> .
#
# <Oblivia_artwork.png> a xsd:anyURI .
#
# <Orange.jpg> a xsd:anyURI .
#
# <Orre> a <http://schema.org/color> .
#
# <Orre.png> a xsd:anyURI .
#
# <PE_Kanto_Map.png> a xsd:anyURI .
#
# <Paldea_artwork.png> a xsd:anyURI .
#
# <Pasio.png> a xsd:anyURI .
#
# <PokePark_Wii_Map.png> a xsd:anyURI .
#
# <Poketopia.png> a xsd:anyURI .
#
# <PokéPark> a <http://schema.org/color> .
#
# <Professor_Bellis> a <http://example.org/character/Character> .
#
# <Professor_Mirror> a <http://example.org/character/Character> .
#
# <Professor_Phorus> a <http://example.org/character/Character> .
#
# <Psychic> a <http://schema.org/color> .
#
# <Ranger> a <http://schema.org/color> .
#
# <Ransei.png> a xsd:anyURI .
#
# <Ryme_City_artwork.png> a xsd:anyURI .
#
# <Sevii> a <http://schema.org/color> .
#
# <Sevii_Islands.png> a xsd:anyURI .
#
# <Sinnoh> a <http://schema.org/color> .
#
# <Sinnoh_BDSP_artwork.png> a xsd:anyURI .
#
# <Snap_Pokémon_Island.png> a xsd:anyURI .
#
# <SoA> a <http://schema.org/color> .
#
# <TCG_Island_artwork.jpg> a xsd:anyURI .
#
# <Tumblecube_Island.png> a xsd:anyURI .
#
# <UNITE_Aeos_Island.png> a xsd:anyURI .
#
# <Unova_B2W2_alt.png> a xsd:anyURI .
#
# <White> a <http://schema.org/color> .
#
# <White_City.png> a xsd:anyURI .
#
# <alola> a <http://schema.org/color> .
#
# <electric> a <http://schema.org/color> .
#
# <galar> a <http://schema.org/color> .
#
# <kalos> a <http://schema.org/color> .
#
# <kanto> a <http://schema.org/color> .
#
# <masters> a <http://schema.org/color> .
#
# <orange> a <http://schema.org/color> .
#
# <paldea> a <http://schema.org/color> .
#
# <steel> a <http://schema.org/color> .
#
# <tcg_trainer> a <http://schema.org/color> .
#
# <water> a <http://schema.org/color> .
#
# <Orange> a <http://schema.org/color> .
#
# <Professor_Hastings> a <http://example.org/character/Character> .
#
# <Unova> a <http://schema.org/color> .
#
# <Professor_Oak> a <http://example.org/character/Character> .

# %%
with open('RessourcesList\character_list.txt', 'r') as file:
    character_list = [line.strip() for line in file]

print(character_list)
# Out:
# ['Tracey Sketchit', 'Max', 'Misty', 'Steven Stone', 'Norman', 'Ritchie', 'Giovanni', 'Erika', 'Wes', 'Red (game)', 'Jessie', 'James', 'Lt. Surge', 'Sabrina', 'Blaine', 'Lorelei', 'Lance', 'Nurse Joy', 'Name Rater', 'Todd Snap', 'Leaf (game)', 'Ethan (game)', 'Kris (game)', 'May (game)', 'Anabel', 'Peanut', 'Michael', 'Solana', 'Fantina', 'Lunick', 'Dawn (game)', 'Mark (TCG GB)', 'Mint (TCG GB)', 'Lucy Fleetfoot', 'Mai', 'Marnie', 'PokÃ©mon Center lady', 'Kellyn', 'Kate (Ranger)', 'Koga', 'Ash Ketchum', 'Brock', 'Kanata (CCP)', 'Primo', 'Cynthia', 'Lyra (game)', 'May (anime)', 'Carob', 'Day-Care Couple', 'Dawn (anime)', 'Ben (Ranger)', 'Summer (Ranger)', 'Misty (anime)', 'Brock (anime)', 'Professor Juniper', 'Hilda (game)', 'Hilbert (game)', 'Cheren', 'Bianca', 'N', 'Fennel', 'Iris (anime)', 'Cilan', 'Lenora', 'Cress', 'Chili', 'Ghetsis', 'Iris', 'Clay', 'Drayden', 'Shadow Triad', 'Amanita', 'Giallo', 'Cedric Juniper', 'Hawes', 'Ingo', 'Emmet', 'Charles', 'Anthea and Concordia', 'Gorm', 'Bronius', 'Zinzolin', 'Rood', 'Ryoku', 'Caretaker', "Bianca's father", 'Hop', 'Colress', 'Rosa (game)', 'Hugh', 'Nate (game)', 'Professor Burnet', 'Benga', 'Curtis', 'Yancy', 'Pop Roxie', 'Viola', 'Alexa', 'Shauna', 'Tierno', 'Trevor', 'Calem (game)', 'Serena (game)', 'Clemont', 'Professor Sycamore', 'Grant', 'Korrina', 'Diantha', 'Bonnie', 'Celosia', 'Mable', 'Bryony', 'Aliana', 'Xerosic', 'Ramos', 'Valerie', 'Olympia', 'Wulfric', 'Malva', 'Wikstrom', 'Siebold', 'Drasna', 'Emma', 'Lysandre', 'AZ', 'Grace (Kalos)', 'Nita', 'Evelyn', 'Dana', 'Morgan', 'Gurkinn', 'Cassius', 'Sina', 'Dexio', 'Mr. Bonding', 'Phil the Photo Guy', 'Phil', 'Inver', 'Alain', 'Aarune', 'Lisia', 'Zinnia', 'Chaz (game)', 'Amelia', 'Lillie', 'Hau', 'Professor Kukui', 'Hala', 'Elio (game)', 'Selene (game)', 'Professor Willow', 'Candela', 'Lana', 'Mallow', 'Sophocles', 'Kiawe', 'Plumeria', 'Guzma', 'Lusamine', 'Faba', 'Wicke', 'Gladion', 'Samson Oak', 'Olivia', 'Ilima', 'Mohn', 'Molayne', 'Kahili', 'Ryuki', 'Acerola', 'Nanu', 'Hapu', 'Mina', 'Harper and Sarah', "Hugh's sister", 'Dulse', 'Zossie', 'Soliera', 'Phyco', 'Shin Kyougi', 'Makoto Kyougi', 'Trace (game)', 'Elaine (game)', 'Chase (game)', 'Tim Goodman', 'Spark (GO)', 'Blanche', 'Professor Magnolia', 'Leon', 'Sonia', 'Milo', 'Nessa', 'Victor (game)', 'Gloria (game)', 'Bea', 'Allister', 'Rose', 'Oleana', 'Bede', 'Goh', 'Cliff (GO)', 'Arlo', 'Sierra', 'Green (game)', 'Kabu', 'Opal', 'Melony', 'Gordie', 'Piers', 'Raihan', 'Ball Guy', 'Shielbert', 'Sordward', 'Digging Duo', 'Watt Trader', 'Cara Liss', 'Avery', 'Klara', 'Mustard', 'Jack (Galar)', 'Grand Oak', 'PokÃ© Boy', 'Leon (anime)', 'Cynthia (anime)', 'Peony', 'Honey (Galar)', 'Hyde', 'Leah', 'Scottie', 'Bettie', 'Peonia', 'Cyndy', 'Nate (Battle Revolution)', 'Professor Mirror', 'Rita', 'Rei (game)', 'Akari (game)', 'Giovanni (GO)', 'Professor Laventon', 'Kamado', 'Cyllene', 'Lian', 'Iscan', 'Arezu', 'Adaman', 'Irida', 'Ginter', 'Volo', 'Calaba', 'Palina', 'Melli', 'Sabi', 'Gaeric', 'Zisu', 'Pesselle', 'Tao Hua', 'Sanqua', 'Colza', 'Beni', 'Charm (Hisui)', 'Clover', 'Coin (Hisui)', 'Cogita', 'Choy', 'Anthe', 'Rye', 'Tuli', 'Lance (anime)', 'Professor Phorus', 'Erbie', 'Zirco', 'Nemona', 'Professor Sada', 'Professor Turo', 'Rhi', 'Steven Stone (anime)', 'Grusha', 'Arven', 'Clavell', 'Jacq', 'Penny', 'Florian (game)', 'Juliana (game)', 'Brassius', 'Mela', 'Geeta', 'Iono', 'Dendra', 'Miriam', 'Raifort', 'Saguaro', 'Salvatore', 'Tyme', 'Atticus', 'Eri', 'Giacomo', 'Ortega', 'Larry', 'Katy', 'Kofu', 'Ryme', 'Tulip', 'Rika', 'Poppy', 'Hassel', 'Liko', 'Roy', 'Friede', 'Haru', 'Kieran', 'Carmine', 'Professor Neroli', 'Orla', 'Murdock', 'Mollie', 'Ludlow', 'Amethio', 'Onia', 'Zirc', 'Dot', 'Ann', 'Diana', "Roy's grandfather", 'Lucca', 'Alex', 'Hamber', 'Gibeon', 'Nemona (anime)', 'Spinel', 'Lacey', 'Cyrano', 'Lucius', 'Chalce', 'Coral', 'Sidian', 'Briar', 'Perrin', 'Drayton', 'Amarys', 'Ohara', 'Aliquis', 'Crispin', 'Ava', 'Hohma', 'Joshua (Path to the Peak)', 'Celestine', 'He ...

# %%
CHARACTER = Namespace("http://example.org/character/")
intial_character_graph = Graph()
final_character_graph = Graph()

for character in character_list:
    try:
        # Step 1: Fetch the page text
        result1 = bulbabot.page_text(title=character)
        
        # Step 2: Extract the infobox
        result2 = extract_character_infobox(result1)
        
        # Step 3: Parse the infobox
        result3 = parse_infobox(result2)
        
        # Step 4: Map the parsed infobox to RDF
        final_character_graph = map_infobox_to_rdf(CHARACTER, intial_character_graph, property_mappings, result3)
        
        # Log or handle the final result (optional)
        print(f"Successfully processed {character}")
    except Exception as e:
        # Handle any errors that occur in the pipeline
        print(f"Error processing {character}: {e}")
# Out:
# Successfully processed Tracey Sketchit
# Successfully processed Max
# Successfully processed Misty
# Successfully processed Steven Stone
# Successfully processed Norman
# Successfully processed Ritchie
# Successfully processed Giovanni
# Successfully processed Erika
# Successfully processed Wes
# Successfully processed Red (game)
# Error processing Jessie: invalid literal for int() with base 10: 'Unconfirmed<ref name="age"/> '
# Error processing James: invalid literal for int() with base 10: 'Unconfirmed<ref name="age"/>'
# Successfully processed Lt. Surge
# Successfully processed Sabrina
# Successfully processed Blaine
# Successfully processed Lorelei
# Successfully processed Lance
# Successfully processed Nurse Joy
# Successfully processed Name Rater
# Successfully processed Todd Snap
# Successfully processed Leaf (game)
# Successfully processed Ethan (game)
# Successfully processed Kris (game)
# Successfully processed May (game)
# Successfully processed Anabel
# Successfully processed Peanut
# Successfully processed Michael
# Successfully processed Solana
# Successfully processed Fantina
# Successfully processed Lunick
# Successfully processed Dawn (game)
# Successfully processed Mark (TCG GB)
# Successfully processed Mint (TCG GB)
# Successfully processed Lucy Fleetfoot
# Successfully processed Mai
# Successfully processed Marnie
# Error processing PokÃ©mon Center lady: 'NoneType' object has no attribute 'split'
# Successfully processed Kellyn
# Successfully processed Kate (Ranger)
# Successfully processed Koga
# Successfully processed Ash Ketchum
# Successfully processed Brock
# Successfully processed Kanata (CCP)
# Successfully processed Primo
# Successfully processed Cynthia
# Successfully processed Lyra (game)
# Successfully processed May (anime)
# Successfully processed Carob
# Successfully processed Day-Care Couple
# Successfully processed Dawn (anime)
# Successfully processed Ben (Ranger)
# Successfully processed Summer (Ranger)
# Successfully processed Misty (anime)
# Successfully processed Brock (anime)
# Successfully processed Professor Juniper
# Successfully processed Hilda (game)
# Successfully processed Hilbert (game)
# Successfully processed Cheren
# Successfully processed Bianca
# Successfully processed N
# Successfully processed Fennel
# Successfully processed Iris (anime)
# Successfully processed Cilan
# Successfully processed Lenora
# Successfully processed Cress
# Successfully processed Chili
# Successfully processed Ghetsis
# Successfully processed Iris
# Successfully processed Clay
# Successfully processed Drayden
# Successfully processed Shadow Triad
# Successfully processed Amanita
# Successfully processed Giallo
# Successfully processed Cedric Juniper
# Successfully processed Hawes
# Successfully processed Ingo
# Successfully processed Emmet
# Successfully processed Charles
# Successfully processed Anthea and Concordia
# Successfully processed Gorm
# Successfully processed Bronius
# Successfully processed Zinzolin
# Successfully processed Rood
# Successfully processed Ryoku
# Successfully processed Caretaker
# Successfully processed Bianca's father
# Successfully processed Hop
# Successfully processed Colress
# Successfully processed Rosa (game)
# Successfully processed Hugh
# Successfully processed Nate (game)
# Successfully processed Professor Burnet
# Successfully processed Benga
# Successfully processed Curtis
# Successfully processed Yancy
# Successfully processed Pop Roxie
# Successfully processed Viola
# Successfully processed Alexa
# Successfully processed Shauna
# Successfully processed Tierno
# Successfully processed Trevor
# Successfully processed Calem (game)
# Successfully processed Serena (game)
# Successfully processed Clemont
# Successfully processed Professor Sycamore
# Successfully processed Grant
# Successfully processed Korrina
# Successfully processed Diantha
# Successfully processed Bonnie
# Successfully processed Celosia
# Successfully processed Mable
# Successfully processed Bryony
# Successfully processed Aliana
# Successfully processed Xerosic
# Successfully processed Ramos
# Successfully processed Valerie
# Successfully processed Olympia
# Successfully processed Wulfric
# Successfully processed Malva
# Successfully processed Wikstrom
# Successfully processed Siebold
# Successfully processed Drasna
# Successfully processed Emma
# Successfully processed Lysandre
# Successfully processed AZ
# Successfully processed Grace (Kalos)
# Successfully processed Nita
# Successfully processed Evelyn
# Successfully processed Dana
# Successfully processed Morgan
# Successfully processed Gurkinn
# Successfully processed Cassius
# Successfully processed Sina
# Successfully processed Dexio
# Successfully processed Mr. Bonding
# Successfully processed Phil the Photo Guy
# Successfully processed Phil
# Successfully processed Inver
# Successfully processed Alain
# Successfully processed Aarune
# Successfully processed Lisia
# Successfully processed Zinnia
# Successfully processed Chaz (game)
# Successfully processed Amelia
# Successfully processed Lillie
# Successfully processed Hau
# Successfully processed Professor Kukui
# Successfully processed Hala
# Successfully processed Elio (game)
# Successfully processed Selene (game)
# Successfully processed Professor Willow
# Successfully processed Candela
# Successfully processed Lana
# Successfully processed Mallow
# Successfully processed Sophocles
# Successfully processed Kiawe
# Successfully processed Plumeria
# Successfully processed Guzma
# Successfully processed Lusamine
# Successfully processed Faba
# Successfully processed Wicke
# Successfully processed Gladion
# Successfully processed Samson Oak
# Successfully processed Olivia
# Successfully processed Ilima
# Successfully processed Mohn
# Successfully processed Molayne
# Successfully processed Kahili
# Successfully processed Ryuki
# Successfully processed Acerola
# Successfully processed Nanu
# Successfully processed Hapu
# Successfully processed Mina
# Successfully processed Harper and Sarah
# Successfully processed Hugh's sister
# Successfully processed Dulse
# Successfully processed Zossie
# Successfully processed Soliera
# Successfully processed Phyco
# Successfully processed Shin Kyougi
# Successfully processed Makoto Kyougi
# Successfully processed Trace (game)
# Successfully processed Elaine (game)
# Successfully processed Chase (game)
# Successfully processed Tim Goodman
# Successfully processed Spark (GO)
# Successfully processed Blanche
# Successfully processed Professor Magnolia
# Successfully processed Leon
# Successfully processed Sonia
# Successfully processed Milo
# Successfully processed Nessa
# Successfully processed Victor (game)
# Successfully processed Gloria (game)
# Successfully processed Bea
# Successfully processed Allister
# Successfully processed Rose
# Successfully processed Oleana
# Successfully processed Bede
# Successfully processed Goh
# Successfully processed Cliff (GO)
# Successfully processed Arlo
# Successfully processed Sierra
# Successfully processed Green (game)
# Successfully processed Kabu
# Successfully processed Opal
# Successfully processed Melony
# Successfully processed Gordie
# Successfully processed Piers
# Successfully processed Raihan
# Successfully processed Ball Guy
# Successfully processed Shielbert
# Successfully processed Sordward
# Successfully processed Digging Duo
# Successfully processed Watt Trader
# Successfully processed Cara Liss
# Successfully processed Avery
# Successfully processed Klara
# Successfully processed Mustard
# Successfully processed Jack (Galar)
# Successfully processed Grand Oak
# Error processing PokÃ© Boy: 'NoneType' object has no attribute 'split'
# Successfully processed Leon (anime)
# Successfully processed Cynthia (anime)
# Successfully processed Peony
# Successfully processed Honey (Galar)
# Successfully processed Hyde
# Successfully processed Leah
# Successfully processed Scottie
# Successfully processed Bettie
# Successfully processed Peonia
# Successfully processed Cyndy
# Successfully processed Nate (Battle Revolution)
# Successfully processed Professor Mirror
# Successfully processed Rita
# Successfully processed Rei (game)
# Successfully processed Akari (game)
# Successfully processed Giovanni (GO)
# Successfully processed Professor Laventon
# Successfully processed Kamado
# Successfully processed Cyllene
# Successfully processed Lian
# Successfully processed Iscan
# Successfully processed Arezu
# Successfully processed Adaman
# Successfully processed Irida
# Successfully processed Ginter
# Successfully processed Volo
# Successfully processed Calaba
# Successfully processed Palina
# Successfully processed Melli
# Successfully processed Sabi
# Successfully processed Gaeric
# Successfully processed Zisu
# Successfully processed Pesselle
# Successfully processed Tao Hua
# Successfully processed Sanqua
# Successfully processed Colza
# Successfully processed Beni
# Successfully processed Charm (Hisui)
# Successfully processed Clover
# Successfully processed Coin (Hisui)
# Successfully processed Cogita
# Successfully processed Choy
# Successfully processed Anthe
# Successfully processed Rye
# Successfully processed Tuli
# Successfully processed Lance (anime)
# Successfully processed Professor Phorus
# Successfully processed Erbie
# Successfully processed Zirco
# Successfully processed Nemona
# Successfully processed Professor Sada
# Successfully processed Professor Turo
# Successfully processed Rhi
# Successfully processed Steven Stone (anime)
# Successfully processed Grusha
# Successfully processed Arven
# Successfully processed Clavell
# Successfully processed Jacq
# Successfully processed Penny
# Successfully processed Florian (game)
# Successfully processed Juliana (game)
# Successfully processed Brassius
# Successfully processed Mela
# Successfully processed Geeta
# Successfully processed Iono
# Successfully processed Dendra
# Successfully processed Miriam
# Successfully processed Raifort
# Successfully processed Saguaro
# Successfully processed Salvatore
# Successfully processed Tyme
# Successfully processed Atticus
# Successfully processed Eri
# Successfully processed Giacomo
# Successfully processed Ortega
# Successfully processed Larry
# Successfully processed Katy
# Successfully processed Kofu
# Successfully processed Ryme
# Successfully processed Tulip
# Successfully processed Rika
# Successfully processed Poppy
# Successfully processed Hassel
# Successfully processed Liko
# Successfully processed Roy
# Successfully processed Friede
# Successfully processed Haru
# Successfully processed Kieran
# Successfully processed Carmine
# Successfully processed Professor Neroli
# Successfully processed Orla
# Successfully processed Murdock
# Successfully processed Mollie
# Successfully processed Ludlow
# Successfully processed Amethio
# Successfully processed Onia
# Successfully processed Zirc
# Successfully processed Dot
# Successfully processed Ann
# Successfully processed Diana
# Successfully processed Roy's grandfather
# Successfully processed Lucca
# Successfully processed Alex
# Successfully processed Hamber
# Successfully processed Gibeon
# Successfully processed Nemona (anime)
# Successfully processed Spinel
# Successfully processed Lacey
# Successfully processed Cyrano
# Successfully processed Lucius
# Successfully processed Chalce
# Successfully processed Coral
# Successfully processed Sidian
# Successfully processed Briar
# Successfully processed Perrin
# Successfully processed Drayton
# Successfully processed Amarys
# Successfully processed Ohara
# Successfully processed Aliquis
# Successfully processed Crispin
# Successfully processed Ava
# Successfully processed Hohma
# Successfully processed Joshua (Path to the Peak)
# Successfully processed Celestine
# Successfully processed Heath
# Successfully processed Violet (Adventures)
# Successfully processed Edgar Troy
# Successfully processed Captain Vince
# Successfully processed Vessa
# Successfully processed Glitterati
# Successfully processed Yukito and Hideko
# Successfully processed Ingredients Seller
# Successfully processed Watanabe
# Successfully processed Tyler
# Successfully processed Alisa
# Successfully processed Carmen
# Successfully processed Harrington
# Successfully processed Mateo
# Successfully processed Snacksworth
# Successfully processed Synclaire
# Successfully processed Scarlet (Adventures)
# Successfully processed Nao
# Successfully processed Liko's homeroom teacher
# Successfully processed Franka
# Successfully processed Ress
# Successfully processed MoBee
# Successfully processed Iono (anime)
# Successfully processed Rai
# Successfully processed Luka (HZ053)
# Successfully processed Aeos Emporium shopkeeper
# Successfully processed Crave
# Error processing Master RosÃ©: 'NoneType' object has no attribute 'split'
# Successfully processed Yuji (Duel)
# Successfully processed Brenda
# Successfully processed Tamarind
# Successfully processed Nadya
# Successfully processed Don Roger
# Successfully processed Joe (Duel)
# Successfully processed Karolin
# Successfully processed Number 7
# Successfully processed Luca
# Successfully processed Sharon (Duel)
# Successfully processed Carlo
# Successfully processed Another
# Successfully processed Tia
# Successfully processed Marabelle
# Successfully processed Chalmers
# Successfully processed Charles Merloch
# Successfully processed Will Butler
# Successfully processed Jessica Miller
# Successfully processed Youssef
# Successfully processed Shizune
# Successfully processed MC Sledge
# Successfully processed Rystal

# %%
# Save or print the created graph
print(final_character_graph.serialize(format="turtle"))
with open(os.path.join(graph_path,"character_graph.ttl"), "w", encoding="utf-8") as file:
    file.write(final_character_graph.serialize(format="turtle"))
# Out:
# @prefix ns1: <http://example.org/character/> .
#
# ns1:Aliquis a ns1:character ;
#     ns1:bordercolor <D87257> ;
#     ns1:caption "Aliquis" ;
#     ns1:color <4B5293> ;
#     ns1:corecolor <F1CB90> ;
#     ns1:eyes <Blue> ;
#     ns1:gender <Male> ;
#     ns1:hair <Dark_blue_(Yellow_highlights)> ;
#     ns1:hometown <Unknown> ;
#     ns1:image "Aliquis PW.png" ;
#     ns1:jname "アリキス" ;
#     ns1:region <Paldea> ;
#     ns1:tmname "Aliquis" .
#
# ns1:Anabel a ns1:character ;
#     ns1:bordercolor <4a474a> ;
#     ns1:caption "Concept art from Pokémon Sun and Moon" ;
#     ns1:color <c0b2dd> ;
#     ns1:corecolor <e5cff9> ;
#     ns1:gender <Female> ;
#     ns1:image "Anabel SM concept art.png" ;
#     ns1:jname "リラ" ;
#     ns1:tmname "Lila" .
#
# ns1:Anthea_and_Concordia a ns1:character ;
#     ns1:bordercolor <f1c8b4> ;
#     ns1:color <fffeba> ;
#     ns1:corecolor <f1c8b4> ;
#     ns1:image "Black 2 White 2 Anthea and Concordia.png" ;
#     ns1:jname "愛の女神と平和の女神" ;
#     ns1:tmname "<br />Goddess of Love and Goddess of Peace" .
#
# ns1:Diantha a ns1:character ;
#     ns1:bordercolor <BAC5D7> ;
#     ns1:color <F3F7FA> ;
#     ns1:corecolor <E8E48E> ;
#     ns1:image "XY Diantha.png" ;
#     ns1:jname "カルネ" ;
#     ns1:tmname "Carne" .
#
# ns1:Giovanni a ns1:character ;
#     ns1:bordercolor <CC0000> ;
#     ns1:color <666> ;
#     ns1:corecolor <CCC> ;
#     ns1:image "GO Team GO Rocket Giovanni and legendary birds.png" ;
#     ns1:jname "サカキ" ;
#     ns1:tmname "Sakaki" .
#
# ns1:Hohma a ns1:character ;
#     ns1:bordercolor <D46C50> ;
#     ns1:caption "Hohma" ;
#     ns1:color <B88354> ;
#     ns1:corecolor <E49E7F> ;
#     ns1:eyes <Green> ;
#     ns1:gender <Male> ;
#     ns1:hair <Honey> ;
#     ns1:hometown <Unknown> ;
#     ns1:image "Hohma PW.png" ;
#     ns1:jname "ホーマ" ;
#     ns1:region <Paldea> ;
#     ns1:tmname "Hohma" .
#
# ns1:James a ns1:character ;
#     ns1:bordercolor <C00> ;
#     ns1:caption "James in ''Pokémon Journeys: The Series''" ;
#     ns1:color <666> ;
#     ns1:corecolor <CCC> ;
#     ns1:image "James JN.png" ;
#     ns1:jname "コジロウ" ;
#     ns1:tmname "Kojirō" .
#
# ns1:Jessie a ns1:character ;
#     ns1:bordercolor <C00> ;
#     ns1:caption "Jessie in ''Pokémon Journeys: The Series''" ;
#     ns1:color <666> ;
#     ns1:corecolor <CCC> ;
#     ns1:image "Jessie JN.png" ;
#     ns1:jname "ムサシ" ;
#     ns1:tmname "Musashi" .
#
# ns1:Kris a ns1:character ;
#     ns1:bordercolor <439ba7> ;
#     ns1:color <76c7d2> ;
#     ns1:corecolor <b6f0f8> ;
#     ns1:image "Crystal Kris.png" ;
#     ns1:jname "クリス" ;
#     ns1:tmname "Kris" .
#
# ns1:Leon a ns1:character ;
#     ns1:bordercolor <761724> ;
#     ns1:caption "Leon" ;
#     ns1:color <6C62A1> ;
#     ns1:corecolor <F7DD98> ;
#     ns1:eyes <Yellow> ;
#     ns1:gender <Male> ;
#     ns1:hair <Purple> ;
#     ns1:hometown <Postwick> ;
#     ns1:image "Leon anime JN.png",
#         "Sword Shield Leon.png" ;
#     ns1:jname "ダンデ" ;
#     ns1:region <Galar> ;
#     ns1:relatives "Mentioned parents<br>Hop (younger brother)" ;
#     ns1:tmname "Dande" .
#
# ns1:Lysandre a ns1:character ;
#     ns1:bordercolor <ab3f26> ;
#     ns1:color <eb8b51> ;
#     ns1:corecolor <e36226> .
#
# ns1:Name_Rater a ns1:character ;
#     ns1:bordercolor <ADA1C9> ;
#     ns1:color <D5CFE3> ;
#     ns1:corecolor <E7E4ED> .
#
# ns1:Unknown a ns1:character ;
#     ns1:bordercolor <ab3f26>,
#         <black_color_dark>,
#         <blue_color>,
#         <red_color>,
#         <yellow_color> ;
#     ns1:color <#switch:_#expr:_#time:_U>,
#         <526D82>,
#         <666>,
#         <Alola_color>,
#         <Bug_color>,
#         <Dark_color>,
#         <Fighting_color>,
#         <Fire_color>,
#         <GO_color>,
#         <GS_color>,
#         <Ghost_color>,
#         <Grass_color>,
#         <Green_color>,
#         <HOME_color>,
#         <Indigo_Disk_color>,
#         <Indigo_Disk_color_light>,
#         <Isle_of_Armor_color>,
#         <Kalos_color>,
#         <Kitakami_color>,
#         <Let's_Go_Eevee_color>,
#         <Let's_Go_Pikachu_color>,
#         <Mineral_egg_color>,
#         <Normal_color>,
#         <Omega_Ruby_color>,
#         <Orange_color>,
#         <Paldea_color>,
#         <Pokémon_color>,
#         <Rock_color>,
#         <Scarlet_color>,
#         <SoA_color>,
#         <Steel_color>,
#         <Stellar_color>,
#         <TCG_Ability_color>,
#         <TCG_Poké-Body_color_light>,
#         <TCG_Poké-Power_color>,
#         <TCG_Pokémon_Tool_color>,
#         <Treasures_color>,
#         <Unknown_color>,
#         <Unova_color>,
#         <Water_color>,
#         <XD_color>,
#         <X_color>,
#         <X_color_light>,
#         <Y_color>,
#         <alder_color>,
#         <alola_color>,
#         <beauty_color>,
#         <black_2_color>,
#         <black_color>,
#         <black_color_light>,
#         <blue_color>,
#         <blue_color_light>,
#         <blueberry_color>,
#         <bronze_color>,
#         <bug_color>,
#         <bulba_color>,
#         <castle_color>,
#         <cleverness_color_light>,
#         <colo_color>,
#         <contest_color>,
#         <cute_color>,
#         <cute_color_light>,
#         <cuteness_color>,
#         <cynthia_color>,
#         <dark_color>,
#         <dark_color_light>,
#         <diamond_color>,
#         <diamond_color_dark>,
#         <dragon_color>,
#         <dream_color>,
#         <eb8b51>,
#         <electric_color>,
#         <emerald_color>,
#         <fairy_color>,
#         <fairy_egg_color>,
#         <fighting_color>,
#         <fire_color>,
#         <fire_color_light>,
#         <flying_color>,
#         <galar_color>,
#         <ghost_color>,
#         <ghost_color_light>,
#         <gold_color>,
#         <grass_color>,
#         <green_color>,
#         <green_color_light>,
#         <grey_color_light>,
#         <ground_color>,
#         <heartgold_color_light>,
#         <hisui_color>,
#         <hoenn_color>,
#         <ice_color>,
#         <indigo_color>,
#         <kalos_color>,
#         <kitakami_color>,
#         <leafgreen_color>,
#         <legends_arceus_color>,
#         <mail_color>,
#         <masters_color>,
#         <moon_color>,
#         <night_color>,
#         <night_color_light>,
#         <normal_color>,
#         <normal_color_light>,
#         <orange_color>,
#         <paldea_color>,
#         <pbr_color>,
#         <pearl_color>,
#         <poison_color>,
#         <power_color>,
#         <psychic_color>,
#         <psychic_color_light>,
#         <ranger_color>,
#         <red_color>,
#         <red_color_light>,
#         <rock_color>,
#         <ruby_color>,
#         <sapphire_color>,
#         <scarlet_color>,
#         <shield_color>,
#         <silver_color>,
#         <sinnoh_color>,
#         <slumbering_color_light>,
#         <soulsilver_color>,
#         <spicy_color>,
#         <status_color>,
#         <steel_color>,
#         <steel_color_light>,
#         <stellar_color_light>,
#         <summer_color>,
#         <sun_color>,
#         <sweet_color>,
#         <sword_color>,
#         <tcg_Supporter_color>,
#         <tcg_fighting_color>,
#         <tcg_grass_color>,
#         <tcg_lightning_color>,
#         <tcg_psychic_color>,
#         <tcg_water_color>,
#         <unite_color>,
#         <unova_color>,
#         <violet_color>,
#         <water_color>,
#         <water_color_light>,
#         <white_2_color>,
#         <white_color>,
#         <white_color_light>,
#         <x_color>,
#         <y_color>,
#         <yellow_color> ;
#     ns1:corecolor <CCC>,
#         <F1ECD7>,
#         <grass_color_light>,
#         <orange_color_light>,
#         <poison_color_light>,
#         <water_color_light>,
#         <white_color_light> .
#
# <#switch:_#expr:_#time:_U> a <http://schema.org/color> .
#
# <439ba7> a <http://schema.org/color> .
#
# <4B5293> a <http://schema.org/color> .
#
# <4a474a> a <http://schema.org/color> .
#
# <526D82> a <http://schema.org/color> .
#
# <6C62A1> a <http://schema.org/color> .
#
# <761724> a <http://schema.org/color> .
#
# <76c7d2> a <http://schema.org/color> .
#
# <ADA1C9> a <http://schema.org/color> .
#
# <Alola_color> a <http://schema.org/color> .
#
# <B88354> a <http://schema.org/color> .
#
# <BAC5D7> a <http://schema.org/color> .
#
# <Blue> a <http://schema.org/color> .
#
# <Bug_color> a <http://schema.org/color> .
#
# <CC0000> a <http://schema.org/color> .
#
# <D46C50> a <http://schema.org/color> .
#
# <D5CFE3> a <http://schema.org/color> .
#
# <D87257> a <http://schema.org/color> .
#
# <Dark_blue_(Yellow_highlights)> a <http://schema.org/color> .
#
# <Dark_color> a <http://schema.org/color> .
#
# <E49E7F> a <http://schema.org/color> .
#
# <E7E4ED> a <http://schema.org/color> .
#
# <E8E48E> a <http://schema.org/color> .
#
# <F1CB90> a <http://schema.org/color> .
#
# <F1ECD7> a <http://schema.org/color> .
#
# <F3F7FA> a <http://schema.org/color> .
#
# <F7DD98> a <http://schema.org/color> .
#
# <Female> a <http://schema.org/gender> .
#
# <Fighting_color> a <http://schema.org/color> .
#
# <Fire_color> a <http://schema.org/color> .
#
# <GO_color> a <http://schema.org/color> .
#
# <GS_color> a <http://schema.org/color> .
#
# <Galar> a <http://example.org/region/Region> .
#
# <Ghost_color> a <http://schema.org/color> .
#
# <Grass_color> a <http://schema.org/color> .
#
# <Green> a <http://schema.org/color> .
#
# <Green_color> a <http://schema.org/color> .
#
# <HOME_color> a <http://schema.org/color> .
#
# <Honey> a <http://schema.org/color> .
#
# <Indigo_Disk_color> a <http://schema.org/color> .
#
# <Indigo_Disk_color_light> a <http://schema.org/color> .
#
# <Isle_of_Armor_color> a <http://schema.org/color> .
#
# <Kalos_color> a <http://schema.org/color> .
#
# <Kitakami_color> a <http://schema.org/color> .
#
# <Let's_Go_Eevee_color> a <http://schema.org/color> .
#
# <Let's_Go_Pikachu_color> a <http://schema.org/color> .
#
# <Mineral_egg_color> a <http://schema.org/color> .
#
# <Normal_color> a <http://schema.org/color> .
#
# <Omega_Ruby_color> a <http://schema.org/color> .
#
# <Orange_color> a <http://schema.org/color> .
#
# <Paldea_color> a <http://schema.org/color> .
#
# <Pokémon_color> a <http://schema.org/color> .
#
# <Postwick> a <http://example.org/location/location> .
#
# <Purple> a <http://schema.org/color> .
#
# <Rock_color> a <http://schema.org/color> .
#
# <Scarlet_color> a <http://schema.org/color> .
#
# <SoA_color> a <http://schema.org/color> .
#
# <Steel_color> a <http://schema.org/color> .
#
# <Stellar_color> a <http://schema.org/color> .
#
# <TCG_Ability_color> a <http://schema.org/color> .
#
# <TCG_Poké-Body_color_light> a <http://schema.org/color> .
#
# <TCG_Poké-Power_color> a <http://schema.org/color> .
#
# <TCG_Pokémon_Tool_color> a <http://schema.org/color> .
#
# <Treasures_color> a <http://schema.org/color> .
#
# <Unknown_color> a <http://schema.org/color> .
#
# <Unova_color> a <http://schema.org/color> .
#
# <Water_color> a <http://schema.org/color> .
#
# <XD_color> a <http://schema.org/color> .
#
# <X_color> a <http://schema.org/color> .
#
# <X_color_light> a <http://schema.org/color> .
#
# <Y_color> a <http://schema.org/color> .
#
# <Yellow> a <http://schema.org/color> .
#
# <alder_color> a <http://schema.org/color> .
#
# <alola_color> a <http://schema.org/color> .
#
# <b6f0f8> a <http://schema.org/color> .
#
# <beauty_color> a <http://schema.org/color> .
#
# <black_2_color> a <http://schema.org/color> .
#
# <black_color> a <http://schema.org/color> .
#
# <black_color_dark> a <http://schema.org/color> .
#
# <black_color_light> a <http://schema.org/color> .
#
# <blue_color_light> a <http://schema.org/color> .
#
# <blueberry_color> a <http://schema.org/color> .
#
# <bronze_color> a <http://schema.org/color> .
#
# <bug_color> a <http://schema.org/color> .
#
# <bulba_color> a <http://schema.org/color> .
#
# <c0b2dd> a <http://schema.org/color> .
#
# <castle_color> a <http://schema.org/color> .
#
# <cleverness_color_light> a <http://schema.org/color> .
#
# <colo_color> a <http://schema.org/color> .
#
# <contest_color> a <http://schema.org/color> .
#
# <cute_color> a <http://schema.org/color> .
#
# <cute_color_light> a <http://schema.org/color> .
#
# <cuteness_color> a <http://schema.org/color> .
#
# <cynthia_color> a <http://schema.org/color> .
#
# <dark_color> a <http://schema.org/color> .
#
# <dark_color_light> a <http://schema.org/color> .
#
# <diamond_color> a <http://schema.org/color> .
#
# <diamond_color_dark> a <http://schema.org/color> .
#
# <dragon_color> a <http://schema.org/color> .
#
# <dream_color> a <http://schema.org/color> .
#
# <e36226> a <http://schema.org/color> .
#
# <e5cff9> a <http://schema.org/color> .
#
# <electric_color> a <http://schema.org/color> .
#
# <emerald_color> a <http://schema.org/color> .
#
# <fairy_color> a <http://schema.org/color> .
#
# <fairy_egg_color> a <http://schema.org/color> .
#
# <fffeba> a <http://schema.org/color> .
#
# <fighting_color> a <http://schema.org/color> .
#
# <fire_color> a <http://schema.org/color> .
#
# <fire_color_light> a <http://schema.org/color> .
#
# <flying_color> a <http://schema.org/color> .
#
# <galar_color> a <http://schema.org/color> .
#
# <ghost_color> a <http://schema.org/color> .
#
# <ghost_color_light> a <http://schema.org/color> .
#
# <gold_color> a <http://schema.org/color> .
#
# <grass_color> a <http://schema.org/color> .
#
# <grass_color_light> a <http://schema.org/color> .
#
# <green_color> a <http://schema.org/color> .
#
# <green_color_light> a <http://schema.org/color> .
#
# <grey_color_light> a <http://schema.org/color> .
#
# <ground_color> a <http://schema.org/color> .
#
# <heartgold_color_light> a <http://schema.org/color> .
#
# <hisui_color> a <http://schema.org/color> .
#
# <hoenn_color> a <http://schema.org/color> .
#
# <ice_color> a <http://schema.org/color> .
#
# <indigo_color> a <http://schema.org/color> .
#
# <kalos_color> a <http://schema.org/color> .
#
# <kitakami_color> a <http://schema.org/color> .
#
# <leafgreen_color> a <http://schema.org/color> .
#
# <legends_arceus_color> a <http://schema.org/color> .
#
# <mail_color> a <http://schema.org/color> .
#
# <masters_color> a <http://schema.org/color> .
#
# <moon_color> a <http://schema.org/color> .
#
# <night_color> a <http://schema.org/color> .
#
# <night_color_light> a <http://schema.org/color> .
#
# <normal_color> a <http://schema.org/color> .
#
# <normal_color_light> a <http://schema.org/color> .
#
# <orange_color> a <http://schema.org/color> .
#
# <orange_color_light> a <http://schema.org/color> .
#
# <paldea_color> a <http://schema.org/color> .
#
# <pbr_color> a <http://schema.org/color> .
#
# <pearl_color> a <http://schema.org/color> .
#
# <poison_color> a <http://schema.org/color> .
#
# <poison_color_light> a <http://schema.org/color> .
#
# <power_color> a <http://schema.org/color> .
#
# <psychic_color> a <http://schema.org/color> .
#
# <psychic_color_light> a <http://schema.org/color> .
#
# <ranger_color> a <http://schema.org/color> .
#
# <red_color_light> a <http://schema.org/color> .
#
# <rock_color> a <http://schema.org/color> .
#
# <ruby_color> a <http://schema.org/color> .
#
# <sapphire_color> a <http://schema.org/color> .
#
# <scarlet_color> a <http://schema.org/color> .
#
# <shield_color> a <http://schema.org/color> .
#
# <silver_color> a <http://schema.org/color> .
#
# <sinnoh_color> a <http://schema.org/color> .
#
# <slumbering_color_light> a <http://schema.org/color> .
#
# <soulsilver_color> a <http://schema.org/color> .
#
# <spicy_color> a <http://schema.org/color> .
#
# <status_color> a <http://schema.org/color> .
#
# <steel_color> a <http://schema.org/color> .
#
# <steel_color_light> a <http://schema.org/color> .
#
# <stellar_color_light> a <http://schema.org/color> .
#
# <summer_color> a <http://schema.org/color> .
#
# <sun_color> a <http://schema.org/color> .
#
# <sweet_color> a <http://schema.org/color> .
#
# <sword_color> a <http://schema.org/color> .
#
# <tcg_Supporter_color> a <http://schema.org/color> .
#
# <tcg_fighting_color> a <http://schema.org/color> .
#
# <tcg_grass_color> a <http://schema.org/color> .
#
# <tcg_lightning_color> a <http://schema.org/color> .
#
# <tcg_psychic_color> a <http://schema.org/color> .
#
# <tcg_water_color> a <http://schema.org/color> .
#
# <unite_color> a <http://schema.org/color> .
#
# <unova_color> a <http://schema.org/color> .
#
# <violet_color> a <http://schema.org/color> .
#
# <water_color> a <http://schema.org/color> .
#
# <white_2_color> a <http://schema.org/color> .
#
# <white_color> a <http://schema.org/color> .
#
# <x_color> a <http://schema.org/color> .
#
# <y_color> a <http://schema.org/color> .
#
# <C00> a <http://schema.org/color> .
#
# <Paldea> a <http://example.org/region/Region> .
#
# <Unknown> a <http://example.org/location/location> .
#
# <ab3f26> a <http://schema.org/color> .
#
# <blue_color> a <http://schema.org/color> .
#
# <eb8b51> a <http://schema.org/color> .
#
# <f1c8b4> a <http://schema.org/color> .
#
# <red_color> a <http://schema.org/color> .
#
# <water_color_light> a <http://schema.org/color> .
#
# <white_color_light> a <http://schema.org/color> .
#
# <yellow_color> a <http://schema.org/color> .
#
# <Male> a <http://schema.org/gender> .
#
# <666> a <http://schema.org/color> .
#
# <CCC> a <http://schema.org/color> .

# %%
with open('RessourcesList\move_list.txt', 'r') as file:
    move_list = [line.strip() for line in file]

print(move_list)
# Out:
# ['Hidden Power (move)', 'Volt Tackle (move)', 'Earthquake (move)', 'Surf (move)', 'Toxic (move)', 'Double Team (move)', 'Rest (move)', 'Double-Edge (move)', 'Swagger (move)', 'Protect (move)', 'Endure (move)', 'Defense Curl (move)', 'Rain Dance (move)', 'Rock Smash (move)', 'Thunder (move)', 'Strength (move)', 'Pound (move)', 'Karate Chop (move)', 'Double Slap (move)', 'Comet Punch (move)', 'Mega Punch (move)', 'Pay Day (move)', 'Fire Punch (move)', 'Ice Punch (move)', 'Thunder Punch (move)', 'Scratch (move)', 'Vise Grip (move)', 'Guillotine (move)', 'Razor Wind (move)', 'Swords Dance (move)', 'Cut (move)', 'Gust (move)', 'Wing Attack (move)', 'Whirlwind (move)', 'Fly (move)', 'Bind (move)', 'Slam (move)', 'Vine Whip (move)', 'Stomp (move)', 'Double Kick (move)', 'Mega Kick (move)', 'Jump Kick (move)', 'Rolling Kick (move)', 'Sand Attack (move)', 'Headbutt (move)', 'Horn Attack (move)', 'Fury Attack (move)', 'Horn Drill (move)', 'Tackle (move)', 'Body Slam (move)', 'Wrap (move)', 'Take Down (move)', 'Thrash (move)', 'Tail Whip (move)', 'Poison Sting (move)', 'Twineedle (move)', 'Pin Missile (move)', 'Leer (move)', 'Bite (move)', 'Growl (move)', 'Roar (move)', 'Sing (move)', 'Supersonic (move)', 'Sonic Boom (move)', 'Disable (move)', 'Acid (move)', 'Ember (move)', 'Flamethrower (move)', 'Mist (move)', 'Water Gun (move)', 'Hydro Pump (move)', 'Blizzard (move)', 'Psybeam (move)', 'Bubble Beam (move)', 'Aurora Beam (move)', 'Hyper Beam (move)', 'Peck (move)', 'Drill Peck (move)', 'Submission (move)', 'Low Kick (move)', 'Counter (move)', 'Seismic Toss (move)', 'Mega Drain (move)', 'Leech Seed (move)', 'Growth (move)', 'Razor Leaf (move)', 'Solar Beam (move)', 'Poison Powder (move)', 'Stun Spore (move)', 'Sleep Powder (move)', 'Petal Dance (move)', 'String Shot (move)', 'Dragon Rage (move)', 'Fire Spin (move)', 'Thunder Shock (move)', 'Thunderbolt (move)', 'Thunder Wave (move)', 'Rock Throw (move)', 'Fissure (move)', 'Dig (move)', 'Confusion (move)', 'Psychic (move)', 'Hypnosis (move)', 'Meditate (move)', 'Agility (move)', 'Quick Attack (move)', 'Rage (move)', 'Teleport (move)', 'Night Shade (move)', 'Mimic (move)', 'Screech (move)', 'Recover (move)', 'Harden (move)', 'Minimize (move)', 'Smokescreen (move)', 'Confuse Ray (move)', 'Withdraw (move)', 'Barrier (move)', 'Light Screen (move)', 'Haze (move)', 'Reflect (move)', 'Focus Energy (move)', 'Bide (move)', 'Metronome (move)', 'Mirror Move (move)', 'Self-Destruct (move)', 'Egg Bomb (move)', 'Lick (move)', 'Smog (move)', 'Sludge (move)', 'Bone Club (move)', 'Waterfall (move)', 'Clamp (move)', 'Swift (move)', 'Skull Bash (move)', 'Spike Cannon (move)', 'Constrict (move)', 'Amnesia (move)', 'Kinesis (move)', 'Soft-Boiled (move)', 'High Jump Kick (move)', 'Glare (move)', 'Dream Eater (move)', 'Poison Gas (move)', 'Barrage (move)', 'Leech Life (move)', 'Lovely Kiss (move)', 'Sky Attack (move)', 'Transform (move)', 'Bubble (move)', 'Dizzy Punch (move)', 'Spore (move)', 'Flash (move)', 'Psywave (move)', 'Splash (move)', 'Acid Armor (move)', 'Crabhammer (move)', 'Explosion (move)', 'Fury Swipes (move)', 'Bonemerang (move)', 'Rock Slide (move)', 'Hyper Fang (move)', 'Sharpen (move)', 'Conversion (move)', 'Tri Attack (move)', 'Super Fang (move)', 'Slash (move)', 'Substitute (move)', 'Struggle (move)', 'Sketch (move)', 'Triple Kick (move)', 'Thief (move)', 'Spider Web (move)', 'Mind Reader (move)', 'Nightmare (move)', 'Flame Wheel (move)', 'Snore (move)', 'Flail (move)', 'Conversion 2 (move)', 'Aeroblast (move)', 'Cotton Spore (move)', 'Reversal (move)', 'Spite (move)', 'Powder Snow (move)', 'Mach Punch (move)', 'Scary Face (move)', 'Feint Attack (move)', 'Sweet Kiss (move)', 'Belly Drum (move)', 'Sludge Bomb (move)', 'Mud-Slap (move)', 'Octazooka (move)', 'Spikes (move)', 'Zap Cannon (move)', 'Foresight (move)', 'Destiny Bond (move)', 'Perish Song (move)', 'Icy Wind (move)', 'Detect (move)', 'Bone Rush (move)', 'Lock-On (move)', 'Outrage (move)', 'Sandstorm (move)', 'Giga Drain (move)', 'Cha ...

# %%
MOVE = Namespace("http://example.org/move/")
intial_move_graph = Graph()
final_move_graph = Graph()

for individual_move in move_list:
    try:
        # Step 1: Fetch the page text
        result1 = bulbabot.page_text(title=individual_move)
        
        # Step 2: Extract the infobox
        result2 = extract_move_infobox(result1)
        
        # Step 3: Parse the infobox
        result3 = parse_infobox(result2)
        
        # Step 4: Map the parsed infobox to RDF
        final_move_graph = map_infobox_to_rdf(MOVE, intial_move_graph, property_mappings, result3)
        
        # Log or handle the final result (optional)
        print(f"Successfully processed {individual_move}")
    except Exception as e:
        # Handle any errors that occur in the pipeline
        print(f"Error processing {individual_move}: {e}")
# Out:
# Successfully processed Hidden Power (move)
# Successfully processed Volt Tackle (move)
# Successfully processed Earthquake (move)
# Successfully processed Surf (move)
# Error processing Toxic (move): invalid literal for int() with base 10: '—'
# Error processing Double Team (move): invalid literal for int() with base 10: '—'
# Successfully processed Rest (move)
# Error processing Double-Edge (move): invalid literal for int() with base 10: '300px'
# Error processing Swagger (move): invalid literal for int() with base 10: '—'
# Error processing Protect (move): invalid literal for int() with base 10: '—'
# Error processing Endure (move): invalid literal for int() with base 10: '—'
# Error processing Defense Curl (move): invalid literal for int() with base 10: '—'
# Error processing Rain Dance (move): invalid literal for int() with base 10: '—'
# Successfully processed Rock Smash (move)
# Successfully processed Thunder (move)
# Successfully processed Strength (move)
# Successfully processed Pound (move)
# Error processing Karate Chop (move): invalid literal for int() with base 10: '300px'
# Error processing Double Slap (move): invalid literal for int() with base 10: '300px'
# Successfully processed Comet Punch (move)
# Successfully processed Mega Punch (move)
# Successfully processed Pay Day (move)
# Error processing Fire Punch (move): invalid literal for int() with base 10: '300px'
# Error processing Ice Punch (move): invalid literal for int() with base 10: '300px'
# Error processing Thunder Punch (move): invalid literal for int() with base 10: '300 px'
# Error processing Scratch (move): invalid literal for int() with base 10: '300px'
# Successfully processed Vise Grip (move)
# Error processing Guillotine (move): invalid literal for int() with base 10: '300px'
# Successfully processed Razor Wind (move)
# Successfully processed Swords Dance (move)
# Successfully processed Cut (move)
# Error processing Gust (move): invalid literal for int() with base 10: '300px'
# Successfully processed Wing Attack (move)
# Error processing Whirlwind (move): invalid literal for int() with base 10: '—'
# Error processing Fly (move): invalid literal for int() with base 10: '300px'
# Successfully processed Bind (move)
# Error processing Slam (move): invalid literal for int() with base 10: '300px'
# Error processing Vine Whip (move): invalid literal for int() with base 10: '300px'
# Successfully processed Stomp (move)
# Successfully processed Double Kick (move)
# Successfully processed Mega Kick (move)
# Successfully processed Jump Kick (move)
# Successfully processed Rolling Kick (move)
# Error processing Sand Attack (move): invalid literal for int() with base 10: '300px'
# Error processing Headbutt (move): invalid literal for int() with base 10: '300px'
# Successfully processed Horn Attack (move)
# Error processing Fury Attack (move): invalid literal for int() with base 10: '300px'
# Error processing Horn Drill (move): invalid literal for int() with base 10: '—'
# Error processing Tackle (move): invalid literal for int() with base 10: '300px'
# Successfully processed Body Slam (move)
# Successfully processed Wrap (move)
# Successfully processed Take Down (move)
# Successfully processed Thrash (move)
# Error processing Tail Whip (move): invalid literal for int() with base 10: '300px'
# Successfully processed Poison Sting (move)
# Successfully processed Twineedle (move)
# Successfully processed Pin Missile (move)
# Error processing Leer (move): invalid literal for int() with base 10: '300px'
# Successfully processed Bite (move)
# Error processing Growl (move): invalid literal for int() with base 10: '300px'
# Error processing Roar (move): invalid literal for int() with base 10: '300px'
# Error processing Sing (move): invalid literal for int() with base 10: '300px'
# Error processing Supersonic (move): invalid literal for int() with base 10: '300px'
# Error processing Sonic Boom (move): invalid literal for int() with base 10: '—'
# Error processing Disable (move): invalid literal for int() with base 10: '300px'
# Successfully processed Acid (move)
# Error processing Ember (move): invalid literal for int() with base 10: '300px'
# Successfully processed Flamethrower (move)
# Error processing Mist (move): invalid literal for int() with base 10: '300px'
# Error processing Water Gun (move): invalid literal for int() with base 10: '300px'
# Error processing Hydro Pump (move): invalid literal for int() with base 10: '300px'
# Successfully processed Blizzard (move)
# Successfully processed Psybeam (move)
# Error processing Bubble Beam (move): invalid literal for int() with base 10: '300px'
# Successfully processed Aurora Beam (move)
# Error processing Hyper Beam (move): invalid literal for int() with base 10: '300px'
# Successfully processed Peck (move)
# Successfully processed Drill Peck (move)
# Error processing Submission (move): invalid literal for int() with base 10: '300px'
# Successfully processed Low Kick (move)
# Error processing Counter (move): invalid literal for int() with base 10: '—'
# Error processing Seismic Toss (move): invalid literal for int() with base 10: '300px'
# Successfully processed Mega Drain (move)
# Error processing Leech Seed (move): invalid literal for int() with base 10: '—'
# Successfully processed Growth (move)
# Successfully processed Razor Leaf (move)
# Error processing Solar Beam (move): invalid literal for int() with base 10: '300px'
# Error processing Poison Powder (move): invalid literal for int() with base 10: '—'
# Error processing Stun Spore (move): invalid literal for int() with base 10: '—'
# Error processing Sleep Powder (move): invalid literal for int() with base 10: '—'
# Successfully processed Petal Dance (move)
# Error processing String Shot (move): invalid literal for int() with base 10: '—'
# Error processing Dragon Rage (move): invalid literal for int() with base 10: '300px'
# Successfully processed Fire Spin (move)
# Successfully processed Thunder Shock (move)
# Successfully processed Thunderbolt (move)
# Error processing Thunder Wave (move): invalid literal for int() with base 10: '300px'
# Successfully processed Rock Throw (move)
# Error processing Fissure (move): invalid literal for int() with base 10: '—'
# Successfully processed Dig (move)
# Successfully processed Confusion (move)
# Successfully processed Psychic (move)
# Error processing Hypnosis (move): invalid literal for int() with base 10: '300px'
# Error processing Meditate (move): invalid literal for int() with base 10: '300px'
# Error processing Agility (move): invalid literal for int() with base 10: '300px'
# Successfully processed Quick Attack (move)
# Error processing Rage (move): invalid literal for int() with base 10: '300px'
# Error processing Teleport (move): invalid literal for int() with base 10: '—'
# Error processing Night Shade (move): invalid literal for int() with base 10: '—'
# Error processing Mimic (move): invalid literal for int() with base 10: '—'
# Error processing Screech (move): invalid literal for int() with base 10: '—'
# Successfully processed Recover (move)
# Error processing Harden (move): invalid literal for int() with base 10: '—'
# Successfully processed Minimize (move)
# Error processing Smokescreen (move): invalid literal for int() with base 10: '—'
# Error processing Confuse Ray (move): invalid literal for int() with base 10: '—'
# Error processing Withdraw (move): invalid literal for int() with base 10: '—'
# Successfully processed Barrier (move)
# Error processing Light Screen (move): invalid literal for int() with base 10: '—'
# Error processing Haze (move): invalid literal for int() with base 10: '—'
# Error processing Reflect (move): invalid literal for int() with base 10: '—'
# Error processing Focus Energy (move): invalid literal for int() with base 10: '—'
# Error processing Bide (move): invalid literal for int() with base 10: '—'
# Error processing Metronome (move): invalid literal for int() with base 10: '—'
# Error processing Mirror Move (move): invalid literal for int() with base 10: '—'
# Successfully processed Self-Destruct (move)
# Successfully processed Egg Bomb (move)
# Successfully processed Lick (move)
# Successfully processed Smog (move)
# Successfully processed Sludge (move)
# Successfully processed Bone Club (move)
# Successfully processed Waterfall (move)
# Successfully processed Clamp (move)
# Error processing Swift (move): invalid literal for int() with base 10: '—'
# Successfully processed Skull Bash (move)
# Successfully processed Spike Cannon (move)
# Successfully processed Constrict (move)
# Error processing Amnesia (move): invalid literal for int() with base 10: '—'
# Error processing Kinesis (move): invalid literal for int() with base 10: '—'
# Successfully processed Soft-Boiled (move)
# Successfully processed High Jump Kick (move)
# Error processing Glare (move): invalid literal for int() with base 10: '—'
# Successfully processed Dream Eater (move)
# Error processing Poison Gas (move): invalid literal for int() with base 10: '—'
# Successfully processed Barrage (move)
# Successfully processed Leech Life (move)
# Error processing Lovely Kiss (move): invalid literal for int() with base 10: '—'
# Successfully processed Sky Attack (move)
# Error processing Transform (move): invalid literal for int() with base 10: '—'
# Successfully processed Bubble (move)
# Successfully processed Dizzy Punch (move)
# Error processing Spore (move): invalid literal for int() with base 10: '—'
# Error processing Flash (move): invalid literal for int() with base 10: '—'
# Error processing Psywave (move): invalid literal for int() with base 10: '—'
# Error processing Splash (move): invalid literal for int() with base 10: '—'
# Successfully processed Acid Armor (move)
# Successfully processed Crabhammer (move)
# Successfully processed Explosion (move)
# Successfully processed Fury Swipes (move)
# Successfully processed Bonemerang (move)
# Successfully processed Rock Slide (move)
# Successfully processed Hyper Fang (move)
# Error processing Sharpen (move): invalid literal for int() with base 10: '—'
# Error processing Conversion (move): invalid literal for int() with base 10: '—'
# Error processing Tri Attack (move): invalid literal for int() with base 10: '300px'
# Error processing Super Fang (move): invalid literal for int() with base 10: '—'
# Successfully processed Slash (move)
# Successfully processed Substitute (move)
# Successfully processed Struggle (move)
# Error processing Sketch (move): invalid literal for int() with base 10: '—'
# Successfully processed Triple Kick (move)
# Successfully processed Thief (move)
# Error processing Spider Web (move): invalid literal for int() with base 10: '—'
# Error processing Mind Reader (move): invalid literal for int() with base 10: '—'
# Error processing Nightmare (move): invalid literal for int() with base 10: '—'
# Successfully processed Flame Wheel (move)
# Successfully processed Snore (move)
# Error processing Flail (move): invalid literal for int() with base 10: '—'
# Error processing Conversion 2 (move): invalid literal for int() with base 10: '—'
# Successfully processed Aeroblast (move)
# Error processing Cotton Spore (move): invalid literal for int() with base 10: '—'
# Error processing Reversal (move): invalid literal for int() with base 10: '—'
# Error processing Spite (move): invalid literal for int() with base 10: '—'
# Successfully processed Powder Snow (move)
# Successfully processed Mach Punch (move)
# Error processing Scary Face (move): invalid literal for int() with base 10: '—'
# Error processing Feint Attack (move): invalid literal for int() with base 10: '—'
# Error processing Sweet Kiss (move): invalid literal for int() with base 10: '—'
# Error processing Belly Drum (move): invalid literal for int() with base 10: '—'
# Successfully processed Sludge Bomb (move)
# Successfully processed Mud-Slap (move)
# Successfully processed Octazooka (move)
# Error processing Spikes (move): invalid literal for int() with base 10: '—'
# Successfully processed Zap Cannon (move)
# Error processing Foresight (move): invalid literal for int() with base 10: '—'
# Error processing Destiny Bond (move): invalid literal for int() with base 10: '—'
# Error processing Perish Song (move): invalid literal for int() with base 10: '—'
# Successfully processed Icy Wind (move)
# Error processing Detect (move): invalid literal for int() with base 10: '—'
# Successfully processed Bone Rush (move)
# Error processing Lock-On (move): invalid literal for int() with base 10: '—'
# Successfully processed Outrage (move)
# Error processing Sandstorm (move): invalid literal for int() with base 10: '—'
# Successfully processed Giga Drain (move)
# Error processing Charm (move): invalid literal for int() with base 10: '—'
# Successfully processed Rollout (move)
# Successfully processed False Swipe (move)
# Successfully processed Milk Drink (move)
# Successfully processed Spark (move)
# Successfully processed Fury Cutter (move)
# Successfully processed Steel Wing (move)
# Error processing Mean Look (move): invalid literal for int() with base 10: '—'
# Error processing Attract (move): invalid literal for int() with base 10: '—'
# Error processing Sleep Talk (move): invalid literal for int() with base 10: '—'
# Error processing Heal Bell (move): invalid literal for int() with base 10: '—'
# Error processing Return (move): invalid literal for int() with base 10: '—'
# Error processing Present (move): invalid literal for int() with base 10: '—'
# Error processing Frustration (move): invalid literal for int() with base 10: '—'
# Error processing Safeguard (move): invalid literal for int() with base 10: '—'
# Error processing Pain Split (move): invalid literal for int() with base 10: '—'
# Successfully processed Sacred Fire (move)
# Error processing Magnitude (move): invalid literal for int() with base 10: '—'
# Error processing Dynamic Punch (move): invalid literal for int() with base 10: '300px'
# Successfully processed Megahorn (move)
# Successfully processed Dragon Breath (move)
# Error processing Baton Pass (move): invalid literal for int() with base 10: '—'
# Error processing Encore (move): invalid literal for int() with base 10: '—'
# Successfully processed Pursuit (move)
# Successfully processed Rapid Spin (move)
# Error processing Sweet Scent (move): invalid literal for int() with base 10: '—'
# Successfully processed Iron Tail (move)
# Successfully processed Metal Claw (move)
# Error processing Vital Throw (move): invalid literal for int() with base 10: '—'
# Error processing Morning Sun (move): invalid literal for int() with base 10: '—'
# Error processing Synthesis (move): invalid literal for int() with base 10: '—'
# Error processing Moonlight (move): invalid literal for int() with base 10: '—'
# Successfully processed Cross Chop (move)
# Successfully processed Twister (move)
# Error processing Sunny Day (move): invalid literal for int() with base 10: '—'
# Successfully processed Crunch (move)
# Error processing Mirror Coat (move): invalid literal for int() with base 10: '—'
# Error processing Psych Up (move): invalid literal for int() with base 10: '—'
# Successfully processed Extreme Speed (move)
# Successfully processed Ancient Power (move)
# Successfully processed Shadow Ball (move)
# Successfully processed Future Sight (move)
# Successfully processed Whirlpool (move)
# Successfully processed Beat Up (move)
# Error processing Fake Out (move): invalid literal for int() with base 10: '300px'
# Successfully processed Uproar (move)
# Error processing Stockpile (move): invalid literal for int() with base 10: '300px'
# Successfully processed Spit Up (move)
# Error processing Swallow (move): invalid literal for int() with base 10: '300px'
# Error processing Heat Wave (move): invalid literal for int() with base 10: '300px'
# Error processing Hail (move): invalid literal for int() with base 10: '—'
# Error processing Torment (move): invalid literal for int() with base 10: '—'
# Error processing Flatter (move): invalid literal for int() with base 10: '—'
# Error processing Will-O-Wisp (move): invalid literal for int() with base 10: '—'
# Error processing Memento (move): invalid literal for int() with base 10: '—'
# Error processing Facade (move): invalid literal for int() with base 10: '300px'
# Successfully processed Focus Punch (move)
# Successfully processed Smelling Salts (move)
# Error processing Follow Me (move): invalid literal for int() with base 10: '—'
# Error processing Nature Power (move): invalid literal for int() with base 10: '—'
# Error processing Charge (move): invalid literal for int() with base 10: '—'
# Error processing Taunt (move): invalid literal for int() with base 10: '300px'
# Error processing Helping Hand (move): invalid literal for int() with base 10: '—'
# Error processing Trick (move): invalid literal for int() with base 10: '—'
# Error processing Role Play (move): invalid literal for int() with base 10: '—'
# Error processing Wish (move): invalid literal for int() with base 10: '—'
# Error processing Assist (move): invalid literal for int() with base 10: '—'
# Error processing Ingrain (move): invalid literal for int() with base 10: '—'
# Successfully processed Superpower (move)
# Error processing Magic Coat (move): invalid literal for int() with base 10: '300px'
# Error processing Recycle (move): invalid literal for int() with base 10: '—'
# Error processing Revenge (move): invalid literal for int() with base 10: '300px'
# Successfully processed Brick Break (move)
# Error processing Yawn (move): invalid literal for int() with base 10: '—'
# Error processing Knock Off (move): invalid literal for int() with base 10: '300px'
# Error processing Endeavor (move): invalid literal for int() with base 10: '—'
# Successfully processed Eruption (move)
# Error processing Skill Swap (move): invalid literal for int() with base 10: '—'
# Error processing Imprison (move): invalid literal for int() with base 10: '—'
# Error processing Refresh (move): invalid literal for int() with base 10: '—'
# Error processing Grudge (move): invalid literal for int() with base 10: '300px'
# Error processing Snatch (move): invalid literal for int() with base 10: '—'
# Successfully processed Dive (move)
# Successfully processed Arm Thrust (move)
# Error processing Camouflage (move): invalid literal for int() with base 10: '300px'
# Error processing Tail Glow (move): invalid literal for int() with base 10: '300px'
# Error processing Luster Purge (move): invalid literal for int() with base 10: '300px'
# Successfully processed Mist Ball (move)
# Error processing Feather Dance (move): invalid literal for int() with base 10: '—'
# Error processing Teeter Dance (move): invalid literal for int() with base 10: '—'
# Error processing Blaze Kick (move): invalid literal for int() with base 10: '300px'
# Error processing Mud Sport (move): invalid literal for int() with base 10: '—'
# Error processing Ice Ball (move): invalid literal for int() with base 10: '300px'
# Successfully processed Needle Arm (move)
# Successfully processed Slack Off (move)
# Successfully processed Hyper Voice (move)
# Successfully processed Poison Fang (move)
# Successfully processed Crush Claw (move)
# Successfully processed Blast Burn (move)
# Successfully processed Hydro Cannon (move)
# Successfully processed Meteor Mash (move)
# Successfully processed Astonish (move)
# Successfully processed Weather Ball (move)
# Error processing Aromatherapy (move): invalid literal for int() with base 10: '300px'
# Successfully processed Fake Tears (move)
# Successfully processed Air Cutter (move)
# Successfully processed Overheat (move)
# Error processing Odor Sleuth (move): invalid literal for int() with base 10: '—'
# Successfully processed Rock Tomb (move)
# Successfully processed Silver Wind (move)
# Successfully processed Metal Sound (move)
# Error processing Grass Whistle (move): invalid literal for int() with base 10: '—'
# Successfully processed Tickle (move)
# Successfully processed Cosmic Power (move)
# Successfully processed Water Spout (move)
# Error processing Signal Beam (move): invalid literal for int() with base 10: '300px'
# Error processing Shadow Punch (move): invalid literal for int() with base 10: '—'
# Successfully processed Extrasensory (move)
# Successfully processed Sky Uppercut (move)
# Successfully processed Sand Tomb (move)
# Successfully processed Sheer Cold (move)
# Error processing Muddy Water (move): invalid literal for int() with base 10: '300px'
# Successfully processed Bullet Seed (move)
# Error processing Aerial Ace (move): invalid literal for int() with base 10: '—'
# Successfully processed Icicle Spear (move)
# Successfully processed Iron Defense (move)
# Error processing Block (move): invalid literal for int() with base 10: '—'
# Successfully processed Howl (move)
# Successfully processed Dragon Claw (move)
# Successfully processed Frenzy Plant (move)
# Error processing Bulk Up (move): invalid literal for int() with base 10: '300px'
# Successfully processed Bounce (move)
# Successfully processed Mud Shot (move)
# Successfully processed Poison Tail (move)
# Error processing Covet (move): invalid literal for int() with base 10: '300px'
# Error processing Magical Leaf (move): invalid literal for int() with base 10: '—'
# Error processing Water Sport (move): invalid literal for int() with base 10: '—'
# Successfully processed Calm Mind (move)
# Successfully processed Leaf Blade (move)
# Successfully processed Dragon Dance (move)
# Successfully processed Rock Blast (move)
# Error processing Shock Wave (move): invalid literal for int() with base 10: '300px'
# Error processing Water Pulse (move): invalid literal for int() with base 10: '300px'
# Successfully processed Doom Desire (move)
# Successfully processed Psycho Boost (move)
# Error processing Shadow Rush (move): invalid literal for int() with base 10: 'N/A'
# Successfully processed Absorb (move)
# Error processing Shadow Blast (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Blitz (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Bolt (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Chill (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Fire (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Break (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Down (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow End (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Half (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Hold (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Mist (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Panic (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Rave (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Shed (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Sky (move): invalid literal for int() with base 10: '—'
# Error processing Shadow Storm (move): invalid literal for int() with base 10: 'N/A'
# Error processing Shadow Wave (move): invalid literal for int() with base 10: 'N/A'
# Successfully processed Cross Poison (move)
# Successfully processed Draco Meteor (move)
# Error processing Heart Swap (move): invalid literal for int() with base 10: '—'
# Error processing Aura Sphere (move): invalid literal for int() with base 10: '300px'
# Error processing Embargo (move): invalid literal for int() with base 10: '—'
# Successfully processed Worry Seed (move)
# Successfully processed Aqua Jet (move)
# Successfully processed Close Combat (move)
# Error processing Discharge (move): invalid literal for int() with base 10: '300px'
# Successfully processed Shadow Claw (move)
# Successfully processed Force Palm (move)
# Error processing Me First (move): invalid literal for int() with base 10: '—'
# Successfully processed Copycat (move)
# Error processing Ice Fang (move): invalid literal for int() with base 10: '300px'
# Successfully processed Thunder Fang (move)
# Successfully processed Fire Fang (move)
# Error processing Nasty Plot (move): invalid literal for int() with base 10: '300px'
# Successfully processed Giga Impact (move)
# Successfully processed Feint (move)
# Successfully processed Chatter (move)
# Error processing Lucky Chant (move): invalid literal for int() with base 10: '—'
# Successfully processed Brave Bird (move)
# Successfully processed Leaf Storm (move)
# Successfully processed Charge Beam (move)
# Successfully processed Brine (move)
# Error processing Roost (move): invalid literal for int() with base 10: '300px'
# Successfully processed Gravity (move)
# Error processing Miracle Eye (move): invalid literal for int() with base 10: '—'
# Error processing Wake-Up Slap (move): invalid literal for int() with base 10: '300px'
# Successfully processed Energy Ball (move)
# Successfully processed Hammer Arm (move)
# Successfully processed Gyro Ball (move)
# Successfully processed Healing Wish (move)
# Error processing Natural Gift (move): invalid literal for int() with base 10: '—'
# Successfully processed Pluck (move)
# Successfully processed Tailwind (move)
# Error processing Acupressure (move): invalid literal for int() with base 10: '—'
# Error processing Metal Burst (move): invalid literal for int() with base 10: '—'
# Successfully processed U-turn (move)
# Successfully processed Ice Shard (move)
# Error processing Payback (move): invalid literal for int() with base 10: '300px'
# Error processing Grass Knot (move): invalid literal for int() with base 10: 'Varies'
# Successfully processed Flash Cannon (move)
# Error processing Captivate (move): invalid literal for int() with base 10: '—'
# Error processing Stealth Rock (move): invalid literal for int() with base 10: '300px'
# Successfully processed Night Slash (move)
# Successfully processed Last Resort (move)
# Successfully processed Wood Hammer (move)
# Successfully processed Zen Headbutt (move)
# Error processing Fling (move): invalid literal for int() with base 10: '—'
# Successfully processed Psycho Shift (move)
# Error processing Heal Block (move): invalid literal for int() with base 10: '—'
# Successfully processed Flare Blitz (move)
# Error processing Punishment (move): invalid literal for int() with base 10: '—'
# Successfully processed Seed Flare (move)
# Error processing Wring Out (move): invalid literal for int() with base 10: '—'
# Error processing Power Whip (move): invalid literal for int() with base 10: '300px'
# Error processing Trump Card (move): invalid literal for int() with base 10: '300px'
# Successfully processed Seed Bomb (move)
# Error processing Double Hit (move): invalid literal for int() with base 10: '300px'
# Error processing Judgment (move): invalid literal for int() with base 10: '300px'
# Error processing Rock Climb (move): invalid literal for int() with base 10: '300px'
# Successfully processed Crush Grip (move)
# Successfully processed Focus Blast (move)
# Successfully processed Stone Edge (move)
# Error processing Poison Jab (move): invalid literal for int() with base 10: '300px'
# Error processing Defog (move): invalid literal for int() with base 10: '—'
# Successfully processed Dark Pulse (move)
# Error processing Avalanche (move): invalid literal for int() with base 10: '300px'
# Successfully processed Trick Room (move)
# Successfully processed Drain Punch (move)
# Error processing X-Scissor (move): invalid literal for int() with base 10: '300px'
# Successfully processed Dragon Pulse (move)
# Successfully processed Vacuum Wave (move)
# Successfully processed Air Slash (move)
# Successfully processed Gunk Shot (move)
# Error processing Gastro Acid (move): invalid literal for int() with base 10: '—'
# Successfully processed Toxic Spikes (move)
# Error processing Earth Power (move): invalid literal for int() with base 10: '300px'
# Error processing Mud Bomb (move): invalid literal for int() with base 10: '300px'
# Successfully processed Rock Polish (move)
# Successfully processed Roar of Time (move)
# Error processing Power Trick (move): invalid literal for int() with base 10: '—'
# Error processing Power Swap (move): invalid literal for int() with base 10: '—'
# Error processing Guard Swap (move): invalid literal for int() with base 10: '—'
# Successfully processed Sucker Punch (move)
# Error processing Aqua Ring (move): invalid literal for int() with base 10: '—'
# Error processing Magnet Rise (move): invalid literal for int() with base 10: '—'
# Error processing Aqua Tail (move): invalid literal for int() with base 10: '300px'
# Successfully processed Bug Buzz (move)
# Successfully processed Dragon Rush (move)
# Successfully processed Switcheroo (move)
# Successfully processed Bullet Punch (move)
# Successfully processed Shadow Sneak (move)
# Successfully processed Mirror Shot (move)
# Successfully processed Lava Plume (move)
# Successfully processed Rock Wrecker (move)
# Successfully processed Iron Head (move)
# Error processing Magnet Bomb (move): invalid literal for int() with base 10: '300px'
# Error processing Bug Bite (move): invalid literal for int() with base 10: '300px'
# Successfully processed Attack Order (move)
# Error processing Defend Order (move): invalid literal for int() with base 10: '—'
# Error processing Heal Order (move): invalid literal for int() with base 10: '—'
# Successfully processed Head Smash (move)
# Successfully processed Spacial Rend (move)
# Successfully processed Lunar Dance (move)
# Successfully processed Magma Storm (move)
# Successfully processed Dark Void (move)
# Error processing Ominous Wind (move): invalid literal for int() with base 10: '300px'
# Successfully processed Shadow Force (move)
# Successfully processed Psycho Cut (move)
# Successfully processed Power Gem (move)
# Successfully processed Assurance (move)
# Successfully processed Secret Power (move)
# Successfully processed Fire Blast (move)
# Successfully processed Curse (move)
# Successfully processed Ice Beam (move)
# Successfully processed Hone Claws (move)
# Successfully processed Heart Stamp (move)
# Error processing Acrobatics (move): invalid literal for int() with base 10: '300px'
# Error processing Flame Charge (move): invalid literal for int() with base 10: '300px'
# Successfully processed Scald (move)
# Successfully processed Flame Burst (move)
# Successfully processed Electro Ball (move)
# Successfully processed Leaf Tornado (move)
# Successfully processed Rage Powder (move)
# Successfully processed Struggle Bug (move)
# Error processing Quiver Dance (move): invalid literal for int() with base 10: '300px'
# Successfully processed Steamroller (move)
# Successfully processed Magic Room (move)
# Successfully processed Wide Guard (move)
# Successfully processed Bulldoze (move)

# %%
# Save or print the created graph
print(final_move_graph.serialize(format="turtle"))
with open(os.path.join(graph_path,"move_graph.ttl"), "w", encoding="utf-8") as file:
    file.write(final_move_graph.serialize(format="turtle"))
# Out:
# @prefix ns1: <http://example.org/move/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ns1:Absorb a ns1:move ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Absorb_IX.png> ;
#     ns1:gameimage2 <Absorb_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "すいとる" ;
#     ns1:jtrans "Absorb" ;
#     ns1:jtranslit "Suitoru" ;
#     ns1:n 71 ;
#     ns1:type <http://example.org/move/type/Grass> .
#
# ns1:Acid a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 1 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 30 ;
#     ns1:category "Smart" ;
#     ns1:category6 "Clever" ;
#     ns1:cdesc "Badly startles the Pokémon in front." ;
#     ns1:cdesc6 "Brings down the energy of any Pokémon that have already used a move this turn." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Acid_IX.png> ;
#     ns1:gameimage2 <Acid_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 4 ;
#     ns1:jam6 0 ;
#     ns1:jname "ようかいえき" ;
#     ns1:jtrans "Corrosive Liquid" ;
#     ns1:jtranslit "Yōkaieki" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 48 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 51 ;
#     ns1:power 40 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "adjacentfoes" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Poison> .
#
# ns1:Acid_Armor a ns1:move ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Acid_Armor_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "とける" ;
#     ns1:jtrans "Liquefy" ;
#     ns1:jtranslit "Tokeru" ;
#     ns1:n 151 ;
#     ns1:type <http://example.org/move/type/Poison> .
#
# ns1:Acrobatics a ns1:move ;
#     ns1:gameimage <Acrobatics_IX.png> ;
#     ns1:jname "アクロバット" ;
#     ns1:jtrans "Acrobat" ;
#     ns1:jtranslit "Akurobatto" ;
#     ns1:n 512 .
#
# ns1:Acupressure a ns1:move ;
#     ns1:basepp 30 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Acupressure_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "つぼをつく" ;
#     ns1:jtrans "Pressure Point Poke" ;
#     ns1:jtranslit "Tsubo o Tsuku" ;
#     ns1:maxpp 48 ;
#     ns1:n 367 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Aerial_Ace a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Aerial_Ace_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "つばめがえし" ;
#     ns1:jtrans "Swallow Return" ;
#     ns1:jtranslit "Tsubame Gaeshi" ;
#     ns1:maxpp 32 ;
#     ns1:n 332 ;
#     ns1:power 60 ;
#     ns1:type <http://example.org/move/type/Flying> .
#
# ns1:Aeroblast a ns1:move ;
#     ns1:accuracy 95 ;
#     ns1:appeal 3 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 5 ;
#     ns1:category "Cool" ;
#     ns1:cdesc "Affected by how well the appeal in front goes." ;
#     ns1:cdesc6 "Excites the audience a lot if used last." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Aeroblast_IX.png> ;
#     ns1:gameimage2 <Aeroblast_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "II" ;
#     ns1:jam 0 ;
#     ns1:jam6 0 ;
#     ns1:jname "エアロブラスト" ;
#     ns1:jtrans "Aeroblast" ;
#     ns1:jtranslit "Earoburasuto" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 8 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 177 ;
#     ns1:power 100 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +3 if the Pokémon that just went hit max Voltage." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "any" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Flying> .
#
# ns1:Agility a ns1:move ;
#     ns1:gameimage <Agility_IX.png> ;
#     ns1:jname "こうそくいどう" ;
#     ns1:jtrans "High-speed Movement" ;
#     ns1:jtranslit "Kōsoku Idō" ;
#     ns1:n 97 .
#
# ns1:Air_Cutter a ns1:move ;
#     ns1:basepp 25 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Air_Cutter_IX.png> ;
#     ns1:gameimage2 <Air_Cutter_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "エアカッター" ;
#     ns1:jtrans "Air Cutter" ;
#     ns1:jtranslit "Ea Kattā" ;
#     ns1:maxpp 40 ;
#     ns1:n 314 ;
#     ns1:type <http://example.org/move/type/Flying> .
#
# ns1:Amnesia a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Amnesia_IX.png> ;
#     ns1:gameimage2 <Amnesia_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ドわすれ" ;
#     ns1:jtrans "Memory Lapse" ;
#     ns1:jtranslit "Dowasure" ;
#     ns1:maxpp 32 ;
#     ns1:n 133 ;
#     ns1:type <http://example.org/move/type/Psychic> .
#
# ns1:Ancient_Power a ns1:move ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Ancient_Power_IX.png> ;
#     ns1:gameimage2 <Ancient_Power_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "げんしのちから" ;
#     ns1:jtrans "Primeval Power" ;
#     ns1:jtranslit "Genshi no Chikara" ;
#     ns1:n 246 ;
#     ns1:type <http://example.org/move/type/Rock> .
#
# ns1:Aqua_Jet a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 20 ;
#     ns1:category "Beauty" ;
#     ns1:category6 "Cool" ;
#     ns1:cdesc "Appeals first in the next turn" ;
#     ns1:cdesc6 "Causes the user to move earlier on the next turn." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Aqua_Jet_IX.png> ;
#     ns1:gameimage2 <Aqua_Jet_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "IV" ;
#     ns1:jam 0 ;
#     ns1:jam6 0 ;
#     ns1:jname "アクアジェット" ;
#     ns1:jtrans "Aqua Jet" ;
#     ns1:jtranslit "Akua Jetto" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 32 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 453 ;
#     ns1:power 40 ;
#     ns1:priority 1 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Enables the user to perform first in the next turn." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Water> .
#
# ns1:Aqua_Ring a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Aqua_Ring_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "アクアリング" ;
#     ns1:jtrans "Aqua Ring" ;
#     ns1:jtranslit "Akua Ringu" ;
#     ns1:maxpp 32 ;
#     ns1:n 392 ;
#     ns1:type <http://example.org/move/type/Water> .
#
# ns1:Aqua_Tail a ns1:move ;
#     ns1:gameimage <Aqua_Tail_IX.png> ;
#     ns1:gameimage2 <Aqua_Tail_IX_2.png> ;
#     ns1:jname "アクアテール" ;
#     ns1:jtrans "Aqua Tail" ;
#     ns1:jtranslit "Akua Tēru" ;
#     ns1:n 401 .
#
# ns1:Arm_Thrust a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 1 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 20 ;
#     ns1:category "Tough" ;
#     ns1:cdesc "Startles the Pokémon that has the judge's attention." ;
#     ns1:cdesc6 "Effectiveness varies depending on when it is used." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Arm_Thrust_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "III" ;
#     ns1:jam 1 ;
#     ns1:jam6 0 ;
#     ns1:jname "つっぱり" ;
#     ns1:jtrans "Thrust" ;
#     ns1:jtranslit "Tsuppari" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 32 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 292 ;
#     ns1:power 15 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Allows performance of the same move twice in a row." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Fighting> .
#
# ns1:Aromatherapy a ns1:move ;
#     ns1:gameimage <Aromatherapy_VIII.png> ;
#     ns1:jname "アロマセラピー" ;
#     ns1:jtrans "Aromatherapy" ;
#     ns1:jtranslit "Aromaserapī" ;
#     ns1:n 312 .
#
# ns1:Assist a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Assist_VII.png> ;
#     ns1:gameimage2 <Assist_VII_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ねこのて" ;
#     ns1:jtrans "Cat's Paw" ;
#     ns1:jtranslit "Neko no Te" ;
#     ns1:maxpp 32 ;
#     ns1:n 274 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Assurance a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Assurance_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ダメおし" ;
#     ns1:jtrans "Make Sure" ;
#     ns1:jtranslit "Dameoshi" ;
#     ns1:maxpp 16 ;
#     ns1:n 372 ;
#     ns1:type <http://example.org/move/type/Dark> .
#
# ns1:Astonish a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 2 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 15 ;
#     ns1:category "Smart" ;
#     ns1:category6 "Cute" ;
#     ns1:cdesc "Startles the Pokémon that appealed before the user." ;
#     ns1:cdesc6 "Startles the last Pokémon to act before the user." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Astonish_IX.png> ;
#     ns1:gameimage2 <Astonish_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "III" ;
#     ns1:jam 3 ;
#     ns1:jam6 3 ;
#     ns1:jname "おどろかす" ;
#     ns1:jtrans "Astonish" ;
#     ns1:jtranslit "Odorokasu" ;
#     ns1:kingsrock <no> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 310 ;
#     ns1:power 30 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Ghost> .
#
# ns1:Attack_Order a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 15 ;
#     ns1:category "Smart" ;
#     ns1:category6 "Clever" ;
#     ns1:cdesc6 "An appealing move that can be used repeatedly without boring the audience." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Attack_Order_IX.png> ;
#     ns1:gameimage2 <Attack_Order_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "IV" ;
#     ns1:jam6 0 ;
#     ns1:jname "こうげきしれい" ;
#     ns1:jtrans "Attack Order" ;
#     ns1:jtranslit "Kōgeki Shirei" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 454 ;
#     ns1:power 90 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Judge's Voltage goes up." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Bug> .
#
# ns1:Attract a ns1:move ;
#     ns1:basepp 15 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Attract_IX.png> ;
#     ns1:gameimage2 <Attract_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "メロメロ" ;
#     ns1:jtrans "Mad Love" ;
#     ns1:jtranslit "Meromero" ;
#     ns1:maxpp 24 ;
#     ns1:n 213 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Aura_Sphere a ns1:move ;
#     ns1:gameimage <Aura_Sphere_IX.png> ;
#     ns1:gameimage2 <Aura_Sphere_IX_2.png> ;
#     ns1:jname "はどうだん" ;
#     ns1:jtrans "Wave Bomb" ;
#     ns1:jtranslit "Hadōdan" ;
#     ns1:n 396 .
#
# ns1:Aurora_Beam a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 2 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 20 ;
#     ns1:category "Beauty" ;
#     ns1:category6 "Beautiful" ;
#     ns1:cdesc "Startles Pokémon that made a same-type appeal." ;
#     ns1:cdesc6 "Startles the last Pokémon to act before the user." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Aurora_Beam_IX.png> ;
#     ns1:gameimage2 <> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 1 ;
#     ns1:jam6 3 ;
#     ns1:jname "オーロラビーム" ;
#     ns1:jtrans "Aurora Beam" ;
#     ns1:jtranslit "Ōrora Bīmu" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 32 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 62 ;
#     ns1:power 65 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Pokémon performs first in the turn." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Ice> .
#
# ns1:Avalanche a ns1:move ;
#     ns1:gameimage <Avalanche_IX.png> ;
#     ns1:jname "ゆきなだれ" ;
#     ns1:jtrans "Avalanche" ;
#     ns1:jtranslit "Yukinadare" ;
#     ns1:n 419 .
#
# ns1:Barrage a ns1:move ;
#     ns1:accuracy 85 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 1 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 20 ;
#     ns1:category "Tough" ;
#     ns1:category6 "Cute" ;
#     ns1:cdesc "Works well if it's the same type as the one before." ;
#     ns1:cdesc6 "Effectiveness varies depending on when it is used." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Barrage_PE.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 0 ;
#     ns1:jam6 0 ;
#     ns1:jname "たまなげ" ;
#     ns1:jtrans "Ball Throw" ;
#     ns1:jtranslit "Tamanage" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 32 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 140 ;
#     ns1:power 15 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Allows performance of the same move twice in a row." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Barrier a ns1:move ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Barrier_PE.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "バリアー" ;
#     ns1:jtrans "Barrier" ;
#     ns1:jtranslit "Bariā" ;
#     ns1:n 112 ;
#     ns1:type <http://example.org/move/type/Psychic> .
#
# ns1:Baton_Pass a ns1:move ;
#     ns1:basepp 40 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Baton_Pass_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "バトンタッチ" ;
#     ns1:jtrans "Baton Touch" ;
#     ns1:jtranslit "Baton Tacchi" ;
#     ns1:maxpp 64 ;
#     ns1:n 226 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Beat_Up a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Beat_Up_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ふくろだたき" ;
#     ns1:jtrans "Gang Up" ;
#     ns1:jtranslit "Fukurodataki" ;
#     ns1:maxpp 16 ;
#     ns1:n 251 ;
#     ns1:type <http://example.org/move/type/Dark> .
#
# ns1:Belly_Drum a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Belly_Drum_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "はらだいこ" ;
#     ns1:jtrans "Belly Drum" ;
#     ns1:jtranslit "Haradaiko" ;
#     ns1:maxpp 16 ;
#     ns1:n 187 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Bide a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Bide_PE.png> ;
#     ns1:gameimage2 <Bide_PE_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "がまん" ;
#     ns1:jtrans "Perseverance" ;
#     ns1:jtranslit "Gaman" ;
#     ns1:maxpp 16 ;
#     ns1:n 117 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Bind a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Bind_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "しめつける" ;
#     ns1:jtrans "Bind" ;
#     ns1:jtranslit "Shimetsukeru" ;
#     ns1:maxpp 32 ;
#     ns1:n 20 ;
#     ns1:power 15 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Bite a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 1 ;
#     ns1:appeal6 2 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 25 ;
#     ns1:category "Tough" ;
#     ns1:cdesc "Badly startles those that have made appeals." ;
#     ns1:cdesc6 "Startles the last Pokémon to act before the user." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Bite_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 3 ;
#     ns1:jam6 3 ;
#     ns1:jname "かみつく" ;
#     ns1:jtrans "Bite" ;
#     ns1:jtranslit "Kamitsuku" ;
#     ns1:kingsrock <no> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 40 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 44 ;
#     ns1:power 60 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Dark> .
#
# ns1:Blaze_Kick a ns1:move ;
#     ns1:gameimage <Blaze_Kick_IX.png> ;
#     ns1:jname "ブレイズキック" ;
#     ns1:jtrans "Blaze Kick" ;
#     ns1:jtranslit "Bureizu Kikku" ;
#     ns1:n 299 .
#
# ns1:Blizzard a ns1:move ;
#     ns1:basepp 5 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Blizzard_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ふぶき" ;
#     ns1:jtrans "Blizzard" ;
#     ns1:jtranslit "Fubuki" ;
#     ns1:maxpp 8 ;
#     ns1:n 59 ;
#     ns1:type <http://example.org/move/type/Ice> .
#
# ns1:Block a ns1:move ;
#     ns1:basepp 5 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Block_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "とおせんぼう" ;
#     ns1:jtrans "Block" ;
#     ns1:jtranslit "Tōsenbō" ;
#     ns1:maxpp 8 ;
#     ns1:n 335 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Body_Slam a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 1 ;
#     ns1:appeal6 1 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 15 ;
#     ns1:category "Tough" ;
#     ns1:cdesc "Badly startles the Pokémon in front." ;
#     ns1:cdesc6 "Badly startles the last Pokémon to act before the user." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Body_Slam_IX.png> ;
#     ns1:gameimage2 <Body_Slam_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 4 ;
#     ns1:jam6 4 ;
#     ns1:jname "のしかかり" ;
#     ns1:jtrans "Lean On" ;
#     ns1:jtranslit "Noshikakari" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 34 ;
#     ns1:power 85 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Bone_Club a ns1:move ;
#     ns1:accuracy 85 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 20 ;
#     ns1:category "Tough" ;
#     ns1:cdesc "Startles the Pokémon that has the Judge's attention." ;
#     ns1:cdesc6 "An appealing move that can be used repeatedly without boring the audience." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Bone_Club_PE.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 1 ;
#     ns1:jam6 0 ;
#     ns1:jname "ホネこんぼう" ;
#     ns1:jtrans "Bone Club" ;
#     ns1:jtranslit "Hone Konbō" ;
#     ns1:kingsrock <no> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 32 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 125 ;
#     ns1:power 65 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Ground> .
#
# ns1:Bone_Rush a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Bone_Rush_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ボーンラッシュ" ;
#     ns1:jtrans "Bone Rush" ;
#     ns1:jtranslit "Bōn Rasshu" ;
#     ns1:maxpp 16 ;
#     ns1:n 198 ;
#     ns1:power 25 ;
#     ns1:type <http://example.org/move/type/Ground> .
#
# ns1:Bonemerang a ns1:move ;
#     ns1:accuracy 90 ;
#     ns1:appeal 4 ;
#     ns1:appeal6 2 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 10 ;
#     ns1:category "Tough" ;
#     ns1:cdesc "A highly appealing move." ;
#     ns1:cdesc6 "Badly startles Pokémon that used a move of the same type." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Bonemerang_VIII.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 0 ;
#     ns1:jam6 1 ;
#     ns1:jname "ホネブーメラン" ;
#     ns1:jtrans "Bone Boomerang" ;
#     ns1:jtranslit "Hone Būmeran" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 16 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 155 ;
#     ns1:power 50 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Allows performance of the same move twice in a row." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Ground> .
#
# ns1:Brick_Break a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 1 ;
#     ns1:appeal6 4 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 15 ;
#     ns1:category "Cool" ;
#     ns1:cdesc "Badly startles the Pokémon in front." ;
#     ns1:cdesc6 "Quite an appealing move." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Brick_Break_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "III" ;
#     ns1:jam 4 ;
#     ns1:jam6 0 ;
#     ns1:jname "かわらわり" ;
#     ns1:jtrans "Tile Break" ;
#     ns1:jtranslit "Kawarawari" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 280 ;
#     ns1:power 75 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Fighting> .
#
# ns1:Brine a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 10 ;
#     ns1:category "Smart" ;
#     ns1:category6 "Tough" ;
#     ns1:cdesc "Increases judges voltage by 2" ;
#     ns1:cdesc6 "Affected by how well the previous Pokémon's move went." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Brine_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "IV" ;
#     ns1:jam 0 ;
#     ns1:jam6 0 ;
#     ns1:jname "しおみず" ;
#     ns1:jtrans "Brine" ;
#     ns1:jtranslit "Shiomizu" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 16 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 362 ;
#     ns1:power 65 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Judge's Voltage goes up." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Water> .
#
# ns1:Bubble a ns1:move ;
#     ns1:basepp 30 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Bubble_LA.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "あわ" ;
#     ns1:jtrans "Bubble" ;
#     ns1:jtranslit "Awa" ;
#     ns1:maxpp 48 ;
#     ns1:n 145 ;
#     ns1:type <http://example.org/move/type/Water> .
#
# ns1:Bubble_Beam a ns1:move ;
#     ns1:gameimage <Bubble_Beam_IX.png> ;
#     ns1:gameimage2 <> ;
#     ns1:jname "バブルこうせん" ;
#     ns1:jtrans "Bubble Beam" ;
#     ns1:jtranslit "Baburu Kōsen" ;
#     ns1:n 61 .
#
# ns1:Bug_Bite a ns1:move ;
#     ns1:gameimage <Bug_Bite_IX.png> ;
#     ns1:jname "むしくい" ;
#     ns1:jtrans "Bug Bite" ;
#     ns1:jtranslit "Mushikui" ;
#     ns1:n 450 .
#
# ns1:Bug_Buzz a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal6 1 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 10 ;
#     ns1:category "Cute" ;
#     ns1:category6 "Beautiful" ;
#     ns1:cdesc6 "Badly startles the last Pokémon to act before the user." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Bug_Buzz_IX.png> ;
#     ns1:gameimage2 <Bug_Buzz_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "IV" ;
#     ns1:jam6 4 ;
#     ns1:jname "むしのさざめき" ;
#     ns1:jtrans "Insect Noise" ;
#     ns1:jtranslit "Mushi no Sazameki" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 16 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 405 ;
#     ns1:power 90 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Judge's Voltage goes up." ;
#     ns1:snatch <no> ;
#     ns1:sound <yes> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Bug> .
#
# ns1:Bulk_Up a ns1:move ;
#     ns1:gameimage <Bulk_Up_IX.png> ;
#     ns1:jname "ビルドアップ" ;
#     ns1:jtrans "Build Up" ;
#     ns1:jtranslit "Birudo Appu" ;
#     ns1:n 339 .
#
# ns1:Bulldoze a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal6 2 ;
#     ns1:basepp 20 ;
#     ns1:category "Tough" ;
#     ns1:cdesc6 "Startles all of the Pokémon to act before the user." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Bulldoze_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "V" ;
#     ns1:jam6 2 ;
#     ns1:jname "じならし" ;
#     ns1:jtrans "Ground Levelling" ;
#     ns1:jtranslit "Jinarashi" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 32 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 523 ;
#     ns1:power 60 ;
#     ns1:protect <yes> ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "alladjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Ground> .
#
# ns1:Bullet_Seed a ns1:move ;
#     ns1:basepp 30 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Bullet_Seed_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "タネマシンガン" ;
#     ns1:jtrans "Seed Machine Gun" ;
#     ns1:jtranslit "Tane Mashin Gan" ;
#     ns1:maxpp 48 ;
#     ns1:n 331 ;
#     ns1:type <http://example.org/move/type/Grass> .
#
# ns1:Camouflage a ns1:move ;
#     ns1:gameimage <Camouflage_VII.png> ;
#     ns1:jname "ほごしょく" ;
#     ns1:jtrans "Camouflage" ;
#     ns1:jtranslit "Hogoshoku" ;
#     ns1:n 293 .
#
# ns1:Captivate a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Captivate_VII.png> ;
#     ns1:gameimage2 <Captivate_VII_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ゆうわく" ;
#     ns1:jtrans "Allure" ;
#     ns1:jtranslit "Yūwaku" ;
#     ns1:maxpp 32 ;
#     ns1:n 445 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Charge a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Charge_IX.png> ;
#     ns1:gameimage2 <Charge_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "じゅうでん" ;
#     ns1:jtrans "Charge" ;
#     ns1:jtranslit "Jūden" ;
#     ns1:maxpp 32 ;
#     ns1:n 268 ;
#     ns1:type <http://example.org/move/type/Electric> .
#
# ns1:Charge_Beam a ns1:move ;
#     ns1:accuracy 90 ;
#     ns1:appeal6 1 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 10 ;
#     ns1:category "Beauty" ;
#     ns1:category6 "Beautiful" ;
#     ns1:cdesc6 "Works well if the user is pumped up." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Charge_Beam_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "IV" ;
#     ns1:jam6 0 ;
#     ns1:jname "チャージビーム" ;
#     ns1:jtrans "Charge Beam" ;
#     ns1:jtranslit "Chāji Bīmu" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 16 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 451 ;
#     ns1:power 50 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Pokémon performs first in the turn." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Electric> .
#
# ns1:Charm a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Charm_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "あまえる" ;
#     ns1:jtrans "Fawn" ;
#     ns1:jtranslit "Amaeru" ;
#     ns1:maxpp 32 ;
#     ns1:n 204 ;
#     ns1:type <http://example.org/move/type/Fairy> .
#
# ns1:Clamp a ns1:move ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Clamp_PE.png> ;
#     ns1:gameimage2 <Clamp_PE_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "からではさむ" ;
#     ns1:jtrans "Shell Squeeze" ;
#     ns1:jtranslit "Kara de Hasamu" ;
#     ns1:n 128 ;
#     ns1:type <http://example.org/move/type/Water> .
#
# ns1:Comet_Punch a ns1:move ;
#     ns1:accuracy 85 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 1 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 15 ;
#     ns1:category "Tough" ;
#     ns1:cdesc "Works well if it's the same type as the one before." ;
#     ns1:cdesc6 "Effectiveness varies depending on when it is used." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Comet_Punch_PE.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 0 ;
#     ns1:jam6 0 ;
#     ns1:jname "れんぞくパンチ" ;
#     ns1:jtrans "Consecutive Punch" ;
#     ns1:jtranslit "Renzoku Panchi" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 4 ;
#     ns1:power 18 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Allows performance of the same move twice in a row." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Confuse_Ray a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Confuse_Ray_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "あやしいひかり" ;
#     ns1:jtrans "Eerie Light" ;
#     ns1:jtranslit "Ayashii Hikari" ;
#     ns1:maxpp 16 ;
#     ns1:n 109 ;
#     ns1:type <http://example.org/move/type/Ghost> .
#
# ns1:Confusion a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 4 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 25 ;
#     ns1:category "Smart" ;
#     ns1:category6 "Clever" ;
#     ns1:cdesc "Startles the Pokémon that appealed before the user." ;
#     ns1:cdesc6 "Quite an appealing move." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Confusion_IX.png> ;
#     ns1:gameimage2 <Confusion_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 3 ;
#     ns1:jam6 0 ;
#     ns1:jname "ねんりき" ;
#     ns1:jtrans "Willpower" ;
#     ns1:jtranslit "Nenriki" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 40 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 93 ;
#     ns1:power 50 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Psychic> .
#
# ns1:Constrict a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 0 ;
#     ns1:basepp 35 ;
#     ns1:category "Tough" ;
#     ns1:cdesc "Startles the Pokémon that appealed before the user." ;
#     ns1:cdesc6 "Brings down the energy of any Pokémon that have already used a move this turn." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Constrict_PE.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 3 ;
#     ns1:jam6 0 ;
#     ns1:jname "からみつく" ;
#     ns1:jtrans "Coil Around" ;
#     ns1:jtranslit "Karamitsuku" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 56 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 132 ;
#     ns1:power 10 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn a higher score the later the Pokémon performs." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Conversion a ns1:move ;
#     ns1:basepp 30 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Conversion_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "テクスチャー" ;
#     ns1:jtrans "Texture" ;
#     ns1:jtranslit "Tekusuchā" ;
#     ns1:maxpp 48 ;
#     ns1:n 160 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Conversion_2 a ns1:move ;
#     ns1:basepp 30 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Conversion_2_IX.png> ;
#     ns1:gameimage2 <Conversion_2_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "テクスチャー２" ;
#     ns1:jtrans "Texture 2" ;
#     ns1:jtranslit "Tekusuchā 2" ;
#     ns1:maxpp 48 ;
#     ns1:n 176 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Cotton_Spore a ns1:move ;
#     ns1:basepp 40 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Cotton_Spore_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "わたほうし" ;
#     ns1:jtrans "Cotton Spore" ;
#     ns1:jtranslit "Wata Hōshi" ;
#     ns1:maxpp 64 ;
#     ns1:n 178 ;
#     ns1:type <http://example.org/move/type/Grass> .
#
# ns1:Counter a ns1:move ;
#     ns1:basepp 20 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Counter_IX.png> ;
#     ns1:gameimage2 <Counter_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "カウンター" ;
#     ns1:jtrans "Counter" ;
#     ns1:jtranslit "Kauntā" ;
#     ns1:maxpp 32 ;
#     ns1:n 68 ;
#     ns1:type <http://example.org/move/type/Fighting> .
#
# ns1:Covet a ns1:move ;
#     ns1:gameimage <Covet_IX.png> ;
#     ns1:jname "ほしがる" ;
#     ns1:jtrans "Covet" ;
#     ns1:jtranslit "Hoshigaru" ;
#     ns1:n 343 .
#
# ns1:Crabhammer a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Crabhammer_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "クラブハンマー" ;
#     ns1:jtrans "Crab Hammer" ;
#     ns1:jtranslit "Kurabu Hanmā" ;
#     ns1:maxpp 16 ;
#     ns1:n 152 ;
#     ns1:type <http://example.org/move/type/Water> .
#
# ns1:Cross_Chop a ns1:move ;
#     ns1:accuracy 80 ;
#     ns1:appeal 3 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 5 ;
#     ns1:category "Cool" ;
#     ns1:cdesc "Affected by how well the appeal in front goes." ;
#     ns1:cdesc6 "Affected by how well the previous Pokémon's move went." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Cross_Chop_IX.png> ;
#     ns1:gameimage2 <Cross_Chop_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "II" ;
#     ns1:jam 0 ;
#     ns1:jam6 0 ;
#     ns1:jname "クロスチョップ" ;
#     ns1:jtrans "Cross Chop" ;
#     ns1:jtranslit "Kurosu Choppu" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 8 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 238 ;
#     ns1:power 100 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Pokémon performs last in the turn." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Fighting> .
#
# ns1:Cross_Poison a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal6 2 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 20 ;
#     ns1:category "Cool" ;
#     ns1:cdesc6 "Badly startles Pokémon that used a move of the same type." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Cross_Poison_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "IV" ;
#     ns1:jam6 1 ;
#     ns1:jname "クロスポイズン" ;
#     ns1:jtrans "Cross Poison" ;
#     ns1:jtranslit "Kurosu Poizun" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 32 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 440 ;
#     ns1:power 70 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Poison> .
#
# ns1:Crunch a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 1 ;
#     ns1:appeal6 1 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 15 ;
#     ns1:category "Tough" ;
#     ns1:cdesc "Badly startles the Pokémon in front." ;
#     ns1:cdesc6 "Badly startles the last Pokémon to act before the user." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Crunch_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "II" ;
#     ns1:jam 4 ;
#     ns1:jam6 4 ;
#     ns1:jname "かみくだく" ;
#     ns1:jtrans "Crunch" ;
#     ns1:jtranslit "Kamikudaku" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 242 ;
#     ns1:power 80 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Pokémon performs last in the turn." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Dark> .
#
# ns1:Curse a ns1:move ;
#     ns1:jname "のろい" ;
#     ns1:n 174 .
#
# ns1:Cut a ns1:move ;
#     ns1:accuracy 95 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 4 ;
#     ns1:appealsc 3 ;
#     ns1:basepp 30 ;
#     ns1:category "Cool" ;
#     ns1:cdesc "Badly startles all Pokémon that made good appeals." ;
#     ns1:cdesc6 "Quite an appealing move." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:field <yes> ;
#     ns1:gameimage <Cut_IX.png> ;
#     ns1:gameimage2 <Cut_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 1 ;
#     ns1:jam6 0 ;
#     ns1:jname "いあいぎり" ;
#     ns1:jtrans "Iai Cut" ;
#     ns1:jtranslit "Iai Giri" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 48 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 15 ;
#     ns1:power 50 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "A basic performance using a move known by the Pokémon." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Dark_Pulse a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 4 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 15 ;
#     ns1:category "Cool" ;
#     ns1:cdesc6 "Quite an appealing move." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Dark_Pulse_IX.png> ;
#     ns1:gameimage2 <Dark_Pulse_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "IV" ;
#     ns1:jam 0 ;
#     ns1:jam6 0 ;
#     ns1:jname "あくのはどう" ;
#     ns1:jtrans "Evil Pulse" ;
#     ns1:jtranslit "Aku no Hadō" ;
#     ns1:kingsrock <no> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 399 ;
#     ns1:power 80 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Pokémon performs first in the turn." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "any" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Dark> .
#
# ns1:Defend_Order a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Defend_Order_IX.png> ;
#     ns1:gameimage2 <Defend_Order_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ぼうぎょしれい" ;
#     ns1:jtrans "Defense Order" ;
#     ns1:jtranslit "Bōgyo Shirei" ;
#     ns1:maxpp 16 ;
#     ns1:n 455 ;
#     ns1:type <http://example.org/move/type/Bug> .
#
# ns1:Defense_Curl a ns1:move ;
#     ns1:basepp 40 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Defense_Curl_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "まるくなる" ;
#     ns1:jtrans "Curl Up" ;
#     ns1:jtranslit "Maruku Naru" ;
#     ns1:maxpp 64 ;
#     ns1:n 111 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Defog a ns1:move ;
#     ns1:basepp 15 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Defog_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "きりばらい" ;
#     ns1:jtrans "Fog Wipe" ;
#     ns1:jtranslit "Kiribarai" ;
#     ns1:maxpp 24 ;
#     ns1:n 432 ;
#     ns1:type <http://example.org/move/type/Flying> .
#
# ns1:Destiny_Bond a ns1:move ;
#     ns1:basepp 5 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Destiny_Bond_IX.png> ;
#     ns1:gameimage2 <Destiny_Bond_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "みちづれ" ;
#     ns1:jtrans "Take Along With" ;
#     ns1:jtranslit "Michizure" ;
#     ns1:maxpp 8 ;
#     ns1:n 194 ;
#     ns1:type <http://example.org/move/type/Ghost> .
#
# ns1:Detect a ns1:move ;
#     ns1:basepp 5 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Detect_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "みきり" ;
#     ns1:jtrans "All-Seeing" ;
#     ns1:jtranslit "Mikiri" ;
#     ns1:maxpp 8 ;
#     ns1:n 197 ;
#     ns1:type <http://example.org/move/type/Fighting> .
#
# ns1:Dig a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Dig_IX.png> ;
#     ns1:gameimage2 <Dig_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "あなをほる" ;
#     ns1:jtrans "Dig Hole" ;
#     ns1:jtranslit "Ana o Horu" ;
#     ns1:maxpp 16 ;
#     ns1:n 91 ;
#     ns1:type <http://example.org/move/type/Ground> .
#
# ns1:Disable a ns1:move ;
#     ns1:gameimage <Disable_IX.png> ;
#     ns1:gameimage2 <Disable_IX_2.png> ;
#     ns1:jname "かなしばり" ;
#     ns1:jtrans "Temporary Binding" ;
#     ns1:jtranslit "Kanashibari" ;
#     ns1:n 50 .
#
# ns1:Discharge a ns1:move ;
#     ns1:gameimage <Discharge_IX.png> ;
#     ns1:jname "ほうでん" ;
#     ns1:jtrans "Electrical Discharge" ;
#     ns1:jtranslit "Hōden" ;
#     ns1:n 435 .
#
# ns1:Dive a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Dive_IX.png> ;
#     ns1:gameimage2 <Dive_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ダイビング" ;
#     ns1:jtrans "Diving" ;
#     ns1:jtranslit "Daibingu" ;
#     ns1:maxpp 16 ;
#     ns1:n 291 ;
#     ns1:type <http://example.org/move/type/Water> .
#
# ns1:Dizzy_Punch a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 1 ;
#     ns1:appeal6 3 ;
#     ns1:appealsc 0 ;
#     ns1:basepp 10 ;
#     ns1:category "Cool" ;
#     ns1:category6 "Cute" ;
#     ns1:cdesc "Badly startles the Pokémon in front." ;
#     ns1:cdesc6 "Makes audience expect little of other contestants." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Dizzy_Punch_PE.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 4 ;
#     ns1:jam6 0 ;
#     ns1:jname "ピヨピヨパンチ" ;
#     ns1:jtrans "Chirp Chirp Punch" ;
#     ns1:jtranslit "Piyopiyo Panchi" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 16 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 146 ;
#     ns1:power 70 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Raises the score if the Voltage is low." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Double-Edge a ns1:move ;
#     ns1:gameimage <Double-Edge_IX.png> ;
#     ns1:gameimage2 <Double-Edge_IX_2.png> ;
#     ns1:jname "すてみタックル" ;
#     ns1:jtrans "Life-Risking Tackle" ;
#     ns1:jtranslit "Sutemi Takkuru" ;
#     ns1:n 38 .
#
# ns1:Double_Hit a ns1:move ;
#     ns1:gameimage <Double_Hit_IX.png> ;
#     ns1:jname "ダブルアタック" ;
#     ns1:jtrans "Double Attack" ;
#     ns1:jtranslit "Daburu Atakku" ;
#     ns1:n 458 .
#
# ns1:Double_Kick a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 2 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 30 ;
#     ns1:category "Cool" ;
#     ns1:cdesc "Works well if it's the same type as the one before." ;
#     ns1:cdesc6 "Badly startles Pokémon that used a move of the same type." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Double_Kick_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 0 ;
#     ns1:jam6 1 ;
#     ns1:jname "にどげり" ;
#     ns1:jtrans "Double Kick" ;
#     ns1:jtranslit "Nidogeri" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 48 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 24 ;
#     ns1:power 30 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Allows performance of the same move twice in a row." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Fighting> .
#
# ns1:Double_Slap a ns1:move ;
#     ns1:gameimage <Double_Slap_PE.png> ;
#     ns1:jname "おうふくビンタ" ;
#     ns1:jtrans "Round Trip Slap" ;
#     ns1:jtranslit "Ōfuku Binta" ;
#     ns1:n 3 .
#
# ns1:Double_Team a ns1:move ;
#     ns1:basepp 15 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Status> ;
#     ns1:gameimage <Double_Team_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "かげぶんしん" ;
#     ns1:jtrans "Shadow Divide" ;
#     ns1:jtranslit "Kage Bunshin" ;
#     ns1:maxpp 24 ;
#     ns1:n 104 ;
#     ns1:type <http://example.org/move/type/Normal> .
#
# ns1:Dragon_Breath a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 1 ;
#     ns1:appeal6 2 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 20 ;
#     ns1:category "Cool" ;
#     ns1:cdesc "Badly startles those that have made appeals." ;
#     ns1:cdesc6 "Startles the last Pokémon to act before the user." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Dragon_Breath_IX.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "II" ;
#     ns1:jam 3 ;
#     ns1:jam6 3 ;
#     ns1:jname "りゅうのいぶき" ;
#     ns1:jtrans "Dragon Breath" ;
#     ns1:jtranslit "Ryū no Ibuki" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 32 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 225 ;
#     ns1:power 60 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Pokémon performs first in the turn." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <no> ;
#     ns1:type <http://example.org/move/type/Dragon> .
#
# ns1:Dragon_Claw a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 4 ;
#     ns1:appealsc 2 ;
#     ns1:basepp 15 ;
#     ns1:category "Cool" ;
#     ns1:cdesc "Startles Pokémon that made a same-type appeal." ;
#     ns1:cdesc6 "Quite an appealing move." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:footnotes "" ;
#     ns1:gameimage <Dragon_Claw_IX.png> ;
#     ns1:gameimage2 <Dragon_Claw_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "III" ;
#     ns1:jam 1 ;
#     ns1:jam6 0 ;
#     ns1:jname "ドラゴンクロー" ;
#     ns1:jtrans "Dragon Claw" ;
#     ns1:jtranslit "Doragon Kurō" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 337 ;
#     ns1:power 80 ;
#     ns1:protect <yes> ;
#     ns1:scdesc "Earn +2 if the Pokémon performs first in the turn." ;
#     ns1:snatch <no> ;
#     ns1:sound <no> ;
#     ns1:target "anyadjacent" ;
#     ns1:touches <yes> ;
#     ns1:type <http://example.org/move/type/Dragon> .
#
# ns1:Dragon_Pulse a ns1:move ;
#     ns1:basepp 10 ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Dragon_Pulse_IX.png> ;
#     ns1:gameimage2 <> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "りゅうのはどう" ;
#     ns1:jtrans "Dragon Pulse" ;
#     ns1:jtranslit "Ryū no Hadō" ;
#     ns1:maxpp 16 ;
#     ns1:n 406 ;
#     ns1:type <http://example.org/move/type/Dragon> .
#
# ns1:Dragon_Rage a ns1:move ;
#     ns1:gameimage <Dragon_Rage_PE.png> ;
#     ns1:jname "りゅうのいかり" ;
#     ns1:jtrans "Dragon Rage" ;
#     ns1:jtranslit "Ryū no Ikari" ;
#     ns1:n 82 .
#
# ns1:Drain_Punch a ns1:move ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Physical> ;
#     ns1:gameimage <Drain_Punch_IX.png> ;
#     ns1:gameimage2 <Drain_Punch_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:jname "ドレインパンチ" ;
#     ns1:jtrans "Drain Punch" ;
#     ns1:jtranslit "Dorein Panchi" ;
#     ns1:n 409 ;
#     ns1:type <http://example.org/move/type/Fighting> .
#
# ns1:Dream_Eater a ns1:move ;
#     ns1:accuracy 100 ;
#     ns1:appeal 2 ;
#     ns1:appeal6 2 ;
#     ns1:appealsc 1 ;
#     ns1:basepp 15 ;
#     ns1:category "Smart" ;
#     ns1:category6 "Clever" ;
#     ns1:cdesc "Startles all Pokémon that have done their appeals." ;
#     ns1:cdesc6 "Works well if it is the same type as the move used by the last Pokémon." ;
#     ns1:damagecategory <http://example.org/move/damagecategory/Special> ;
#     ns1:gameimage <Dream_Eater_IX.png> ;
#     ns1:gameimage2 <Dream_Eater_IX_2.png> ;
#     ns1:gameimagewidth 300 ;
#     ns1:gen "I" ;
#     ns1:jam 2 ;
#     ns1:jam6 0 ;
#     ns1:jname "ゆめくい" ;
#     ns1:jtrans "Dream Eat" ;
#     ns1:jtranslit "Yume Kui" ;
#     ns1:kingsrock <yes> ;
#     ns1:magiccoat <no> ;
#     ns1:maxpp 24 ;
#     ns1:mirrormove <yes> ;
#     ns1:n 138 ;
#     ns1:power 100 ;
#     ns1:protect <yes> ;
# ...
#
# <Frustration_VII_2.png> a xsd:anyURI .
#
# <Fury_Attack_IX.png> a xsd:anyURI .
#
# <Fury_Cutter_IX.png> a xsd:anyURI .
#
# <Fury_Swipes_IX.png> a xsd:anyURI .
#
# <Future_Sight_IX.png> a xsd:anyURI .
#
# <Future_Sight_IX_2.png> a xsd:anyURI .
#
# <Gastro_Acid_IX.png> a xsd:anyURI .
#
# <Gastro_Acid_IX_2.png> a xsd:anyURI .
#
# <Giga_Drain_IX.png> a xsd:anyURI .
#
# <Giga_Drain_IX_2.png> a xsd:anyURI .
#
# <Giga_Impact_IX.png> a xsd:anyURI .
#
# <Giga_Impact_IX_2.png> a xsd:anyURI .
#
# <Glare_IX.png> a xsd:anyURI .
#
# <Grass_Knot_IX.png> a xsd:anyURI .
#
# <Grass_Whistle_VII.png> a xsd:anyURI .
#
# <Growl_IX.png> a xsd:anyURI .
#
# <Growth_IX.png> a xsd:anyURI .
#
# <Grudge_VIII.png> a xsd:anyURI .
#
# <Guard_Swap_IX.png> a xsd:anyURI .
#
# <Guard_Swap_IX_2.png> a xsd:anyURI .
#
# <Guillotine_IX.png> a xsd:anyURI .
#
# <Gunk_Shot_IX.png> a xsd:anyURI .
#
# <Gunk_Shot_IX_2.png> a xsd:anyURI .
#
# <Gust_IX.png> a xsd:anyURI .
#
# <Hail_VIII.png> a xsd:anyURI .
#
# <Harden_IX.png> a xsd:anyURI .
#
# <Harden_IX_2.png> a xsd:anyURI .
#
# <Haze_IX.png> a xsd:anyURI .
#
# <Headbutt_IX.png> a xsd:anyURI .
#
# <Heal_Bell_IX.png> a xsd:anyURI .
#
# <Heal_Block_VII.png> a xsd:anyURI .
#
# <Heal_Order_VII.png> a xsd:anyURI .
#
# <Heart_Stamp_VII.png> a xsd:anyURI .
#
# <Heart_Stamp_VII_2.png> a xsd:anyURI .
#
# <Heart_Swap_IX.png> a xsd:anyURI .
#
# <Heart_Swap_IX_2.png> a xsd:anyURI .
#
# <Heat_Wave_IX.png> a xsd:anyURI .
#
# <Heat_Wave_IX_2.png> a xsd:anyURI .
#
# <Helping_Hand_IX.png> a xsd:anyURI .
#
# <Hidden_Power_VIII.png> a xsd:anyURI .
#
# <Hidden_Power_VIII_2.png> a xsd:anyURI .
#
# <High_Jump_Kick_IX.png> a xsd:anyURI .
#
# <High_Jump_Kick_IX_2.png> a xsd:anyURI .
#
# <Horn_Attack_IX.png> a xsd:anyURI .
#
# <Horn_Drill_IX.png> a xsd:anyURI .
#
# <Horn_Drill_IX_2.png> a xsd:anyURI .
#
# <Hydro_Pump_IX.png> a xsd:anyURI .
#
# <Hyper_Beam_IX.png> a xsd:anyURI .
#
# <Hyper_Beam_IX_2.png> a xsd:anyURI .
#
# <Hyper_Fang_PE.png> a xsd:anyURI .
#
# <Hypnosis_IX.png> a xsd:anyURI .
#
# <Hypnosis_IX_2.png> a xsd:anyURI .
#
# <Ice_Ball_LA.png> a xsd:anyURI .
#
# <Ice_Ball_LA_2.png> a xsd:anyURI .
#
# <Ice_Beam_IX.png> a xsd:anyURI .
#
# <Ice_Fang_IX.png> a xsd:anyURI .
#
# <Ice_Punch_IX.png> a xsd:anyURI .
#
# <Ice_Shard_IX.png> a xsd:anyURI .
#
# <Ice_Shard_IX_2.png> a xsd:anyURI .
#
# <Icicle_Spear_IX.png> a xsd:anyURI .
#
# <Icicle_Spear_IX_2.png> a xsd:anyURI .
#
# <Icy_Wind_IX.png> a xsd:anyURI .
#
# <Imprison_IX.png> a xsd:anyURI .
#
# <Ingrain_IX.png> a xsd:anyURI .
#
# <Iron_Head_IX.png> a xsd:anyURI .
#
# <Iron_Head_IX_2.png> a xsd:anyURI .
#
# <Iron_Tail_IX.png> a xsd:anyURI .
#
# <Iron_Tail_IX_2.png> a xsd:anyURI .
#
# <Judgment_IX.png> a xsd:anyURI .
#
# <Judgment_IX_2.png> a xsd:anyURI .
#
# <Jump_Kick_PE.png> a xsd:anyURI .
#
# <Karate_Chop_PE.png> a xsd:anyURI .
#
# <Kinesis_BDSP.png> a xsd:anyURI .
#
# <Kinesis_BDSP_2.png> a xsd:anyURI .
#
# <Knock_Off_IX.png> a xsd:anyURI .
#
# <Knock_Off_IX_2.png> a xsd:anyURI .
#
# <Leech_Life_IX.png> a xsd:anyURI .
#
# <Leech_Life_IX_2.png> a xsd:anyURI .
#
# <Leech_Seed_IX.png> a xsd:anyURI .
#
# <Leech_Seed_IX_2.png> a xsd:anyURI .
#
# <Leer_IX.png> a xsd:anyURI .
#
# <Lick_IX.png> a xsd:anyURI .
#
# <Light_Screen_IX.png> a xsd:anyURI .
#
# <Lock-On_IX.png> a xsd:anyURI .
#
# <Lovely_Kiss_VIII.png> a xsd:anyURI .
#
# <Low_Kick_IX.png> a xsd:anyURI .
#
# <Lucky_Chant_VII.png> a xsd:anyURI .
#
# <Luster_Purge_IX.png> a xsd:anyURI .
#
# <Luster_Purge_IX_2.png> a xsd:anyURI .
#
# <Mach_Punch_IX.png> a xsd:anyURI .
#
# <Magic_Coat_VIII.png> a xsd:anyURI .
#
# <Magical_Leaf_IX.png> a xsd:anyURI .
#
# <Magnet_Bomb_VII.png> a xsd:anyURI .
#
# <Magnet_Bomb_VII_2.png> a xsd:anyURI .
#
# <Magnet_Rise_IX.png> a xsd:anyURI .
#
# <Magnitude_VII.png> a xsd:anyURI .
#
# <Me_First_VII.png> a xsd:anyURI .
#
# <Me_First_VII_2.png> a xsd:anyURI .
#
# <Mean_Look_IX.png> a xsd:anyURI .
#
# <Meditate_PE.png> a xsd:anyURI .
#
# <Mega_Drain_IX.png> a xsd:anyURI .
#
# <Mega_Drain_IX_2.png> a xsd:anyURI .
#
# <Mega_Kick_IX.png> a xsd:anyURI .
#
# <Mega_Punch_IX.png> a xsd:anyURI .
#
# <Megahorn_IX.png> a xsd:anyURI .
#
# <Megahorn_IX_2.png> a xsd:anyURI .
#
# <Memento_IX.png> a xsd:anyURI .
#
# <Memento_IX_2.png> a xsd:anyURI .
#
# <Metal_Burst_IX.png> a xsd:anyURI .
#
# <Metal_Burst_IX_2.png> a xsd:anyURI .
#
# <Metal_Claw_IX.png> a xsd:anyURI .
#
# <Metronome_IX.png> a xsd:anyURI .
#
# <Milk_Drink_IX.png> a xsd:anyURI .
#
# <Milk_Drink_IX_2.png> a xsd:anyURI .
#
# <Mimic_IX.png> a xsd:anyURI .
#
# <Mimic_IX_2.png> a xsd:anyURI .
#
# <Mind_Reader_VIII.png> a xsd:anyURI .
#
# <Minimize_IX.png> a xsd:anyURI .
#
# <Miracle_Eye_VII.png> a xsd:anyURI .
#
# <Mirror_Coat_IX.png> a xsd:anyURI .
#
# <Mirror_Coat_IX_2.png> a xsd:anyURI .
#
# <Mirror_Move_PE.png> a xsd:anyURI .
#
# <Mirror_Move_PE_2.png> a xsd:anyURI .
#
# <Mirror_Shot_VII.png> a xsd:anyURI .
#
# <Mirror_Shot_VII_2.png> a xsd:anyURI .
#
# <Mist_Ball_IX.png> a xsd:anyURI .
#
# <Mist_IX.png> a xsd:anyURI .
#
# <Moonlight_IX.png> a xsd:anyURI .
#
# <Moonlight_IX_2.png> a xsd:anyURI .
#
# <Morning_Sun_IX.png> a xsd:anyURI .
#
# <Mud-Slap_IX.png> a xsd:anyURI .
#
# <Mud-Slap_IX_2.png> a xsd:anyURI .
#
# <Mud_Bomb_LA.png> a xsd:anyURI .
#
# <Mud_Shot_IX.png> a xsd:anyURI .
#
# <Mud_Shot_IX_2.png> a xsd:anyURI .
#
# <Mud_Sport_VII.png> a xsd:anyURI .
#
# <Muddy_Water_IX.png> a xsd:anyURI .
#
# <Muddy_Water_IX_2.png> a xsd:anyURI .
#
# <Nasty_Plot_IX.png> a xsd:anyURI .
#
# <Nasty_Plot_IX_2.png> a xsd:anyURI .
#
# <Natural_Gift_VII.png> a xsd:anyURI .
#
# <Nature_Power_VIII.png> a xsd:anyURI .
#
# <Nature_Power_VIII_2.png> a xsd:anyURI .
#
# <Needle_Arm_VII.png> a xsd:anyURI .
#
# <Night_Shade_IX.png> a xsd:anyURI .
#
# <Night_Shade_IX_2.png> a xsd:anyURI .
#
# <Night_Slash_IX.png> a xsd:anyURI .
#
# <Night_Slash_IX_2.png> a xsd:anyURI .
#
# <Nightmare_VII.png> a xsd:anyURI .
#
# <Octazooka_VIII.png> a xsd:anyURI .
#
# <Odor_Sleuth_VII.png> a xsd:anyURI .
#
# <Odor_Sleuth_VII_2.png> a xsd:anyURI .
#
# <Ominous_Wind_LA.png> a xsd:anyURI .
#
# <Outrage_IX.png> a xsd:anyURI .
#
# <Outrage_IX_2.png> a xsd:anyURI .
#
# <Pain_Split_IX.png> a xsd:anyURI .
#
# <Pay_Day_IX.png> a xsd:anyURI .
#
# <Pay_Day_IX_2.png> a xsd:anyURI .
#
# <Payback_IX.png> a xsd:anyURI .
#
# <Payback_IX_2.png> a xsd:anyURI .
#
# <Peck_IX.png> a xsd:anyURI .
#
# <Perish_Song_IX.png> a xsd:anyURI .
#
# <Perish_Song_IX_2.png> a xsd:anyURI .
#
# <Petal_Dance_IX.png> a xsd:anyURI .
#
# <Petal_Dance_IX_2.png> a xsd:anyURI .
#
# <Pin_Missile_IX.png> a xsd:anyURI .
#
# <Pin_Missile_IX_2.png> a xsd:anyURI .
#
# <Poison_Fang_IX.png> a xsd:anyURI .
#
# <Poison_Gas_IX.png> a xsd:anyURI .
#
# <Poison_Jab_IX.png> a xsd:anyURI .
#
# <Poison_Jab_IX_2.png> a xsd:anyURI .
#
# <Poison_Powder_IX.png> a xsd:anyURI .
#
# <Poison_Sting_IX.png> a xsd:anyURI .
#
# <Pound_IX.png> a xsd:anyURI .
#
# <Powder_Snow_IX.png> a xsd:anyURI .
#
# <Powder_Snow_IX_2.png> a xsd:anyURI .
#
# <Power_Swap_IX.png> a xsd:anyURI .
#
# <Power_Swap_IX_2.png> a xsd:anyURI .
#
# <Power_Trick_IX.png> a xsd:anyURI .
#
# <Power_Trick_IX_2.png> a xsd:anyURI .
#
# <Power_Whip_IX.png> a xsd:anyURI .
#
# <Power_Whip_IX_2.png> a xsd:anyURI .
#
# <Present_IX.png> a xsd:anyURI .
#
# <Present_IX_2.png> a xsd:anyURI .
#
# <Protect_IX.png> a xsd:anyURI .
#
# <Psybeam_IX.png> a xsd:anyURI .
#
# <Psych_Up_IX.png> a xsd:anyURI .
#
# <Psychic_IX.png> a xsd:anyURI .
#
# <Psychic_IX_2.png> a xsd:anyURI .
#
# <Psycho_Cut_IX.png> a xsd:anyURI .
#
# <Psywave_PE.png> a xsd:anyURI .
#
# <Psywave_PE_2.png> a xsd:anyURI .
#
# <Punishment_VII.png> a xsd:anyURI .
#
# <Pursuit_VII.png> a xsd:anyURI .
#
# <Quick_Attack_IX.png> a xsd:anyURI .
#
# <Quiver_Dance_IX.png> a xsd:anyURI .
#
# <Rage_PE.png> a xsd:anyURI .
#
# <Rage_PE_2.png> a xsd:anyURI .
#
# <Rain_Dance_IX.png> a xsd:anyURI .
#
# <Rapid_Spin_IX.png> a xsd:anyURI .
#
# <Razor_Leaf_IX.png> a xsd:anyURI .
#
# <Razor_Leaf_IX_2.png> a xsd:anyURI .
#
# <Razor_Wind_PE.png> a xsd:anyURI .
#
# <Razor_Wind_PE_2.png> a xsd:anyURI .
#
# <Recover_IX.png> a xsd:anyURI .
#
# <Recycle_IX.png> a xsd:anyURI .
#
# <Reflect_IX.png> a xsd:anyURI .
#
# <Refresh_VII.png> a xsd:anyURI .
#
# <Rest_IX.png> a xsd:anyURI .
#
# <Return_VII.png> a xsd:anyURI .
#
# <Return_VII_2.png> a xsd:anyURI .
#
# <Revenge_VIII.png> a xsd:anyURI .
#
# <Revenge_VIII_2.png> a xsd:anyURI .
#
# <Reversal_IX.png> a xsd:anyURI .
#
# <Reversal_IX_2.png> a xsd:anyURI .
#
# <Roar_IX.png> a xsd:anyURI .
#
# <Rock_Blast_IX.png> a xsd:anyURI .
#
# <Rock_Blast_IX_2.png> a xsd:anyURI .
#
# <Rock_Climb_VIII.png> a xsd:anyURI .
#
# <Rock_Climb_VIII_2.png> a xsd:anyURI .
#
# <Rock_Slide_IX.png> a xsd:anyURI .
#
# <Rock_Smash_IX.png> a xsd:anyURI .
#
# <Rock_Smash_IX_2.png> a xsd:anyURI .
#
# <Rock_Throw_IX.png> a xsd:anyURI .
#
# <Rock_Tomb_IX.png> a xsd:anyURI .
#
# <Rock_Tomb_IX_2.png> a xsd:anyURI .
#
# <Role_Play_IX.png> a xsd:anyURI .
#
# <Role_Play_IX_2.png> a xsd:anyURI .
#
# <Rolling_Kick_PE.png> a xsd:anyURI .
#
# <Rollout_IX.png> a xsd:anyURI .
#
# <Roost_IX.png> a xsd:anyURI .
#
# <Sacred_Fire_IX.png> a xsd:anyURI .
#
# <Sacred_Fire_IX_2.png> a xsd:anyURI .
#
# <Safeguard_IX.png> a xsd:anyURI .
#
# <Sand_Attack_IX.png> a xsd:anyURI .
#
# <Sandstorm_IX.png> a xsd:anyURI .
#
# <Scald_IX.png> a xsd:anyURI .
#
# <Scary_Face_IX.png> a xsd:anyURI .
#
# <Scratch_IX.png> a xsd:anyURI .
#
# <Screech_IX.png> a xsd:anyURI .
#
# <Screech_IX_2.png> a xsd:anyURI .
#
# <Secret_Power_VII_building.png> a xsd:anyURI .
#
# <Secret_Power_VII_building_2.png> a xsd:anyURI .
#
# <Seed_Bomb_IX.png> a xsd:anyURI .
#
# <Seismic_Toss_IX.png> a xsd:anyURI .
#
# <Seismic_Toss_IX_2.png> a xsd:anyURI .
#
# <Self-Destruct_IX.png> a xsd:anyURI .
#
# <Self-Destruct_IX_2.png> a xsd:anyURI .
#
# <Shadow_Ball_IX.png> a xsd:anyURI .
#
# <Shadow_Ball_IX_2.png> a xsd:anyURI .
#
# <Shadow_Blast.png> a xsd:anyURI .
#
# <Shadow_Blast_2.png> a xsd:anyURI .
#
# <Shadow_Blitz.png> a xsd:anyURI .
#
# <Shadow_Blitz_2.png> a xsd:anyURI .
#
# <Shadow_Bolt.png> a xsd:anyURI .
#
# <Shadow_Bolt_2.png> a xsd:anyURI .
#
# <Shadow_Break.png> a xsd:anyURI .
#
# <Shadow_Break_2.png> a xsd:anyURI .
#
# <Shadow_Chill.png> a xsd:anyURI .
#
# <Shadow_Chill_2.png> a xsd:anyURI .
#
# <Shadow_Claw_IX.png> a xsd:anyURI .
#
# <Shadow_Down.png> a xsd:anyURI .
#
# <Shadow_Down_2.png> a xsd:anyURI .
#
# <Shadow_End.png> a xsd:anyURI .
#
# <Shadow_End_2.png> a xsd:anyURI .
#
# <Shadow_Fire.png> a xsd:anyURI .
#
# <Shadow_Fire_2.png> a xsd:anyURI .
#
# <Shadow_Force_IX.png> a xsd:anyURI .
#
# <Shadow_Force_IX_2.png> a xsd:anyURI .
#
# <Shadow_Half.png> a xsd:anyURI .
#
# <Shadow_Half_2.png> a xsd:anyURI .
#
# <Shadow_Hold.png> a xsd:anyURI .
#
# <Shadow_Hold_2.png> a xsd:anyURI .
#
# <Shadow_Mist.png> a xsd:anyURI .
#
# <Shadow_Mist_2.png> a xsd:anyURI .
#
# <Shadow_Panic.png> a xsd:anyURI .
#
# <Shadow_Panic_2.png> a xsd:anyURI .
#
# <Shadow_Punch_IX.png> a xsd:anyURI .
#
# <Shadow_Rave.png> a xsd:anyURI .
#
# <Shadow_Rave_2.png> a xsd:anyURI .
#
# <Shadow_Rush.png> a xsd:anyURI .
#
# <Shadow_Rush_2.png> a xsd:anyURI .
#
# <Shadow_Shed.png> a xsd:anyURI .
#
# <Shadow_Shed_2.png> a xsd:anyURI .
#
# <Shadow_Sky.png> a xsd:anyURI .
#
# <Shadow_Storm.png> a xsd:anyURI .
#
# <Shadow_Storm_2.png> a xsd:anyURI .
#
# <Shadow_Wave.png> a xsd:anyURI .
#
# <Shadow_Wave_2.png> a xsd:anyURI .
#
# <Sharpen_PE.png> a xsd:anyURI .
#
# <Sharpen_PE_2.png> a xsd:anyURI .
#
# <Shock_Wave_IX.png> a xsd:anyURI .
#
# <Shock_Wave_IX_2.png> a xsd:anyURI .
#
# <Signal_Beam_VII.png> a xsd:anyURI .
#
# <Signal_Beam_VII_2.png> a xsd:anyURI .
#
# <Silver_Wind_LA.png> a xsd:anyURI .
#
# <Sing_IX.png> a xsd:anyURI .
#
# <Sketch_IX.png> a xsd:anyURI .
#
# <Skill_Swap_IX.png> a xsd:anyURI .
#
# <Skill_Swap_IX_2.png> a xsd:anyURI .
#
# <Skull_Bash_VIII.png> a xsd:anyURI .
#
# <Skull_Bash_VIII_2.png> a xsd:anyURI .
#
# <Sky_Attack_IX.png> a xsd:anyURI .
#
# <Sky_Attack_IX_2.png> a xsd:anyURI .
#
# <Sky_Uppercut_VII.png> a xsd:anyURI .
#
# <Slack_Off_IX.png> a xsd:anyURI .
#
# <Slam_IX.png> a xsd:anyURI .
#
# <Slash_IX.png> a xsd:anyURI .
#
# <Sleep_Powder_IX.png> a xsd:anyURI .
#
# <Sleep_Talk_IX.png> a xsd:anyURI .
#
# <Sludge_Bomb_IX.png> a xsd:anyURI .
#
# <Sludge_Bomb_IX_2.png> a xsd:anyURI .
#
# <Sludge_IX.png> a xsd:anyURI .
#
# <Sludge_IX_2.png> a xsd:anyURI .
#
# <Smelling_Salts_VII.png> a xsd:anyURI .
#
# <Smog_IX.png> a xsd:anyURI .
#
# <Smokescreen_IX.png> a xsd:anyURI .
#
# <Snatch_VII.png> a xsd:anyURI .
#
# <Snore_IX.png> a xsd:anyURI .
#
# <Snore_IX_2.png> a xsd:anyURI .
#
# <Soft-Boiled_IX.png> a xsd:anyURI .
#
# <Solar_Beam_IX.png> a xsd:anyURI .
#
# <Solar_Beam_IX_2.png> a xsd:anyURI .
#
# <Sonic_Boom_PE.png> a xsd:anyURI .
#
# <Spark_IX.png> a xsd:anyURI .
#
# <Spark_IX_2.png> a xsd:anyURI .
#
# <Spider_Web_VII.png> a xsd:anyURI .
#
# <Spider_Web_VII_2.png> a xsd:anyURI .
#
# <Spike_Cannon_PE.png> a xsd:anyURI .
#
# <Spike_Cannon_PE_2.png> a xsd:anyURI .
#
# <Spikes_IX.png> a xsd:anyURI .
#
# <Spikes_IX_2.png> a xsd:anyURI .
#
# <Spit_Up_IX.png> a xsd:anyURI .
#
# <Spit_Up_IX_2.png> a xsd:anyURI .
#
# <Spite_IX.png> a xsd:anyURI .
#
# <Spite_IX_2.png> a xsd:anyURI .
#
# <Splash_IX.png> a xsd:anyURI .
#
# <Spore_IX.png> a xsd:anyURI .
#
# <Stealth_Rock_IX.png> a xsd:anyURI .
#
# <Stealth_Rock_IX_2.png> a xsd:anyURI .
#
# <Steamroller_VII.png> a xsd:anyURI .
#
# <Steamroller_VII_2.png> a xsd:anyURI .
#
# <Steel_Wing_IX.png> a xsd:anyURI .
#
# <Stockpile_IX.png> a xsd:anyURI .
#
# <Stockpile_IX_2.png> a xsd:anyURI .
#
# <Stomp_IX.png> a xsd:anyURI .
#
# <Stone_Edge_IX.png> a xsd:anyURI .
#
# <Strength_IX.png> a xsd:anyURI .
#
# <Strength_IX_2.png> a xsd:anyURI .
#
# <String_Shot_IX.png> a xsd:anyURI .
#
# <Struggle_IX.png> a xsd:anyURI .
#
# <Stun_Spore_IX.png> a xsd:anyURI .
#
# <Submission_VIII.png> a xsd:anyURI .
#
# <Substitute_IX.png!> a xsd:anyURI .
#
# <Sunny_Day_IX.png> a xsd:anyURI .
#
# <Super_Fang_IX.png> a xsd:anyURI .
#
# <Super_Fang_IX_2.png> a xsd:anyURI .
#
# <Superpower_IX.png> a xsd:anyURI .
#
# <Superpower_IX_2.png> a xsd:anyURI .
#
# <Supersonic_IX.png> a xsd:anyURI .
#
# <Supersonic_IX_2.png> a xsd:anyURI .
#
# <Surf_IX.png> a xsd:anyURI .
#
# <Surf_IX_2.png> a xsd:anyURI .
#
# <Swagger_IX.png> a xsd:anyURI .
#
# <Swallow_IX.png> a xsd:anyURI .
#
# <Swallow_IX_2.png> a xsd:anyURI .
#
# <Sweet_Kiss_IX.png> a xsd:anyURI .
#
# <Sweet_Scent_IX.png> a xsd:anyURI .
#
# <Swift_IX.png> a xsd:anyURI .
#
# <Swift_IX_2.png> a xsd:anyURI .
#
# <Swords_Dance_IX.png> a xsd:anyURI .
#
# <Swords_Dance_IX_2.png> a xsd:anyURI .
#
# <Synthesis_IX.png> a xsd:anyURI .
#
# <Synthesis_IX_2.png> a xsd:anyURI .
#
# <Tackle_IX.png> a xsd:anyURI .
#
# <Tail_Glow_IX.png> a xsd:anyURI .
#
# <Tail_Whip_IX.png> a xsd:anyURI .
#
# <Take_Down_IX.png> a xsd:anyURI .
#
# <Take_Down_IX_2.png> a xsd:anyURI .
#
# <Taunt_IX.png> a xsd:anyURI .
#
# <Taunt_IX_2.png> a xsd:anyURI .
#
# <Teeter_Dance_IX.png> a xsd:anyURI .
#
# <Teleport_IX.png> a xsd:anyURI .
#
# <Teleport_IX_2.png> a xsd:anyURI .
#
# <Thief_IX.png> a xsd:anyURI .
#
# <Thrash_IX.png> a xsd:anyURI .
#
# <Thunder_Fang_IX.png> a xsd:anyURI .
#
# <Thunder_IX.png> a xsd:anyURI .
#
# <Thunder_IX_2.png> a xsd:anyURI .
#
# <Thunder_Punch_IX.png> a xsd:anyURI .
#
# <Thunder_Shock_IX.png> a xsd:anyURI .
#
# <Thunder_Shock_IX_2.png> a xsd:anyURI .
#
# <Thunder_Wave_IX.png> a xsd:anyURI .
#
# <Thunder_Wave_IX_2.png> a xsd:anyURI .
#
# <Thunderbolt_IX.png> a xsd:anyURI .
#
# <Torment_IX.png> a xsd:anyURI .
#
# <Torment_IX_2.png> a xsd:anyURI .
#
# <Toxic_IX.png> a xsd:anyURI .
#
# <Toxic_IX_2.png> a xsd:anyURI .
#
# <Transform_IX.png> a xsd:anyURI .
#
# <Transform_IX_2.png> a xsd:anyURI .
#
# <Tri_Attack_IX.png> a xsd:anyURI .
#
# <Tri_Attack_IX_2.png> a xsd:anyURI .
#
# <Trick_IX.png> a xsd:anyURI .
#
# <Triple_Kick_IX.png> a xsd:anyURI .
#
# <Trump_Card_VII.png> a xsd:anyURI .
#
# <Twineedle_PE.png> a xsd:anyURI .
#
# <Twister_IX.png> a xsd:anyURI .
#
# <Twister_IX_2.png> a xsd:anyURI .
#
# <Uproar_IX.png> a xsd:anyURI .
#
# <Uproar_IX_2.png> a xsd:anyURI .
#
# <Vine_Whip_IX.png> a xsd:anyURI .
#
# <Vise_Grip_IX.png> a xsd:anyURI .
#
# <Vital_Throw_VIII.png> a xsd:anyURI .
#
# <Wake-Up_Slap_VII.png> a xsd:anyURI .
#
# <Wake-Up_Slap_VII_2.png> a xsd:anyURI .
#
# <Water_Gun_IX.png> a xsd:anyURI .
#
# <Water_Pulse_IX.png> a xsd:anyURI .
#
# <Water_Pulse_IX_2.png> a xsd:anyURI .
#
# <Water_Sport_VII.png> a xsd:anyURI .
#
# <Water_Spout_IX.png> a xsd:anyURI .
#
# <Water_Spout_IX_2.png> a xsd:anyURI .
#
# <Waterfall_IX.png> a xsd:anyURI .
#
# <Waterfall_IX_2.png> a xsd:anyURI .
#
# <Weather_Ball_IX.png> a xsd:anyURI .
#
# <Weather_Ball_IX_2.png> a xsd:anyURI .
#
# <Whirlpool_IX.png> a xsd:anyURI .
#
# <Whirlwind_IX.png> a xsd:anyURI .
#
# <Will-O-Wisp_IX.png> a xsd:anyURI .
#
# <Will-O-Wisp_IX_2.png> a xsd:anyURI .
#
# <Wing_Attack_IX.png> a xsd:anyURI .
#
# <Wish_IX.png> a xsd:anyURI .
#
# <Wish_IX_2.png> a xsd:anyURI .
#
# <Withdraw_IX.png> a xsd:anyURI .
#
# <Wrap_IX.png> a xsd:anyURI .
#
# <Wring_Out_VII.png> a xsd:anyURI .
#
# <X-Scissor_IX.png> a xsd:anyURI .
#
# <Yawn_IX.png> a xsd:anyURI .
#
# <Yawn_IX_2.png> a xsd:anyURI .
#
# <Zap_Cannon_IX.png> a xsd:anyURI .
#
# <Zap_Cannon_IX_2.png> a xsd:anyURI .
#
# <Zen_Headbutt_IX.png> a xsd:anyURI .
#
# <Zen_Headbutt_IX_2.png> a xsd:anyURI .
#
# <> a xsd:anyURI .
#
# <yes> a xsd:boolean .
#
# <no> a xsd:boolean .

# %%
with open('RessourcesList\location_list.txt', 'r') as file:
    location_list = [line.strip() for line in file]

print(location_list)
# Out:
# ['Tohjo Falls', 'Realgam Tower', 'Viridian Forest', 'Outskirt Stand', 'Petalburg Woods', 'The Under Subway', 'Relic Cave', 'Mt. Battle', 'Cipher Lab', 'One Island', 'Two Island', 'Three Island', 'Silph Co.', 'Five Island', 'Six Island', 'Devon Corporation', 'Bell Tower', 'Pewter Museum of Science', 'Celadon Department Store', 'Goldenrod Department Store', 'Seven Island', 'Mt. Moon', 'Rock Tunnel', 'PokÃ©mon Tower', 'Kanto Power Plant', 'PokÃ©mon Mansion (Kanto)', 'Victory Road (Kanto)', 'Sprout Tower', 'Cerulean Cave', 'Trainer Hill', 'Ilex Forest', 'TV Mauville', 'Faraway Island', 'Southern Island', 'Pattern Bush', 'Whirl Islands', 'Mt. Chimney', 'Meteor Falls', 'Altering Cave', 'Rusturf Tunnel', 'S.S. Tidal', 'Icefall Cave', 'Tanoby Key', 'Orre Colosseum', 'Deep Colosseum', 'Pyrite Colosseum', 'ONBS', 'Citadark Isle', 'Shoal Cave', 'Granite Cave', 'Scorched Slab', 'Seafloor Cavern', 'Sealed Chamber', 'Mt. Pyre', 'Sky Pillar', 'Island Cave', 'Desert Ruins', 'Ancient Tomb', 'Desert Underpass', 'Ruins of Alph', 'Slowpoke Well', 'Union Cave', 'Dark Cave', 'National Park', 'Mt. Mortar', "Kaminko's House", 'PokÃ©mon HQ Lab', 'Snagem Hideout', 'Phenac Stadium', 'Prestige Precept Center', 'Realgam Colosseum', 'Under Colosseum', 'Mirage Tower', 'Birth Island', 'Navel Rock', 'Seagallop', 'Seaside Cycling Road', 'Magnet Train', 'Lake of Rage', 'Celadon Game Corner', 'Mt. Ember', 'S.S. Anne', 'Relic Stone', 'Mauville Game Corner', 'Goldenrod Game Corner', 'Kanto Safari Zone', 'Sea Cottage', 'Miracle Cycle', 'PokÃ©mon League Reception Gate', 'Weather Institute', 'Goldenrod Radio Tower', 'Burned Tower', 'Terra Cave', 'Marine Cave', 'Tanoby Chambers', 'Lake Verity', 'Cipher Key Lair', 'Mirage Island (Generation III)', 'Flower Paradise', 'Hall of Origin', 'Pal Park', 'Underground', 'Spear Pillar', 'Lost Cave', 'Fiery Path', 'Turnback Cave', 'Stark Mountain', 'Olivine Lighthouse', 'Old Chateau', "PokÃ©mon Trainers' School", "Professor Oak's Laboratory", 'S.S. Aqua', 'Fullmoon Island', 'Kisara Plain', 'Lilycove Department Store', 'Mount Coronet', 'Berry Forest', "Dragon's Den", 'Underwater', 'Hoenn Safari Zone', 'Lake Valor', 'Lake Acuity', 'Fiore Temple', 'Jungle Relic', 'Rocket Warehouse', 'Team Aqua Hideout', 'Victory Road (Hoenn)', 'Dotted Hole', 'Victory Road (Sinnoh)', 'Trick House', 'Iron Island', 'Eterna Forest', 'Ice Path', "Rydel's Cycles", 'Pretty Petal flower shop', 'Snowpoint Temple', 'Great Marsh', 'Waterworks', 'Go-Rock Base', 'Goldenrod Tunnel', 'Solaceon Ruins', 'Celadon Condominiums', 'Oreburgh Mine', 'Valley Windworks', 'Floaroma Meadow', 'Fuego Ironworks', 'Wayward Cave', 'Lilycove Museum', 'Global Terminal', 'Moomoo Farm', 'Oceanic Museum', 'Hallowed Tower', 'Sendoff Spring', 'Ravaged Path', 'Veilstone Game Corner', 'Veilstone Department Store', "Trainers' School (Sinnoh)", 'Vista Lighthouse', 'Pick a Peck of Colors Flower Shop', 'Ribbon Syndicate', 'Maniac Tunnel', 'Trainer Tower', 'Battle Park (Sinnoh)', 'Hotel Grand Lake', 'Lost Tower', 'Trophy Garden', 'PokÃ©tch Company', 'Gateway Colosseum', 'Main Street Colosseum', 'Lagoon Colosseum', 'Waterfall Colosseum', 'Neon Colosseum', 'Crystal Colosseum', 'Jubilife TV', 'PokÃ©mon Mansion (Sinnoh)', 'Oreburgh Mining Museum', "Rad Rickshaw's Cycle Shop", 'Cinnabar Lab', 'Fighting Dojo', 'Artisan Cave', 'Team Rocket HQ', 'Courtyard Colosseum', 'Team Rocket Hideout', 'CafÃ© Cabin', 'Trainer House', 'PokÃ©mon Network Center', 'Magma Colosseum', 'Sunset Colosseum', 'Stargazer Colosseum', 'Sunny Park Colosseum', 'Mt. Moon Square', 'Eterna Condominiums', 'Altru Tower', 'Mossdeep Space Center', 'Capture Arena', 'Distortion World', 'PokÃ©mon Communication Center', 'Cove Lily Motel', 'Joyful Game Corner', 'Team Galactic Eterna Building', 'Almia Castle', 'Hippowdon Temple', 'Chroma Ruins', 'Volcano Cave', 'Oil Field Hideout', 'Sea of Wailord', 'Battleground', 'Rock Peak Ruins (Sinnoh)', 'Iceberg Ruins (Sinnoh)', 'Iron Ruins (Sinnoh)', 'Seven Stars Restaurant', 'Cargo Ship', 'Puel Sea', ' ...

# %%
LOCATION = Namespace("http://example.org/location/")
intial_location_graph = Graph()
final_location_graph = Graph()

for individual_location in location_list:
    try:
        # Step 1: Fetch the page text
        result1 = bulbabot.page_text(title=individual_location)
        
        # Step 2: Extract the infobox
        result2 = extract_location_infobox(result1)
        
        # Step 3: Parse the infobox
        result3 = parse_infobox(result2)
        
        # Step 4: Map the parsed infobox to RDF
        final_location_graph = map_infobox_to_rdf(LOCATION, intial_location_graph, property_mappings, result3)
        
        # Log or handle the final result (optional)
        print(f"Successfully processed {individual_location}")
    except Exception as e:
        # Handle any errors that occur in the pipeline
        print(f"Error processing {individual_location}: {e}")
# Out:
# Successfully processed Tohjo Falls
# Successfully processed Realgam Tower
# Successfully processed Viridian Forest
# Successfully processed Outskirt Stand
# Successfully processed Petalburg Woods
# Successfully processed The Under Subway
# Successfully processed Relic Cave
# Successfully processed Mt. Battle
# Successfully processed Cipher Lab
# Successfully processed One Island
# Successfully processed Two Island
# Successfully processed Three Island
# Successfully processed Silph Co.
# Successfully processed Five Island
# Successfully processed Six Island
# Successfully processed Devon Corporation
# Successfully processed Bell Tower
# Successfully processed Pewter Museum of Science
# Successfully processed Celadon Department Store
# Successfully processed Goldenrod Department Store
# Successfully processed Seven Island
# Successfully processed Mt. Moon
# Successfully processed Rock Tunnel
# Error processing PokÃ©mon Tower: 'NoneType' object has no attribute 'split'
# Successfully processed Kanto Power Plant
# Error processing PokÃ©mon Mansion (Kanto): 'NoneType' object has no attribute 'split'
# Successfully processed Victory Road (Kanto)
# Successfully processed Sprout Tower
# Successfully processed Cerulean Cave
# Successfully processed Trainer Hill
# Successfully processed Ilex Forest
# Successfully processed TV Mauville
# Successfully processed Faraway Island
# Successfully processed Southern Island
# Successfully processed Pattern Bush
# Successfully processed Whirl Islands
# Successfully processed Mt. Chimney
# Successfully processed Meteor Falls
# Successfully processed Altering Cave
# Successfully processed Rusturf Tunnel
# Successfully processed S.S. Tidal
# Successfully processed Icefall Cave
# Successfully processed Tanoby Key
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 8
#       5 for individual_location in location_list:
#       6     try:
#       7         # Step 1: Fetch the page text
# ----> 8         result1 = bulbabot.page_text(title=individual_location)
#      10         # Step 2: Extract the infobox
#      11         result2 = extract_location_infobox(result1)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pwiki\wiki.py:657, in Wiki.page_text(self, title)
#     648 """Queries the Wiki for the text of `title`.
#     649
#     650 Args:
#    (...)
#     654     str: The text of `title`.  `None` if `title` does not exist.
#     655 """
#     656 log.info("%s: fetching page text of '%s'", self, title)
# --> 657 return self._xq_simple(MQuery.page_text, title)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pwiki\wiki.py:396, in Wiki._xq_simple(self, func, title, *extra_args)
#     386 def _xq_simple(self, func: Callable[..., dict], title: str, *extra_args: Any) -> Any:
#     387     """Convienence method which makes it easy to execute `MQuery` or `MQuery`-like functions with a single title.  Shorthand for `func(self, [title]).get(title)`.
#     388
#     389     Args:
#    (...)
#     394         Any: The value obtained by performing a `.get(title)` call on the `dict` returned by `func`.
#     395     """
# --> 396     return func(self, [title], *extra_args).get(title)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pwiki\mquery.py:126, in MQuery.page_text(wiki, titles)
#     115 @staticmethod
#     116 def page_text(wiki: Wiki, titles: list[str]) -> dict:
#     117     """Queries the Wiki for the text of a title.
#     118
#     119     Args:
#    (...)
#     124         dict: A `dict` where each key is the title and each value is a `str` with the wikitext of the title.  If a title does not exist, the str will be replaced with `None`.
#     125     """
# --> 126     return MQuery._prop_no_cont(wiki, titles, PropNoCont.PAGE_TEXT)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pwiki\mquery.py:74, in MQuery._prop_no_cont(wiki, titles, template)
#      71 out = dict.fromkeys(titles)
#      73 for chunk in chunker(titles, wiki.prop_title_max):
# ---> 74     if response := query_and_validate(wiki, {**template.pl, "prop": template.name, "titles": "|".join(chunk)}, len(chunk) > PROP_TITLE_MAX, f"peform a prop_no_cont query with '{template.name}'"):
#      75         for p in mine_for(response, "query", "pages"):
#      76             try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py:135, in query_and_validate(wiki, pl, big_query, desc)
#     123 def query_and_validate(wiki: Wiki, pl: dict, big_query: bool = False, desc: str = "perform query") -> dict:
#     124     """Performs a `basic_query()` and checks the results for errors.  If there is an error, it will be logged accordingly.
#     125
#     126     Args:
#    (...)
#     133         dict: The response from the server.  `None` if something went wrong.
#     134     """
# --> 135     if not (response := basic_query(wiki, pl, big_query)):
#     136         log.error("%s: No response from server while trying to %s", wiki, desc)
#     137         log.debug("Sent parameters: %s", pl)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py:33, in basic_query(wiki, pl, big_query)
#      31 p = make_params("query", pl)
#      32 try:
# ---> 33     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#      34 except Exception:
#      35     log.error("%s: Could not reach server or read response while performing a (big_query: %s) query with params: %s", wiki, big_query, p, exc_info=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python311\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\Program Files\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Program Files\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Program Files\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Program Files\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Program Files\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Program Files\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Save or print the created graph
print(final_location_graph.serialize(format="turtle"))
# with open(os.path.join(graph_path,"location_graph.ttl"), "w", encoding="utf-8") as file:
#     file.write(final_location_graph.serialize(format="turtle"))
# Out:
# @prefix ns1: <http://example.org/location/> .
#
# ns1:Unknown a ns1:location ;
#     ns1:slogan "Full Selection of Pokémon Goods!" .

# %%
# def map_infobox_to_rdf(properties):
#     # Define RDF namespaces
#     POKEMON = Namespace("http://example.org/pokemon/")
#     RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

#     # Initialize RDF graph
#     g = Graph()

#     # Add Pokémon URI
#     pokemon_uri = URIRef(POKEMON[properties.get("name", "Unknown").replace(" ", "_")])
#     g.add((pokemon_uri, RDF.type, POKEMON.Pokémon))

#     # Map general properties
#     mappings = {
#         "name": POKEMON.name,
#         "jname": POKEMON.japaneseName,
#         "tmname": POKEMON.trademarkedJapaneseName,
#         "jtranslit": POKEMON.japaneseTransliteration,
#         "category": POKEMON.category,
#         "ndex": POKEMON.nationalDexNumber,
#         "forme": POKEMON.numberOfForms,
#         "type1": POKEMON.primaryType,
#         "type2": POKEMON.secondaryType,
#         "ability1": POKEMON.ability1,
#         "ability2": POKEMON.ability2,
#         "abilityd": POKEMON.hiddenAbility,
#         "height-m": POKEMON.heightInMeters,
#         "height-ftin": POKEMON.heightInFeetInches,
#         "weight-kg": POKEMON.weightInKilograms,
#         "weight-lbs": POKEMON.weightInPounds,
#         "catchrate": POKEMON.catchRate,
#         "gendercode": POKEMON.genderRatioCode,
#         "egggroup1": POKEMON.eggGroup1,
#         "egggroup2": POKEMON.eggGroup2,
#         "color": POKEMON.color,
#         "friendship": POKEMON.baseFriendship,
#         "generation": POKEMON.generationIntroduced,
#         "expyield": POKEMON.baseExperienceYield,
#         "evtotal": POKEMON.evTotal,
#         "evhp": POKEMON.evYieldHP,
#         "evat": POKEMON.evYieldAttack,
#         "evde": POKEMON.evYieldDefense,
#         "evsa": POKEMON.evYieldSpecialAttack,
#         "evsd": POKEMON.evYieldSpecialDefense,
#         "evsp": POKEMON.evYieldSpeed
#     }

#     # Map form-specific properties dynamically
#     for i in range(2, 7):  # Forms 2 through 6
#         form_suffix = f"form{i}"
#         mappings.update({
#             f"{form_suffix}": POKEMON[f"form{i}Name"],
#             f"{form_suffix}type1": POKEMON[f"form{i}PrimaryType"],
#             f"{form_suffix}type2": POKEMON[f"form{i}SecondaryType"],
#             f"height-m{i}": POKEMON[f"form{i}HeightInMeters"],
#             f"height-ftin{i}": POKEMON[f"form{i}HeightInFeetInches"],
#             f"weight-kg{i}": POKEMON[f"form{i}WeightInKilograms"],
#             f"weight-lbs{i}": POKEMON[f"form{i}WeightInPounds"],
#         })

#     # Generate RDF triples for properties that exist in the input
#     for key, predicate in mappings.items():
#         if key in properties and properties[key]:
#             g.add((pokemon_uri, predicate, Literal(properties[key])))

#     return g

# %%
# grap = map_infobox_to_rdf(properties)
# print(grap.serialize(format="turtle"))

# %%
# # FUNCTION DEFINITION : mapping of character infobox properties to existing graph
# def map_character_infobox_to_rdf(graph, property_mappings, properties):
#     CHARACTER = Namespace("http://example.org/character/")
#     RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

#     character_uri = URIRef(CHARACTER[properties.get("name", "Unknown").replace(" ", "_")])
#     graph.add((character_uri, RDF.type, CHARACTER.Character))

#     mappings = {
#         "color": CHARACTER.color,
#         "bordercolor": CHARACTER.borderColor,
#         "corecolor": CHARACTER.coreColor,
#         "name": CHARACTER.name,
#         "jname": CHARACTER.japaneseName,
#         "tmname": CHARACTER.romanizedJapaneseName,
#         "jtranslit": CHARACTER.japaneseTransliteration,
#         "text": CHARACTER.textColor,
#         "sloganline": CHARACTER.sloganLine,
#         "image": CHARACTER.image,
#         "size": CHARACTER.imageSize,
#         "caption": CHARACTER.imageCaption,
#         "age": CHARACTER.age,
#         "birthday": CHARACTER.birthday,
#         "gender": CHARACTER.gender,
#         "height": CHARACTER.height,
#         "eyes": CHARACTER.eyeColor,
#         "hair": CHARACTER.hairColor,
#         "hometown": CHARACTER.hometown,
#         "region": CHARACTER.region,
#         "relatives": CHARACTER.relatives,
#     }

#     for key, predicate in mappings.items():
#         if key in properties and properties[key]:
#             property_type = property_mappings.get(str(URIRef(CHARACTER + key)))
#             match property_type:
#                 case "Literal":
#                     graph.add((character_uri, predicate, Literal(properties[key])))
#                 case "Integer":
#                     if isinstance(int(properties[key]), int):
#                         graph.add((character_uri, predicate, Literal(int(properties[key]))))
#                 case _:
#                     print(property_type)
#                     uriString = properties[key].replace(" ","_")
#                     if not("<" in uriString) and not(">" in uriString):
#                         graph.add((character_uri, predicate, URIRef(CHARACTER + uriString)))

#     return graph

# %%
# # FUNCTION DEFINITION : mapping of region infobox properties to existing graph
# def map_region_infobox_to_rdf(graphModify, property_mappings, properties):

#     REGION = Namespace("http://example.org/region/")
#     RDF = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

#     region_uri = URIRef(REGION[properties.get("name", "Unknown").replace(" ", "_")])
#     graphModify.add((region_uri, RDF.type, REGION.Region))

#     mappings = {
#         "regioncolor": REGION.colorTemplate,
#         "name": REGION.name,
#         "jname": REGION.japaneseName,
#         "tmname": REGION.romanizedJapaneseName,
#         "region": REGION.isRegion,
#         "image": REGION.image,
#         "size": REGION.imageSize,
#         "caption": REGION.imageCaption,
#         "introduction": REGION.introductionMedia,
#         "professor": REGION.professor,
#         "firstpartner": REGION.firstPartnerPokemon,
#         "villain": REGION.villainousOrganization,
#         "league": REGION.league,
#         "location": REGION.leagueLocation,
#         "pokedext": REGION.pokedex,
#         "series": REGION.animationSeries,
#         "season": REGION.animationSeason,
#         "generation": REGION.generation,
#         "games": REGION.games,
#         "manga": REGION.mangaChapter,
#     }
    
#     for key, predicate in mappings.items():
#         if key in properties and properties[key]:
#             property_type = property_mappings.get(str(URIRef(REGION + key)))
#             match property_type:
#                 case "Literal":
#                     graphModify.add((region_uri, predicate, Literal(properties[key])))
#                 case "Integer":
#                     if isinstance(int(properties[key]), int):
#                         graphModify.add((region_uri, predicate, Literal(int(properties[key]))))
#                 case _:
#                     uriString = properties[key].replace(" ","_")
#                     graphModify.add((region_uri, predicate, URIRef(REGION + uriString)))

#     return graphModify
