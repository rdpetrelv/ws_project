# %%
# Import definitions
import pwiki
import pwiki.wiki
import mwparserfromhell
import re
import os
import urllib.parse
import rdflib
import time


from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS, XSD, OWL

# %%
#Name spaces definition
RESOURCE = Namespace("http://example.org/resource/")
BULBAPEDIA = Namespace("https://bulbapedia.bulbagarden.net/w/api.php")

# %%
# piwiki configuration
bulbabot = pwiki.wiki.Wiki(api_endpoint="https://bulbapedia.bulbagarden.net/w/api.php")
print(bulbabot.exists("Bulbasaur (Pokémon)"))
# Out:
# True

# %%
# General inforbox extraction based on the standar output of the bulbabot.page_text(title) function
# content = bulbabot.page_text(title)
# pattern = r"{{Pokémon Infobox.*?}}" for example

def extract_infobox(content, pattern):
    # pattern = pattern = r'{{' + re.escape(pattern) + r'\s*(?:[^{}]++|{{[^{}]++}})*}}'
    pattern = pattern = r'{{' + re.escape(pattern).replace(r'\ ', " ") + r'\s*(?:[^{}]++|{{[^{}]++}})*}}'
    # print(pattern)
    # pattern =  r'\{\{' + re.escape(pattern).replace(r'\ ', " ") + r'([^{]*(?:\{[^{]*\}[^{}]*)*)\}\}'
    # print(pattern)
    match = re.search(pattern, content, re.DOTALL)
    if match:
        return match.group(0)
    return None

def load_regex_patterns(file_path):
    regex_dict = {}
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                # Strip whitespace, skip empty lines or comments
                line = line.strip()
                if not line or line.startswith('#'):
                    continue
                
                # Split the line into key and regex pattern by '='
                key, pattern = line.split('=', 1)
                
                # Add to the dictionary
                regex_dict[key.strip()] = pattern.strip()
    except FileNotFoundError:
        print(f"Error: The file {file_path} was not found.")
    except Exception as e:
        print(f"Error: {e}")
    
    return regex_dict

# parsing of the infobox text 
def parse_infobox(infobox):
    properties = {}
    if infobox is None:
        return properties
    lines = infobox.split("\n")
    for line in lines:
        if line.startswith("|"):
            key_value = line[1:].split("=", 1)  # Remove leading `|` and split at `=`
            if len(key_value) == 2:
                key, value = key_value
                new_key = key.strip()
                new_value = value
                new_value = re.sub(r'<.*?>', '', new_value.replace("{{","_").replace("}}","_").replace("|","_").replace(" ", "_"))
                new_value = re.sub(r'<!--.*?-->', '', new_value, flags=re.DOTALL)
                new_value = new_value.strip().replace("[[","").replace("]]","").replace("{{","").replace("}}","").replace("?","").replace("\\", "").replace("\"", "").replace("'", "")
                if new_key == "size":
                    new_value = new_value.replace("px", "")
                if not("|" in new_value):
                    properties[new_key] = new_value
    return properties

def is_valid_xsd_date(date_string):
    # Regex pattern for the date format YYYY-MM-DD
    xsd_date_pattern = r"^\d{4}-\d{2}-\d{2}$"
    
    # Check if the date string matches the pattern
    if re.match(xsd_date_pattern, date_string):
        return True
    else:
        return False
    
def is_valid_uri(uri_string):
    # Simple regex for checking if the string is a valid URI format
    pattern = re.compile(r'^[a-zA-Z][a-zA-Z\d+\-.]*://(?:[^\s/?#]+(?:[^\s/?#]*[^\s/?#])?/?[^\s]*)?$')
    return bool(pattern.match(uri_string))

# %%
def read_vocabulary(initial_vocabulary_graph, vocabulary_path): 
    for file_name in os.listdir(vocabulary_path):
        if file_name.endswith('.ttl'):
            initial_vocabulary_graph.parse(os.path.join(vocabulary_path,file_name), format="ttl", encoding="utf-8" )
            print("Read: " + file_name)

    property_mappings = {}

    # Iterate over the graph to get class properties and their types
    for subject, predicate, obj in initial_vocabulary_graph:
        if predicate == RDF.type and obj == RDFS.Class:
            # Class found, check for properties of this class
            class_uri = subject
            for s, p, o in initial_vocabulary_graph.triples((None, RDFS.domain, class_uri)):
                if p == RDFS.domain and o == class_uri:
                    # Now we know this property is for our class
                    property_uri = s
                    # Check for range (type) of the property
                    range_type = None
                    values_list = []

                    for _, p, o in initial_vocabulary_graph.triples((property_uri, RDFS.range, None)):
                        range_type = o

                    values_list.append(range_type)
                    match range_type:
                        case XSD.string:
                            values_list.append('Literal')
                        case XSD.integer:
                            values_list.append('Integer')
                        case XSD.date:
                            values_list.append('Date')
                        case XSD.decimal:
                            values_list.append('Decimal')
                        case _:
                            values_list.append('URIRef')

                    property_mappings[str(property_uri)] = values_list
                        

    return initial_vocabulary_graph, property_mappings

# %%
# FUNCTION DEFINITION : mapping of pokemon infobox properties to existing graph
def map_infobox_to_rdf(name_space, graph, property_mappings, properties, bulbapedia_title, resource_category, images_list, internal_links, external_links):
    
    # POKEMON = Namespace("http://example.org/pokemon/")
    # name_space = RESOURCE = Namespace("http://example.org/resource/")
    nstype = str(resource_category.replace("Infobox", "").replace("infobox", "").replace(" ", ""))
    ns1 = URIRef(name_space +  nstype.lower())
    PROPERTY = Namespace("http://example.org/property/")
    BULBAPEDIA = Namespace("https://bulbapedia.bulbagarden.net/wiki/")
    DBPEDIA = Namespace("https://dbpedia.org/page/")

    graph.bind("property", PROPERTY)
    graph.bind("resource", name_space)
    graph.bind("BPD", BULBAPEDIA)
    graph.bind("BPD", DBPEDIA)




    # print(name_space)
    # print(nstype)
    # print(ns1)
    
    # resoucre_uri = URIRef(name_space+ nstype.lower() +"/" + properties.get("name", "Unknown").replace(" ", "_"))
    resoucre_uri = URIRef(name_space+ nstype.lower() +"/" + properties.get("name", "Unknown").replace(" ", "_"))

    resoucre_uri1 = URIRef(name_space+ properties.get("name", "Unknown").replace(" ", "_"))

    # Probably best to enhance URI management, must be revised and decided afterwards:
    # resoucre_uri = URIRef(name_space[properties.get("name", "Unknown").replace(" ", "_")])

    if properties.get("name", "Unknown").replace(" ", "_") == "Unknown":
        resoucre_uri = URIRef(name_space+ nstype.lower() +"/" +bulbapedia_title.replace(" ", "_"))
    #Declare resource is of class type
    graph.add((resoucre_uri, RDF.type, URIRef(name_space + nstype )))
    graph.add((resoucre_uri1, OWL.sameAs, resoucre_uri))
    graph.add((resoucre_uri, OWL.sameAs, URIRef(DBPEDIA +nstype)))

    #Declare class type is rsfs:Class
    graph.add((URIRef(name_space + nstype ), RDF.type, RDFS.Class))
    #declare resource has bulbapediapage
    graph.add((resoucre_uri, URIRef(PROPERTY + "bulbapediapage"), URIRef(BULBAPEDIA + bulbapedia_title.replace(" ", "_") )))

    #Include images 
    if images_list:
        for image in images_list:
            graph.add((resoucre_uri, URIRef(PROPERTY + "bulbapediaImage"), URIRef(BULBAPEDIA + image.replace(" ", "_"))))
            if image == images_list[0]:
                graph.add((resoucre_uri, URIRef(PROPERTY + "bulbapediaMainImage"), URIRef(BULBAPEDIA + image.replace(" ", "_"))))
    
    
    # include external links
    if external_links:
        for link in external_links:
            graph.add((resoucre_uri, URIRef(PROPERTY + "hasExternalLink"), URIRef(link)))

    # Include internal links
    if internal_links:
        for link in internal_links:
            link = link.replace(" ", "_")
            graph.add((resoucre_uri, URIRef(PROPERTY + "hasBulbapediaLink"), URIRef(BULBAPEDIA +link.replace(" ", "_") )))
            graph.add((resoucre_uri, URIRef(PROPERTY + "hasBulbapediaLinkedResoruce"), URIRef(name_space +link.replace(" ", "_") )))





    # print(graph.serialize(format="turtle"))

    # for propertyUri, propertyRestriction in property_mappings.items():
    #     if name_space in propertyUri:
    #         property_name = propertyUri[propertyUri.rfind('/') + 1:]
    #         print(property_name)
    #         print(propertyUri)
    #         print("----------------------------------------------------------------")

    #         if property_name in properties:
    #             match propertyRestriction[1]:
    #                 case "Literal":
    #                     # print("here1")
    #                     graph.add((resoucre_uri, URIRef(propertyUri), Literal(properties[property_name])))
    #                 case "Integer":
    #                     # print("here2")
    #                     if isinstance(int(properties[property_name]), int):
    #                         graph.add((resoucre_uri, URIRef(propertyUri), Literal(int(properties[property_name]))))
    #                 case "Date": 
    #                     # print("here3")
    #                     graph.add((resoucre_uri, URIRef(propertyUri), Literal(properties[property_name], datatype=XSD.date)))
    #                 case "Decimal": 
    #                     # print("here4")
    #                     graph.add((resoucre_uri, URIRef(propertyUri), Literal(properties[property_name], datatype=XSD.decimal)))
    #                 case _:
    #                     uriString = re.sub(r"<[^>]*>", "", re.sub(r'<.*?>', '', properties[property_name].replace(" ","_").replace(";", "_")))
    #                     if str(name_space) in str(propertyRestriction[0]):
    #                         # print("here5")
    #                         graph.add((resoucre_uri, URIRef(propertyUri), URIRef(propertyRestriction[0] +"/" +uriString)))
    #                     else:
    #                         graph.add((resoucre_uri, URIRef(propertyUri), URIRef(uriString)))
    #                         graph.add((URIRef(uriString), RDF.type ,propertyRestriction[0]))
    #             mapped_properties.append(property_name)

    for propertyToBeIncluded, propertyValue in properties.items():
        #Test if it exist in the property mappings directory 
        testing_property = PROPERTY + propertyToBeIncluded
        if testing_property in property_mappings :      
            propertyRestriction = property_mappings[str(testing_property)]
            propertyValue = re.sub(r'<.*?>', '', propertyValue.replace("{{","_").replace("}}","_").replace("|","_"))
            match propertyRestriction[1]:
                case "Literal":
                    # print("here1")
                    graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyValue)))
                case "Integer":
                    # print("here2")
                    # if isinstance(int(propertyValue), int):
                    try:
                        graph.add((resoucre_uri, URIRef(testing_property), Literal(int(propertyValue))))
                    except :
                        graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyValue)))
                case "Date": 
                    # print("here3")
                    try:
                        if is_valid_xsd_date(propertyValue):
                            graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyValue, datatype=XSD.date)))
                        else: 
                            graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyValue)))
                    except :
                        graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyValue)))
                case "Decimal": 
                    # print("here4")
                    try:
                        graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyValue, datatype=XSD.decimal)))
                    except:
                        graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyValue)))
                case _:
                    uriString = re.sub(r"<[^>]*>", "", re.sub(r'<.*?>', '', propertyValue.replace(" ","_").replace(";", "_")))
                    if (str(name_space) in str(propertyRestriction[0])) and (is_valid_uri(propertyRestriction[0] +"/" +uriString)) :
                        try:
                            graph.add((resoucre_uri, URIRef(testing_property), URIRef(re.sub(r'/[^/]+$', '', propertyRestriction[0]) +"/" +uriString)))
                            graph.add((URIRef(name_space + uriString), RDF.type , propertyRestriction[0]))
                        except:
                            graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyRestriction[0]) +"/" +uriString))
                            graph.add((URIRef(name_space +uriString), RDF.type , propertyRestriction[0]))
                    else:
                        graph.add((resoucre_uri, URIRef(testing_property), URIRef(uriString)))
                        graph.add((URIRef(name_space + uriString), RDF.type , propertyRestriction[0]))


        #If not exist in mappings directorym then adds it as a generic property and a its valua as a literal string
        # algo declare it as a generic property
        else:
    #         print("not")
            propertyToBeIncluded = re.sub(r'<.*?>', '', propertyToBeIncluded.replace("{{","_").replace("}}","_").replace("- ", "").replace("|","_").replace(" ", "_") )
            propertyValue = re.sub(r'<.*?>', '', propertyValue.replace("{{","_").replace("}}","_").replace("|","_").replace(" ", "_"))
            # propertyToBeIncluded = urllib.parse.quote(propertyToBeIncluded)
            # propertyValue = urllib.parse.quote(propertyValue)
            try: 
                graph.add((resoucre_uri, URIRef(testing_property), Literal(propertyValue)))
                graph.add((URIRef(testing_property), RDF.type, RDF.Property))
            # graph.add((URIRef(name_space+ nstype.lower() +propertyToBeIncluded), RDF.type, URIRef(name_space+ nstype.lower() +"/genericproperty")))
            except:
                print("Imposible to add property key " + propertyToBeIncluded)
                print("property value:" +propertyValue)
    # print(graph.serialize(format="turtle"))
    # print("----------------------------------------------------------------")

    return graph

# %%
def final_function(resources_list, infoboxes_patterns, vocabulary_property_mappings, resource_namespace ):
    for resource in resources_list:
        start = time.time()
        if resource.endswith('.txt'):
            with open(resource, 'r', encoding='utf-8') as file:
                bulbapedia_titles = [line.strip() for line in file]

            resource_category = resource.split('/')[1].split('_')[0].replace("&", "/")

    
            graph_path = "GeneratedGraphs/"
            if os.path.exists(os.path.join(graph_path, resource_category + "_graph.ttl")):
                continue
            initial_graph = Graph()
            final_graph = Graph()
            for bulbapedia_title in bulbapedia_titles:
                try:
                    # Step 1: Fetch the page text
                    result1 = bulbabot.page_text(title=bulbapedia_title)
                    
                    # # Step 2: Extract the infobox                    
                    result2 = extract_infobox(result1, infoboxes_patterns[resource_category])
                    
                    # # Step 3: Parse the infobox
                    result3 = parse_infobox(result2)
                    result4 = bulbabot.images_on_page(title=bulbapedia_title)
                    result5 = bulbabot.links_on_page(title=bulbapedia_title)
                    result6 = bulbabot.external_links(title=bulbapedia_title)
                    
                    # Step 4: Map the parsed infobox to RDF
                    final_graph = map_infobox_to_rdf(resource_namespace, initial_graph, vocabulary_property_mappings, result3, bulbapedia_title, resource_category, result4, result5, result6)
                    # Log or handle the final result (optional)
                    with open(os.path.join(graph_path, resource_category + "_graph.ttl"), "w", encoding="utf-8") as file:
                        file.write(final_graph.serialize(format="turtle"))
                    # print(final_graph.serialize(format="turtle"))
                    # print(f"Successfully processed {bulbapedia_title}")


                except Exception as e:
                    # Handle any errors that occur in the pipeline
                    print(f"Error processing {resource}  / {bulbapedia_title}: {e}")
                    break
        print(f"Successfully processed {resource} in  {time.time() - start}")

# %%
regex_infoboxes_path = "Infoboxes\infoboxes.txt"
regex_infoboxes = load_regex_patterns(regex_infoboxes_path)
regex_infoboxes
# Out:
# {'AbilityInfobox': 'AbilityInfobox',
#  'AbilityInfoboxNoncat': 'AbilityInfoboxNoncat',
#  'AdvArcInfobox': 'AdvArcInfobox',
#  'AnimeLocationInfobox': 'AnimeLocationInfobox',
#  'AnimePokémonInfobox': 'AnimePokémonInfobox',
#  'ArchetypeInfobox': 'ArchetypeInfobox',
#  'BadgeInfobox': 'BadgeInfobox',
#  'BattleEInfobox': 'BattleEInfobox',
#  'BattrioExpansionInfobox': 'BattrioExpansionInfobox',
#  'BattrioPuckInfobox': 'BattrioPuckInfobox',
#  'BerryInfobox': 'BerryInfobox',
#  'Blueinfobox': 'Blueinfobox',
#  'Boardgame Infobox': 'Boardgame Infobox',
#  'BookInfobox': 'BookInfobox',
#  'CDInfobox': 'CDInfobox',
#  'ChapInfobox': 'ChapInfobox',
#  'Chapterinfobox': 'Chapterinfobox',
#  'Character Infobox': 'Character Infobox',
#  'CharInfobox': 'CharInfobox',
#  'CharInfoboxUser': 'CharInfoboxUser',
#  'Company Infobox': 'Company Infobox',
#  'Console infobox': 'Console infobox',
#  'CountryInfobox': 'CountryInfobox',
#  'DeckInfobox': 'DeckInfobox',
#  'DuelInfobox': 'DuelInfobox',
#  'Dungeon infobox': 'Dungeon infobox',
#  'DWGame': 'DWGame',
#  'DWInfobox': 'DWInfobox',
#  'Pokémon Infobox': 'Pokémon Infobox',
#  'EnergyCardInfobox': 'EnergyCardInfobox',
#  'EpisodeInfobox': 'EpisodeInfobox',
#  'EpisodeInfobox2': 'EpisodeInfobox2',
#  'EpisodeInfoboxShort': 'EpisodeInfoboxShort',
#  'EpisodeInfoboxSpecial': 'EpisodeInfoboxSpecial',
#  'FA Infobox': 'FA Infobox',
#  'Facility infobox': 'Facility infobox',
#  'Fan site': 'Fan site',
#  'Ga-OleInfobox': 'Ga-OleInfobox',
#  'GenInfo': 'GenInfo',
#  'GlitchMoveInfobox': 'GlitchMoveInfobox',
#  'GlitchPkmnInfobox': 'GlitchPkmnInfobox',
#  'GlitchPkmnInfoboxNocat': 'GlitchPkmnInfoboxNocat',
#  'GlitchSpriteBox': 'GlitchSpriteBox',
#  'GymInfobox': 'GymInfobox',
#  'IllustStoryInfobox': 'IllustStoryInfobox',
#  'Infobox game': 'Infobox game',
#  'Infobox island': 'Infobox island',
#  'Infobox location': 'Infobox location',
#  'Infobox walkthrough': 'Infobox walkthrough',
#  'Infobox zone': 'Infobox zone',
#  'InfoboxBlock': 'InfoboxBlock',
#  'InfoboxTV': 'InfoboxTV',
#  'Item': 'Item',
#  'ItemInfobox': 'ItemInfobox',
#  'KingdomInfobox': 'KingdomInfobox',
#  'MagazineInfobox': 'MagazineInfobox',
#  'MastersChapInfobox': 'MastersChapInfobox',
#  'MastersEventInfobox': 'MastersEventInfobox',
#  'MastersInfobox': 'MastersInfobox',
#  'MastersSkillInfobox': 'MastersSkillInfobox',
#  'MDMoveInfobox': 'MDMoveInfobox',
#  'Merchandise Infobox': 'Merchandise Infobox',
#  'MerchCollectionInfobox': 'MerchCollectionInfobox',
#  'MezastarInfobox': 'MezastarInfobox',
#  'MoveInfobox': 'MoveInfobox',
#  'MoveInfoboxNoncat': 'MoveInfoboxNoncat',
#  'MovieInfobox': 'MovieInfobox',
#  'Mystery Dungeon location': 'Mystery Dungeon location',
#  'NintendoService': 'NintendoService',
#  'Podcast': 'Podcast',
#  'PokkénInfobox': 'PokkénInfobox',
#  'Pokémon Center Infobox': 'Pokémon Center Infobox',
#  'PokémoncardInfobox': 'PokémoncardInfobox',
#  'PokémonInfobox': 'PokémonInfobox',
#  'PokémonInfoboxNoncat': 'PokémonInfoboxNoncat',
#  'PokéstarMovie': 'PokéstarMovie',
#  'PokéWalkerInfobox': 'PokéWalkerInfobox',
#  'RangerLocationInfobox': 'RangerLocationInfobox',
#  'RegionInfobox': 'RegionInfobox',
#  'Ribbon': 'Ribbon',
#  'Route infobox': 'Route infobox',
#  'Season Infobox': 'Season Infobox',
#  'SeasonInfobox': 'SeasonInfobox',
#  'SkyEpInfobox': 'SkyEpInfobox',
#  'SleepIsland': 'SleepIsland',
#  'Song': 'Song',
#  'TCGEnergyCardInfobox': 'TCGEnergyCardInfobox',
#  'TCGExpansionInfobox': 'TCGExpansionInfobox',
#  'TCGGBInfobox': 'TCGGBInfobox',
#  'TCGPocketDeckInfobox': 'TCGPocketDeckInfobox',
#  'TCGPocketEventInfobox': 'TCGPocketEventInfobox',
#  'TCGPocketExpansionInfobox': 'TCGPocketExpansionInfobox',
#  'TCGPromoInfobox': 'TCGPromoInfobox',
#  'TCGTrainerCardInfobox': 'TCGTrainerCardInfobox',
#  'Team Infobox': 'Team Infobox',
#  'TehPerson': 'TehPerson',
#  'TFGCardInfobox': 'TFGCardInfobox',
#  'TFGCrystalInfobox': 'TFGCrystalInfobox',
#  'TFGInfobox': 'TFGInfobox',
#  'TFGPearlInfobox': 'TFGPearlInfobox',
#  'Theme Park Infobox': 'Theme Park Infobox',
#  'Tiddlywinks': 'Tiddlywinks',
#  'TournamentInfobox': 'TournamentInfobox',
#  'Town infobox': 'Town infobox',
#  'TrainercardInfobox': 'TrainercardInfobox',
#  'TrainerClassInfobox': 'TrainerClassInfobox',
#  'TrettaInfobox': 'TrettaInfobox',
#  'TrettaSetInfobox': 'TrettaSetInfobox',
#  'Trozei location infobox': 'Trozei location infobox',
#  'UniteInfobox': 'UniteInfobox',
#  'UserPokémonInfobox': 'UserPokémonInfobox',
#  'VolumeInfobox': 'VolumeInfobox',
#  'WarlordInfobox': 'WarlordInfobox',
#  'WarriorInfobox': 'WarriorInfobox',
#  'WeatherInfobox': 'WeatherInfobox'}

# %%
vocabulary_path = f'C:/Users/HP/Documents/07. EMSE/Master DSC/WS/Project-BulbapediaKG/BulbapediaKG1/Vocabulary/'
vocabulary_graph = Graph()

vocabulary = read_vocabulary(vocabulary_graph, vocabulary_path)
vocabulary[1]
# Out:
# Read: infoboxCharacter.ttl
# Read: infoboxLocation.ttl
# Read: infoboxMove.ttl
# Read: infoboxPokemon.ttl
# Read: infoboxRegion.ttl
# {'http://example.org/property/slogan': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/imageSize': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/mapDescription': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/Region': [rdflib.term.URIRef('http://example.org/resource/Region'),
#   'URIRef'],
#  'http://example.org/property/appearsInGeneration': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/locationType': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/mapFile': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://schema.org/name': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://schema.org/image': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://example.org/property/n': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/jname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/jtrans': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/jtranslit': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/gameimage': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://example.org/property/gameimage2': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://example.org/property/gameimagewidth': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/type': [rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#   'URIRef'],
#  'http://example.org/property/damagecategory': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/basepp': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/maxpp': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/power': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/accuracy': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/priority': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/touches': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/property/protect': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/property/magiccoat': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/property/snatch': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/property/mirrormove': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/property/kingsrock': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/property/sound': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/property/field': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'),
#   'URIRef'],
#  'http://example.org/property/target': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/gen': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/category': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/appeal': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/jam': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/cdesc': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/appealsc': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/scdesc': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/category6': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/appeal6': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/jam6': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/cdesc6': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/footnotes': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/spm': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/name': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/tmname': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/ndex': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/type1': [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#type'),
#   'URIRef'],
#  'http://example.org/property/type2': [rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#type'),
#   'URIRef'],
#  'http://example.org/property/ability1': [rdflib.term.URIRef('http://example.org/resource/Ability'),
#   'URIRef'],
#  'http://example.org/property/ability2': [rdflib.term.URIRef('http://example.org/resource/Ability'),
#   'URIRef'],
#  'http://example.org/property/abilityd': [rdflib.term.URIRef('http://example.org/resource/Ability'),
#   'URIRef'],
#  'http://example.org/property/height-m': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal'),
#   'Decimal'],
#  'http://example.org/property/weight-kg': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#decimal'),
#   'Decimal'],
#  'http://example.org/property/color': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/property/friendship': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/regioncolor': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/property/image': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#anyURI'),
#   'URIRef'],
#  'http://example.org/property/size': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/caption': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/introduction': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/professor': [rdflib.term.URIRef('http://example.org/resource/Character'),
#   'URIRef'],
#  'http://example.org/property/firstpartner': [rdflib.term.URIRef('http://example.org/resource/Pokémon'),
#   'URIRef'],
#  'http://example.org/property/villain': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/league': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/location': [rdflib.term.URIRef('http://example.org/resource/Location'),
#   'URIRef'],
#  'http://example.org/property/pokelist': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/series': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/season': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/generation': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/games': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/manga': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/bordercolor': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/property/corecolor': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/property/textcolor': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/property/age': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'),
#   'Integer'],
#  'http://example.org/property/birthday': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#date'),
#   'Date'],
#  'http://example.org/property/gender': [rdflib.term.URIRef('http://schema.org/gender'),
#   'URIRef'],
#  'http://example.org/property/height': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal'],
#  'http://example.org/property/eyes': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/property/hair': [rdflib.term.URIRef('http://schema.org/color'),
#   'URIRef'],
#  'http://example.org/property/hometown': [rdflib.term.URIRef('http://example.org/resource/Location'),
#   'URIRef'],
#  'http://example.org/property/region': [rdflib.term.URIRef('http://example.org/resource/Region'),
#   'URIRef'],
#  'http://example.org/property/relatives': [rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'),
#   'Literal']}

# %%
# Get the ressources path, this must be the folder with all the txt files representing the title pages in bulbapedia 
# that uses an specific infobox template, ie the ressource, namin convention for those files is:
# 1. Get the bulbapedia infobox name, ex MovieInfobox.
# 2. keep only the part before Infobox and add _list.txt

resources_path = 'RessourcesList1' 
all_files_and_dirs = os.listdir(resources_path)
resource_list = [("RessourcesList1/"+f) for f in all_files_and_dirs if os.path.isfile(os.path.join(resources_path, f))]

test = final_function(resource_list, regex_infoboxes,vocabulary[1], RESOURCE)
# Out:
# Successfully processed RessourcesList1/AnimeLocationInfobox_list.txt in  1095.9352571964264
# http://example.org/resource/Location/(by_Paul)-->Hearthome_City_(by__Ash_) does not look like a valid URI, trying to serialize this will break.
# http://example.org/resource/(by_Paul)-->Hearthome_City_(by__Ash_) does not look like a valid URI, trying to serialize this will break.
# http://example.org/resource/(by_Paul)-->Hearthome_City_(by__Ash_) does not look like a valid URI, trying to serialize this will break.
# Error processing RessourcesList1/AnimePokémonInfobox_list.txt  / Ash's Infernape: "http://example.org/resource/(by_Paul)-->Hearthome_City_(by__Ash_)" does not look like a valid URI, I cannot serialize this as N3/Turtle. Perhaps you wanted to urlencode it?
# Successfully processed RessourcesList1/AnimePokémonInfobox_list.txt in  319.4847209453583
# http://example.org/property/|cards does not look like a valid URI, trying to serialize this will break.
# http://example.org/property/|cards does not look like a valid URI, trying to serialize this will break.
# Error processing RessourcesList1/ArchetypeInfobox_list.txt  / MagneRock (TCG): "http://example.org/property/|cards" does not look like a valid URI, I cannot serialize this as N3/Turtle. Perhaps you wanted to urlencode it?
# Successfully processed RessourcesList1/ArchetypeInfobox_list.txt in  30.926008701324463
# Successfully processed RessourcesList1/BadgeInfobox_list.txt in  5.7541184425354
# Successfully processed RessourcesList1/BattleEInfobox_list.txt in  165.7728488445282
# Successfully processed RessourcesList1/BattrioPuckInfobox_list.txt in  3505.628735780716
# Successfully processed RessourcesList1/Boardgame Infobox_list.txt in  5.065236806869507
# Successfully processed RessourcesList1/BookInfobox_list.txt in  2049.564234018326
# Successfully processed RessourcesList1/CDInfobox_list.txt in  694.9029881954193
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'pllimit': 'max', 'prop': 'links', 'titles': 'PS276', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'links'
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'imlimit': 'max', 'prop': 'images', 'titles': 'PS152', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'images'
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'elexpandurl': 1, 'ellimit': 'max', 'prop': 'extlinks', 'titles': 'PS152', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'extlinks'
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'elexpandurl': 1, 'ellimit': 'max', 'prop': 'extlinks', 'titles': 'PS281', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'extlinks'
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'elexpandurl': 1, 'ellimit': 'max', 'prop': 'extlinks', 'titles': 'PS156', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'extlinks'
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'rvprop': 'content', 'rvslots': 'main', 'prop': 'revisions', 'titles': 'PS157', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_no_cont query with 'revisions'
# Error processing RessourcesList1/ChapInfobox_list.txt  / PS157: expected string or bytes-like object, got 'NoneType'
# Successfully processed RessourcesList1/ChapInfobox_list.txt in  792.8663539886475
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'pllimit': 'max', 'prop': 'links', 'titles': 'ET01', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'links'
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'rvprop': 'content', 'rvslots': 'main', 'prop': 'revisions', 'titles': 'PPPB10', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_no_cont query with 'revisions'
# Error processing RessourcesList1/Chapterinfobox_list.txt  / PPPB10: expected string or bytes-like object, got 'NoneType'
# Successfully processed RessourcesList1/Chapterinfobox_list.txt in  8.956715106964111
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'pllimit': 'max', 'prop': 'links', 'titles': 'Norman', 'plcontinue': '877|0|Pokémon_Trainer', 'continue': '||', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'links'
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'elexpandurl': 1, 'ellimit': 'max', 'prop': 'extlinks', 'titles': 'Norman', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'extlinks'
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'rvprop': 'content', 'rvslots': 'main', 'prop': 'revisions', 'titles': 'Erika', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_no_cont query with 'revisions'
# Error processing RessourcesList1/Character Infobox_Anime_list.txt  / Erika: expected string or bytes-like object, got 'NoneType'
# Successfully processed RessourcesList1/Character Infobox_Anime_list.txt in  17.45201873779297
# [<Anonymous> @ bulbapedia.bulbagarden.net]: Could not reach server or read response while performing a (big_query: False) query with params: {'format': 'json', 'formatversion': '2', 'pllimit': 'max', 'prop': 'links', 'titles': 'Professor Oak', 'action': 'query'}
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 971, in json
#     return complexjson.loads(self.text, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Program Files\Python311\Lib\json\decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\pwiki\query_utils.py", line 33, in basic_query
#     return (wiki.client.post(wiki.endpoint, data=p) if big_query else wiki.client.get(wiki.endpoint, params=p)).json()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\requests\models.py", line 975, in json
#     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
# requests.exceptions.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# [<Anonymous> @ bulbapedia.bulbagarden.net]: No response from server while trying to peform a prop_cont query with 'links'
# http://example.org/property/|trainer does not look like a valid URI, trying to serialize this will break.
# http://example.org/property/|trainer does not look like a valid URI, trying to serialize this will break.
# Error processing RessourcesList1/CharInfobox_list.txt  / Charon: "http://example.org/property/|trainer" does not look like a valid URI, I cannot serialize this as N3/Turtle. Perhaps you wanted to urlencode it?
# Successfully processed RessourcesList1/CharInfobox_list.txt in  4196.999352455139
# Successfully processed RessourcesList1/Company Infobox_list.txt in  72.66980814933777
# Successfully processed RessourcesList1/Console infobox_list.txt in  39.78700542449951
# Successfully processed RessourcesList1/CountryInfobox_list.txt in  91.08505415916443
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       7 all_files_and_dirs = os.listdir(resources_path)
#       8 resource_list = [("RessourcesList1/"+f) for f in all_files_and_dirs if os.path.isfile(os.path.join(resources_path, f))]
# ---> 10 test = final_function(resource_list, regex_infoboxes,vocabulary[1], RESOURCE)
#
# Cell In[7], line 34, in final_function(resources_list, infoboxes_patterns, vocabulary_property_mappings, resource_namespace)
#      32     # Log or handle the final result (optional)
#      33     with open(os.path.join(graph_path, resource_category + "_graph.ttl"), "w", encoding="utf-8") as file:
# ---> 34         file.write(final_graph.serialize(format="turtle"))
#      35     # print(final_graph.serialize(format="turtle"))
#      36     # print(f"Successfully processed {bulbapedia_title}")
#      39 except Exception as e:
#      40     # Handle any errors that occur in the pipeline
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\graph.py:1334, in Graph.serialize(self, destination, format, base, encoding, **args)
#    1332 stream = BytesIO()
#    1333 if encoding is None:
# -> 1334     serializer.serialize(stream, base=base, encoding="utf-8", **args)
#    1335     return stream.getvalue().decode("utf-8")
#    1336 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\plugins\serializers\turtle.py:244, in TurtleSerializer.serialize(self, stream, base, encoding, spacious, **args)
#     241 if spacious is not None:
#     242     self._spacious = spacious
# --> 244 self.preprocess()
#     245 subjects_list = self.orderSubjects()
#     247 self.startDocument()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\plugins\serializers\turtle.py:95, in RecursiveSerializer.preprocess(self)
#      93 def preprocess(self) -> None:
#      94     for triple in self.store.triples((None, None, None)):
# ---> 95         self.preprocessTriple(triple)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\plugins\serializers\turtle.py:270, in TurtleSerializer.preprocessTriple(self, triple)
#     268     continue
#     269 # Don't use generated prefixes for subjects and objects
# --> 270 self.getQName(node, gen_prefix=(i == VERB))
#     271 if isinstance(node, Literal) and node.datatype:
#     272     self.getQName(node.datatype, gen_prefix=_GEN_QNAME_FOR_DT)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\plugins\serializers\turtle.py:285, in TurtleSerializer.getQName(self, uri, gen_prefix)
#     282 parts = None
#     284 try:
# --> 285     parts = self.store.compute_qname(uri, generate=gen_prefix)
#     286 except Exception:
#     287     # is the uri a namespace in itself?
#     288     pfx = self.store.store.prefix(uri)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\graph.py:1190, in Graph.compute_qname(self, uri, generate)
#    1189 def compute_qname(self, uri: str, generate: bool = True) -> Tuple[str, URIRef, str]:
# -> 1190     return self.namespace_manager.compute_qname(uri, generate)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\namespace\__init__.py:589, in NamespaceManager.compute_qname(self, uri, generate)
#     586     insert_strie(self.__strie, self.__trie, namespace)
#     588 if self.__strie[namespace]:
# --> 589     pl_namespace = get_longest_namespace(self.__strie[namespace], uri)
#     590     if pl_namespace is not None:
#     591         namespace = pl_namespace
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\namespace\__init__.py:920, in get_longest_namespace(trie, value)
#     918 def get_longest_namespace(trie: Dict[str, Any], value: str) -> Optional[str]:
#     919     for key in trie:
# --> 920         if value.startswith(key):
#     921             out = get_longest_namespace(trie[key], value)
#     922             if out is None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\rdflib\term.py:245, in Identifier.startswith(self, prefix, start, end)
#     244 def startswith(self, prefix: str, start=..., end=...) -> bool:  # type: ignore[override] # FIXME
# --> 245     return str(self).startswith(str(prefix))
#
# KeyboardInterrupt:

# %%
# Include Links 
# Bulbapedia

# Include names and descriptions in multiple lenguages

# %%
bulbasaur_test = bulbabot.page_text(title="Bulbasaur (Pokémon)")
bulbasaur_infoboxtest = extract_infobox(bulbasaur_test, regex_infoboxes["Pokémon Infobox"])
bulbasaur_infoboxparsed = parse_infobox(bulbasaur_infoboxtest)

# %%
bulbasaur_test = bulbabot.page_text(title="Cynthia")
# print(bulbasaur_test)
# print("-----------------------")
# print(regex_infoboxes["Character Infobox"])
bulbasaur_infoboxtest = extract_infobox(bulbasaur_test, regex_infoboxes["Character Infobox"])
bulbasaur_infoboxtest
bulbasaur_infoboxparsed = parse_infobox(bulbasaur_infoboxtest)
bulbasaur_infoboxparsed

# %%
vocabulary[1]
